# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import datetime
import cv2
from keras import backend as K
from keras.layers import Layer,InputSpec
from keras import layers
import keras.layers as kl
from glob import glob
from sklearn.metrics import roc_curve, auc
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing
from tensorflow.keras import callbacks 
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from  matplotlib import pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,BatchNormalization,Dropout
# %matplotlib inline
import shutil
from sklearn.metrics import  precision_score, recall_score, accuracy_score,classification_report ,confusion_matrix
from tensorflow.python.platform import build_info as tf_build_info
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # Data Preparation

# %%
# Environment variable
main_dir = 'D:/Data/HAM100000 - Harvard Dataset'
main_img_dir = main_dir + '/img_data'
preprocessed_data_dir = main_dir + '/preprocessed_data'
train_dir = preprocessed_data_dir + '/train'
test_dir = preprocessed_data_dir + '/val'
train_label = preprocessed_data_dir + '/train_label.csv'
val_label = preprocessed_data_dir + '/val_label.csv'

model_path = 'IRV2SoftAtt_10split.hdf5'

# %%
from multiprocessing import Pool
target_size = (299, 299)
def Get_data(df_path, img_path, _target_size):
    img_list = []
    labels = []
    ages = []
    sex_list = []
    localizations = []
    
    df = pd.read_csv(df_path)
    for index, row in df.iterrows():
        img_list.append(cv2.imread(img_path + '/' + row['image_id'] + '.jpg'))
        labels.append(row['dx'])
        ages.append(float(row['age']))
        sex_list.append(row['sex'])
        localizations.append(row['localization'])
    for x in range(len(img_list)):
        img_list[x] = tf.keras.preprocessing.image.smart_resize(img_list[x], _target_size)
        img_list[x] = tf.keras.applications.mobilenet.preprocess_input(img_list[x])
    le = preprocessing.LabelEncoder()
    le.fit(labels)
    labels = le.transform(labels)
    labels = tf.keras.utils.to_categorical(labels)
    return (img_list, ages, sex_list, localizations), labels

# %%
train_df = pd.read_csv(train_label)
train_df.head()
# Out:
#    Unnamed: 0      image_id   dx   age   sex localization
# 0           0  ISIC_0027419  bkl  80.0  male        scalp
# 1           1  ISIC_0025030  bkl  80.0  male        scalp
# 2           2  ISIC_0026769  bkl  80.0  male        scalp
# 3           3  ISIC_0025661  bkl  80.0  male        scalp
# 4           4  ISIC_0031633  bkl  75.0  male          ear

# %%
val_df = pd.read_csv(val_label)
val_df.head()
# Out:
#    Unnamed: 0      image_id   dx   age     sex     localization
# 0        2973  ISIC_0031531  bcc  70.0    male             back
# 1         483  ISIC_0026526  bkl  60.0    male             face
# 2        8870  ISIC_0026805   nv  75.0  female  lower extremity
# 3        1991  ISIC_0030756  mel  85.0    male            chest
# 4        8324  ISIC_0024834   nv  70.0    male            chest

# %% [markdown]
# ## Training Data

# %%
(train_img_lst, train_ages, train_sexes, train_localizations), labels = Get_data(train_label, main_img_dir, target_size)

# %%
any(elem is None for elem in train_img_lst)
# Out:
# False

# %%
print("Number of images: {}".format(len(train_img_lst)))
print("Image shape: {0} {1}".format(train_img_lst[0].shape[0], train_img_lst[0].shape[1]))
print("Example of Age: {}".format(train_ages[0]))
print("Example of Sex: {}".format(train_sexes[0]))
print("Example of Localization: {}".format(train_localizations[0]))
# Out:
# Number of images: 8962
# Image shape: 299 299
# Example of Age: 80.0
# Example of Sex: male
# Example of Localization: scalp

# %% [markdown]
# ## Validation Data

# %%
(val_img_lst, val_ages, val_sexes, val_localizations), val_labels = Get_data(val_label, main_img_dir, target_size)

# %%
any(elem is None for elem in val_img_lst)
# Out:
# False

# %%
print("Number of images: {}".format(len(val_img_lst)))
print("Image shape: {0} {1}".format(val_img_lst[0].shape[0], val_img_lst[0].shape[1]))
print("Example of Age: {}".format(val_ages[0]))
print("Example of Sex: {}".format(val_sexes[0]))
print("Example of Localization: {}".format(val_localizations[0]))
# Out:
# Number of images: 996
# Image shape: 299 299
# Example of Age: 70.0
# Example of Sex: male
# Example of Localization: back

# %% [markdown]
# # Model

# %% [markdown]
# ## Input Block

# %%
age_input = tf.keras.Input(shape=(1,), name='age', dtype=tf.float32)
sex_input = tf.keras.Input(shape=(1,), name='sex', dtype=tf.string)
localizations_input = tf.keras.Input(shape=(1,), name='localization', dtype=tf.string)

inputs = {'age' : age_input,
         'sex' : sex_input,
         'local' : localizations_input}

# %%
norm = layers.Normalization()
norm.adapt(np.array(train_df[['age']]))
age_norm_input = norm(age_input)
age_norm_input
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'normalization')>

# %%
# Sex input
sex_lookup = layers.StringLookup(vocabulary=np.unique(train_df['sex']))
sex_one_hot = layers.CategoryEncoding(num_tokens=sex_lookup.vocabulary_size())

preprocessed_sex_input = sex_lookup(sex_input)
preprocessed_sex_input = sex_one_hot(preprocessed_sex_input)
preprocessed_sex_input
# Out:
# <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'category_encoding')>

# %%
# Localization input
local_lookup = layers.StringLookup(vocabulary=np.unique(train_df['localization']))
local_one_hot = layers.CategoryEncoding(num_tokens=local_lookup.vocabulary_size())

preprocess_local_input = local_lookup(localizations_input)
preprocess_local_input = local_one_hot(preprocess_local_input)
preprocess_local_input
# Out:
# <KerasTensor: shape=(None, 16) dtype=float32 (created by layer 'category_encoding_1')>

# %%
preprocessed_inputs = [age_norm_input, preprocessed_sex_input, preprocess_local_input]
preprocessed_inputs_cat = layers.Concatenate()(preprocessed_inputs)

# preprocessed_Model = tf.keras.Model(inputs, preprocessed_inputs_cat)
# tf.keras.utils.plot_model(model = preprocessed_Model , rankdir="LR", dpi=72, show_shapes=True)

preprocessed_inputs_cat
# Out:
# <KerasTensor: shape=(None, 21) dtype=float32 (created by layer 'concatenate')>

# %% [markdown]
# ## Soft Attention

# %%
from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
import tensorflow as tf

# %%
class SoftAttention(Layer):
    def __init__(self,ch,m,concat_with_x=False,aggregate=False,**kwargs):
        self.channels=int(ch)
        self.multiheads = m
        self.aggregate_channels = aggregate
        self.concat_input_with_scaled = concat_with_x

        
        super(SoftAttention,self).__init__(**kwargs)

    def build(self,input_shape):

        self.i_shape = input_shape

        kernel_shape_conv3d = (self.channels, 3, 3) + (1, self.multiheads) # DHWC
    
        self.out_attention_maps_shape = input_shape[0:1]+(self.multiheads,)+input_shape[1:-1]
        
        if self.aggregate_channels==False:

            self.out_features_shape = input_shape[:-1]+(input_shape[-1]+(input_shape[-1]*self.multiheads),)
        else:
            if self.concat_input_with_scaled:
                self.out_features_shape = input_shape[:-1]+(input_shape[-1]*2,)
            else:
                self.out_features_shape = input_shape
        

        self.kernel_conv3d = self.add_weight(shape=kernel_shape_conv3d,
                                        initializer='he_uniform',
                                        name='kernel_conv3d')
        self.bias_conv3d = self.add_weight(shape=(self.multiheads,),
                                      initializer='zeros',
                                      name='bias_conv3d')

        super(SoftAttention, self).build(input_shape)

    def call(self, x):

        exp_x = K.expand_dims(x,axis=-1)

        c3d = K.conv3d(exp_x,
                     kernel=self.kernel_conv3d,
                     strides=(1,1,self.i_shape[-1]), padding='same', data_format='channels_last')
        conv3d = K.bias_add(c3d,
                        self.bias_conv3d)
        conv3d = kl.Activation('relu')(conv3d)

        conv3d = K.permute_dimensions(conv3d,pattern=(0,4,1,2,3))

        
        conv3d = K.squeeze(conv3d, axis=-1)
        conv3d = K.reshape(conv3d,shape=(-1, self.multiheads ,self.i_shape[1]*self.i_shape[2]))

        softmax_alpha = K.softmax(conv3d, axis=-1) 
        softmax_alpha = kl.Reshape(target_shape=(self.multiheads, self.i_shape[1],self.i_shape[2]))(softmax_alpha)

        
        if self.aggregate_channels==False:
            exp_softmax_alpha = K.expand_dims(softmax_alpha, axis=-1)       
            exp_softmax_alpha = K.permute_dimensions(exp_softmax_alpha,pattern=(0,2,3,1,4))
   
            x_exp = K.expand_dims(x,axis=-2)
   
            u = kl.Multiply()([exp_softmax_alpha, x_exp])   
  
            u = kl.Reshape(target_shape=(self.i_shape[1],self.i_shape[2],u.shape[-1]*u.shape[-2]))(u)

        else:
            exp_softmax_alpha = K.permute_dimensions(softmax_alpha,pattern=(0,2,3,1))

            exp_softmax_alpha = K.sum(exp_softmax_alpha,axis=-1)

            exp_softmax_alpha = K.expand_dims(exp_softmax_alpha, axis=-1)

            u = kl.Multiply()([exp_softmax_alpha, x])   

        if self.concat_input_with_scaled:
            o = kl.Concatenate(axis=-1)([u,x])
        else:
            o = u
        
        return [o, softmax_alpha]

    def compute_output_shape(self, input_shape): 
        return [self.out_features_shape, self.out_attention_maps_shape]

    
    def get_config(self):
        return super(SoftAttention,self).get_config()

# %% [markdown]
# ## Base Model

# %%
irv2 = tf.keras.applications.InceptionResNetV2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classifier_activation="softmax",
)

inputs['image'] = irv2.input

# Exclude the last 28 layers of the model.
irv2_output = irv2.layers[-28].output

# %% [markdown]
# ## Final Model

# %%
attention_layer,map2 = SoftAttention(aggregate=True,m=16,concat_with_x=False,ch=int(irv2_output.shape[-1]),name='soft_attention')(irv2_output)
attention_layer=(MaxPooling2D(pool_size=(2, 2),padding="same")(attention_layer))
irv2_output=(MaxPooling2D(pool_size=(2, 2),padding="same")(irv2_output))

irv2_output = layers.Concatenate()([irv2_output, attention_layer])
irv2_output = Activation('relu')(irv2_output)
irv2_output = Dropout(0.5)(irv2_output)

# %%
output = Flatten()(irv2_output)
preprocessed_inputs_cat = (layers.Dense(4096, activation = 'relu')(preprocessed_inputs_cat))
output = layers.Concatenate()([output, preprocessed_inputs_cat])
output = Dense(7, activation='softmax')(output)
model = Model(inputs=inputs, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 35, 35, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['block35_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 35, 35, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['block35_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 35, 35, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 35, 35, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 35, 35, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['block35_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 35, 35, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 35, 35, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 35, 35, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 35, 35, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 35, 35, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 35, 35, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 35, 35, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['block35_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 35, 35, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 35, 35, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 35, 35, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 35, 35, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 35, 35, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 35, 35, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 35, 35, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['block35_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 35, 35, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 35, 35, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 35, 35, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 35, 35, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 35, 35, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 35, 35, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 35, 35, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['block35_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 35, 35, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 35, 35, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 35, 35, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 35, 35, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 35, 35, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 35, 35, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 35, 35, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['block35_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 35, 35, 32)  96          ['conv2d_57[0][0]']
#  ormalization)
#
# ...
#
#  conv2d_185 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_184[0][0]']
#
#  batch_normalization_185 (Batch  (None, 8, 8, 224)   672         ['conv2d_185[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_185[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_5_ac[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_185[0][0]']
#
#  batch_normalization_183 (Batch  (None, 8, 8, 192)   576         ['conv2d_183[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 8, 8, 256)   768         ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_183[0][0]']
#
#  activation_186 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_186[0][0]']
#
#  block8_6_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_183[0][0]',
#                                                                   'activation_186[0][0]']
#
#  block8_6_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_6_mixed[0][0]']
#
#  block8_6 (Lambda)              (None, 8, 8, 2080)   0           ['block8_5_ac[0][0]',
#                                                                   'block8_6_conv[0][0]']
#
#  block8_6_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_6[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_6_ac[0][0]']
#
#  batch_normalization_188 (Batch  (None, 8, 8, 192)   576         ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_188[0][0]']
#
#  batch_normalization_189 (Batch  (None, 8, 8, 224)   672         ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_189[0][0]']
#
#  batch_normalization_187 (Batch  (None, 8, 8, 192)   576         ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 8, 8, 256)   768         ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 8, 8, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 8, 8, 192)   576         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 8, 8, 224)   672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 8, 8, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 8, 8, 256)   768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 8, 8, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_195 (Batch  (None, 8, 8, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  soft_attention (SoftAttention)  [(None, 8, 8, 192),  27664      ['batch_normalization_195[0][0]']
#                                  (None, 16, 8, 8)]
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 192)   0           ['batch_normalization_195[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 192)   0           ['soft_attention[0][0]']
#
#  sex (InputLayer)               [(None, 1)]          0           []
#
#  localization (InputLayer)      [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 384)    0           ['max_pooling2d_5[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  age (InputLayer)               [(None, 1)]          0           []
#
#  string_lookup (StringLookup)   (None, 1)            0           ['sex[0][0]']
#
#  string_lookup_1 (StringLookup)  (None, 1)           0           ['localization[0][0]']
#
#  activation_203 (Activation)    (None, 4, 4, 384)    0           ['concatenate_1[0][0]']
#
#  normalization (Normalization)  (None, 1)            3           ['age[0][0]']
#
#  category_encoding (CategoryEnc  (None, 4)           0           ['string_lookup[0][0]']
#  oding)
#
#  category_encoding_1 (CategoryE  (None, 16)          0           ['string_lookup_1[0][0]']
#  ncoding)
#
#  dropout (Dropout)              (None, 4, 4, 384)    0           ['activation_203[0][0]']
#
#  concatenate (Concatenate)      (None, 21)           0           ['normalization[0][0]',
#                                                                   'category_encoding[0][0]',
#                                                                   'category_encoding_1[0][0]']
#
#  flatten (Flatten)              (None, 6144)         0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 4096)         90112       ['concatenate[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 10240)        0           ['flatten[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 7)            71687       ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 47,654,074
# Trainable params: 47,599,671
# Non-trainable params: 54,403
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
feature_dict = {'age' : np.array(train_ages),
                'sex' : np.array(train_sexes),
                'local' : np.array(train_localizations),
                'image' : np.array(train_img_lst)}

# %%
val_dict = {'age' : np.array(val_ages),
                'sex' : np.array(val_sexes),
                'local' : np.array(val_localizations),
                'image' : np.array(val_img_lst)}

# %%
class_weights = { 
                    0: 4.37,  # akiec
                    1: 2.78,  # bcc
                    2: 1.3,  # bkl
                    3: 12.44,  # df
                    4: 1.28,  # mel
                    5: 0.21,  # nv
                    6: 10,  # vasc
                }


checkpoint=  ModelCheckpoint(filepath = model_path,monitor='val_accuracy',save_best_only=True,save_weights_only=True)

# %%
opt1=tf.keras.optimizers.Adam(learning_rate=0.001,epsilon=0.1)
model.compile(optimizer=opt1,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              verbose = 1, mode = 'min',
                              patience=5, min_lr=0.0000001)

# %%
batch_size = 32 

Earlystop = EarlyStopping(monitor='val_loss', mode='min',patience=35, min_delta=0.001)

with tf.device('/CPU:0'):
    history = model.fit(feature_dict, labels,
                        steps_per_epoch=(len(train_df)/10),
                        epochs=500,
                        validation_data=(val_dict, val_labels), 
                        validation_steps=len(val_df)/batch_size,
                        callbacks=[checkpoint, Earlystop, reduce_lr],
                        class_weight=class_weights)
# Out:
# Epoch 1/500
# 896/896 [==============================] - 3506s 4s/step - loss: 1.3841 - accuracy: 0.4886 - val_loss: 1.2976 - val_accuracy: 0.5392 - lr: 0.0010
# Epoch 2/500
# 896/896 [==============================] - 3512s 4s/step - loss: 0.8178 - accuracy: 0.6678 - val_loss: 1.8479 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 3/500
# 896/896 [==============================] - 3518s 4s/step - loss: 0.6003 - accuracy: 0.7089 - val_loss: 0.9537 - val_accuracy: 0.7731 - lr: 0.0010
# Epoch 4/500
# 896/896 [==============================] - 3517s 4s/step - loss: 0.4594 - accuracy: 0.7550 - val_loss: 1.3367 - val_accuracy: 0.6456 - lr: 0.0010
# Epoch 5/500
# 896/896 [==============================] - 3515s 4s/step - loss: 0.3459 - accuracy: 0.7998 - val_loss: 0.7711 - val_accuracy: 0.7912 - lr: 0.0010
# Epoch 6/500
# 896/896 [==============================] - 3511s 4s/step - loss: 0.2776 - accuracy: 0.8282 - val_loss: 0.9313 - val_accuracy: 0.7580 - lr: 0.0010
# Epoch 7/500
# 896/896 [==============================] - 3509s 4s/step - loss: 0.2954 - accuracy: 0.8123 - val_loss: 0.7736 - val_accuracy: 0.7741 - lr: 0.0010
# Epoch 8/500
# 896/896 [==============================] - 3511s 4s/step - loss: 0.1779 - accuracy: 0.8783 - val_loss: 0.6522 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 9/500
# 896/896 [==============================] - 3505s 4s/step - loss: 0.1389 - accuracy: 0.9020 - val_loss: 0.4852 - val_accuracy: 0.8414 - lr: 0.0010
# Epoch 10/500
# 896/896 [==============================] - 3505s 4s/step - loss: 0.0839 - accuracy: 0.9353 - val_loss: 0.4894 - val_accuracy: 0.8384 - lr: 0.0010
# Epoch 11/500
# 896/896 [==============================] - 3517s 4s/step - loss: 0.1381 - accuracy: 0.9170 - val_loss: 0.8367 - val_accuracy: 0.7851 - lr: 0.0010
# Epoch 12/500
# 896/896 [==============================] - 3515s 4s/step - loss: 0.4807 - accuracy: 0.7621 - val_loss: 0.8481 - val_accuracy: 0.7450 - lr: 0.0010
# Epoch 13/500
# 896/896 [==============================] - 3515s 4s/step - loss: 0.1774 - accuracy: 0.8709 - val_loss: 0.9526 - val_accuracy: 0.7219 - lr: 0.0010
# Epoch 14/500
# 897/896 [==============================] - ETA: -3s - loss: 0.1031 - accuracy: 0.9164
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 896/896 [==============================] - 3516s 4s/step - loss: 0.1031 - accuracy: 0.9164 - val_loss: 0.4962 - val_accuracy: 0.8655 - lr: 0.0010
# Epoch 15/500
# 896/896 [==============================] - 3517s 4s/step - loss: 0.0598 - accuracy: 0.9449 - val_loss: 0.4384 - val_accuracy: 0.8805 - lr: 2.0000e-04
# Epoch 16/500
# 896/896 [==============================] - 3513s 4s/step - loss: 0.0434 - accuracy: 0.9585 - val_loss: 0.4257 - val_accuracy: 0.8735 - lr: 2.0000e-04
# Epoch 17/500
# 896/896 [==============================] - 3521s 4s/step - loss: 0.0408 - accuracy: 0.9649 - val_loss: 0.4386 - val_accuracy: 0.8825 - lr: 2.0000e-04
# Epoch 18/500
# 896/896 [==============================] - 3557s 4s/step - loss: 0.0375 - accuracy: 0.9673 - val_loss: 0.4191 - val_accuracy: 0.8815 - lr: 2.0000e-04
# Epoch 19/500
# 896/896 [==============================] - 3579s 4s/step - loss: 0.0353 - accuracy: 0.9707 - val_loss: 0.4608 - val_accuracy: 0.8715 - lr: 2.0000e-04
# Epoch
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 896/896 [==============================] - 3504s 4s/step - loss: 0.0179 - accuracy: 0.9839 - val_loss: 0.4231 - val_accuracy: 0.8845 - lr: 1.6000e-06
# Epoch 39/500
# 896/896 [==============================] - 3505s 4s/step - loss: 0.0173 - accuracy: 0.9854 - val_loss: 0.4248 - val_accuracy: 0.8835 - lr: 3.2000e-07
# Epoch 40/500
# 896/896 [==============================] - 3500s 4s/step - loss: 0.0193 - accuracy: 0.9849 - val_loss: 0.4289 - val_accuracy: 0.8865 - lr: 3.2000e-07
# Epoch 41/500
# 896/896 [==============================] - 3501s 4s/step - loss: 0.0182 - accuracy: 0.9832 - val_loss: 0.4297 - val_accuracy: 0.8835 - lr: 3.2000e-07
# Epoch 42/500
# 896/896 [==============================] - 3504s 4s/step - loss: 0.0183 - accuracy: 0.9842 - val_loss: 0.4290 - val_accuracy: 0.8835 - lr: 3.2000e-07
# Epoch 43/500
# 763/896 [========================>.....] - ETA: 8:32 - loss: 0.0163 - accuracy: 0.9827
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [29], line 6
#       3 Earlystop = EarlyStopping(monitor='val_loss', mode='min',patience=35, min_delta=0.001)
#       5 with tf.device('/CPU:0'):
# ----> 6     history = model.fit(feature_dict, labels,
#       7                         steps_per_epoch=(len(train_df)/10),
#       8                         epochs=500,
#       9                         validation_data=(val_dict, val_labels),
#      10                         validation_steps=len(val_df)/batch_size,
#      11                         callbacks=[checkpoint, Earlystop, reduce_lr],
#      12                         class_weight=class_weights)
#
# File d:\data\tf270\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\data\tf270\lib\site-packages\keras\engine\training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1209 with tf.profiler.experimental.Trace(
#    1210     'train',
#    1211     epoch_num=epoch,
#    1212     step_num=step,
#    1213     batch_size=batch_size,
#    1214     _r=1):
#    1215   callbacks.on_train_batch_begin(step)
# -> 1216   tmp_logs = self.train_function(iterator)
#    1217   if data_handler.should_sync:
#    1218     context.async_wait()
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\eager\def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\eager\def_function.py:942, in Function._call(self, *args, **kwds)
#     939   self._lock.release()
#     940   # In this case we have created variables on the first call, so we run the
#     941   # defunned version which is guaranteed to never create variables.
# --> 942   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943 elif self._stateful_fn is not None:
#     944   # Release the lock early so that multiple threads can perform the call
#     945   # in parallel.
#     946   self._lock.release()
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function.__call__(self, *args, **kwargs)
#    3127 with self._lock:
#    3128   (graph_function,
#    3129    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130 return graph_function._call_flat(
#    3131     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\eager\function.py:1959, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1955 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1956 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1957     and executing_eagerly):
#    1958   # No tape is watching; skip to running the function.
# -> 1959   return self._build_call_outputs(self._inference_function.call(
#    1960       ctx, args, cancellation_manager=cancellation_manager))
#    1961 forward_backward = self._select_forward_and_backward_functions(
#    1962     args,
#    1963     possible_gradient_type,
#    1964     executing_eagerly)
#    1965 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\eager\function.py:598, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     596 with _InterpolateFunctionError(self):
#     597   if cancellation_manager is None:
# --> 598     outputs = execute.execute(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#     601         inputs=args,
#     602         attrs=attrs,
#     603         ctx=ctx)
#     604   else:
#     605     outputs = execute.execute_with_cancellation(
#     606         str(self.signature.name),
#     607         num_outputs=self._num_outputs,
#    (...)
#     610         ctx=ctx,
#     611         cancellation_manager=cancellation_manager)
#
# File d:\data\tf270\lib\site-packages\tensorflow\python\eager\execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56 try:
#      57   ctx.ensure_initialized()
# ---> 58   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                       inputs, attrs, num_outputs)
#      60 except core._NotOkStatusException as e:
#      61   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Classification report

# %%
from tensorflow.keras import models
model.load_weights(model_path)

# %%
batch_size = 32 
with tf.device('/CPU:0'):
    predictions = model.predict(val_dict, steps=len(val_df)/batch_size)

# %%
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#getting the true labels per image 
y_true = np.argmax(val_labels, axis=1)
#getting the predicted labels per image 
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report 
report = classification_report(y_true, y_pred, target_names=targetnames)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.74      0.88      0.81        33
#          bcc       0.75      0.84      0.80        51
#          bkl       0.86      0.81      0.83       109
#           df       0.69      0.92      0.79        12
#          mel       0.77      0.71      0.74       111
#           nv       0.94      0.93      0.94       666
#         vasc       0.81      0.93      0.87        14
#
#     accuracy                           0.89       996
#    macro avg       0.80      0.86      0.82       996
# weighted avg       0.89      0.89      0.89       996

# %% [markdown]
# ## Confusion Matrix Metrics

# %%
import seaborn as sns
sns.set(font_scale=2)
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix
multi_cm = multilabel_confusion_matrix(y_true, y_pred)
cm = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cm, index = targetnames, columns = targetnames)
plt.figure(figsize = (15,15))
sns.heatmap(df_cm, annot=True, cmap = "Blues")
#print(multi_cm)

# TN     FP
# FN     TP
# Out:
# <AxesSubplot:>

# %%
def cm_compute(_cm, _index, _name):
    print("Confusion Matrix of {}".format(_name))
    print(_cm[index])
    TP = _cm[index][1][1]
    FP = _cm[index][0][1]
    FN = _cm[index][1][0]
    TN = _cm[index][0][0]
    print("True Positive of {0}: {1}".format(_name, TP))
    print("False Positive of {0}: {1}".format(_name, FP))
    print("False Negative of {0}: {1}".format(_name, FN))
    print("True Negative of {0}: {1}".format(_name, TN))
    sensitivity = TP/(TP + FN)
    specificity = TN/(TN + FP)
    print("Sensitivity of {0}: {1}".format(_name, sensitivity))
    print("Specificity of {0}: {1}".format(_name, specificity))
    print("Precision of {0}: {1}".format(_name, TP/(TP + FP)))
    print("Accuracy of {0}: {1}".format(_name, (TP+TN)/(TP + FP + FN + TN)))
    print("Balanced Accuracy of {0} : {1}".format(_name, (sensitivity + specificity)/2))
    print("F1 Score of {0}: {1}".format(_name, (2*TP)/(2*TP + FP + FN)))

# %% [markdown]
# ### akiec

# %%
index = 0
cm_compute(multi_cm, index, targetnames[index])
# Out:
# Confusion Matrix of akiec
# [[953  10]
#  [  4  29]]
# True Positive of akiec: 29
# False Positive of akiec: 10
# False Negative of akiec: 4
# True Negative of akiec: 953
# Sensitivity of akiec: 0.8787878787878788
# Specificity of akiec: 0.9896157840083074
# Precision of akiec: 0.7435897435897436
# Accuracy of akiec: 0.9859437751004017
# Balanced Accuracy of akiec : 0.9342018313980931
# F1 Score of akiec: 0.8055555555555556

# %% [markdown]
# ### bcc

# %%
index = 1
cm_compute(multi_cm, index, targetnames[index])
# Out:
# Confusion Matrix of bcc
# [[931  14]
#  [  8  43]]
# True Positive of bcc: 43
# False Positive of bcc: 14
# False Negative of bcc: 8
# True Negative of bcc: 931
# Sensitivity of bcc: 0.8431372549019608
# Specificity of bcc: 0.9851851851851852
# Precision of bcc: 0.7543859649122807
# Accuracy of bcc: 0.9779116465863453
# Balanced Accuracy of bcc : 0.9141612200435729
# F1 Score of bcc: 0.7962962962962963

# %% [markdown]
# ### bkl

# %%
index = 3
cm_compute(multi_cm, index, targetnames[index])
# Out:
# Confusion Matrix of df
# [[979   5]
#  [  1  11]]
# True Positive of df: 11
# False Positive of df: 5
# False Negative of df: 1
# True Negative of df: 979
# Sensitivity of df: 0.9166666666666666
# Specificity of df: 0.9949186991869918
# Precision of df: 0.6875
# Accuracy of df: 0.9939759036144579
# Balanced Accuracy of df : 0.9557926829268293
# F1 Score of df: 0.7857142857142857

# %% [markdown]
# ### mel

# %%
index = 4
cm_compute(multi_cm, index, targetnames[index])
# Out:
# Confusion Matrix of mel
# [[862  23]
#  [ 32  79]]
# True Positive of mel: 79
# False Positive of mel: 23
# False Negative of mel: 32
# True Negative of mel: 862
# Sensitivity of mel: 0.7117117117117117
# Specificity of mel: 0.9740112994350283
# Precision of mel: 0.7745098039215687
# Accuracy of mel: 0.9447791164658634
# Balanced Accuracy of mel : 0.8428615055733699
# F1 Score of mel: 0.7417840375586855

# %% [markdown]
# ### nv

# %%
index = 5
cm_compute(multi_cm, index, targetnames[index])
# Out:
# Confusion Matrix of nv
# [[288  42]
#  [ 44 622]]
# True Positive of nv: 622
# False Positive of nv: 42
# False Negative of nv: 44
# True Negative of nv: 288
# Sensitivity of nv: 0.933933933933934
# Specificity of nv: 0.8727272727272727
# Precision of nv: 0.9367469879518072
# Accuracy of nv: 0.9136546184738956
# Balanced Accuracy of nv : 0.9033306033306033
# F1 Score of nv: 0.9353383458646617

# %% [markdown]
# ### vasc

# %%
index = 6
cm_compute(multi_cm, index, targetnames[index])
# Out:
# Confusion Matrix of vasc
# [[979   3]
#  [  1  13]]
# True Positive of vasc: 13
# False Positive of vasc: 3
# False Negative of vasc: 1
# True Negative of vasc: 979
# Sensitivity of vasc: 0.9285714285714286
# Specificity of vasc: 0.9969450101832994
# Precision of vasc: 0.8125
# Accuracy of vasc: 0.9959839357429718
# Balanced Accuracy of vasc : 0.962758219377364
# F1 Score of vasc: 0.8666666666666667

# %% [markdown]
# ## Weighted, Macro, Micro, ROC AUC

# %%
print("Precision: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("weighted Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='weighted')))
# Out:
# Precision: 0.