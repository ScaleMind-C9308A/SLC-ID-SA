# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model

def model_analyze(_model):
    for x in range(len(_model.layers)):
        print(f"Layers {x}({x - len(_model.layers)}): {_model.layers[x].name}")
        
def K_plot_model(_model, model_name):
    plot_model(_model, 
               to_file=f"{model_name}.png", 
               show_shapes=True, 
               show_dtype=True,  
               show_layer_names=True,
               expand_nested=False,
               dpi=150,
               show_layer_activations=True)

# %% [markdown]
# # Xception

# %%
xception = tf.keras.applications.Xception(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91889664/91884032 [==============================] - 9s 0us/step
# 91897856/91884032 [==============================] - 9s 0us/step

# %%
model_analyze(xception)
# Out:
# Layers 0(-134): input_1
# Layers 1(-133): block1_conv1
# Layers 2(-132): block1_conv1_bn
# Layers 3(-131): block1_conv1_act
# Layers 4(-130): block1_conv2
# Layers 5(-129): block1_conv2_bn
# Layers 6(-128): block1_conv2_act
# Layers 7(-127): block2_sepconv1
# Layers 8(-126): block2_sepconv1_bn
# Layers 9(-125): block2_sepconv2_act
# Layers 10(-124): block2_sepconv2
# Layers 11(-123): block2_sepconv2_bn
# Layers 12(-122): conv2d
# Layers 13(-121): block2_pool
# Layers 14(-120): batch_normalization
# Layers 15(-119): add
# Layers 16(-118): block3_sepconv1_act
# Layers 17(-117): block3_sepconv1
# Layers 18(-116): block3_sepconv1_bn
# Layers 19(-115): block3_sepconv2_act
# Layers 20(-114): block3_sepconv2
# Layers 21(-113): block3_sepconv2_bn
# Layers 22(-112): conv2d_1
# Layers 23(-111): block3_pool
# Layers 24(-110): batch_normalization_1
# Layers 25(-109): add_1
# Layers 26(-108): block4_sepconv1_act
# Layers 27(-107): block4_sepconv1
# Layers 28(-106): block4_sepconv1_bn
# Layers 29(-105): block4_sepconv2_act
# Layers 30(-104): block4_sepconv2
# Layers 31(-103): block4_sepconv2_bn
# Layers 32(-102): conv2d_2
# Layers 33(-101): block4_pool
# Layers 34(-100): batch_normalization_2
# Layers 35(-99): add_2
# Layers 36(-98): block5_sepconv1_act
# Layers 37(-97): block5_sepconv1
# Layers 38(-96): block5_sepconv1_bn
# Layers 39(-95): block5_sepconv2_act
# Layers 40(-94): block5_sepconv2
# Layers 41(-93): block5_sepconv2_bn
# Layers 42(-92): block5_sepconv3_act
# Layers 43(-91): block5_sepconv3
# Layers 44(-90): block5_sepconv3_bn
# Layers 45(-89): add_3
# Layers 46(-88): block6_sepconv1_act
# Layers 47(-87): block6_sepconv1
# Layers 48(-86): block6_sepconv1_bn
# Layers 49(-85): block6_sepconv2_act
# Layers 50(-84): block6_sepconv2
# Layers 51(-83): block6_sepconv2_bn
# Layers 52(-82): block6_sepconv3_act
# Layers 53(-81): block6_sepconv3
# Layers 54(-80): block6_sepconv3_bn
# Layers 55(-79): add_4
# Layers 56(-78): block7_sepconv1_act
# Layers 57(-77): block7_sepconv1
# Layers 58(-76): block7_sepconv1_bn
# Layers 59(-75): block7_sepconv2_act
# Layers 60(-74): block7_sepconv2
# Layers 61(-73): block7_sepconv2_bn
# Layers 62(-72): block7_sepconv3_act
# Layers 63(-71): block7_sepconv3
# Layers 64(-70): block7_sepconv3_bn
# Layers 65(-69): add_5
# Layers 66(-68): block8_sepconv1_act
# Layers 67(-67): block8_sepconv1
# Layers 68(-66): block8_sepconv1_bn
# Layers 69(-65): block8_sepconv2_act
# Layers 70(-64): block8_sepconv2
# Layers 71(-63): block8_sepconv2_bn
# Layers 72(-62): block8_sepconv3_act
# Layers 73(-61): block8_sepconv3
# Layers 74(-60): block8_sepconv3_bn
# Layers 75(-59): add_6
# Layers 76(-58): block9_sepconv1_act
# Layers 77(-57): block9_sepconv1
# Layers 78(-56): block9_sepconv1_bn
# Layers 79(-55): block9_sepconv2_act
# Layers 80(-54): block9_sepconv2
# Layers 81(-53): block9_sepconv2_bn
# Layers 82(-52): block9_sepconv3_act
# Layers 83(-51): block9_sepconv3
# Layers 84(-50): block9_sepconv3_bn
# Layers 85(-49): add_7
# Layers 86(-48): block10_sepconv1_act
# Layers 87(-47): block10_sepconv1
# Layers 88(-46): block10_sepconv1_bn
# Layers 89(-45): block10_sepconv2_act
# Layers 90(-44): block10_sepconv2
# Layers 91(-43): block10_sepconv2_bn
# Layers 92(-42): block10_sepconv3_act
# Layers 93(-41): block10_sepconv3
# Layers 94(-40): block10_sepconv3_bn
# Layers 95(-39): add_8
# Layers 96(-38): block11_sepconv1_act
# Layers 97(-37): block11_sepconv1
# Layers 98(-36): block11_sepconv1_bn
# Layers 99(-35): block11_sepconv2_act
# Layers 100(-34): block11_sepconv2
# Layers 101(-33): block11_sepconv2_bn
# Layers 102(-32): block11_sepconv3_act
# Layers 103(-31): block11_sepconv3
# Layers 104(-30): block11_sepconv3_bn
# Layers 105(-29): add_9
# Layers 106(-28): block12_sepconv1_act
# Layers 107(-27): block12_sepconv1
# Layers 108(-26): block12_sepconv1_bn
# Layers 109(-25): block12_sepconv2_act
# Layers 110(-24): block12_sepconv2
# Layers 111(-23): block12_sepconv2_bn
# Layers 112(-22): block12_sepconv3_act
# Layers 113(-21): block12_sepconv3
# Layers 114(-20): block12_sepconv3_bn
# Layers 115(-19): add_10
# Layers 116(-18): block13_sepconv1_act
# Layers 117(-17): block13_sepconv1
# Layers 118(-16): block13_sepconv1_bn
# Layers 119(-15): block13_sepconv2_act
# Layers 120(-14): block13_sepconv2
# Layers 121(-13): block13_sepconv2_bn
# Layers 122(-12): conv2d_3
# Layers 123(-11): block13_pool
# Layers 124(-10): batch_normalization_3
# Layers 125(-9): add_11
# Layers 126(-8): block14_sepconv1
# Layers 127(-7): block14_sepconv1_bn
# Layers 128(-6): block14_sepconv1_act
# Layers 129(-5): block14_sepconv2
# Layers 130(-4): block14_sepconv2_bn
# Layers 131(-3): block14_sepconv2_act
# Layers 132(-2): avg_pool
# Layers 133(-1): predictions

# %%
xception.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 147, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 147, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 147, 147, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 147, 147, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 147, 147, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 147, 147, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 74, 74, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 74, 74, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 74, 74, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 74, 74, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 74, 74, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 74, 74, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 74, 74, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 74, 74, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 37, 37, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 37, 37, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 37, 37, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 37, 37, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 37, 37, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 37, 37, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#  block4_sepconv1_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 37, 37, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 37, 37, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 19, 19, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 19, 19, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 19, 19, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 19, 19, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 19, 19, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 19, 19, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 19, 19, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#  block9_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 19, 19, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 19, 19, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 19, 19, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 19, 19, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 19, 19, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 19, 19, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 10, 10, 1024  745472      ['add_10[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 10, 10, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 10, 10, 1024  4096       ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  add_11 (Add)                   (None, 10, 10, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 10, 10, 1536  1582080    ['add_11[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 10, 10, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 10, 10, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 10, 10, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 10, 10, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 10, 10, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 22,910,480
# Trainable params: 22,855,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# # VGG16

# %%
VGG16 = tf.keras.applications.VGG16(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 51s 0us/step
# 553476096/553467096 [==============================] - 51s 0us/step

# %%
model_analyze(VGG16)
# Out:
# Layers 0(-23): input_2
# Layers 1(-22): block1_conv1
# Layers 2(-21): block1_conv2
# Layers 3(-20): block1_pool
# Layers 4(-19): block2_conv1
# Layers 5(-18): block2_conv2
# Layers 6(-17): block2_pool
# Layers 7(-16): block3_conv1
# Layers 8(-15): block3_conv2
# Layers 9(-14): block3_conv3
# Layers 10(-13): block3_pool
# Layers 11(-12): block4_conv1
# Layers 12(-11): block4_conv2
# Layers 13(-10): block4_conv3
# Layers 14(-9): block4_pool
# Layers 15(-8): block5_conv1
# Layers 16(-7): block5_conv2
# Layers 17(-6): block5_conv3
# Layers 18(-5): block5_pool
# Layers 19(-4): flatten
# Layers 20(-3): fc1
# Layers 21(-2): fc2
# Layers 22(-1): predictions

# %%
VGG16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # VGG19

# %%
VGG19 = tf.keras.applications.VGG19(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 53s 0us/step
# 574726144/574710816 [==============================] - 53s 0us/step

# %%
model_analyze(VGG19)
# Out:
# Layers 0(-26): input_3
# Layers 1(-25): block1_conv1
# Layers 2(-24): block1_conv2
# Layers 3(-23): block1_pool
# Layers 4(-22): block2_conv1
# Layers 5(-21): block2_conv2
# Layers 6(-20): block2_pool
# Layers 7(-19): block3_conv1
# Layers 8(-18): block3_conv2
# Layers 9(-17): block3_conv3
# Layers 10(-16): block3_conv4
# Layers 11(-15): block3_pool
# Layers 12(-14): block4_conv1
# Layers 13(-13): block4_conv2
# Layers 14(-12): block4_conv3
# Layers 15(-11): block4_conv4
# Layers 16(-10): block4_pool
# Layers 17(-9): block5_conv1
# Layers 18(-8): block5_conv2
# Layers 19(-7): block5_conv3
# Layers 20(-6): block5_conv4
# Layers 21(-5): block5_pool
# Layers 22(-4): flatten
# Layers 23(-3): fc1
# Layers 24(-2): fc2
# Layers 25(-1): predictions

# %%
VGG19.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # ResNet50

# %%
ResNet50 = tf.keras.applications.ResNet50(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000
)

# %%
model_analyze(ResNet50)
# Out:
# Layers 0(-177): input_4
# Layers 1(-176): conv1_pad
# Layers 2(-175): conv1_conv
# Layers 3(-174): conv1_bn
# Layers 4(-173): conv1_relu
# Layers 5(-172): pool1_pad
# Layers 6(-171): pool1_pool
# Layers 7(-170): conv2_block1_1_conv
# Layers 8(-169): conv2_block1_1_bn
# Layers 9(-168): conv2_block1_1_relu
# Layers 10(-167): conv2_block1_2_conv
# Layers 11(-166): conv2_block1_2_bn
# Layers 12(-165): conv2_block1_2_relu
# Layers 13(-164): conv2_block1_0_conv
# Layers 14(-163): conv2_block1_3_conv
# Layers 15(-162): conv2_block1_0_bn
# Layers 16(-161): conv2_block1_3_bn
# Layers 17(-160): conv2_block1_add
# Layers 18(-159): conv2_block1_out
# Layers 19(-158): conv2_block2_1_conv
# Layers 20(-157): conv2_block2_1_bn
# Layers 21(-156): conv2_block2_1_relu
# Layers 22(-155): conv2_block2_2_conv
# Layers 23(-154): conv2_block2_2_bn
# Layers 24(-153): conv2_block2_2_relu
# Layers 25(-152): conv2_block2_3_conv
# Layers 26(-151): conv2_block2_3_bn
# Layers 27(-150): conv2_block2_add
# Layers 28(-149): conv2_block2_out
# Layers 29(-148): conv2_block3_1_conv
# Layers 30(-147): conv2_block3_1_bn
# Layers 31(-146): conv2_block3_1_relu
# Layers 32(-145): conv2_block3_2_conv
# Layers 33(-144): conv2_block3_2_bn
# Layers 34(-143): conv2_block3_2_relu
# Layers 35(-142): conv2_block3_3_conv
# Layers 36(-141): conv2_block3_3_bn
# Layers 37(-140): conv2_block3_add
# Layers 38(-139): conv2_block3_out
# Layers 39(-138): conv3_block1_1_conv
# Layers 40(-137): conv3_block1_1_bn
# Layers 41(-136): conv3_block1_1_relu
# Layers 42(-135): conv3_block1_2_conv
# Layers 43(-134): conv3_block1_2_bn
# Layers 44(-133): conv3_block1_2_relu
# Layers 45(-132): conv3_block1_0_conv
# Layers 46(-131): conv3_block1_3_conv
# Layers 47(-130): conv3_block1_0_bn
# Layers 48(-129): conv3_block1_3_bn
# Layers 49(-128): conv3_block1_add
# Layers 50(-127): conv3_block1_out
# Layers 51(-126): conv3_block2_1_conv
# Layers 52(-125): conv3_block2_1_bn
# Layers 53(-124): conv3_block2_1_relu
# Layers 54(-123): conv3_block2_2_conv
# Layers 55(-122): conv3_block2_2_bn
# Layers 56(-121): conv3_block2_2_relu
# Layers 57(-120): conv3_block2_3_conv
# Layers 58(-119): conv3_block2_3_bn
# Layers 59(-118): conv3_block2_add
# Layers 60(-117): conv3_block2_out
# Layers 61(-116): conv3_block3_1_conv
# Layers 62(-115): conv3_block3_1_bn
# Layers 63(-114): conv3_block3_1_relu
# Layers 64(-113): conv3_block3_2_conv
# Layers 65(-112): conv3_block3_2_bn
# Layers 66(-111): conv3_block3_2_relu
# Layers 67(-110): conv3_block3_3_conv
# Layers 68(-109): conv3_block3_3_bn
# Layers 69(-108): conv3_block3_add
# Layers 70(-107): conv3_block3_out
# Layers 71(-106): conv3_block4_1_conv
# Layers 72(-105): conv3_block4_1_bn
# Layers 73(-104): conv3_block4_1_relu
# Layers 74(-103): conv3_block4_2_conv
# Layers 75(-102): conv3_block4_2_bn
# Layers 76(-101): conv3_block4_2_relu
# Layers 77(-100): conv3_block4_3_conv
# Layers 78(-99): conv3_block4_3_bn
# Layers 79(-98): conv3_block4_add
# Layers 80(-97): conv3_block4_out
# Layers 81(-96): conv4_block1_1_conv
# Layers 82(-95): conv4_block1_1_bn
# Layers 83(-94): conv4_block1_1_relu
# Layers 84(-93): conv4_block1_2_conv
# Layers 85(-92): conv4_block1_2_bn
# Layers 86(-91): conv4_block1_2_relu
# Layers 87(-90): conv4_block1_0_conv
# Layers 88(-89): conv4_block1_3_conv
# Layers 89(-88): conv4_block1_0_bn
# Layers 90(-87): conv4_block1_3_bn
# Layers 91(-86): conv4_block1_add
# Layers 92(-85): conv4_block1_out
# Layers 93(-84): conv4_block2_1_conv
# Layers 94(-83): conv4_block2_1_bn
# Layers 95(-82): conv4_block2_1_relu
# Layers 96(-81): conv4_block2_2_conv
# Layers 97(-80): conv4_block2_2_bn
# Layers 98(-79): conv4_block2_2_relu
# Layers 99(-78): conv4_block2_3_conv
# Layers 100(-77): conv4_block2_3_bn
# Layers 101(-76): conv4_block2_add
# Layers 102(-75): conv4_block2_out
# Layers 103(-74): conv4_block3_1_conv
# Layers 104(-73): conv4_block3_1_bn
# Layers 105(-72): conv4_block3_1_relu
# Layers 106(-71): conv4_block3_2_conv
# Layers 107(-70): conv4_block3_2_bn
# Layers 108(-69): conv4_block3_2_relu
# Layers 109(-68): conv4_block3_3_conv
# Layers 110(-67): conv4_block3_3_bn
# Layers 111(-66): conv4_block3_add
# Layers 112(-65): conv4_block3_out
# Layers 113(-64): conv4_block4_1_conv
# Layers 114(-63): conv4_block4_1_bn
# Layers 115(-62): conv4_block4_1_relu
# Layers 116(-61): conv4_block4_2_conv
# Layers 117(-60): conv4_block4_2_bn
# Layers 118(-59): conv4_block4_2_relu
# Layers 119(-58): conv4_block4_3_conv
# Layers 120(-57): conv4_block4_3_bn
# Layers 121(-56): conv4_block4_add
# Layers 122(-55): conv4_block4_out
# Layers 123(-54): conv4_block5_1_conv
# Layers 124(-53): conv4_block5_1_bn
# Layers 125(-52): conv4_block5_1_relu
# Layers 126(-51): conv4_block5_2_conv
# Layers 127(-50): conv4_block5_2_bn
# Layers 128(-49): conv4_block5_2_relu
# Layers 129(-48): conv4_block5_3_conv
# Layers 130(-47): conv4_block5_3_bn
# Layers 131(-46): conv4_block5_add
# Layers 132(-45): conv4_block5_out
# Layers 133(-44): conv4_block6_1_conv
# Layers 134(-43): conv4_block6_1_bn
# Layers 135(-42): conv4_block6_1_relu
# Layers 136(-41): conv4_block6_2_conv
# Layers 137(-40): conv4_block6_2_bn
# Layers 138(-39): conv4_block6_2_relu
# Layers 139(-38): conv4_block6_3_conv
# Layers 140(-37): conv4_block6_3_bn
# Layers 141(-36): conv4_block6_add
# Layers 142(-35): conv4_block6_out
# Layers 143(-34): conv5_block1_1_conv
# Layers 144(-33): conv5_block1_1_bn
# Layers 145(-32): conv5_block1_1_relu
# Layers 146(-31): conv5_block1_2_conv
# Layers 147(-30): conv5_block1_2_bn
# Layers 148(-29): conv5_block1_2_relu
# Layers 149(-28): conv5_block1_0_conv
# Layers 150(-27): conv5_block1_3_conv
# Layers 151(-26): conv5_block1_0_bn
# Layers 152(-25): conv5_block1_3_bn
# Layers 153(-24): conv5_block1_add
# Layers 154(-23): conv5_block1_out
# Layers 155(-22): conv5_block2_1_conv
# Layers 156(-21): conv5_block2_1_bn
# Layers 157(-20): conv5_block2_1_relu
# Layers 158(-19): conv5_block2_2_conv
# Layers 159(-18): conv5_block2_2_bn
# Layers 160(-17): conv5_block2_2_relu
# Layers 161(-16): conv5_block2_3_conv
# Layers 162(-15): conv5_block2_3_bn
# Layers 163(-14): conv5_block2_add
# Layers 164(-13): conv5_block2_out
# Layers 165(-12): conv5_block3_1_conv
# Layers 166(-11): conv5_block3_1_bn
# Layers 167(-10): conv5_block3_1_relu
# Layers 168(-9): conv5_block3_2_conv
# Layers 169(-8): conv5_block3_2_bn
# Layers 170(-7): conv5_block3_2_relu
# Layers 171(-6): conv5_block3_3_conv
# Layers 172(-5): conv5_block3_3_bn
# Layers 173(-4): conv5_block3_add
# Layers 174(-3): conv5_block3_out
# Layers 175(-2): avg_pool
# Layers 176(-1): predictions

# %%
ResNet50.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_4[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# # ResNet50V2

# %%
ResNet50V2 = tf.keras.applications.ResNet50V2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels.h5
# 102875136/102869336 [==============================] - 10s 0us/step
# 102883328/102869336 [==============================] - 10s 0us/step

# %%
model_analyze(ResNet50V2)
# Out:
# Layers 0(-192): input_5
# Layers 1(-191): conv1_pad
# Layers 2(-190): conv1_conv
# Layers 3(-189): pool1_pad
# Layers 4(-188): pool1_pool
# Layers 5(-187): conv2_block1_preact_bn
# Layers 6(-186): conv2_block1_preact_relu
# Layers 7(-185): conv2_block1_1_conv
# Layers 8(-184): conv2_block1_1_bn
# Layers 9(-183): conv2_block1_1_relu
# Layers 10(-182): conv2_block1_2_pad
# Layers 11(-181): conv2_block1_2_conv
# Layers 12(-180): conv2_block1_2_bn
# Layers 13(-179): conv2_block1_2_relu
# Layers 14(-178): conv2_block1_0_conv
# Layers 15(-177): conv2_block1_3_conv
# Layers 16(-176): conv2_block1_out
# Layers 17(-175): conv2_block2_preact_bn
# Layers 18(-174): conv2_block2_preact_relu
# Layers 19(-173): conv2_block2_1_conv
# Layers 20(-172): conv2_block2_1_bn
# Layers 21(-171): conv2_block2_1_relu
# Layers 22(-170): conv2_block2_2_pad
# Layers 23(-169): conv2_block2_2_conv
# Layers 24(-168): conv2_block2_2_bn
# Layers 25(-167): conv2_block2_2_relu
# Layers 26(-166): conv2_block2_3_conv
# Layers 27(-165): conv2_block2_out
# Layers 28(-164): conv2_block3_preact_bn
# Layers 29(-163): conv2_block3_preact_relu
# Layers 30(-162): conv2_block3_1_conv
# Layers 31(-161): conv2_block3_1_bn
# Layers 32(-160): conv2_block3_1_relu
# Layers 33(-159): conv2_block3_2_pad
# Layers 34(-158): conv2_block3_2_conv
# Layers 35(-157): conv2_block3_2_bn
# Layers 36(-156): conv2_block3_2_relu
# Layers 37(-155): max_pooling2d
# Layers 38(-154): conv2_block3_3_conv
# Layers 39(-153): conv2_block3_out
# Layers 40(-152): conv3_block1_preact_bn
# Layers 41(-151): conv3_block1_preact_relu
# Layers 42(-150): conv3_block1_1_conv
# Layers 43(-149): conv3_block1_1_bn
# Layers 44(-148): conv3_block1_1_relu
# Layers 45(-147): conv3_block1_2_pad
# Layers 46(-146): conv3_block1_2_conv
# Layers 47(-145): conv3_block1_2_bn
# Layers 48(-144): conv3_block1_2_relu
# Layers 49(-143): conv3_block1_0_conv
# Layers 50(-142): conv3_block1_3_conv
# Layers 51(-141): conv3_block1_out
# Layers 52(-140): conv3_block2_preact_bn
# Layers 53(-139): conv3_block2_preact_relu
# Layers 54(-138): conv3_block2_1_conv
# Layers 55(-137): conv3_block2_1_bn
# Layers 56(-136): conv3_block2_1_relu
# Layers 57(-135): conv3_block2_2_pad
# Layers 58(-134): conv3_block2_2_conv
# Layers 59(-133): conv3_block2_2_bn
# Layers 60(-132): conv3_block2_2_relu
# Layers 61(-131): conv3_block2_3_conv
# Layers 62(-130): conv3_block2_out
# Layers 63(-129): conv3_block3_preact_bn
# Layers 64(-128): conv3_block3_preact_relu
# Layers 65(-127): conv3_block3_1_conv
# Layers 66(-126): conv3_block3_1_bn
# Layers 67(-125): conv3_block3_1_relu
# Layers 68(-124): conv3_block3_2_pad
# Layers 69(-123): conv3_block3_2_conv
# Layers 70(-122): conv3_block3_2_bn
# Layers 71(-121): conv3_block3_2_relu
# Layers 72(-120): conv3_block3_3_conv
# Layers 73(-119): conv3_block3_out
# Layers 74(-118): conv3_block4_preact_bn
# Layers 75(-117): conv3_block4_preact_relu
# Layers 76(-116): conv3_block4_1_conv
# Layers 77(-115): conv3_block4_1_bn
# Layers 78(-114): conv3_block4_1_relu
# Layers 79(-113): conv3_block4_2_pad
# Layers 80(-112): conv3_block4_2_conv
# Layers 81(-111): conv3_block4_2_bn
# Layers 82(-110): conv3_block4_2_relu
# Layers 83(-109): max_pooling2d_1
# Layers 84(-108): conv3_block4_3_conv
# Layers 85(-107): conv3_block4_out
# Layers 86(-106): conv4_block1_preact_bn
# Layers 87(-105): conv4_block1_preact_relu
# Layers 88(-104): conv4_block1_1_conv
# Layers 89(-103): conv4_block1_1_bn
# Layers 90(-102): conv4_block1_1_relu
# Layers 91(-101): conv4_block1_2_pad
# Layers 92(-100): conv4_block1_2_conv
# Layers 93(-99): conv4_block1_2_bn
# Layers 94(-98): conv4_block1_2_relu
# Layers 95(-97): conv4_block1_0_conv
# Layers 96(-96): conv4_block1_3_conv
# Layers 97(-95): conv4_block1_out
# Layers 98(-94): conv4_block2_preact_bn
# Layers 99(-93): conv4_block2_preact_relu
# Layers 100(-92): conv4_block2_1_conv
# Layers 101(-91): conv4_block2_1_bn
# Layers 102(-90): conv4_block2_1_relu
# Layers 103(-89): conv4_block2_2_pad
# Layers 104(-88): conv4_block2_2_conv
# Layers 105(-87): conv4_block2_2_bn
# Layers 106(-86): conv4_block2_2_relu
# Layers 107(-85): conv4_block2_3_conv
# Layers 108(-84): conv4_block2_out
# Layers 109(-83): conv4_block3_preact_bn
# Layers 110(-82): conv4_block3_preact_relu
# Layers 111(-81): conv4_block3_1_conv
# Layers 112(-80): conv4_block3_1_bn
# Layers 113(-79): conv4_block3_1_relu
# Layers 114(-78): conv4_block3_2_pad
# Layers 115(-77): conv4_block3_2_conv
# Layers 116(-76): conv4_block3_2_bn
# Layers 117(-75): conv4_block3_2_relu
# Layers 118(-74): conv4_block3_3_conv
# Layers 119(-73): conv4_block3_out
# Layers 120(-72): conv4_block4_preact_bn
# Layers 121(-71): conv4_block4_preact_relu
# Layers 122(-70): conv4_block4_1_conv
# Layers 123(-69): conv4_block4_1_bn
# Layers 124(-68): conv4_block4_1_relu
# Layers 125(-67): conv4_block4_2_pad
# Layers 126(-66): conv4_block4_2_conv
# Layers 127(-65): conv4_block4_2_bn
# Layers 128(-64): conv4_block4_2_relu
# Layers 129(-63): conv4_block4_3_conv
# Layers 130(-62): conv4_block4_out
# Layers 131(-61): conv4_block5_preact_bn
# Layers 132(-60): conv4_block5_preact_relu
# Layers 133(-59): conv4_block5_1_conv
# Layers 134(-58): conv4_block5_1_bn
# Layers 135(-57): conv4_block5_1_relu
# Layers 136(-56): conv4_block5_2_pad
# Layers 137(-55): conv4_block5_2_conv
# Layers 138(-54): conv4_block5_2_bn
# Layers 139(-53): conv4_block5_2_relu
# Layers 140(-52): conv4_block5_3_conv
# Layers 141(-51): conv4_block5_out
# Layers 142(-50): conv4_block6_preact_bn
# Layers 143(-49): conv4_block6_preact_relu
# Layers 144(-48): conv4_block6_1_conv
# Layers 145(-47): conv4_block6_1_bn
# Layers 146(-46): conv4_block6_1_relu
# Layers 147(-45): conv4_block6_2_pad
# Layers 148(-44): conv4_block6_2_conv
# Layers 149(-43): conv4_block6_2_bn
# Layers 150(-42): conv4_block6_2_relu
# Layers 151(-41): max_pooling2d_2
# Layers 152(-40): conv4_block6_3_conv
# Layers 153(-39): conv4_block6_out
# Layers 154(-38): conv5_block1_preact_bn
# Layers 155(-37): conv5_block1_preact_relu
# Layers 156(-36): conv5_block1_1_conv
# Layers 157(-35): conv5_block1_1_bn
# Layers 158(-34): conv5_block1_1_relu
# Layers 159(-33): conv5_block1_2_pad
# Layers 160(-32): conv5_block1_2_conv
# Layers 161(-31): conv5_block1_2_bn
# Layers 162(-30): conv5_block1_2_relu
# Layers 163(-29): conv5_block1_0_conv
# Layers 164(-28): conv5_block1_3_conv
# Layers 165(-27): conv5_block1_out
# Layers 166(-26): conv5_block2_preact_bn
# Layers 167(-25): conv5_block2_preact_relu
# Layers 168(-24): conv5_block2_1_conv
# Layers 169(-23): conv5_block2_1_bn
# Layers 170(-22): conv5_block2_1_relu
# Layers 171(-21): conv5_block2_2_pad
# Layers 172(-20): conv5_block2_2_conv
# Layers 173(-19): conv5_block2_2_bn
# Layers 174(-18): conv5_block2_2_relu
# Layers 175(-17): conv5_block2_3_conv
# Layers 176(-16): conv5_block2_out
# Layers 177(-15): conv5_block3_preact_bn
# Layers 178(-14): conv5_block3_preact_relu
# Layers 179(-13): conv5_block3_1_conv
# Layers 180(-12): conv5_block3_1_bn
# Layers 181(-11): conv5_block3_1_relu
# Layers 182(-10): conv5_block3_2_pad
# Layers 183(-9): conv5_block3_2_conv
# Layers 184(-8): conv5_block3_2_bn
# Layers 185(-7): conv5_block3_2_relu
# Layers 186(-6): conv5_block3_3_conv
# Layers 187(-5): conv5_block3_out
# Layers 188(-4): post_bn
# Layers 189(-3): post_relu
# Layers 190(-2): avg_pool
# Layers 191(-1): predictions

# %%
ResNet50V2.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_5[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,613,800
# Trainable params: 25,568,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %% [markdown]
# # ResNet101

# %%
ResNet101 = tf.keras.applications.ResNet101(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels.h5
# 179650560/179648224 [==============================] - 18s 0us/step
# 179658752/179648224 [==============================] - 18s 0us/step

# %%
model_analyze(ResNet101)
# Out:
# Layers 0(-347): input_6
# Layers 1(-346): conv1_pad
# Layers 2(-345): conv1_conv
# Layers 3(-344): conv1_bn
# Layers 4(-343): conv1_relu
# Layers 5(-342): pool1_pad
# Layers 6(-341): pool1_pool
# Layers 7(-340): conv2_block1_1_conv
# Layers 8(-339): conv2_block1_1_bn
# Layers 9(-338): conv2_block1_1_relu
# Layers 10(-337): conv2_block1_2_conv
# Layers 11(-336): conv2_block1_2_bn
# Layers 12(-335): conv2_block1_2_relu
# Layers 13(-334): conv2_block1_0_conv
# Layers 14(-333): conv2_block1_3_conv
# Layers 15(-332): conv2_block1_0_bn
# Layers 16(-331): conv2_block1_3_bn
# Layers 17(-330): conv2_block1_add
# Layers 18(-329): conv2_block1_out
# Layers 19(-328): conv2_block2_1_conv
# Layers 20(-327): conv2_block2_1_bn
# Layers 21(-326): conv2_block2_1_relu
# Layers 22(-325): conv2_block2_2_conv
# Layers 23(-324): conv2_block2_2_bn
# Layers 24(-323): conv2_block2_2_relu
# Layers 25(-322): conv2_block2_3_conv
# Layers 26(-321): conv2_block2_3_bn
# Layers 27(-320): conv2_block2_add
# Layers 28(-319): conv2_block2_out
# Layers 29(-318): conv2_block3_1_conv
# Layers 30(-317): conv2_block3_1_bn
# Layers 31(-316): conv2_block3_1_relu
# Layers 32(-315): conv2_block3_2_conv
# Layers 33(-314): conv2_block3_2_bn
# Layers 34(-313): conv2_block3_2_relu
# Layers 35(-312): conv2_block3_3_conv
# Layers 36(-311): conv2_block3_3_bn
# Layers 37(-310): conv2_block3_add
# Layers 38(-309): conv2_block3_out
# Layers 39(-308): conv3_block1_1_conv
# Layers 40(-307): conv3_block1_1_bn
# Layers 41(-306): conv3_block1_1_relu
# Layers 42(-305): conv3_block1_2_conv
# Layers 43(-304): conv3_block1_2_bn
# Layers 44(-303): conv3_block1_2_relu
# Layers 45(-302): conv3_block1_0_conv
# Layers 46(-301): conv3_block1_3_conv
# Layers 47(-300): conv3_block1_0_bn
# Layers 48(-299): conv3_block1_3_bn
# Layers 49(-298): conv3_block1_add
# Layers 50(-297): conv3_block1_out
# Layers 51(-296): conv3_block2_1_conv
# Layers 52(-295): conv3_block2_1_bn
# Layers 53(-294): conv3_block2_1_relu
# Layers 54(-293): conv3_block2_2_conv
# Layers 55(-292): conv3_block2_2_bn
# Layers 56(-291): conv3_block2_2_relu
# Layers 57(-290): conv3_block2_3_conv
# Layers 58(-289): conv3_block2_3_bn
# Layers 59(-288): conv3_block2_add
# Layers 60(-287): conv3_block2_out
# Layers 61(-286): conv3_block3_1_conv
# Layers 62(-285): conv3_block3_1_bn
# Layers 63(-284): conv3_block3_1_relu
# Layers 64(-283): conv3_block3_2_conv
# Layers 65(-282): conv3_block3_2_bn
# Layers 66(-281): conv3_block3_2_relu
# Layers 67(-280): conv3_block3_3_conv
# Layers 68(-279): conv3_block3_3_bn
# Layers 69(-278): conv3_block3_add
# Layers 70(-277): conv3_block3_out
# Layers 71(-276): conv3_block4_1_conv
# Layers 72(-275): conv3_block4_1_bn
# Layers 73(-274): conv3_block4_1_relu
# Layers 74(-273): conv3_block4_2_conv
# Layers 75(-272): conv3_block4_2_bn
# Layers 76(-271): conv3_block4_2_relu
# Layers 77(-270): conv3_block4_3_conv
# Layers 78(-269): conv3_block4_3_bn
# Layers 79(-268): conv3_block4_add
# Layers 80(-267): conv3_block4_out
# Layers 81(-266): conv4_block1_1_conv
# Layers 82(-265): conv4_block1_1_bn
# Layers 83(-264): conv4_block1_1_relu
# Layers 84(-263): conv4_block1_2_conv
# Layers 85(-262): conv4_block1_2_bn
# Layers 86(-261): conv4_block1_2_relu
# Layers 87(-260): conv4_block1_0_conv
# Layers 88(-259): conv4_block1_3_conv
# Layers 89(-258): conv4_block1_0_bn
# Layers 90(-257): conv4_block1_3_bn
# Layers 91(-256): conv4_block1_add
# Layers 92(-255): conv4_block1_out
# Layers 93(-254): conv4_block2_1_conv
# Layers 94(-253): conv4_block2_1_bn
# Layers 95(-252): conv4_block2_1_relu
# Layers 96(-251): conv4_block2_2_conv
# Layers 97(-250): conv4_block2_2_bn
# Layers 98(-249): conv4_block2_2_relu
# Layers 99(-248): conv4_block2_3_conv
# Layers 100(-247): conv4_block2_3_bn
# Layers 101(-246): conv4_block2_add
# Layers 102(-245): conv4_block2_out
# Layers 103(-244): conv4_block3_1_conv
# Layers 104(-243): conv4_block3_1_bn
# Layers 105(-242): conv4_block3_1_relu
# Layers 106(-241): conv4_block3_2_conv
# Layers 107(-240): conv4_block3_2_bn
# Layers 108(-239): conv4_block3_2_relu
# Layers 109(-238): conv4_block3_3_conv
# Layers 110(-237): conv4_block3_3_bn
# Layers 111(-236): conv4_block3_add
# Layers 112(-235): conv4_block3_out
# Layers 113(-234): conv4_block4_1_conv
# Layers 114(-233): conv4_block4_1_bn
# Layers 115(-232): conv4_block4_1_relu
# Layers 116(-231): conv4_block4_2_conv
# Layers 117(-230): conv4_block4_2_bn
# Layers 118(-229): conv4_block4_2_relu
# Layers 119(-228): conv4_block4_3_conv
# Layers 120(-227): conv4_block4_3_bn
# Layers 121(-226): conv4_block4_add
# Layers 122(-225): conv4_block4_out
# Layers 123(-224): conv4_block5_1_conv
# Layers 124(-223): conv4_block5_1_bn
# Layers 125(-222): conv4_block5_1_relu
# Layers 126(-221): conv4_block5_2_conv
# Layers 127(-220): conv4_block5_2_bn
# Layers 128(-219): conv4_block5_2_relu
# Layers 129(-218): conv4_block5_3_conv
# Layers 130(-217): conv4_block5_3_bn
# Layers 131(-216): conv4_block5_add
# Layers 132(-215): conv4_block5_out
# Layers 133(-214): conv4_block6_1_conv
# Layers 134(-213): conv4_block6_1_bn
# Layers 135(-212): conv4_block6_1_relu
# Layers 136(-211): conv4_block6_2_conv
# Layers 137(-210): conv4_block6_2_bn
# Layers 138(-209): conv4_block6_2_relu
# Layers 139(-208): conv4_block6_3_conv
# Layers 140(-207): conv4_block6_3_bn
# Layers 141(-206): conv4_block6_add
# Layers 142(-205): conv4_block6_out
# Layers 143(-204): conv4_block7_1_conv
# Layers 144(-203): conv4_block7_1_bn
# Layers 145(-202): conv4_block7_1_relu
# Layers 146(-201): conv4_block7_2_conv
# Layers 147(-200): conv4_block7_2_bn
# Layers 148(-199): conv4_block7_2_relu
# Layers 149(-198): conv4_block7_3_conv
# Layers 150(-197): conv4_block7_3_bn
# Layers 151(-196): conv4_block7_add
# Layers 152(-195): conv4_block7_out
# Layers 153(-194): conv4_block8_1_conv
# Layers 154(-193): conv4_block8_1_bn
# Layers 155(-192): conv4_block8_1_relu
# Layers 156(-191): conv4_block8_2_conv
# Layers 157(-190): conv4_block8_2_bn
# Layers 158(-189): conv4_block8_2_relu
# Layers 159(-188): conv4_block8_3_conv
# Layers 160(-187): conv4_block8_3_bn
# Layers 161(-186): conv4_block8_add
# Layers 162(-185): conv4_block8_out
# Layers 163(-184): conv4_block9_1_conv
# Layers 164(-183): conv4_block9_1_bn
# Layers 165(-182): conv4_block9_1_relu
# Layers 166(-181): conv4_block9_2_conv
# Layers 167(-180): conv4_block9_2_bn
# Layers 168(-179): conv4_block9_2_relu
# Layers 169(-178): conv4_block9_3_conv
# Layers 170(-177): conv4_block9_3_bn
# Layers 171(-176): conv4_block9_add
# Layers 172(-175): conv4_block9_out
# Layers 173(-174): conv4_block10_1_conv
# Layers 174(-173): conv4_block10_1_bn
# Layers 175(-172): conv4_block10_1_relu
# Layers 176(-171): conv4_block10_2_conv
# Layers 177(-170): conv4_block10_2_bn
# Layers 178(-169): conv4_block10_2_relu
# Layers 179(-168): conv4_block10_3_conv
# Layers 180(-167): conv4_block10_3_bn
# Layers 181(-166): conv4_block10_add
# Layers 182(-165): conv4_block10_out
# Layers 183(-164): conv4_block11_1_conv
# Layers 184(-163): conv4_block11_1_bn
# Layers 185(-162): conv4_block11_1_relu
# Layers 186(-161): conv4_block11_2_conv
# Layers 187(-160): conv4_block11_2_bn
# Layers 188(-159): conv4_block11_2_relu
# Layers 189(-158): conv4_block11_3_conv
# Layers 190(-157): conv4_block11_3_bn
# Layers 191(-156): conv4_block11_add
# Layers 192(-155): conv4_block11_out
# Layers 193(-154): conv4_block12_1_conv
# Layers 194(-153): conv4_block12_1_bn
# Layers 195(-152): conv4_block12_1_relu
# Layers 196(-151): conv4_block12_2_conv
# Layers 197(-150): conv4_block12_2_bn
# Layers 198(-149): conv4_block12_2_relu
# Layers 199(-148): conv4_block12_3_conv
# Layers 200(-147): conv4_block12_3_bn
# Layers 201(-146): conv4_block12_add
# Layers 202(-145): conv4_block12_out
# Layers 203(-144): conv4_block13_1_conv
# Layers 204(-143): conv4_block13_1_bn
# Layers 205(-142): conv4_block13_1_relu
# Layers 206(-141): conv4_block13_2_conv
# Layers 207(-140): conv4_block13_2_bn
# Layers 208(-139): conv4_block13_2_relu
# Layers 209(-138): conv4_block13_3_conv
# Layers 210(-137): conv4_block13_3_bn
# Layers 211(-136): conv4_block13_add
# Layers 212(-135): conv4_block13_out
# Layers 213(-134): conv4_block14_1_conv
# Layers 214(-133): conv4_block14_1_bn
# Layers 215(-132): conv4_block14_1_relu
# Layers 216(-131): conv4_block14_2_conv
# Layers 217(-130): conv4_block14_2_bn
# Layers 218(-129): conv4_block14_2_relu
# Layers 219(-128): conv4_block14_3_conv
# Layers 220(-127): conv4_block14_3_bn
# Layers 221(-126): conv4_block14_add
# Layers 222(-125): conv4_block14_out
# Layers 223(-124): conv4_block15_1_conv
# Layers 224(-123): conv4_block15_1_bn
# Layers 225(-122): conv4_block15_1_relu
# Layers 226(-121): conv4_block15_2_conv
# Layers 227(-120): conv4_block15_2_bn
# Layers 228(-119): conv4_block15_2_relu
# Layers 229(-118): conv4_block15_3_conv
# Layers 230(-117): conv4_block15_3_bn
# Layers 231(-116): conv4_block15_add
# Layers 232(-115): conv4_block15_out
# Layers 233(-114): conv4_block16_1_conv
# Layers 234(-113): conv4_block16_1_bn
# Layers 235(-112): conv4_block16_1_relu
# Layers 236(-111): conv4_block16_2_conv
# Layers 237(-110): conv4_block16_2_bn
# Layers 238(-109): conv4_block16_2_relu
# Layers 239(-108): conv4_block16_3_conv
# Layers 240(-107): conv4_block16_3_bn
# Layers 241(-106): conv4_block16_add
# Layers 242(-105): conv4_block16_out
# Layers 243(-104): conv4_block17_1_conv
# Layers 244(-103): conv4_block17_1_bn
# Layers 245(-102): conv4_block17_1_relu
# Layers 246(-101): conv4_block17_2_conv
# Layers 247(-100): conv4_block17_2_bn
# Layers 248(-99): conv4_block17_2_relu
# Layers 249(-98): conv4_block17_3_conv
# Layers 250(-97): conv4_block17_3_bn
# Layers 251(-96): conv4_block17_add
# Layers 252(-95): conv4_block17_out
# Layers 253(-94): conv4_block18_1_conv
# Layers 254(-93): conv4_block18_1_bn
# Layers 255(-92): conv4_block18_1_relu
# Layers 256(-91): conv4_block18_2_conv
# Layers 257(-90): conv4_block18_2_bn
# Layers 258(-89): conv4_block18_2_relu
# Layers 259(-88): conv4_block18_3_conv
# Layers 260(-87): conv4_block18_3_bn
# Layers 261(-86): conv4_block18_add
# Layers 262(-85): conv4_block18_out
# Layers 263(-84): conv4_block19_1_conv
# Layers 264(-83): conv4_block19_1_bn
# Layers 265(-82): conv4_block19_1_relu
# Layers 266(-81): conv4_block19_2_conv
# Layers 267(-80): conv4_block19_2_bn
# Layers 268(-79): conv4_block19_2_relu
# Layers 269(-78): conv4_block19_3_conv
# Layers 270(-77): conv4_block19_3_bn
# Layers 271(-76): conv4_block19_add
# Layers 272(-75): conv4_block19_out
# Layers 273(-74): conv4_block20_1_conv
# Layers 274(-73): conv4_block20_1_bn
# Layers 275(-72): conv4_block20_1_relu
# Layers 276(-71): conv4_block20_2_conv
# Layers 277(-70): conv4_block20_2_bn
# Layers 278(-69): conv4_block20_2_relu
# Layers 279(-68): conv4_block20_3_conv
# Layers 280(-67): conv4_block20_3_bn
# Layers 281(-66): conv4_block20_add
# Layers 282(-65): conv4_block20_out
# Layers 283(-64): conv4_block21_1_conv
# Layers 284(-63): conv4_block21_1_bn
# Layers 285(-62): conv4_block21_1_relu
# Layers 286(-61): conv4_block21_2_conv
# Layers 287(-60): conv4_block21_2_bn
# Layers 288(-59): conv4_block21_2_relu
# Layers 289(-58): conv4_block21_3_conv
# Layers 290(-57): conv4_block21_3_bn
# Layers 291(-56): conv4_block21_add
# Layers 292(-55): conv4_block21_out
# Layers 293(-54): conv4_block22_1_conv
# Layers 294(-53): conv4_block22_1_bn
# Layers 295(-52): conv4_block22_1_relu
# Layers 296(-51): conv4_block22_2_conv
# Layers 297(-50): conv4_block22_2_bn
# Layers 298(-49): conv4_block22_2_relu
# Layers 299(-48): conv4_block22_3_conv
# Layers 300(-47): conv4_block22_3_bn
# Layers 301(-46): conv4_block22_add
# Layers 302(-45): conv4_block22_out
# Layers 303(-44): conv4_block23_1_conv
# Layers 304(-43): conv4_block23_1_bn
# Layers 305(-42): conv4_block23_1_relu
# Layers 306(-41): conv4_block23_2_conv
# Layers 307(-40): conv4_block23_2_bn
# Layers 308(-39): conv4_block23_2_relu
# Layers 309(-38): conv4_block23_3_conv
# Layers 310(-37): conv4_block23_3_bn
# Layers 311(-36): conv4_block23_add
# Layers 312(-35): conv4_block23_out
# Layers 313(-34): conv5_block1_1_conv
# Layers 314(-33): conv5_block1_1_bn
# Layers 315(-32): conv5_block1_1_relu
# Layers 316(-31): conv5_block1_2_conv
# Layers 317(-30): conv5_block1_2_bn
# Layers 318(-29): conv5_block1_2_relu
# Layers 319(-28): conv5_block1_0_conv
# Layers 320(-27): conv5_block1_3_conv
# Layers 321(-26): conv5_block1_0_bn
# Layers 322(-25): conv5_block1_3_bn
# Layers 323(-24): conv5_block1_add
# Layers 324(-23): conv5_block1_out
# Layers 325(-22): conv5_block2_1_conv
# Layers 326(-21): conv5_block2_1_bn
# Layers 327(-20): conv5_block2_1_relu
# Layers 328(-19): conv5_block2_2_conv
# Layers 329(-18): conv5_block2_2_bn
# Layers 330(-17): conv5_block2_2_relu
# Layers 331(-16): conv5_block2_3_conv
# Layers 332(-15): conv5_block2_3_bn
# Layers 333(-14): conv5_block2_add
# Layers 334(-13): conv5_block2_out
# Layers 335(-12): conv5_block3_1_conv
# Layers 336(-11): conv5_block3_1_bn
# Layers 337(-10): conv5_block3_1_relu
# Layers 338(-9): conv5_block3_2_conv
# Layers 339(-8): conv5_block3_2_bn
# Layers 340(-7): conv5_block3_2_relu
# Layers 341(-6): conv5_block3_3_conv
# Layers 342(-5): conv5_block3_3_bn
# Layers 343(-4): conv5_block3_add
# Layers 344(-3): conv5_block3_out
# Layers 345(-2): avg_pool
# Layers 346(-1): predictions

# %%
ResNet101.summary()
# Out:
# Model: "resnet101"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_6[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv4_block7_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block6_out[0][0]']
#
#  conv4_block7_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block7_1_conv[0][0]']
#  ization)
#
#  conv4_block7_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block7_1_bn[0][0]']
#  n)
#
#  conv4_block7_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block7_1_relu[0][0]']
#
#  conv4_block7_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block7_2_conv[0][0]']
#  ization)
#
#  conv4_block7_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block7_2_bn[0][0]']
#  n)
#
#  conv4_block7_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block7_2_relu[0][0]']
#                                 )
#
#  conv4_block7_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block7_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block7_add (Add)         (None, 14, 14, 1024  0           ['conv4_block6_out[0][0]',
#                                 )                                 'conv4_block7_3_bn[0][0]']
#
#  conv4_block7_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block7_add[0][0]']
#                                 )
#
#  conv4_block8_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block7_out[0][0]']
#
#  conv4_block8_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block8_1_conv[0][0]']
#  ization)
#
#  conv4_block8_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block8_1_bn[0][0]']
#  n)
#
#  conv4_block8_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block8_1_relu[0][0]']
#
#  conv4_block8_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block8_2_conv[0][0]']
#  ization)
#
#  conv4_block8_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block8_2_bn[0][0]']
#  n)
#
#  conv4_block8_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block8_2_relu[0][0]']
#                                 )
#
#  conv4_block8_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block8_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block8_add (Add)         (None, 14, 14, 1024  0           ['conv4_block7_out[0][0]',
#                                 )                                 'conv4_block8_3_bn[0][0]']
#
#  conv4_block8_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block8_add[0][0]']
#                                 )
#
#  conv4_block9_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block8_out[0][0]']
#
#  conv4_block9_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block9_1_conv[0][0]']
#  ization)
#
#  conv4_block9_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block9_1_bn[0][0]']
#  n)
#
#  conv4_block9_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block9_1_relu[0][0]']
#
#  conv4_block9_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block9_2_conv[0][0]']
#  ization)
#
#  conv4_block9_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block9_2_bn[0][0]']
#  n)
#
#  conv4_block9_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block9_2_relu[0][0]']
#                                 )
#
#  conv4_block9_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block9_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block9_add (Add)         (None, 14, 14, 1024  0           ['conv4_block8_out[0][0]',
#                                 )                                 'conv4_block9_3_bn[0][0]']
#
#  conv4_block9_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block9_add[0][0]']
#                                 )
#
#  conv4_block10_1_conv (Conv2D)  (None, 14, 14, 256)  262400      ['conv4_block9_out[0][0]']
#
#  conv4_block10_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block10_1_conv[0][0]']
#  lization)
#
#  conv4_block10_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block10_1_bn[0][0]']
#  on)
#
#  conv4_block10_2_conv (Conv2D)  (None, 14, 14, 256)  590080      ['conv4_block10_1_relu[0][0]']
#
#  conv4_block10_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block10_2_conv[0][0]']
#  lization)
#
#  conv4_block10_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block10_2_bn[0][0]']
#  on)
#
# ...
#  lization)
#
#  conv4_block21_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block21_2_bn[0][0]']
#  on)
#
#  conv4_block21_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block21_2_relu[0][0]']
#                                 )
#
#  conv4_block21_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['conv4_block21_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block21_add (Add)        (None, 14, 14, 1024  0           ['conv4_block20_out[0][0]',
#                                 )                                 'conv4_block21_3_bn[0][0]']
#
#  conv4_block21_out (Activation)  (None, 14, 14, 1024  0          ['conv4_block21_add[0][0]']
#                                 )
#
#  conv4_block22_1_conv (Conv2D)  (None, 14, 14, 256)  262400      ['conv4_block21_out[0][0]']
#
#  conv4_block22_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block22_1_conv[0][0]']
#  lization)
#
#  conv4_block22_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_conv (Conv2D)  (None, 14, 14, 256)  590080      ['conv4_block22_1_relu[0][0]']
#
#  conv4_block22_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block22_2_conv[0][0]']
#  lization)
#
#  conv4_block22_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block22_2_bn[0][0]']
#  on)
#
#  conv4_block22_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block22_2_relu[0][0]']
#                                 )
#
#  conv4_block22_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['conv4_block22_3_conv[0][0]']
#  lization)                      )
#  conv4_block22_add (Add)        (None, 14, 14, 1024  0           ['conv4_block21_out[0][0]',
#                                 )                                 'conv4_block22_3_bn[0][0]']
#
#  conv4_block22_out (Activation)  (None, 14, 14, 1024  0          ['conv4_block22_add[0][0]']
#                                 )
#
#  conv4_block23_1_conv (Conv2D)  (None, 14, 14, 256)  262400      ['conv4_block22_out[0][0]']
#
#  conv4_block23_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_conv (Conv2D)  (None, 14, 14, 256)  590080      ['conv4_block23_1_relu[0][0]']
#
#  conv4_block23_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block23_2_conv[0][0]']
#  lization)
#
#  conv4_block23_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block23_2_bn[0][0]']
#  on)
#
#  conv4_block23_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block23_2_relu[0][0]']
#                                 )
#
#  conv4_block23_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['conv4_block23_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block23_add (Add)        (None, 14, 14, 1024  0           ['conv4_block22_out[0][0]',
#                                 )                                 'conv4_block23_3_bn[0][0]']
#
#  conv4_block23_out (Activation)  (None, 14, 14, 1024  0          ['conv4_block23_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block23_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block23_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 44,707,176
# Trainable params: 44,601,832
# Non-trainable params: 105,344
# __________________________________________________________________________________________________

# %% [markdown]
# # ResNet101V2

# %%
ResNet101V2 = tf.keras.applications.ResNet101V2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels.h5
# 179519488/179518384 [==============================] - 17s 0us/step
# 179527680/179518384 [==============================] - 17s 0us/step

# %%
model_analyze(ResNet101V2)
# Out:
# Layers 0(-379): input_7
# Layers 1(-378): conv1_pad
# Layers 2(-377): conv1_conv
# Layers 3(-376): pool1_pad
# Layers 4(-375): pool1_pool
# Layers 5(-374): conv2_block1_preact_bn
# Layers 6(-373): conv2_block1_preact_relu
# Layers 7(-372): conv2_block1_1_conv
# Layers 8(-371): conv2_block1_1_bn
# Layers 9(-370): conv2_block1_1_relu
# Layers 10(-369): conv2_block1_2_pad
# Layers 11(-368): conv2_block1_2_conv
# Layers 12(-367): conv2_block1_2_bn
# Layers 13(-366): conv2_block1_2_relu
# Layers 14(-365): conv2_block1_0_conv
# Layers 15(-364): conv2_block1_3_conv
# Layers 16(-363): conv2_block1_out
# Layers 17(-362): conv2_block2_preact_bn
# Layers 18(-361): conv2_block2_preact_relu
# Layers 19(-360): conv2_block2_1_conv
# Layers 20(-359): conv2_block2_1_bn
# Layers 21(-358): conv2_block2_1_relu
# Layers 22(-357): conv2_block2_2_pad
# Layers 23(-356): conv2_block2_2_conv
# Layers 24(-355): conv2_block2_2_bn
# Layers 25(-354): conv2_block2_2_relu
# Layers 26(-353): conv2_block2_3_conv
# Layers 27(-352): conv2_block2_out
# Layers 28(-351): conv2_block3_preact_bn
# Layers 29(-350): conv2_block3_preact_relu
# Layers 30(-349): conv2_block3_1_conv
# Layers 31(-348): conv2_block3_1_bn
# Layers 32(-347): conv2_block3_1_relu
# Layers 33(-346): conv2_block3_2_pad
# Layers 34(-345): conv2_block3_2_conv
# Layers 35(-344): conv2_block3_2_bn
# Layers 36(-343): conv2_block3_2_relu
# Layers 37(-342): max_pooling2d_3
# Layers 38(-341): conv2_block3_3_conv
# Layers 39(-340): conv2_block3_out
# Layers 40(-339): conv3_block1_preact_bn
# Layers 41(-338): conv3_block1_preact_relu
# Layers 42(-337): conv3_block1_1_conv
# Layers 43(-336): conv3_block1_1_bn
# Layers 44(-335): conv3_block1_1_relu
# Layers 45(-334): conv3_block1_2_pad
# Layers 46(-333): conv3_block1_2_conv
# Layers 47(-332): conv3_block1_2_bn
# Layers 48(-331): conv3_block1_2_relu
# Layers 49(-330): conv3_block1_0_conv
# Layers 50(-329): conv3_block1_3_conv
# Layers 51(-328): conv3_block1_out
# Layers 52(-327): conv3_block2_preact_bn
# Layers 53(-326): conv3_block2_preact_relu
# Layers 54(-325): conv3_block2_1_conv
# Layers 55(-324): conv3_block2_1_bn
# Layers 56(-323): conv3_block2_1_relu
# Layers 57(-322): conv3_block2_2_pad
# Layers 58(-321): conv3_block2_2_conv
# Layers 59(-320): conv3_block2_2_bn
# Layers 60(-319): conv3_block2_2_relu
# Layers 61(-318): conv3_block2_3_conv
# Layers 62(-317): conv3_block2_out
# Layers 63(-316): conv3_block3_preact_bn
# Layers 64(-315): conv3_block3_preact_relu
# Layers 65(-314): conv3_block3_1_conv
# Layers 66(-313): conv3_block3_1_bn
# Layers 67(-312): conv3_block3_1_relu
# Layers 68(-311): conv3_block3_2_pad
# Layers 69(-310): conv3_block3_2_conv
# Layers 70(-309): conv3_block3_2_bn
# Layers 71(-308): conv3_block3_2_relu
# Layers 72(-307): conv3_block3_3_conv
# Layers 73(-306): conv3_block3_out
# Layers 74(-305): conv3_block4_preact_bn
# Layers 75(-304): conv3_block4_preact_relu
# Layers 76(-303): conv3_block4_1_conv
# Layers 77(-302): conv3_block4_1_bn
# Layers 78(-301): conv3_block4_1_relu
# Layers 79(-300): conv3_block4_2_pad
# Layers 80(-299): conv3_block4_2_conv
# Layers 81(-298): conv3_block4_2_bn
# Layers 82(-297): conv3_block4_2_relu
# Layers 83(-296): max_pooling2d_4
# Layers 84(-295): conv3_block4_3_conv
# Layers 85(-294): conv3_block4_out
# Layers 86(-293): conv4_block1_preact_bn
# Layers 87(-292): conv4_block1_preact_relu
# Layers 88(-291): conv4_block1_1_conv
# Layers 89(-290): conv4_block1_1_bn
# Layers 90(-289): conv4_block1_1_relu
# Layers 91(-288): conv4_block1_2_pad
# Layers 92(-287): conv4_block1_2_conv
# Layers 93(-286): conv4_block1_2_bn
# Layers 94(-285): conv4_block1_2_relu
# Layers 95(-284): conv4_block1_0_conv
# Layers 96(-283): conv4_block1_3_conv
# Layers 97(-282): conv4_block1_out
# Layers 98(-281): conv4_block2_preact_bn
# Layers 99(-280): conv4_block2_preact_relu
# Layers 100(-279): conv4_block2_1_conv
# Layers 101(-278): conv4_block2_1_bn
# Layers 102(-277): conv4_block2_1_relu
# Layers 103(-276): conv4_block2_2_pad
# Layers 104(-275): conv4_block2_2_conv
# Layers 105(-274): conv4_block2_2_bn
# Layers 106(-273): conv4_block2_2_relu
# Layers 107(-272): conv4_block2_3_conv
# Layers 108(-271): conv4_block2_out
# Layers 109(-270): conv4_block3_preact_bn
# Layers 110(-269): conv4_block3_preact_relu
# Layers 111(-268): conv4_block3_1_conv
# Layers 112(-267): conv4_block3_1_bn
# Layers 113(-266): conv4_block3_1_relu
# Layers 114(-265): conv4_block3_2_pad
# Layers 115(-264): conv4_block3_2_conv
# Layers 116(-263): conv4_block3_2_bn
# Layers 117(-262): conv4_block3_2_relu
# Layers 118(-261): conv4_block3_3_conv
# Layers 119(-260): conv4_block3_out
# Layers 120(-259): conv4_block4_preact_bn
# Layers 121(-258): conv4_block4_preact_relu
# Layers 122(-257): conv4_block4_1_conv
# Layers 123(-256): conv4_block4_1_bn
# Layers 124(-255): conv4_block4_1_relu
# Layers 125(-254): conv4_block4_2_pad
# Layers 126(-253): conv4_block4_2_conv
# Layers 127(-252): conv4_block4_2_bn
# Layers 128(-251): conv4_block4_2_relu
# Layers 129(-250): conv4_block4_3_conv
# Layers 130(-249): conv4_block4_out
# Layers 131(-248): conv4_block5_preact_bn
# Layers 132(-247): conv4_block5_preact_relu
# Layers 133(-246): conv4_block5_1_conv
# Layers 134(-245): conv4_block5_1_bn
# Layers 135(-244): conv4_block5_1_relu
# Layers 136(-243): conv4_block5_2_pad
# Layers 137(-242): conv4_block5_2_conv
# Layers 138(-241): conv4_block5_2_bn
# Layers 139(-240): conv4_block5_2_relu
# Layers 140(-239): conv4_block5_3_conv
# Layers 141(-238): conv4_block5_out
# Layers 142(-237): conv4_block6_preact_bn
# Layers 143(-236): conv4_block6_preact_relu
# Layers 144(-235): conv4_block6_1_conv
# Layers 145(-234): conv4_block6_1_bn
# Layers 146(-233): conv4_block6_1_relu
# Layers 147(-232): conv4_block6_2_pad
# Layers 148(-231): conv4_block6_2_conv
# Layers 149(-230): conv4_block6_2_bn
# Layers 150(-229): conv4_block6_2_relu
# Layers 151(-228): conv4_block6_3_conv
# Layers 152(-227): conv4_block6_out
# Layers 153(-226): conv4_block7_preact_bn
# Layers 154(-225): conv4_block7_preact_relu
# Layers 155(-224): conv4_block7_1_conv
# Layers 156(-223): conv4_block7_1_bn
# Layers 157(-222): conv4_block7_1_relu
# Layers 158(-221): conv4_block7_2_pad
# Layers 159(-220): conv4_block7_2_conv
# Layers 160(-219): conv4_block7_2_bn
# Layers 161(-218): conv4_block7_2_relu
# Layers 162(-217): conv4_block7_3_conv
# Layers 163(-216): conv4_block7_out
# Layers 164(-215): conv4_block8_preact_bn
# Layers 165(-214): conv4_block8_preact_relu
# Layers 166(-213): conv4_block8_1_conv
# Layers 167(-212): conv4_block8_1_bn
# Layers 168(-211): conv4_block8_1_relu
# Layers 169(-210): conv4_block8_2_pad
# Layers 170(-209): conv4_block8_2_conv
# Layers 171(-208): conv4_block8_2_bn
# Layers 172(-207): conv4_block8_2_relu
# Layers 173(-206): conv4_block8_3_conv
# Layers 174(-205): conv4_block8_out
# Layers 175(-204): conv4_block9_preact_bn
# Layers 176(-203): conv4_block9_preact_relu
# Layers 177(-202): conv4_block9_1_conv
# Layers 178(-201): conv4_block9_1_bn
# Layers 179(-200): conv4_block9_1_relu
# Layers 180(-199): conv4_block9_2_pad
# Layers 181(-198): conv4_block9_2_conv
# Layers 182(-197): conv4_block9_2_bn
# Layers 183(-196): conv4_block9_2_relu
# Layers 184(-195): conv4_block9_3_conv
# Layers 185(-194): conv4_block9_out
# Layers 186(-193): conv4_block10_preact_bn
# Layers 187(-192): conv4_block10_preact_relu
# Layers 188(-191): conv4_block10_1_conv
# Layers 189(-190): conv4_block10_1_bn
# Layers 190(-189): conv4_block10_1_relu
# Layers 191(-188): conv4_block10_2_pad
# Layers 192(-187): conv4_block10_2_conv
# Layers 193(-186): conv4_block10_2_bn
# Layers 194(-185): conv4_block10_2_relu
# Layers 195(-184): conv4_block10_3_conv
# Layers 196(-183): conv4_block10_out
# Layers 197(-182): conv4_block11_preact_bn
# Layers 198(-181): conv4_block11_preact_relu
# Layers 199(-180): conv4_block11_1_conv
# Layers 200(-179): conv4_block11_1_bn
# Layers 201(-178): conv4_block11_1_relu
# Layers 202(-177): conv4_block11_2_pad
# Layers 203(-176): conv4_block11_2_conv
# Layers 204(-175): conv4_block11_2_bn
# Layers 205(-174): conv4_block11_2_relu
# Layers 206(-173): conv4_block11_3_conv
# Layers 207(-172): conv4_block11_out
# Layers 208(-171): conv4_block12_preact_bn
# Layers 209(-170): conv4_block12_preact_relu
# Layers 210(-169): conv4_block12_1_conv
# Layers 211(-168): conv4_block12_1_bn
# Layers 212(-167): conv4_block12_1_relu
# Layers 213(-166): conv4_block12_2_pad
# Layers 214(-165): conv4_block12_2_conv
# Layers 215(-164): conv4_block12_2_bn
# Layers 216(-163): conv4_block12_2_relu
# Layers 217(-162): conv4_block12_3_conv
# Layers 218(-161): conv4_block12_out
# Layers 219(-160): conv4_block13_preact_bn
# Layers 220(-159): conv4_block13_preact_relu
# Layers 221(-158): conv4_block13_1_conv
# Layers 222(-157): conv4_block13_1_bn
# Layers 223(-156): conv4_block13_1_relu
# Layers 224(-155): conv4_block13_2_pad
# Layers 225(-154): conv4_block13_2_conv
# Layers 226(-153): conv4_block13_2_bn
# Layers 227(-152): conv4_block13_2_relu
# Layers 228(-151): conv4_block13_3_conv
# Layers 229(-150): conv4_block13_out
# Layers 230(-149): conv4_block14_preact_bn
# Layers 231(-148): conv4_block14_preact_relu
# Layers 232(-147): conv4_block14_1_conv
# Layers 233(-146): conv4_block14_1_bn
# Layers 234(-145): conv4_block14_1_relu
# Layers 235(-144): conv4_block14_2_pad
# Layers 236(-143): conv4_block14_2_conv
# Layers 237(-142): conv4_block14_2_bn
# Layers 238(-141): conv4_block14_2_relu
# Layers 239(-140): conv4_block14_3_conv
# Layers 240(-139): conv4_block14_out
# Layers 241(-138): conv4_block15_preact_bn
# Layers 242(-137): conv4_block15_preact_relu
# Layers 243(-136): conv4_block15_1_conv
# Layers 244(-135): conv4_block15_1_bn
# Layers 245(-134): conv4_block15_1_relu
# Layers 246(-133): conv4_block15_2_pad
# Layers 247(-132): conv4_block15_2_conv
# Layers 248(-131): conv4_block15_2_bn
# Layers 249(-130): conv4_block15_2_relu
# Layers 250(-129): conv4_block15_3_conv
# Layers 251(-128): conv4_block15_out
# Layers 252(-127): conv4_block16_preact_bn
# Layers 253(-126): conv4_block16_preact_relu
# Layers 254(-125): conv4_block16_1_conv
# Layers 255(-124): conv4_block16_1_bn
# Layers 256(-123): conv4_block16_1_relu
# Layers 257(-122): conv4_block16_2_pad
# Layers 258(-121): conv4_block16_2_conv
# Layers 259(-120): conv4_block16_2_bn
# Layers 260(-119): conv4_block16_2_relu
# Layers 261(-118): conv4_block16_3_conv
# Layers 262(-117): conv4_block16_out
# Layers 263(-116): conv4_block17_preact_bn
# Layers 264(-115): conv4_block17_preact_relu
# Layers 265(-114): conv4_block17_1_conv
# Layers 266(-113): conv4_block17_1_bn
# Layers 267(-112): conv4_block17_1_relu
# Layers 268(-111): conv4_block17_2_pad
# Layers 269(-110): conv4_block17_2_conv
# Layers 270(-109): conv4_block17_2_bn
# Layers 271(-108): conv4_block17_2_relu
# Layers 272(-107): conv4_block17_3_conv
# Layers 273(-106): conv4_block17_out
# Layers 274(-105): conv4_block18_preact_bn
# Layers 275(-104): conv4_block18_preact_relu
# Layers 276(-103): conv4_block18_1_conv
# Layers 277(-102): conv4_block18_1_bn
# Layers 278(-101): conv4_block18_1_relu
# Layers 279(-100): conv4_block18_2_pad
# Layers 280(-99): conv4_block18_2_conv
# Layers 281(-98): conv4_block18_2_bn
# Layers 282(-97): conv4_block18_2_relu
# Layers 283(-96): conv4_block18_3_conv
# Layers 284(-95): conv4_block18_out
# Layers 285(-94): conv4_block19_preact_bn
# Layers 286(-93): conv4_block19_preact_relu
# Layers 287(-92): conv4_block19_1_conv
# Layers 288(-91): conv4_block19_1_bn
# Layers 289(-90): conv4_block19_1_relu
# Layers 290(-89): conv4_block19_2_pad
# Layers 291(-88): conv4_block19_2_conv
# Layers 292(-87): conv4_block19_2_bn
# Layers 293(-86): conv4_block19_2_relu
# Layers 294(-85): conv4_block19_3_conv
# Layers 295(-84): conv4_block19_out
# Layers 296(-83): conv4_block20_preact_bn
# Layers 297(-82): conv4_block20_preact_relu
# Layers 298(-81): conv4_block20_1_conv
# Layers 299(-80): conv4_block20_1_bn
# Layers 300(-79): conv4_block20_1_relu
# Layers 301(-78): conv4_block20_2_pad
# Layers 302(-77): conv4_block20_2_conv
# Layers 303(-76): conv4_block20_2_bn
# Layers 304(-75): conv4_block20_2_relu
# Layers 305(-74): conv4_block20_3_conv
# Layers 306(-73): conv4_block20_out
# Layers 307(-72): conv4_block21_preact_bn
# Layers 308(-71): conv4_block21_preact_relu
# Layers 309(-70): conv4_block21_1_conv
# Layers 310(-69): conv4_block21_1_bn
# Layers 311(-68): conv4_block21_1_relu
# Layers 312(-67): conv4_block21_2_pad
# Layers 313(-66): conv4_block21_2_conv
# Layers 314(-65): conv4_block21_2_bn
# Layers 315(-64): conv4_block21_2_relu
# Layers 316(-63): conv4_block21_3_conv
# Layers 317(-62): conv4_block21_out
# Layers 318(-61): conv4_block22_preact_bn
# Layers 319(-60): conv4_block22_preact_relu
# Layers 320(-59): conv4_block22_1_conv
# Layers 321(-58): conv4_block22_1_bn
# Layers 322(-57): conv4_block22_1_relu
# Layers 323(-56): conv4_block22_2_pad
# Layers 324(-55): conv4_block22_2_conv
# Layers 325(-54): conv4_block22_2_bn
# Layers 326(-53): conv4_block22_2_relu
# Layers 327(-52): conv4_block22_3_conv
# Layers 328(-51): conv4_block22_out
# Layers 329(-50): conv4_block23_preact_bn
# Layers 330(-49): conv4_block23_preact_relu
# Layers 331(-48): conv4_block23_1_conv
# Layers 332(-47): conv4_block23_1_bn
# Layers 333(-46): conv4_block23_1_relu
# Layers 334(-45): conv4_block23_2_pad
# Layers 335(-44): conv4_block23_2_conv
# Layers 336(-43): conv4_block23_2_bn
# Layers 337(-42): conv4_block23_2_relu
# Layers 338(-41): max_pooling2d_5
# Layers 339(-40): conv4_block23_3_conv
# Layers 340(-39): conv4_block23_out
# Layers 341(-38): conv5_block1_preact_bn
# Layers 342(-37): conv5_block1_preact_relu
# Layers 343(-36): conv5_block1_1_conv
# Layers 344(-35): conv5_block1_1_bn
# Layers 345(-34): conv5_block1_1_relu
# Layers 346(-33): conv5_block1_2_pad
# Layers 347(-32): conv5_block1_2_conv
# Layers 348(-31): conv5_block1_2_bn
# Layers 349(-30): conv5_block1_2_relu
# Layers 350(-29): conv5_block1_0_conv
# Layers 351(-28): conv5_block1_3_conv
# Layers 352(-27): conv5_block1_out
# Layers 353(-26): conv5_block2_preact_bn
# Layers 354(-25): conv5_block2_preact_relu
# Layers 355(-24): conv5_block2_1_conv
# Layers 356(-23): conv5_block2_1_bn
# Layers 357(-22): conv5_block2_1_relu
# Layers 358(-21): conv5_block2_2_pad
# Layers 359(-20): conv5_block2_2_conv
# Layers 360(-19): conv5_block2_2_bn
# Layers 361(-18): conv5_block2_2_relu
# Layers 362(-17): conv5_block2_3_conv
# Layers 363(-16): conv5_block2_out
# Layers 364(-15): conv5_block3_preact_bn
# Layers 365(-14): conv5_block3_preact_relu
# Layers 366(-13): conv5_block3_1_conv
# Layers 367(-12): conv5_block3_1_bn
# Layers 368(-11): conv5_block3_1_relu
# Layers 369(-10): conv5_block3_2_pad
# Layers 370(-9): conv5_block3_2_conv
# Layers 371(-8): conv5_block3_2_bn
# Layers 372(-7): conv5_block3_2_relu
# Layers 373(-6): conv5_block3_3_conv
# Layers 374(-5): conv5_block3_out
# Layers 375(-4): post_bn
# Layers 376(-3): post_relu
# Layers 377(-2): avg_pool
# Layers 378(-1): predictions

# %%
ResNet101V2.summary()
# Out:
# Model: "resnet101v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_7[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_out (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_conv[0][0]']
#
#  conv4_block7_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block6_out[0][0]']
#  ormalization)                  )
#
#  conv4_block7_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block7_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block7_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block7_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block7_1_conv[0][0]']
#  ization)
#
#  conv4_block7_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block7_1_bn[0][0]']
#  n)
#
#  conv4_block7_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block7_1_relu[0][0]']
#  g2D)
#
#  conv4_block7_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block7_2_pad[0][0]']
#
#  conv4_block7_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block7_2_conv[0][0]']
#  ization)
#
#  conv4_block7_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block7_2_bn[0][0]']
#  n)
#
#  conv4_block7_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block7_2_relu[0][0]']
#                                 )
#
#  conv4_block7_out (Add)         (None, 14, 14, 1024  0           ['conv4_block6_out[0][0]',
#                                 )                                 'conv4_block7_3_conv[0][0]']
#
#  conv4_block8_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block7_out[0][0]']
#  ormalization)                  )
#
#  conv4_block8_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block8_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block8_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block8_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block8_1_conv[0][0]']
#  ization)
#
#  conv4_block8_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block8_1_bn[0][0]']
#  n)
#
#  conv4_block8_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block8_1_relu[0][0]']
#  g2D)
#
#  conv4_block8_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block8_2_pad[0][0]']
#
#  conv4_block8_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block8_2_conv[0][0]']
# ...
#
#  conv4_block22_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block22_1_relu[0][0]']
#  ng2D)
#
#  conv4_block22_2_conv (Conv2D)  (None, 14, 14, 256)  589824      ['conv4_block22_2_pad[0][0]']
#
#  conv4_block22_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block22_2_conv[0][0]']
#  lization)
#
#  conv4_block22_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block22_2_bn[0][0]']
#  on)
#
#  conv4_block22_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block22_2_relu[0][0]']
#                                 )
#
#  conv4_block22_out (Add)        (None, 14, 14, 1024  0           ['conv4_block21_out[0][0]',
#                                 )                                 'conv4_block22_3_conv[0][0]']
#
#  conv4_block23_preact_bn (Batch  (None, 14, 14, 1024  4096       ['conv4_block22_out[0][0]']
#  Normalization)                 )
#
#  conv4_block23_preact_relu (Act  (None, 14, 14, 1024  0          ['conv4_block23_preact_bn[0][0]']
#  ivation)                       )
#
#  conv4_block23_1_conv (Conv2D)  (None, 14, 14, 256)  262144      ['conv4_block23_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block23_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block23_1_relu[0][0]']
#  ng2D)
#
#  conv4_block23_2_conv (Conv2D)  (None, 7, 7, 256)    589824      ['conv4_block23_2_pad[0][0]']
#
#  conv4_block23_2_bn (BatchNorma  (None, 7, 7, 256)   1024        ['conv4_block23_2_conv[0][0]']
#  lization)
#
#  conv4_block23_2_relu (Activati  (None, 7, 7, 256)   0           ['conv4_block23_2_bn[0][0]']
#  on)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block22_out[0][0]']
#
#  conv4_block23_3_conv (Conv2D)  (None, 7, 7, 1024)   263168      ['conv4_block23_2_relu[0][0]']
#
#  conv4_block23_out (Add)        (None, 7, 7, 1024)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv4_block23_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block23_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 44,675,560
# Trainable params: 44,577,896
# Non-trainable params: 97,664
# __________________________________________________________________________________________________

# %% [markdown]
# # ResNet152

# %%
ResNet152 = tf.keras.applications.ResNet152(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels.h5
# 242900992/242900224 [==============================] - 31s 0us/step
# 242909184/242900224 [==============================] - 31s 0us/step

# %%
model_analyze(ResNet152)
# Out:
# Layers 0(-517): input_8
# Layers 1(-516): conv1_pad
# Layers 2(-515): conv1_conv
# Layers 3(-514): conv1_bn
# Layers 4(-513): conv1_relu
# Layers 5(-512): pool1_pad
# Layers 6(-511): pool1_pool
# Layers 7(-510): conv2_block1_1_conv
# Layers 8(-509): conv2_block1_1_bn
# Layers 9(-508): conv2_block1_1_relu
# Layers 10(-507): conv2_block1_2_conv
# Layers 11(-506): conv2_block1_2_bn
# Layers 12(-505): conv2_block1_2_relu
# Layers 13(-504): conv2_block1_0_conv
# Layers 14(-503): conv2_block1_3_conv
# Layers 15(-502): conv2_block1_0_bn
# Layers 16(-501): conv2_block1_3_bn
# Layers 17(-500): conv2_block1_add
# Layers 18(-499): conv2_block1_out
# Layers 19(-498): conv2_block2_1_conv
# Layers 20(-497): conv2_block2_1_bn
# Layers 21(-496): conv2_block2_1_relu
# Layers 22(-495): conv2_block2_2_conv
# Layers 23(-494): conv2_block2_2_bn
# Layers 24(-493): conv2_block2_2_relu
# Layers 25(-492): conv2_block2_3_conv
# Layers 26(-491): conv2_block2_3_bn
# Layers 27(-490): conv2_block2_add
# Layers 28(-489): conv2_block2_out
# Layers 29(-488): conv2_block3_1_conv
# Layers 30(-487): conv2_block3_1_bn
# Layers 31(-486): conv2_block3_1_relu
# Layers 32(-485): conv2_block3_2_conv
# Layers 33(-484): conv2_block3_2_bn
# Layers 34(-483): conv2_block3_2_relu
# Layers 35(-482): conv2_block3_3_conv
# Layers 36(-481): conv2_block3_3_bn
# Layers 37(-480): conv2_block3_add
# Layers 38(-479): conv2_block3_out
# Layers 39(-478): conv3_block1_1_conv
# Layers 40(-477): conv3_block1_1_bn
# Layers 41(-476): conv3_block1_1_relu
# Layers 42(-475): conv3_block1_2_conv
# Layers 43(-474): conv3_block1_2_bn
# Layers 44(-473): conv3_block1_2_relu
# Layers 45(-472): conv3_block1_0_conv
# Layers 46(-471): conv3_block1_3_conv
# Layers 47(-470): conv3_block1_0_bn
# Layers 48(-469): conv3_block1_3_bn
# Layers 49(-468): conv3_block1_add
# Layers 50(-467): conv3_block1_out
# Layers 51(-466): conv3_block2_1_conv
# Layers 52(-465): conv3_block2_1_bn
# Layers 53(-464): conv3_block2_1_relu
# Layers 54(-463): conv3_block2_2_conv
# Layers 55(-462): conv3_block2_2_bn
# Layers 56(-461): conv3_block2_2_relu
# Layers 57(-460): conv3_block2_3_conv
# Layers 58(-459): conv3_block2_3_bn
# Layers 59(-458): conv3_block2_add
# Layers 60(-457): conv3_block2_out
# Layers 61(-456): conv3_block3_1_conv
# Layers 62(-455): conv3_block3_1_bn
# Layers 63(-454): conv3_block3_1_relu
# Layers 64(-453): conv3_block3_2_conv
# Layers 65(-452): conv3_block3_2_bn
# Layers 66(-451): conv3_block3_2_relu
# Layers 67(-450): conv3_block3_3_conv
# Layers 68(-449): conv3_block3_3_bn
# Layers 69(-448): conv3_block3_add
# Layers 70(-447): conv3_block3_out
# Layers 71(-446): conv3_block4_1_conv
# Layers 72(-445): conv3_block4_1_bn
# Layers 73(-444): conv3_block4_1_relu
# Layers 74(-443): conv3_block4_2_conv
# Layers 75(-442): conv3_block4_2_bn
# Layers 76(-441): conv3_block4_2_relu
# Layers 77(-440): conv3_block4_3_conv
# Layers 78(-439): conv3_block4_3_bn
# Layers 79(-438): conv3_block4_add
# Layers 80(-437): conv3_block4_out
# Layers 81(-436): conv3_block5_1_conv
# Layers 82(-435): conv3_block5_1_bn
# Layers 83(-434): conv3_block5_1_relu
# Layers 84(-433): conv3_block5_2_conv
# Layers 85(-432): conv3_block5_2_bn
# Layers 86(-431): conv3_block5_2_relu
# Layers 87(-430): conv3_block5_3_conv
# Layers 88(-429): conv3_block5_3_bn
# Layers 89(-428): conv3_block5_add
# Layers 90(-427): conv3_block5_out
# Layers 91(-426): conv3_block6_1_conv
# Layers 92(-425): conv3_block6_1_bn
# Layers 93(-424): conv3_block6_1_relu
# Layers 94(-423): conv3_block6_2_conv
# Layers 95(-422): conv3_block6_2_bn
# Layers 96(-421): conv3_block6_2_relu
# Layers 97(-420): conv3_block6_3_conv
# Layers 98(-419): conv3_block6_3_bn
# Layers 99(-418): conv3_block6_add
# Layers 100(-417): conv3_block6_out
# Layers 101(-416): conv3_block7_1_conv
# Layers 102(-415): conv3_block7_1_bn
# Layers 103(-414): conv3_block7_1_relu
# Layers 104(-413): conv3_block7_2_conv
# Layers 105(-412): conv3_block7_2_bn
# Layers 106(-411): conv3_block7_2_relu
# Layers 107(-410): conv3_block7_3_conv
# Layers 108(-409): conv3_block7_3_bn
# Layers 109(-408): conv3_block7_add
# Layers 110(-407): conv3_block7_out
# Layers 111(-406): conv3_block8_1_conv
# Layers 112(-405): conv3_block8_1_bn
# Layers 113(-404): conv3_block8_1_relu
# Layers 114(-403): conv3_block8_2_conv
# Layers 115(-402): conv3_block8_2_bn
# Layers 116(-401): conv3_block8_2_relu
# Layers 117(-400): conv3_block8_3_conv
# Layers 118(-399): conv3_block8_3_bn
# Layers 119(-398): conv3_block8_add
# Layers 120(-397): conv3_block8_out
# Layers 121(-396): conv4_block1_1_conv
# Layers 122(-395): conv4_block1_1_bn
# Layers 123(-394): conv4_block1_1_relu
# Layers 124(-393): conv4_block1_2_conv
# Layers 125(-392): conv4_block1_2_bn
# Layers 126(-391): conv4_block1_2_relu
# Layers 127(-390): conv4_block1_0_conv
# Layers 128(-389): conv4_block1_3_conv
# Layers 129(-388): conv4_block1_0_bn
# Layers 130(-387): conv4_block1_3_bn
# Layers 131(-386): conv4_block1_add
# Layers 132(-385): conv4_block1_out
# Layers 133(-384): conv4_block2_1_conv
# Layers 134(-383): conv4_block2_1_bn
# Layers 135(-382): conv4_block2_1_relu
# Layers 136(-381): conv4_block2_2_conv
# Layers 137(-380): conv4_block2_2_bn
# Layers 138(-379): conv4_block2_2_relu
# Layers 139(-378): conv4_block2_3_conv
# Layers 140(-377): conv4_block2_3_bn
# Layers 141(-376): conv4_block2_add
# Layers 142(-375): conv4_block2_out
# Layers 143(-374): conv4_block3_1_conv
# Layers 144(-373): conv4_block3_1_bn
# Layers 145(-372): conv4_block3_1_relu
# Layers 146(-371): conv4_block3_2_conv
# Layers 147(-370): conv4_block3_2_bn
# Layers 148(-369): conv4_block3_2_relu
# Layers 149(-368): conv4_block3_3_conv
# Layers 150(-367): conv4_block3_3_bn
# Layers 151(-366): conv4_block3_add
# Layers 152(-365): conv4_block3_out
# Layers 153(-364): conv4_block4_1_conv
# Layers 154(-363): conv4_block4_1_bn
# Layers 155(-362): conv4_block4_1_relu
# Layers 156(-361): conv4_block4_2_conv
# Layers 157(-360): conv4_block4_2_bn
# Layers 158(-359): conv4_block4_2_relu
# Layers 159(-358): conv4_block4_3_conv
# Layers 160(-357): conv4_block4_3_bn
# Layers 161(-356): conv4_block4_add
# Layers 162(-355): conv4_block4_out
# Layers 163(-354): conv4_block5_1_conv
# Layers 164(-353): conv4_block5_1_bn
# Layers 165(-352): conv4_block5_1_relu
# Layers 166(-351): conv4_block5_2_conv
# Layers 167(-350): conv4_block5_2_bn
# Layers 168(-349): conv4_block5_2_relu
# Layers 169(-348): conv4_block5_3_conv
# Layers 170(-347): conv4_block5_3_bn
# Layers 171(-346): conv4_block5_add
# Layers 172(-345): conv4_block5_out
# Layers 173(-344): conv4_block6_1_conv
# Layers 174(-343): conv4_block6_1_bn
# Layers 175(-342): conv4_block6_1_relu
# Layers 176(-341): conv4_block6_2_conv
# Layers 177(-340): conv4_block6_2_bn
# Layers 178(-339): conv4_block6_2_relu
# Layers 179(-338): conv4_block6_3_conv
# Layers 180(-337): conv4_block6_3_bn
# Layers 181(-336): conv4_block6_add
# Layers 182(-335): conv4_block6_out
# Layers 183(-334): conv4_block7_1_conv
# Layers 184(-333): conv4_block7_1_bn
# Layers 185(-332): conv4_block7_1_relu
# Layers 186(-331): conv4_block7_2_conv
# Layers 187(-330): conv4_block7_2_bn
# Layers 188(-329): conv4_block7_2_relu
# Layers 189(-328): conv4_block7_3_conv
# Layers 190(-327): conv4_block7_3_bn
# Layers 191(-326): conv4_block7_add
# Layers 192(-325): conv4_block7_out
# Layers 193(-324): conv4_block8_1_conv
# Layers 194(-323): conv4_block8_1_bn
# Layers 195(-322): conv4_block8_1_relu
# Layers 196(-321): conv4_block8_2_conv
# Layers 197(-320): conv4_block8_2_bn
# Layers 198(-319): conv4_block8_2_relu
# Layers 199(-318): conv4_block8_3_conv
# Layers 200(-317): conv4_block8_3_bn
# Layers 201(-316): conv4_block8_add
# Layers 202(-315): conv4_block8_out
# Layers 203(-314): conv4_block9_1_conv
# Layers 204(-313): conv4_block9_1_bn
# Layers 205(-312): conv4_block9_1_relu
# Layers 206(-311): conv4_block9_2_conv
# Layers 207(-310): conv4_block9_2_bn
# Layers 208(-309): conv4_block9_2_relu
# Layers 209(-308): conv4_block9_3_conv
# Layers 210(-307): conv4_block9_3_bn
# Layers 211(-306): conv4_block9_add
# Layers 212(-305): conv4_block9_out
# Layers 213(-304): conv4_block10_1_conv
# Layers 214(-303): conv4_block10_1_bn
# Layers 215(-302): conv4_block10_1_relu
# Layers 216(-301): conv4_block10_2_conv
# Layers 217(-300): conv4_block10_2_bn
# Layers 218(-299): conv4_block10_2_relu
# Layers 219(-298): conv4_block10_3_conv
# Layers 220(-297): conv4_block10_3_bn
# Layers 221(-296): conv4_block10_add
# Layers 222(-295): conv4_block10_out
# Layers 223(-294): conv4_block11_1_conv
# Layers 224(-293): conv4_block11_1_bn
# Layers 225(-292): conv4_block11_1_relu
# Layers 226(-291): conv4_block11_2_conv
# Layers 227(-290): conv4_block11_2_bn
# Layers 228(-289): conv4_block11_2_relu
# Layers 229(-288): conv4_block11_3_conv
# Layers 230(-287): conv4_block11_3_bn
# Layers 231(-286): conv4_block11_add
# Layers 232(-285): conv4_block11_out
# Layers 233(-284): conv4_block12_1_conv
# Layers 234(-283): conv4_block12_1_bn
# Layers 235(-282): conv4_block12_1_relu
# Layers 236(-281): conv4_block12_2_conv
# Layers 237(-280): conv4_block12_2_bn
# Layers 238(-279): conv4_block12_2_relu
# Layers 239(-278): conv4_block12_3_conv
# Layers 240(-277): conv4_block12_3_bn
# Layers 241(-276): conv4_block12_add
# Layers 242(-275): conv4_block12_out
# Layers 243(-274): conv4_block13_1_conv
# Layers 244(-273): conv4_block13_1_bn
# Layers 245(-272): conv4_block13_1_relu
# Layers 246(-271): conv4_block13_2_conv
# Layers 247(-270): conv4_block13_2_bn
# Layers 248(-269): conv4_block13_2_relu
# Layers 249(-268): conv4_block13_3_conv
# Layers 250(-267): conv4_block13_3_bn
# Layers 251(-266): conv4_block13_add
# Layers 252(-265): conv4_block13_out
# Layers 253(-264): conv4_block14_1_conv
# Layers 254(-263): conv4_block14_1_bn
# Layers 255(-262): conv4_block14_1_relu
# Layers 256(-261): conv4_block14_2_conv
# Layers 257(-260): conv4_block14_2_bn
# Layers 258(-259): conv4_block14_2_relu
# Layers 259(-258): conv4_block14_3_conv
# Layers 260(-257): conv4_block14_3_bn
# Layers 261(-256): conv4_block14_add
# Layers 262(-255): conv4_block14_out
# Layers 263(-254): conv4_block15_1_conv
# Layers 264(-253): conv4_block15_1_bn
# Layers 265(-252): conv4_block15_1_relu
# Layers 266(-251): conv4_block15_2_conv
# Layers 267(-250): conv4_block15_2_bn
# Layers 268(-249): conv4_block15_2_relu
# Layers 269(-248): conv4_block15_3_conv
# Layers 270(-247): conv4_block15_3_bn
# Layers 271(-246): conv4_block15_add
# Layers 272(-245): conv4_block15_out
# Layers 273(-244): conv4_block16_1_conv
# Layers 274(-243): conv4_block16_1_bn
# Layers 275(-242): conv4_block16_1_relu
# Layers 276(-241): conv4_block16_2_conv
# Layers 277(-240): conv4_block16_2_bn
# Layers 278(-239): conv4_block16_2_relu
# Layers 279(-238): conv4_block16_3_conv
# Layers 280(-237): conv4_block16_3_bn
# Layers 281(-236): conv4_block16_add
# Layers 282(-235): conv4_block16_out
# Layers 283(-234): conv4_block17_1_conv
# Layers 284(-233): conv4_block17_1_bn
# Layers 285(-232): conv4_block17_1_relu
# Layers 286(-231): conv4_block17_2_conv
# Layers 287(-230): conv4_block17_2_bn
# Layers 288(-229): conv4_block17_2_relu
# Layers 289(-228): conv4_block17_3_conv
# Layers 290(-227): conv4_block17_3_bn
# Layers 291(-226): conv4_block17_add
# Layers 292(-225): conv4_block17_out
# Layers 293(-224): conv4_block18_1_conv
# Layers 294(-223): conv4_block18_1_bn
# Layers 295(-222): conv4_block18_1_relu
# Layers 296(-221): conv4_block18_2_conv
# Layers 297(-220): conv4_block18_2_bn
# Layers 298(-219): conv4_block18_2_relu
# Layers 299(-218): conv4_block18_3_conv
# Layers 300(-217): conv4_block18_3_bn
# Layers 301(-216): conv4_block18_add
# Layers 302(-215): conv4_block18_out
# Layers 303(-214): conv4_block19_1_conv
# Layers 304(-213): conv4_block19_1_bn
# Layers 305(-212): conv4_block19_1_relu
# Layers 306(-211): conv4_block19_2_conv
# Layers 307(-210): conv4_block19_2_bn
# Layers 308(-209): conv4_block19_2_relu
# Layers 309(-208): conv4_block19_3_conv
# Layers 310(-207): conv4_block19_3_bn
# Layers 311(-206): conv4_block19_add
# Layers 312(-205): conv4_block19_out
# Layers 313(-204): conv4_block20_1_conv
# Layers 314(-203): conv4_block20_1_bn
# Layers 315(-202): conv4_block20_1_relu
# Layers 316(-201): conv4_block20_2_conv
# Layers 317(-200): conv4_block20_2_bn
# Layers 318(-199): conv4_block20_2_relu
# Layers 319(-198): conv4_block20_3_conv
# Layers 320(-197): conv4_block20_3_bn
# Layers 321(-196): conv4_block20_add
# Layers 322(-195): conv4_block20_out
# Layers 323(-194): conv4_block21_1_conv
# Layers 324(-193): conv4_block21_1_bn
# Layers 325(-192): conv4_block21_1_relu
# Layers 326(-191): conv4_block21_2_conv
# Layers 327(-190): conv4_block21_2_bn
# Layers 328(-189): conv4_block21_2_relu
# Layers 329(-188): conv4_block21_3_conv
# Layers 330(-187): conv4_block21_3_bn
# Layers 331(-186): conv4_block21_add
# Layers 332(-185): conv4_block21_out
# Layers 333(-184): conv4_block22_1_conv
# Layers 334(-183): conv4_block22_1_bn
# Layers 335(-182): conv4_block22_1_relu
# Layers 336(-181): conv4_block22_2_conv
# Layers 337(-180): conv4_block22_2_bn
# Layers 338(-179): conv4_block22_2_relu
# Layers 339(-178): conv4_block22_3_conv
# Layers 340(-177): conv4_block22_3_bn
# Layers 341(-176): conv4_block22_add
# Layers 342(-175): conv4_block22_out
# Layers 343(-174): conv4_block23_1_conv
# Layers 344(-173): conv4_block23_1_bn
# Layers 345(-172): conv4_block23_1_relu
# Layers 346(-171): conv4_block23_2_conv
# Layers 347(-170): conv4_block23_2_bn
# Layers 348(-169): conv4_block23_2_relu
# Layers 349(-168): conv4_block23_3_conv
# Layers 350(-167): conv4_block23_3_bn
# Layers 351(-166): conv4_block23_add
# Layers 352(-165): conv4_block23_out
# Layers 353(-164): conv4_block24_1_conv
# Layers 354(-163): conv4_block24_1_bn
# Layers 355(-162): conv4_block24_1_relu
# Layers 356(-161): conv4_block24_2_conv
# Layers 357(-160): conv4_block24_2_bn
# Layers 358(-159): conv4_block24_2_relu
# Layers 359(-158): conv4_block24_3_conv
# Layers 360(-157): conv4_block24_3_bn
# Layers 361(-156): conv4_block24_add
# Layers 362(-155): conv4_block24_out
# Layers 363(-154): conv4_block25_1_conv
# Layers 364(-153): conv4_block25_1_bn
# Layers 365(-152): conv4_block25_1_relu
# Layers 366(-151): conv4_block25_2_conv
# Layers 367(-150): conv4_block25_2_bn
# Layers 368(-149): conv4_block25_2_relu
# Layers 369(-148): conv4_block25_3_conv
# Layers 370(-147): conv4_block25_3_bn
# Layers 371(-146): conv4_block25_add
# Layers 372(-145): conv4_block25_out
# Layers 373(-144): conv4_block26_1_conv
# Layers 374(-143): conv4_block26_1_bn
# Layers 375(-142): conv4_block26_1_relu
# Layers 376(-141): conv4_block26_2_conv
# Layers 377(-140): conv4_block26_2_bn
# Layers 378(-139): conv4_block26_2_relu
# Layers 379(-138): conv4_block26_3_conv
# Layers 380(-137): conv4_block26_3_bn
# Layers 381(-136): conv4_block26_add
# Layers 382(-135): conv4_block26_out
# Layers 383(-134): conv4_block27_1_conv
# Layers 384(-133): conv4_block27_1_bn
# Layers 385(-132): conv4_block27_1_relu
# Layers 386(-131): conv4_block27_2_conv
# Layers 387(-130): conv4_block27_2_bn
# Layers 388(-129): conv4_block27_2_relu
# Layers 389(-128): conv4_block27_3_conv
# Layers 390(-127): conv4_block27_3_bn
# Layers 391(-126): conv4_block27_add
# Layers 392(-125): conv4_block27_out
# Layers 393(-124): conv4_block28_1_conv
# Layers 394(-123): conv4_block28_1_bn
# Layers 395(-122): conv4_block28_1_relu
# Layers 396(-121): conv4_block28_2_conv
# Layers 397(-120): conv4_block28_2_bn
# Layers 398(-119): conv4_block28_2_relu
# Layers 399(-118): conv4_block28_3_conv
# Layers 400(-117): conv4_block28_3_bn
# Layers 401(-116): conv4_block28_add
# Layers 402(-115): conv4_block28_out
# Layers 403(-114): conv4_block29_1_conv
# Layers 404(-113): conv4_block29_1_bn
# Layers 405(-112): conv4_block29_1_relu
# Layers 406(-111): conv4_block29_2_conv
# Layers 407(-110): conv4_block29_2_bn
# Layers 408(-109): conv4_block29_2_relu
# Layers 409(-108): conv4_block29_3_conv
# Layers 410(-107): conv4_block29_3_bn
# Layers 411(-106): conv4_block29_add
# Layers 412(-105): conv4_block29_out
# Layers 413(-104): conv4_block30_1_conv
# Layers 414(-103): conv4_block30_1_bn
# Layers 415(-102): conv4_block30_1_relu
# Layers 416(-101): conv4_block30_2_conv
# Layers 417(-100): conv4_block30_2_bn
# Layers 418(-99): conv4_block30_2_relu
# Layers 419(-98): conv4_block30_3_conv
# Layers 420(-97): conv4_block30_3_bn
# Layers 421(-96): conv4_block30_add
# Layers 422(-95): conv4_block30_out
# Layers 423(-94): conv4_block31_1_conv
# Layers 424(-93): conv4_block31_1_bn
# Layers 425(-92): conv4_block31_1_relu
# Layers 426(-91): conv4_block31_2_conv
# Layers 427(-90): conv4_block31_2_bn
# Layers 428(-89): conv4_block31_2_relu
# Layers 429(-88): conv4_block31_3_conv
# Layers 430(-87): conv4_block31_3_bn
# Layers 431(-86): conv4_block31_add
# Layers 432(-85): conv4_block31_out
# Layers 433(-84): conv4_block32_1_conv
# Layers 434(-83): conv4_block32_1_bn
# Layers 435(-82): conv4_block32_1_relu
# Layers 436(-81): conv4_block32_2_conv
# Layers 437(-80): conv4_block32_2_bn
# Layers 438(-79): conv4_block32_2_relu
# Layers 439(-78): conv4_block32_3_conv
# Layers 440(-77): conv4_block32_3_bn
# Layers 441(-76): conv4_block32_add
# Layers 442(-75): conv4_block32_out
# Layers 443(-74): conv4_block33_1_conv
# Layers 444(-73): conv4_block33_1_bn
# Layers 445(-72): conv4_block33_1_relu
# Layers 446(-71): conv4_block33_2_conv
# Layers 447(-70): conv4_block33_2_bn
# Layers 448(-69): conv4_block33_2_relu
# Layers 449(-68): conv4_block33_3_conv
# Layers 450(-67): conv4_block33_3_bn
# Layers 451(-66): conv4_block33_add
# Layers 452(-65): conv4_block33_out
# Layers 453(-64): conv4_block34_1_conv
# Layers 454(-63): conv4_block34_1_bn
# Layers 455(-62): conv4_block34_1_relu
# Layers 456(-61): conv4_block34_2_conv
# Layers 457(-60): conv4_block34_2_bn
# Layers 458(-59): conv4_block34_2_relu
# Layers 459(-58): conv4_block34_3_conv
# Layers 460(-57): conv4_block34_3_bn
# Layers 461(-56): conv4_block34_add
# Layers 462(-55): conv4_block34_out
# Layers 463(-54): conv4_block35_1_conv
# Layers 464(-53): conv4_block35_1_bn
# Layers 465(-52): conv4_block35_1_relu
# Layers 466(-51): conv4_block35_2_conv
# Layers 467(-50): conv4_block35_2_bn
# Layers 468(-49): conv4_block35_2_relu
# Layers 469(-48): conv4_block35_3_conv
# Layers 470(-47): conv4_block35_3_bn
# Layers 471(-46): conv4_block35_add
# Layers 472(-45): conv4_block35_out
# Layers 473(-44): conv4_block36_1_conv
# Layers 474(-43): conv4_block36_1_bn
# Layers 475(-42): conv4_block36_1_relu
# Layers 476(-41): conv4_block36_2_conv
# Layers 477(-40): conv4_block36_2_bn
# Layers 478(-39): conv4_block36_2_relu
# Layers 479(-38): conv4_block36_3_conv
# Layers 480(-37): conv4_block36_3_bn
# Layers 481(-36): conv4_block36_add
# Layers 482(-35): conv4_block36_out
# Layers 483(-34): conv5_block1_1_conv
# Layers 484(-33): conv5_block1_1_bn
# Layers 485(-32): conv5_block1_1_relu
# Layers 486(-31): conv5_block1_2_conv
# Layers 487(-30): conv5_block1_2_bn
# Layers 488(-29): conv5_block1_2_relu
# Layers 489(-28): conv5_block1_0_conv
# Layers 490(-27): conv5_block1_3_conv
# Layers 491(-26): conv5_block1_0_bn
# Layers 492(-25): conv5_block1_3_bn
# Layers 493(-24): conv5_block1_add
# Layers 494(-23): conv5_block1_out
# Layers 495(-22): conv5_block2_1_conv
# Layers 496(-21): conv5_block2_1_bn
# Layers 497(-20): conv5_block2_1_relu
# Layers 498(-19): conv5_block2_2_conv
# Layers 499(-18): conv5_block2_2_bn
# Layers 500(-17): conv5_block2_2_relu
# Layers 501(-16): conv5_block2_3_conv
# Layers 502(-15): conv5_block2_3_bn
# Layers 503(-14): conv5_block2_add
# Layers 504(-13): conv5_block2_out
# Layers 505(-12): conv5_block3_1_conv
# Layers 506(-11): conv5_block3_1_bn
# Layers 507(-10): conv5_block3_1_relu
# Layers 508(-9): conv5_block3_2_conv
# Layers 509(-8): conv5_block3_2_bn
# Layers 510(-7): conv5_block3_2_relu
# Layers 511(-6): conv5_block3_3_conv
# Layers 512(-5): conv5_block3_3_bn
# Layers 513(-4): conv5_block3_add
# Layers 514(-3): conv5_block3_out
# Layers 515(-2): avg_pool
# Layers 516(-1): predictions

# %%
ResNet152.summary()
# Out:
# Model: "resnet152"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_8[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block4_out[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block5_3_conv[0][0]']
#  ization)
#
#  conv3_block5_add (Add)         (None, 28, 28, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block5_add[0][0]']
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block5_out[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block6_3_conv[0][0]']
#  ization)
#
#  conv3_block6_add (Add)         (None, 28, 28, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block6_add[0][0]']
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block6_out[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block7_3_conv[0][0]']
#  ization)
#
#  conv3_block7_add (Add)         (None, 28, 28, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block7_add[0][0]']
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block7_out[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  conv3_block8_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block8_3_conv[0][0]']
#  ization)
#
#  conv3_block8_add (Add)         (None, 28, 28, 512)  0           ['conv3_block7_out[0][0]',
#                                                                   'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block8_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block8_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block8_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
# ...
#  on)
#
#  conv4_block34_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block34_2_relu[0][0]']
#                                 )
#
#  conv4_block34_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['conv4_block34_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block34_add (Add)        (None, 14, 14, 1024  0           ['conv4_block33_out[0][0]',
#                                 )                                 'conv4_block34_3_bn[0][0]']
#
#  conv4_block34_out (Activation)  (None, 14, 14, 1024  0          ['conv4_block34_add[0][0]']
#                                 )
#
#  conv4_block35_1_conv (Conv2D)  (None, 14, 14, 256)  262400      ['conv4_block34_out[0][0]']
#
#  conv4_block35_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_1_conv[0][0]']
#  lization)
#
#  conv4_block35_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_1_bn[0][0]']
#  on)
#
#  conv4_block35_2_conv (Conv2D)  (None, 14, 14, 256)  590080      ['conv4_block35_1_relu[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['conv4_block35_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block35_add (Add)        (None, 14, 14, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_bn[0][0]']
#
#  conv4_block35_out (Activation)  (None, 14, 14, 1024  0          ['conv4_block35_add[0][0]']
#                                 )
#
#  conv4_block36_1_conv (Conv2D)  (None, 14, 14, 256)  262400      ['conv4_block35_out[0][0]']
#
#  conv4_block36_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_conv (Conv2D)  (None, 14, 14, 256)  590080      ['conv4_block36_1_relu[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block36_2_bn[0][0]']
#  on)
#
#  conv4_block36_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block36_2_relu[0][0]']
#                                 )
#
#  conv4_block36_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['conv4_block36_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block36_add (Add)        (None, 14, 14, 1024  0           ['conv4_block35_out[0][0]',
#                                 )                                 'conv4_block36_3_bn[0][0]']
#
#  conv4_block36_out (Activation)  (None, 14, 14, 1024  0          ['conv4_block36_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block36_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block36_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 60,419,944
# Trainable params: 60,268,520
# Non-trainable params: 151,424
# __________________________________________________________________________________________________

# %% [markdown]
# # ResNet152V2

# %%
ResNet152V2 = tf.keras.applications.ResNet152V2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels.h5
# 242753536/242745792 [==============================] - 23s 0us/step
# 242761728/242745792 [==============================] - 23s 0us/step

# %%
model_analyze(ResNet152V2)
# Out:
# Layers 0(-566): input_9
# Layers 1(-565): conv1_pad
# Layers 2(-564): conv1_conv
# Layers 3(-563): pool1_pad
# Layers 4(-562): pool1_pool
# Layers 5(-561): conv2_block1_preact_bn
# Layers 6(-560): conv2_block1_preact_relu
# Layers 7(-559): conv2_block1_1_conv
# Layers 8(-558): conv2_block1_1_bn
# Layers 9(-557): conv2_block1_1_relu
# Layers 10(-556): conv2_block1_2_pad
# Layers 11(-555): conv2_block1_2_conv
# Layers 12(-554): conv2_block1_2_bn
# Layers 13(-553): conv2_block1_2_relu
# Layers 14(-552): conv2_block1_0_conv
# Layers 15(-551): conv2_block1_3_conv
# Layers 16(-550): conv2_block1_out
# Layers 17(-549): conv2_block2_preact_bn
# Layers 18(-548): conv2_block2_preact_relu
# Layers 19(-547): conv2_block2_1_conv
# Layers 20(-546): conv2_block2_1_bn
# Layers 21(-545): conv2_block2_1_relu
# Layers 22(-544): conv2_block2_2_pad
# Layers 23(-543): conv2_block2_2_conv
# Layers 24(-542): conv2_block2_2_bn
# Layers 25(-541): conv2_block2_2_relu
# Layers 26(-540): conv2_block2_3_conv
# Layers 27(-539): conv2_block2_out
# Layers 28(-538): conv2_block3_preact_bn
# Layers 29(-537): conv2_block3_preact_relu
# Layers 30(-536): conv2_block3_1_conv
# Layers 31(-535): conv2_block3_1_bn
# Layers 32(-534): conv2_block3_1_relu
# Layers 33(-533): conv2_block3_2_pad
# Layers 34(-532): conv2_block3_2_conv
# Layers 35(-531): conv2_block3_2_bn
# Layers 36(-530): conv2_block3_2_relu
# Layers 37(-529): max_pooling2d_6
# Layers 38(-528): conv2_block3_3_conv
# Layers 39(-527): conv2_block3_out
# Layers 40(-526): conv3_block1_preact_bn
# Layers 41(-525): conv3_block1_preact_relu
# Layers 42(-524): conv3_block1_1_conv
# Layers 43(-523): conv3_block1_1_bn
# Layers 44(-522): conv3_block1_1_relu
# Layers 45(-521): conv3_block1_2_pad
# Layers 46(-520): conv3_block1_2_conv
# Layers 47(-519): conv3_block1_2_bn
# Layers 48(-518): conv3_block1_2_relu
# Layers 49(-517): conv3_block1_0_conv
# Layers 50(-516): conv3_block1_3_conv
# Layers 51(-515): conv3_block1_out
# Layers 52(-514): conv3_block2_preact_bn
# Layers 53(-513): conv3_block2_preact_relu
# Layers 54(-512): conv3_block2_1_conv
# Layers 55(-511): conv3_block2_1_bn
# Layers 56(-510): conv3_block2_1_relu
# Layers 57(-509): conv3_block2_2_pad
# Layers 58(-508): conv3_block2_2_conv
# Layers 59(-507): conv3_block2_2_bn
# Layers 60(-506): conv3_block2_2_relu
# Layers 61(-505): conv3_block2_3_conv
# Layers 62(-504): conv3_block2_out
# Layers 63(-503): conv3_block3_preact_bn
# Layers 64(-502): conv3_block3_preact_relu
# Layers 65(-501): conv3_block3_1_conv
# Layers 66(-500): conv3_block3_1_bn
# Layers 67(-499): conv3_block3_1_relu
# Layers 68(-498): conv3_block3_2_pad
# Layers 69(-497): conv3_block3_2_conv
# Layers 70(-496): conv3_block3_2_bn
# Layers 71(-495): conv3_block3_2_relu
# Layers 72(-494): conv3_block3_3_conv
# Layers 73(-493): conv3_block3_out
# Layers 74(-492): conv3_block4_preact_bn
# Layers 75(-491): conv3_block4_preact_relu
# Layers 76(-490): conv3_block4_1_conv
# Layers 77(-489): conv3_block4_1_bn
# Layers 78(-488): conv3_block4_1_relu
# Layers 79(-487): conv3_block4_2_pad
# Layers 80(-486): conv3_block4_2_conv
# Layers 81(-485): conv3_block4_2_bn
# Layers 82(-484): conv3_block4_2_relu
# Layers 83(-483): conv3_block4_3_conv
# Layers 84(-482): conv3_block4_out
# Layers 85(-481): conv3_block5_preact_bn
# Layers 86(-480): conv3_block5_preact_relu
# Layers 87(-479): conv3_block5_1_conv
# Layers 88(-478): conv3_block5_1_bn
# Layers 89(-477): conv3_block5_1_relu
# Layers 90(-476): conv3_block5_2_pad
# Layers 91(-475): conv3_block5_2_conv
# Layers 92(-474): conv3_block5_2_bn
# Layers 93(-473): conv3_block5_2_relu
# Layers 94(-472): conv3_block5_3_conv
# Layers 95(-471): conv3_block5_out
# Layers 96(-470): conv3_block6_preact_bn
# Layers 97(-469): conv3_block6_preact_relu
# Layers 98(-468): conv3_block6_1_conv
# Layers 99(-467): conv3_block6_1_bn
# Layers 100(-466): conv3_block6_1_relu
# Layers 101(-465): conv3_block6_2_pad
# Layers 102(-464): conv3_block6_2_conv
# Layers 103(-463): conv3_block6_2_bn
# Layers 104(-462): conv3_block6_2_relu
# Layers 105(-461): conv3_block6_3_conv
# Layers 106(-460): conv3_block6_out
# Layers 107(-459): conv3_block7_preact_bn
# Layers 108(-458): conv3_block7_preact_relu
# Layers 109(-457): conv3_block7_1_conv
# Layers 110(-456): conv3_block7_1_bn
# Layers 111(-455): conv3_block7_1_relu
# Layers 112(-454): conv3_block7_2_pad
# Layers 113(-453): conv3_block7_2_conv
# Layers 114(-452): conv3_block7_2_bn
# Layers 115(-451): conv3_block7_2_relu
# Layers 116(-450): conv3_block7_3_conv
# Layers 117(-449): conv3_block7_out
# Layers 118(-448): conv3_block8_preact_bn
# Layers 119(-447): conv3_block8_preact_relu
# Layers 120(-446): conv3_block8_1_conv
# Layers 121(-445): conv3_block8_1_bn
# Layers 122(-444): conv3_block8_1_relu
# Layers 123(-443): conv3_block8_2_pad
# Layers 124(-442): conv3_block8_2_conv
# Layers 125(-441): conv3_block8_2_bn
# Layers 126(-440): conv3_block8_2_relu
# Layers 127(-439): max_pooling2d_7
# Layers 128(-438): conv3_block8_3_conv
# Layers 129(-437): conv3_block8_out
# Layers 130(-436): conv4_block1_preact_bn
# Layers 131(-435): conv4_block1_preact_relu
# Layers 132(-434): conv4_block1_1_conv
# Layers 133(-433): conv4_block1_1_bn
# Layers 134(-432): conv4_block1_1_relu
# Layers 135(-431): conv4_block1_2_pad
# Layers 136(-430): conv4_block1_2_conv
# Layers 137(-429): conv4_block1_2_bn
# Layers 138(-428): conv4_block1_2_relu
# Layers 139(-427): conv4_block1_0_conv
# Layers 140(-426): conv4_block1_3_conv
# Layers 141(-425): conv4_block1_out
# Layers 142(-424): conv4_block2_preact_bn
# Layers 143(-423): conv4_block2_preact_relu
# Layers 144(-422): conv4_block2_1_conv
# Layers 145(-421): conv4_block2_1_bn
# Layers 146(-420): conv4_block2_1_relu
# Layers 147(-419): conv4_block2_2_pad
# Layers 148(-418): conv4_block2_2_conv
# Layers 149(-417): conv4_block2_2_bn
# Layers 150(-416): conv4_block2_2_relu
# Layers 151(-415): conv4_block2_3_conv
# Layers 152(-414): conv4_block2_out
# Layers 153(-413): conv4_block3_preact_bn
# Layers 154(-412): conv4_block3_preact_relu
# Layers 155(-411): conv4_block3_1_conv
# Layers 156(-410): conv4_block3_1_bn
# Layers 157(-409): conv4_block3_1_relu
# Layers 158(-408): conv4_block3_2_pad
# Layers 159(-407): conv4_block3_2_conv
# Layers 160(-406): conv4_block3_2_bn
# Layers 161(-405): conv4_block3_2_relu
# Layers 162(-404): conv4_block3_3_conv
# Layers 163(-403): conv4_block3_out
# Layers 164(-402): conv4_block4_preact_bn
# Layers 165(-401): conv4_block4_preact_relu
# Layers 166(-400): conv4_block4_1_conv
# Layers 167(-399): conv4_block4_1_bn
# Layers 168(-398): conv4_block4_1_relu
# Layers 169(-397): conv4_block4_2_pad
# Layers 170(-396): conv4_block4_2_conv
# Layers 171(-395): conv4_block4_2_bn
# Layers 172(-394): conv4_block4_2_relu
# Layers 173(-393): conv4_block4_3_conv
# Layers 174(-392): conv4_block4_out
# Layers 175(-391): conv4_block5_preact_bn
# Layers 176(-390): conv4_block5_preact_relu
# Layers 177(-389): conv4_block5_1_conv
# Layers 178(-388): conv4_block5_1_bn
# Layers 179(-387): conv4_block5_1_relu
# Layers 180(-386): conv4_block5_2_pad
# Layers 181(-385): conv4_block5_2_conv
# Layers 182(-384): conv4_block5_2_bn
# Layers 183(-383): conv4_block5_2_relu
# Layers 184(-382): conv4_block5_3_conv
# Layers 185(-381): conv4_block5_out
# Layers 186(-380): conv4_block6_preact_bn
# Layers 187(-379): conv4_block6_preact_relu
# Layers 188(-378): conv4_block6_1_conv
# Layers 189(-377): conv4_block6_1_bn
# Layers 190(-376): conv4_block6_1_relu
# Layers 191(-375): conv4_block6_2_pad
# Layers 192(-374): conv4_block6_2_conv
# Layers 193(-373): conv4_block6_2_bn
# Layers 194(-372): conv4_block6_2_relu
# Layers 195(-371): conv4_block6_3_conv
# Layers 196(-370): conv4_block6_out
# Layers 197(-369): conv4_block7_preact_bn
# Layers 198(-368): conv4_block7_preact_relu
# Layers 199(-367): conv4_block7_1_conv
# Layers 200(-366): conv4_block7_1_bn
# Layers 201(-365): conv4_block7_1_relu
# Layers 202(-364): conv4_block7_2_pad
# Layers 203(-363): conv4_block7_2_conv
# Layers 204(-362): conv4_block7_2_bn
# Layers 205(-361): conv4_block7_2_relu
# Layers 206(-360): conv4_block7_3_conv
# Layers 207(-359): conv4_block7_out
# Layers 208(-358): conv4_block8_preact_bn
# Layers 209(-357): conv4_block8_preact_relu
# Layers 210(-356): conv4_block8_1_conv
# Layers 211(-355): conv4_block8_1_bn
# Layers 212(-354): conv4_block8_1_relu
# Layers 213(-353): conv4_block8_2_pad
# Layers 214(-352): conv4_block8_2_conv
# Layers 215(-351): conv4_block8_2_bn
# Layers 216(-350): conv4_block8_2_relu
# Layers 217(-349): conv4_block8_3_conv
# Layers 218(-348): conv4_block8_out
# Layers 219(-347): conv4_block9_preact_bn
# Layers 220(-346): conv4_block9_preact_relu
# Layers 221(-345): conv4_block9_1_conv
# Layers 222(-344): conv4_block9_1_bn
# Layers 223(-343): conv4_block9_1_relu
# Layers 224(-342): conv4_block9_2_pad
# Layers 225(-341): conv4_block9_2_conv
# Layers 226(-340): conv4_block9_2_bn
# Layers 227(-339): conv4_block9_2_relu
# Layers 228(-338): conv4_block9_3_conv
# Layers 229(-337): conv4_block9_out
# Layers 230(-336): conv4_block10_preact_bn
# Layers 231(-335): conv4_block10_preact_relu
# Layers 232(-334): conv4_block10_1_conv
# Layers 233(-333): conv4_block10_1_bn
# Layers 234(-332): conv4_block10_1_relu
# Layers 235(-331): conv4_block10_2_pad
# Layers 236(-330): conv4_block10_2_conv
# Layers 237(-329): conv4_block10_2_bn
# Layers 238(-328): conv4_block10_2_relu
# Layers 239(-327): conv4_block10_3_conv
# Layers 240(-326): conv4_block10_out
# Layers 241(-325): conv4_block11_preact_bn
# Layers 242(-324): conv4_block11_preact_relu
# Layers 243(-323): conv4_block11_1_conv
# Layers 244(-322): conv4_block11_1_bn
# Layers 245(-321): conv4_block11_1_relu
# Layers 246(-320): conv4_block11_2_pad
# Layers 247(-319): conv4_block11_2_conv
# Layers 248(-318): conv4_block11_2_bn
# Layers 249(-317): conv4_block11_2_relu
# Layers 250(-316): conv4_block11_3_conv
# Layers 251(-315): conv4_block11_out
# Layers 252(-314): conv4_block12_preact_bn
# Layers 253(-313): conv4_block12_preact_relu
# Layers 254(-312): conv4_block12_1_conv
# Layers 255(-311): conv4_block12_1_bn
# Layers 256(-310): conv4_block12_1_relu
# Layers 257(-309): conv4_block12_2_pad
# Layers 258(-308): conv4_block12_2_conv
# Layers 259(-307): conv4_block12_2_bn
# Layers 260(-306): conv4_block12_2_relu
# Layers 261(-305): conv4_block12_3_conv
# Layers 262(-304): conv4_block12_out
# Layers 263(-303): conv4_block13_preact_bn
# Layers 264(-302): conv4_block13_preact_relu
# Layers 265(-301): conv4_block13_1_conv
# Layers 266(-300): conv4_block13_1_bn
# Layers 267(-299): conv4_block13_1_relu
# Layers 268(-298): conv4_block13_2_pad
# Layers 269(-297): conv4_block13_2_conv
# Layers 270(-296): conv4_block13_2_bn
# Layers 271(-295): conv4_block13_2_relu
# Layers 272(-294): conv4_block13_3_conv
# Layers 273(-293): conv4_block13_out
# Layers 274(-292): conv4_block14_preact_bn
# Layers 275(-291): conv4_block14_preact_relu
# Layers 276(-290): conv4_block14_1_conv
# Layers 277(-289): conv4_block14_1_bn
# Layers 278(-288): conv4_block14_1_relu
# Layers 279(-287): conv4_block14_2_pad
# Layers 280(-286): conv4_block14_2_conv
# Layers 281(-285): conv4_block14_2_bn
# Layers 282(-284): conv4_block14_2_relu
# Layers 283(-283): conv4_block14_3_conv
# Layers 284(-282): conv4_block14_out
# Layers 285(-281): conv4_block15_preact_bn
# Layers 286(-280): conv4_block15_preact_relu
# Layers 287(-279): conv4_block15_1_conv
# Layers 288(-278): conv4_block15_1_bn
# Layers 289(-277): conv4_block15_1_relu
# Layers 290(-276): conv4_block15_2_pad
# Layers 291(-275): conv4_block15_2_conv
# Layers 292(-274): conv4_block15_2_bn
# Layers 293(-273): conv4_block15_2_relu
# Layers 294(-272): conv4_block15_3_conv
# Layers 295(-271): conv4_block15_out
# Layers 296(-270): conv4_block16_preact_bn
# Layers 297(-269): conv4_block16_preact_relu
# Layers 298(-268): conv4_block16_1_conv
# Layers 299(-267): conv4_block16_1_bn
# Layers 300(-266): conv4_block16_1_relu
# Layers 301(-265): conv4_block16_2_pad
# Layers 302(-264): conv4_block16_2_conv
# Layers 303(-263): conv4_block16_2_bn
# Layers 304(-262): conv4_block16_2_relu
# Layers 305(-261): conv4_block16_3_conv
# Layers 306(-260): conv4_block16_out
# Layers 307(-259): conv4_block17_preact_bn
# Layers 308(-258): conv4_block17_preact_relu
# Layers 309(-257): conv4_block17_1_conv
# Layers 310(-256): conv4_block17_1_bn
# Layers 311(-255): conv4_block17_1_relu
# Layers 312(-254): conv4_block17_2_pad
# Layers 313(-253): conv4_block17_2_conv
# Layers 314(-252): conv4_block17_2_bn
# Layers 315(-251): conv4_block17_2_relu
# Layers 316(-250): conv4_block17_3_conv
# Layers 317(-249): conv4_block17_out
# Layers 318(-248): conv4_block18_preact_bn
# Layers 319(-247): conv4_block18_preact_relu
# Layers 320(-246): conv4_block18_1_conv
# Layers 321(-245): conv4_block18_1_bn
# Layers 322(-244): conv4_block18_1_relu
# Layers 323(-243): conv4_block18_2_pad
# Layers 324(-242): conv4_block18_2_conv
# Layers 325(-241): conv4_block18_2_bn
# Layers 326(-240): conv4_block18_2_relu
# Layers 327(-239): conv4_block18_3_conv
# Layers 328(-238): conv4_block18_out
# Layers 329(-237): conv4_block19_preact_bn
# Layers 330(-236): conv4_block19_preact_relu
# Layers 331(-235): conv4_block19_1_conv
# Layers 332(-234): conv4_block19_1_bn
# Layers 333(-233): conv4_block19_1_relu
# Layers 334(-232): conv4_block19_2_pad
# Layers 335(-231): conv4_block19_2_conv
# Layers 336(-230): conv4_block19_2_bn
# Layers 337(-229): conv4_block19_2_relu
# Layers 338(-228): conv4_block19_3_conv
# Layers 339(-227): conv4_block19_out
# Layers 340(-226): conv4_block20_preact_bn
# Layers 341(-225): conv4_block20_preact_relu
# Layers 342(-224): conv4_block20_1_conv
# Layers 343(-223): conv4_block20_1_bn
# Layers 344(-222): conv4_block20_1_relu
# Layers 345(-221): conv4_block20_2_pad
# Layers 346(-220): conv4_block20_2_conv
# Layers 347(-219): conv4_block20_2_bn
# Layers 348(-218): conv4_block20_2_relu
# Layers 349(-217): conv4_block20_3_conv
# Layers 350(-216): conv4_block20_out
# Layers 351(-215): conv4_block21_preact_bn
# Layers 352(-214): conv4_block21_preact_relu
# Layers 353(-213): conv4_block21_1_conv
# Layers 354(-212): conv4_block21_1_bn
# Layers 355(-211): conv4_block21_1_relu
# Layers 356(-210): conv4_block21_2_pad
# Layers 357(-209): conv4_block21_2_conv
# Layers 358(-208): conv4_block21_2_bn
# Layers 359(-207): conv4_block21_2_relu
# Layers 360(-206): conv4_block21_3_conv
# Layers 361(-205): conv4_block21_out
# Layers 362(-204): conv4_block22_preact_bn
# Layers 363(-203): conv4_block22_preact_relu
# Layers 364(-202): conv4_block22_1_conv
# Layers 365(-201): conv4_block22_1_bn
# Layers 366(-200): conv4_block22_1_relu
# Layers 367(-199): conv4_block22_2_pad
# Layers 368(-198): conv4_block22_2_conv
# Layers 369(-197): conv4_block22_2_bn
# Layers 370(-196): conv4_block22_2_relu
# Layers 371(-195): conv4_block22_3_conv
# Layers 372(-194): conv4_block22_out
# Layers 373(-193): conv4_block23_preact_bn
# Layers 374(-192): conv4_block23_preact_relu
# Layers 375(-191): conv4_block23_1_conv
# Layers 376(-190): conv4_block23_1_bn
# Layers 377(-189): conv4_block23_1_relu
# Layers 378(-188): conv4_block23_2_pad
# Layers 379(-187): conv4_block23_2_conv
# Layers 380(-186): conv4_block23_2_bn
# Layers 381(-185): conv4_block23_2_relu
# Layers 382(-184): conv4_block23_3_conv
# Layers 383(-183): conv4_block23_out
# Layers 384(-182): conv4_block24_preact_bn
# Layers 385(-181): conv4_block24_preact_relu
# Layers 386(-180): conv4_block24_1_conv
# Layers 387(-179): conv4_block24_1_bn
# Layers 388(-178): conv4_block24_1_relu
# Layers 389(-177): conv4_block24_2_pad
# Layers 390(-176): conv4_block24_2_conv
# Layers 391(-175): conv4_block24_2_bn
# Layers 392(-174): conv4_block24_2_relu
# Layers 393(-173): conv4_block24_3_conv
# Layers 394(-172): conv4_block24_out
# Layers 395(-171): conv4_block25_preact_bn
# Layers 396(-170): conv4_block25_preact_relu
# Layers 397(-169): conv4_block25_1_conv
# Layers 398(-168): conv4_block25_1_bn
# Layers 399(-167): conv4_block25_1_relu
# Layers 400(-166): conv4_block25_2_pad
# Layers 401(-165): conv4_block25_2_conv
# Layers 402(-164): conv4_block25_2_bn
# Layers 403(-163): conv4_block25_2_relu
# Layers 404(-162): conv4_block25_3_conv
# Layers 405(-161): conv4_block25_out
# Layers 406(-160): conv4_block26_preact_bn
# Layers 407(-159): conv4_block26_preact_relu
# Layers 408(-158): conv4_block26_1_conv
# Layers 409(-157): conv4_block26_1_bn
# Layers 410(-156): conv4_block26_1_relu
# Layers 411(-155): conv4_block26_2_pad
# Layers 412(-154): conv4_block26_2_conv
# Layers 413(-153): conv4_block26_2_bn
# Layers 414(-152): conv4_block26_2_relu
# Layers 415(-151): conv4_block26_3_conv
# Layers 416(-150): conv4_block26_out
# Layers 417(-149): conv4_block27_preact_bn
# Layers 418(-148): conv4_block27_preact_relu
# Layers 419(-147): conv4_block27_1_conv
# Layers 420(-146): conv4_block27_1_bn
# Layers 421(-145): conv4_block27_1_relu
# Layers 422(-144): conv4_block27_2_pad
# Layers 423(-143): conv4_block27_2_conv
# Layers 424(-142): conv4_block27_2_bn
# Layers 425(-141): conv4_block27_2_relu
# Layers 426(-140): conv4_block27_3_conv
# Layers 427(-139): conv4_block27_out
# Layers 428(-138): conv4_block28_preact_bn
# Layers 429(-137): conv4_block28_preact_relu
# Layers 430(-136): conv4_block28_1_conv
# Layers 431(-135): conv4_block28_1_bn
# Layers 432(-134): conv4_block28_1_relu
# Layers 433(-133): conv4_block28_2_pad
# Layers 434(-132): conv4_block28_2_conv
# Layers 435(-131): conv4_block28_2_bn
# Layers 436(-130): conv4_block28_2_relu
# Layers 437(-129): conv4_block28_3_conv
# Layers 438(-128): conv4_block28_out
# Layers 439(-127): conv4_block29_preact_bn
# Layers 440(-126): conv4_block29_preact_relu
# Layers 441(-125): conv4_block29_1_conv
# Layers 442(-124): conv4_block29_1_bn
# Layers 443(-123): conv4_block29_1_relu
# Layers 444(-122): conv4_block29_2_pad
# Layers 445(-121): conv4_block29_2_conv
# Layers 446(-120): conv4_block29_2_bn
# Layers 447(-119): conv4_block29_2_relu
# Layers 448(-118): conv4_block29_3_conv
# Layers 449(-117): conv4_block29_out
# Layers 450(-116): conv4_block30_preact_bn
# Layers 451(-115): conv4_block30_preact_relu
# Layers 452(-114): conv4_block30_1_conv
# Layers 453(-113): conv4_block30_1_bn
# Layers 454(-112): conv4_block30_1_relu
# Layers 455(-111): conv4_block30_2_pad
# Layers 456(-110): conv4_block30_2_conv
# Layers 457(-109): conv4_block30_2_bn
# Layers 458(-108): conv4_block30_2_relu
# Layers 459(-107): conv4_block30_3_conv
# Layers 460(-106): conv4_block30_out
# Layers 461(-105): conv4_block31_preact_bn
# Layers 462(-104): conv4_block31_preact_relu
# Layers 463(-103): conv4_block31_1_conv
# Layers 464(-102): conv4_block31_1_bn
# Layers 465(-101): conv4_block31_1_relu
# Layers 466(-100): conv4_block31_2_pad
# Layers 467(-99): conv4_block31_2_conv
# Layers 468(-98): conv4_block31_2_bn
# Layers 469(-97): conv4_block31_2_relu
# Layers 470(-96): conv4_block31_3_conv
# Layers 471(-95): conv4_block31_out
# Layers 472(-94): conv4_block32_preact_bn
# Layers 473(-93): conv4_block32_preact_relu
# Layers 474(-92): conv4_block32_1_conv
# Layers 475(-91): conv4_block32_1_bn
# Layers 476(-90): conv4_block32_1_relu
# Layers 477(-89): conv4_block32_2_pad
# Layers 478(-88): conv4_block32_2_conv
# Layers 479(-87): conv4_block32_2_bn
# Layers 480(-86): conv4_block32_2_relu
# Layers 481(-85): conv4_block32_3_conv
# Layers 482(-84): conv4_block32_out
# Layers 483(-83): conv4_block33_preact_bn
# Layers 484(-82): conv4_block33_preact_relu
# Layers 485(-81): conv4_block33_1_conv
# Layers 486(-80): conv4_block33_1_bn
# Layers 487(-79): conv4_block33_1_relu
# Layers 488(-78): conv4_block33_2_pad
# Layers 489(-77): conv4_block33_2_conv
# Layers 490(-76): conv4_block33_2_bn
# Layers 491(-75): conv4_block33_2_relu
# Layers 492(-74): conv4_block33_3_conv
# Layers 493(-73): conv4_block33_out
# Layers 494(-72): conv4_block34_preact_bn
# Layers 495(-71): conv4_block34_preact_relu
# Layers 496(-70): conv4_block34_1_conv
# Layers 497(-69): conv4_block34_1_bn
# Layers 498(-68): conv4_block34_1_relu
# Layers 499(-67): conv4_block34_2_pad
# Layers 500(-66): conv4_block34_2_conv
# Layers 501(-65): conv4_block34_2_bn
# Layers 502(-64): conv4_block34_2_relu
# Layers 503(-63): conv4_block34_3_conv
# Layers 504(-62): conv4_block34_out
# Layers 505(-61): conv4_block35_preact_bn
# Layers 506(-60): conv4_block35_preact_relu
# Layers 507(-59): conv4_block35_1_conv
# Layers 508(-58): conv4_block35_1_bn
# Layers 509(-57): conv4_block35_1_relu
# Layers 510(-56): conv4_block35_2_pad
# Layers 511(-55): conv4_block35_2_conv
# Layers 512(-54): conv4_block35_2_bn
# Layers 513(-53): conv4_block35_2_relu
# Layers 514(-52): conv4_block35_3_conv
# Layers 515(-51): conv4_block35_out
# Layers 516(-50): conv4_block36_preact_bn
# Layers 517(-49): conv4_block36_preact_relu
# Layers 518(-48): conv4_block36_1_conv
# Layers 519(-47): conv4_block36_1_bn
# Layers 520(-46): conv4_block36_1_relu
# Layers 521(-45): conv4_block36_2_pad
# Layers 522(-44): conv4_block36_2_conv
# Layers 523(-43): conv4_block36_2_bn
# Layers 524(-42): conv4_block36_2_relu
# Layers 525(-41): max_pooling2d_8
# Layers 526(-40): conv4_block36_3_conv
# Layers 527(-39): conv4_block36_out
# Layers 528(-38): conv5_block1_preact_bn
# Layers 529(-37): conv5_block1_preact_relu
# Layers 530(-36): conv5_block1_1_conv
# Layers 531(-35): conv5_block1_1_bn
# Layers 532(-34): conv5_block1_1_relu
# Layers 533(-33): conv5_block1_2_pad
# Layers 534(-32): conv5_block1_2_conv
# Layers 535(-31): conv5_block1_2_bn
# Layers 536(-30): conv5_block1_2_relu
# Layers 537(-29): conv5_block1_0_conv
# Layers 538(-28): conv5_block1_3_conv
# Layers 539(-27): conv5_block1_out
# Layers 540(-26): conv5_block2_preact_bn
# Layers 541(-25): conv5_block2_preact_relu
# Layers 542(-24): conv5_block2_1_conv
# Layers 543(-23): conv5_block2_1_bn
# Layers 544(-22): conv5_block2_1_relu
# Layers 545(-21): conv5_block2_2_pad
# Layers 546(-20): conv5_block2_2_conv
# Layers 547(-19): conv5_block2_2_bn
# Layers 548(-18): conv5_block2_2_relu
# Layers 549(-17): conv5_block2_3_conv
# Layers 550(-16): conv5_block2_out
# Layers 551(-15): conv5_block3_preact_bn
# Layers 552(-14): conv5_block3_preact_relu
# Layers 553(-13): conv5_block3_1_conv
# Layers 554(-12): conv5_block3_1_bn
# Layers 555(-11): conv5_block3_1_relu
# Layers 556(-10): conv5_block3_2_pad
# Layers 557(-9): conv5_block3_2_conv
# Layers 558(-8): conv5_block3_2_bn
# Layers 559(-7): conv5_block3_2_relu
# Layers 560(-6): conv5_block3_3_conv
# Layers 561(-5): conv5_block3_out
# Layers 562(-4): post_bn
# Layers 563(-3): post_relu
# Layers 564(-2): avg_pool
# Layers 565(-1): predictions

# %%
ResNet152V2.summary()
# Out:
# Model: "resnet152v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_9[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv3_block5_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block5_preact_bn[0][0]']
#  vation)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block5_1_relu[0][0]']
#  g2D)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block5_2_pad[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_out (Add)         (None, 28, 28, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block5_out[0][0]']
#  ormalization)
#
#  conv3_block6_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block6_preact_bn[0][0]']
#  vation)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block6_1_relu[0][0]']
#  g2D)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block6_2_pad[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_out (Add)         (None, 28, 28, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block6_out[0][0]']
#  ormalization)
#
#  conv3_block7_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block7_preact_bn[0][0]']
#  vation)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block7_1_relu[0][0]']
#  g2D)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block7_2_pad[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_out (Add)         (None, 28, 28, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block7_out[0][0]']
#  ormalization)
#
#  conv3_block8_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block8_preact_bn[0][0]']
#  vation)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block8_1_relu[0][0]']
#  g2D)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block8_2_pad[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block7_out[0][0]']
#
#  conv3_block8_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_7[0][0]',
#                                                                   'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block8_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
# ...
#
#  conv4_block35_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_1_bn[0][0]']
#  on)
#
#  conv4_block35_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block35_1_relu[0][0]']
#  ng2D)
#
#  conv4_block35_2_conv (Conv2D)  (None, 14, 14, 256)  589824      ['conv4_block35_2_pad[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_out (Add)        (None, 14, 14, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_conv[0][0]']
#
#  conv4_block36_preact_bn (Batch  (None, 14, 14, 1024  4096       ['conv4_block35_out[0][0]']
#  Normalization)                 )
#
#  conv4_block36_preact_relu (Act  (None, 14, 14, 1024  0          ['conv4_block36_preact_bn[0][0]']
#  ivation)                       )
#
#  conv4_block36_1_conv (Conv2D)  (None, 14, 14, 256)  262144      ['conv4_block36_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block36_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block36_1_relu[0][0]']
#  ng2D)
#
#  conv4_block36_2_conv (Conv2D)  (None, 7, 7, 256)    589824      ['conv4_block36_2_pad[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 7, 7, 256)   1024        ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 7, 7, 256)   0           ['conv4_block36_2_bn[0][0]']
#  on)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block35_out[0][0]']
#
#  conv4_block36_3_conv (Conv2D)  (None, 7, 7, 1024)   263168      ['conv4_block36_2_relu[0][0]']
#
#  conv4_block36_out (Add)        (None, 7, 7, 1024)   0           ['max_pooling2d_8[0][0]',
#                                                                   'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block36_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 60,380,648
# Trainable params: 60,236,904
# Non-trainable params: 143,744
# __________________________________________________________________________________________________

# %% [markdown]
# # InceptionV3

# %%
InceptionV3 = tf.keras.applications.InceptionV3(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 9s 0us/step
# 96124928/96112376 [==============================] - 9s 0us/step

# %%
model_analyze(InceptionV3)
# Out:
# Layers 0(-313): input_10
# Layers 1(-312): conv2d_4
# Layers 2(-311): batch_normalization_4
# Layers 3(-310): activation
# Layers 4(-309): conv2d_5
# Layers 5(-308): batch_normalization_5
# Layers 6(-307): activation_1
# Layers 7(-306): conv2d_6
# Layers 8(-305): batch_normalization_6
# Layers 9(-304): activation_2
# Layers 10(-303): max_pooling2d_9
# Layers 11(-302): conv2d_7
# Layers 12(-301): batch_normalization_7
# Layers 13(-300): activation_3
# Layers 14(-299): conv2d_8
# Layers 15(-298): batch_normalization_8
# Layers 16(-297): activation_4
# Layers 17(-296): max_pooling2d_10
# Layers 18(-295): conv2d_12
# Layers 19(-294): batch_normalization_12
# Layers 20(-293): activation_8
# Layers 21(-292): conv2d_10
# Layers 22(-291): conv2d_13
# Layers 23(-290): batch_normalization_10
# Layers 24(-289): batch_normalization_13
# Layers 25(-288): activation_6
# Layers 26(-287): activation_9
# Layers 27(-286): average_pooling2d
# Layers 28(-285): conv2d_9
# Layers 29(-284): conv2d_11
# Layers 30(-283): conv2d_14
# Layers 31(-282): conv2d_15
# Layers 32(-281): batch_normalization_9
# Layers 33(-280): batch_normalization_11
# Layers 34(-279): batch_normalization_14
# Layers 35(-278): batch_normalization_15
# Layers 36(-277): activation_5
# Layers 37(-276): activation_7
# Layers 38(-275): activation_10
# Layers 39(-274): activation_11
# Layers 40(-273): mixed0
# Layers 41(-272): conv2d_19
# Layers 42(-271): batch_normalization_19
# Layers 43(-270): activation_15
# Layers 44(-269): conv2d_17
# Layers 45(-268): conv2d_20
# Layers 46(-267): batch_normalization_17
# Layers 47(-266): batch_normalization_20
# Layers 48(-265): activation_13
# Layers 49(-264): activation_16
# Layers 50(-263): average_pooling2d_1
# Layers 51(-262): conv2d_16
# Layers 52(-261): conv2d_18
# Layers 53(-260): conv2d_21
# Layers 54(-259): conv2d_22
# Layers 55(-258): batch_normalization_16
# Layers 56(-257): batch_normalization_18
# Layers 57(-256): batch_normalization_21
# Layers 58(-255): batch_normalization_22
# Layers 59(-254): activation_12
# Layers 60(-253): activation_14
# Layers 61(-252): activation_17
# Layers 62(-251): activation_18
# Layers 63(-250): mixed1
# Layers 64(-249): conv2d_26
# Layers 65(-248): batch_normalization_26
# Layers 66(-247): activation_22
# Layers 67(-246): conv2d_24
# Layers 68(-245): conv2d_27
# Layers 69(-244): batch_normalization_24
# Layers 70(-243): batch_normalization_27
# Layers 71(-242): activation_20
# Layers 72(-241): activation_23
# Layers 73(-240): average_pooling2d_2
# Layers 74(-239): conv2d_23
# Layers 75(-238): conv2d_25
# Layers 76(-237): conv2d_28
# Layers 77(-236): conv2d_29
# Layers 78(-235): batch_normalization_23
# Layers 79(-234): batch_normalization_25
# Layers 80(-233): batch_normalization_28
# Layers 81(-232): batch_normalization_29
# Layers 82(-231): activation_19
# Layers 83(-230): activation_21
# Layers 84(-229): activation_24
# Layers 85(-228): activation_25
# Layers 86(-227): mixed2
# Layers 87(-226): conv2d_31
# Layers 88(-225): batch_normalization_31
# Layers 89(-224): activation_27
# Layers 90(-223): conv2d_32
# Layers 91(-222): batch_normalization_32
# Layers 92(-221): activation_28
# Layers 93(-220): conv2d_30
# Layers 94(-219): conv2d_33
# Layers 95(-218): batch_normalization_30
# Layers 96(-217): batch_normalization_33
# Layers 97(-216): activation_26
# Layers 98(-215): activation_29
# Layers 99(-214): max_pooling2d_11
# Layers 100(-213): mixed3
# Layers 101(-212): conv2d_38
# Layers 102(-211): batch_normalization_38
# Layers 103(-210): activation_34
# Layers 104(-209): conv2d_39
# Layers 105(-208): batch_normalization_39
# Layers 106(-207): activation_35
# Layers 107(-206): conv2d_35
# Layers 108(-205): conv2d_40
# Layers 109(-204): batch_normalization_35
# Layers 110(-203): batch_normalization_40
# Layers 111(-202): activation_31
# Layers 112(-201): activation_36
# Layers 113(-200): conv2d_36
# Layers 114(-199): conv2d_41
# Layers 115(-198): batch_normalization_36
# Layers 116(-197): batch_normalization_41
# Layers 117(-196): activation_32
# Layers 118(-195): activation_37
# Layers 119(-194): average_pooling2d_3
# Layers 120(-193): conv2d_34
# Layers 121(-192): conv2d_37
# Layers 122(-191): conv2d_42
# Layers 123(-190): conv2d_43
# Layers 124(-189): batch_normalization_34
# Layers 125(-188): batch_normalization_37
# Layers 126(-187): batch_normalization_42
# Layers 127(-186): batch_normalization_43
# Layers 128(-185): activation_30
# Layers 129(-184): activation_33
# Layers 130(-183): activation_38
# Layers 131(-182): activation_39
# Layers 132(-181): mixed4
# Layers 133(-180): conv2d_48
# Layers 134(-179): batch_normalization_48
# Layers 135(-178): activation_44
# Layers 136(-177): conv2d_49
# Layers 137(-176): batch_normalization_49
# Layers 138(-175): activation_45
# Layers 139(-174): conv2d_45
# Layers 140(-173): conv2d_50
# Layers 141(-172): batch_normalization_45
# Layers 142(-171): batch_normalization_50
# Layers 143(-170): activation_41
# Layers 144(-169): activation_46
# Layers 145(-168): conv2d_46
# Layers 146(-167): conv2d_51
# Layers 147(-166): batch_normalization_46
# Layers 148(-165): batch_normalization_51
# Layers 149(-164): activation_42
# Layers 150(-163): activation_47
# Layers 151(-162): average_pooling2d_4
# Layers 152(-161): conv2d_44
# Layers 153(-160): conv2d_47
# Layers 154(-159): conv2d_52
# Layers 155(-158): conv2d_53
# Layers 156(-157): batch_normalization_44
# Layers 157(-156): batch_normalization_47
# Layers 158(-155): batch_normalization_52
# Layers 159(-154): batch_normalization_53
# Layers 160(-153): activation_40
# Layers 161(-152): activation_43
# Layers 162(-151): activation_48
# Layers 163(-150): activation_49
# Layers 164(-149): mixed5
# Layers 165(-148): conv2d_58
# Layers 166(-147): batch_normalization_58
# Layers 167(-146): activation_54
# Layers 168(-145): conv2d_59
# Layers 169(-144): batch_normalization_59
# Layers 170(-143): activation_55
# Layers 171(-142): conv2d_55
# Layers 172(-141): conv2d_60
# Layers 173(-140): batch_normalization_55
# Layers 174(-139): batch_normalization_60
# Layers 175(-138): activation_51
# Layers 176(-137): activation_56
# Layers 177(-136): conv2d_56
# Layers 178(-135): conv2d_61
# Layers 179(-134): batch_normalization_56
# Layers 180(-133): batch_normalization_61
# Layers 181(-132): activation_52
# Layers 182(-131): activation_57
# Layers 183(-130): average_pooling2d_5
# Layers 184(-129): conv2d_54
# Layers 185(-128): conv2d_57
# Layers 186(-127): conv2d_62
# Layers 187(-126): conv2d_63
# Layers 188(-125): batch_normalization_54
# Layers 189(-124): batch_normalization_57
# Layers 190(-123): batch_normalization_62
# Layers 191(-122): batch_normalization_63
# Layers 192(-121): activation_50
# Layers 193(-120): activation_53
# Layers 194(-119): activation_58
# Layers 195(-118): activation_59
# Layers 196(-117): mixed6
# Layers 197(-116): conv2d_68
# Layers 198(-115): batch_normalization_68
# Layers 199(-114): activation_64
# Layers 200(-113): conv2d_69
# Layers 201(-112): batch_normalization_69
# Layers 202(-111): activation_65
# Layers 203(-110): conv2d_65
# Layers 204(-109): conv2d_70
# Layers 205(-108): batch_normalization_65
# Layers 206(-107): batch_normalization_70
# Layers 207(-106): activation_61
# Layers 208(-105): activation_66
# Layers 209(-104): conv2d_66
# Layers 210(-103): conv2d_71
# Layers 211(-102): batch_normalization_66
# Layers 212(-101): batch_normalization_71
# Layers 213(-100): activation_62
# Layers 214(-99): activation_67
# Layers 215(-98): average_pooling2d_6
# Layers 216(-97): conv2d_64
# Layers 217(-96): conv2d_67
# Layers 218(-95): conv2d_72
# Layers 219(-94): conv2d_73
# Layers 220(-93): batch_normalization_64
# Layers 221(-92): batch_normalization_67
# Layers 222(-91): batch_normalization_72
# Layers 223(-90): batch_normalization_73
# Layers 224(-89): activation_60
# Layers 225(-88): activation_63
# Layers 226(-87): activation_68
# Layers 227(-86): activation_69
# Layers 228(-85): mixed7
# Layers 229(-84): conv2d_76
# Layers 230(-83): batch_normalization_76
# Layers 231(-82): activation_72
# Layers 232(-81): conv2d_77
# Layers 233(-80): batch_normalization_77
# Layers 234(-79): activation_73
# Layers 235(-78): conv2d_74
# Layers 236(-77): conv2d_78
# Layers 237(-76): batch_normalization_74
# Layers 238(-75): batch_normalization_78
# Layers 239(-74): activation_70
# Layers 240(-73): activation_74
# Layers 241(-72): conv2d_75
# Layers 242(-71): conv2d_79
# Layers 243(-70): batch_normalization_75
# Layers 244(-69): batch_normalization_79
# Layers 245(-68): activation_71
# Layers 246(-67): activation_75
# Layers 247(-66): max_pooling2d_12
# Layers 248(-65): mixed8
# Layers 249(-64): conv2d_84
# Layers 250(-63): batch_normalization_84
# Layers 251(-62): activation_80
# Layers 252(-61): conv2d_81
# Layers 253(-60): conv2d_85
# Layers 254(-59): batch_normalization_81
# Layers 255(-58): batch_normalization_85
# Layers 256(-57): activation_77
# Layers 257(-56): activation_81
# Layers 258(-55): conv2d_82
# Layers 259(-54): conv2d_83
# Layers 260(-53): conv2d_86
# Layers 261(-52): conv2d_87
# Layers 262(-51): average_pooling2d_7
# Layers 263(-50): conv2d_80
# Layers 264(-49): batch_normalization_82
# Layers 265(-48): batch_normalization_83
# Layers 266(-47): batch_normalization_86
# Layers 267(-46): batch_normalization_87
# Layers 268(-45): conv2d_88
# Layers 269(-44): batch_normalization_80
# Layers 270(-43): activation_78
# Layers 271(-42): activation_79
# Layers 272(-41): activation_82
# Layers 273(-40): activation_83
# Layers 274(-39): batch_normalization_88
# Layers 275(-38): activation_76
# Layers 276(-37): mixed9_0
# Layers 277(-36): concatenate
# Layers 278(-35): activation_84
# Layers 279(-34): mixed9
# Layers 280(-33): conv2d_93
# Layers 281(-32): batch_normalization_93
# Layers 282(-31): activation_89
# Layers 283(-30): conv2d_90
# Layers 284(-29): conv2d_94
# Layers 285(-28): batch_normalization_90
# Layers 286(-27): batch_normalization_94
# Layers 287(-26): activation_86
# Layers 288(-25): activation_90
# Layers 289(-24): conv2d_91
# Layers 290(-23): conv2d_92
# Layers 291(-22): conv2d_95
# Layers 292(-21): conv2d_96
# Layers 293(-20): average_pooling2d_8
# Layers 294(-19): conv2d_89
# Layers 295(-18): batch_normalization_91
# Layers 296(-17): batch_normalization_92
# Layers 297(-16): batch_normalization_95
# Layers 298(-15): batch_normalization_96
# Layers 299(-14): conv2d_97
# Layers 300(-13): batch_normalization_89
# Layers 301(-12): activation_87
# Layers 302(-11): activation_88
# Layers 303(-10): activation_91
# Layers 304(-9): activation_92
# Layers 305(-8): batch_normalization_97
# Layers 306(-7): activation_85
# Layers 307(-6): mixed9_1
# Layers 308(-5): concatenate_1
# Layers 309(-4): activation_93
# Layers 310(-3): mixed10
# Layers 311(-2): avg_pool
# Layers 312(-1): predictions

# %%
InceptionV3.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 149, 149, 32  864         ['input_10[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 149, 149, 32  96         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 147, 147, 32  96         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 147, 147, 64  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 73, 73, 64)  0           ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d_9[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#  )
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   12288       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 48)   9216        ['max_pooling2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 48)  144         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_10[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_13[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_10[0][0]']
#  ing2D)
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 96)  288         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_9[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_11[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_14[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_15[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 48)  144         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 96)  288         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_17[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_20[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 64)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 96)  288         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_16[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_21[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#  conv2d_26 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 35, 35, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 48)  144         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 96)  288         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_24[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_27[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 35, 35, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_23[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_29[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 35, 35, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 35, 35, 96)  288         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 96)  288         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_30[0][0]']
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_33[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_11[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 128)  384        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 128)  384        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 128)  384        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_41[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 192)  576        ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 192)  576        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_34[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_37[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_42[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 160)  480        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 160)  480        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 160)  480        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 192)  576        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_44[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_47[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_52[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 17, 17, 160)  480        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_61 (BatchN  (None, 17, 17, 160)  480        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_61[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 192)  576        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 17, 17, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 17, 17, 192)  576        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_54[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_57[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_62[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_63[0][0]']
#
# ...
#                                                                   'max_pooling2d_12[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_84[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_85[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_80 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 8, 8, 320)   960         ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 192)   576         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_80[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_88[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_93[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_94[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_96[0][0]']
#  ormalization)
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 320)   960         ['conv2d_89[0][0]']
#  ormalization)
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_95[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 8, 8, 192)   576         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_89[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_97[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %% [markdown]
# # InceptionResnetV2

# %%
InceptionResNetV2 = tf.keras.applications.InceptionResNetV2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax"
)

# %%
model_analyze(InceptionResNetV2)
# Out:
# Layers 0(-782): input_11
# Layers 1(-781): conv2d_98
# Layers 2(-780): batch_normalization_98
# Layers 3(-779): activation_94
# Layers 4(-778): conv2d_99
# Layers 5(-777): batch_normalization_99
# Layers 6(-776): activation_95
# Layers 7(-775): conv2d_100
# Layers 8(-774): batch_normalization_100
# Layers 9(-773): activation_96
# Layers 10(-772): max_pooling2d_13
# Layers 11(-771): conv2d_101
# Layers 12(-770): batch_normalization_101
# Layers 13(-769): activation_97
# Layers 14(-768): conv2d_102
# Layers 15(-767): batch_normalization_102
# Layers 16(-766): activation_98
# Layers 17(-765): max_pooling2d_14
# Layers 18(-764): conv2d_106
# Layers 19(-763): batch_normalization_106
# Layers 20(-762): activation_102
# Layers 21(-761): conv2d_104
# Layers 22(-760): conv2d_107
# Layers 23(-759): batch_normalization_104
# Layers 24(-758): batch_normalization_107
# Layers 25(-757): activation_100
# Layers 26(-756): activation_103
# Layers 27(-755): average_pooling2d_9
# Layers 28(-754): conv2d_103
# Layers 29(-753): conv2d_105
# Layers 30(-752): conv2d_108
# Layers 31(-751): conv2d_109
# Layers 32(-750): batch_normalization_103
# Layers 33(-749): batch_normalization_105
# Layers 34(-748): batch_normalization_108
# Layers 35(-747): batch_normalization_109
# Layers 36(-746): activation_99
# Layers 37(-745): activation_101
# Layers 38(-744): activation_104
# Layers 39(-743): activation_105
# Layers 40(-742): mixed_5b
# Layers 41(-741): conv2d_113
# Layers 42(-740): batch_normalization_113
# Layers 43(-739): activation_109
# Layers 44(-738): conv2d_111
# Layers 45(-737): conv2d_114
# Layers 46(-736): batch_normalization_111
# Layers 47(-735): batch_normalization_114
# Layers 48(-734): activation_107
# Layers 49(-733): activation_110
# Layers 50(-732): conv2d_110
# Layers 51(-731): conv2d_112
# Layers 52(-730): conv2d_115
# Layers 53(-729): batch_normalization_110
# Layers 54(-728): batch_normalization_112
# Layers 55(-727): batch_normalization_115
# Layers 56(-726): activation_106
# Layers 57(-725): activation_108
# Layers 58(-724): activation_111
# Layers 59(-723): block35_1_mixed
# Layers 60(-722): block35_1_conv
# Layers 61(-721): block35_1
# Layers 62(-720): block35_1_ac
# Layers 63(-719): conv2d_119
# Layers 64(-718): batch_normalization_119
# Layers 65(-717): activation_115
# Layers 66(-716): conv2d_117
# Layers 67(-715): conv2d_120
# Layers 68(-714): batch_normalization_117
# Layers 69(-713): batch_normalization_120
# Layers 70(-712): activation_113
# Layers 71(-711): activation_116
# Layers 72(-710): conv2d_116
# Layers 73(-709): conv2d_118
# Layers 74(-708): conv2d_121
# Layers 75(-707): batch_normalization_116
# Layers 76(-706): batch_normalization_118
# Layers 77(-705): batch_normalization_121
# Layers 78(-704): activation_112
# Layers 79(-703): activation_114
# Layers 80(-702): activation_117
# Layers 81(-701): block35_2_mixed
# Layers 82(-700): block35_2_conv
# Layers 83(-699): block35_2
# Layers 84(-698): block35_2_ac
# Layers 85(-697): conv2d_125
# Layers 86(-696): batch_normalization_125
# Layers 87(-695): activation_121
# Layers 88(-694): conv2d_123
# Layers 89(-693): conv2d_126
# Layers 90(-692): batch_normalization_123
# Layers 91(-691): batch_normalization_126
# Layers 92(-690): activation_119
# Layers 93(-689): activation_122
# Layers 94(-688): conv2d_122
# Layers 95(-687): conv2d_124
# Layers 96(-686): conv2d_127
# Layers 97(-685): batch_normalization_122
# Layers 98(-684): batch_normalization_124
# Layers 99(-683): batch_normalization_127
# Layers 100(-682): activation_118
# Layers 101(-681): activation_120
# Layers 102(-680): activation_123
# Layers 103(-679): block35_3_mixed
# Layers 104(-678): block35_3_conv
# Layers 105(-677): block35_3
# Layers 106(-676): block35_3_ac
# Layers 107(-675): conv2d_131
# Layers 108(-674): batch_normalization_131
# Layers 109(-673): activation_127
# Layers 110(-672): conv2d_129
# Layers 111(-671): conv2d_132
# Layers 112(-670): batch_normalization_129
# Layers 113(-669): batch_normalization_132
# Layers 114(-668): activation_125
# Layers 115(-667): activation_128
# Layers 116(-666): conv2d_128
# Layers 117(-665): conv2d_130
# Layers 118(-664): conv2d_133
# Layers 119(-663): batch_normalization_128
# Layers 120(-662): batch_normalization_130
# Layers 121(-661): batch_normalization_133
# Layers 122(-660): activation_124
# Layers 123(-659): activation_126
# Layers 124(-658): activation_129
# Layers 125(-657): block35_4_mixed
# Layers 126(-656): block35_4_conv
# Layers 127(-655): block35_4
# Layers 128(-654): block35_4_ac
# Layers 129(-653): conv2d_137
# Layers 130(-652): batch_normalization_137
# Layers 131(-651): activation_133
# Layers 132(-650): conv2d_135
# Layers 133(-649): conv2d_138
# Layers 134(-648): batch_normalization_135
# Layers 135(-647): batch_normalization_138
# Layers 136(-646): activation_131
# Layers 137(-645): activation_134
# Layers 138(-644): conv2d_134
# Layers 139(-643): conv2d_136
# Layers 140(-642): conv2d_139
# Layers 141(-641): batch_normalization_134
# Layers 142(-640): batch_normalization_136
# Layers 143(-639): batch_normalization_139
# Layers 144(-638): activation_130
# Layers 145(-637): activation_132
# Layers 146(-636): activation_135
# Layers 147(-635): block35_5_mixed
# Layers 148(-634): block35_5_conv
# Layers 149(-633): block35_5
# Layers 150(-632): block35_5_ac
# Layers 151(-631): conv2d_143
# Layers 152(-630): batch_normalization_143
# Layers 153(-629): activation_139
# Layers 154(-628): conv2d_141
# Layers 155(-627): conv2d_144
# Layers 156(-626): batch_normalization_141
# Layers 157(-625): batch_normalization_144
# Layers 158(-624): activation_137
# Layers 159(-623): activation_140
# Layers 160(-622): conv2d_140
# Layers 161(-621): conv2d_142
# Layers 162(-620): conv2d_145
# Layers 163(-619): batch_normalization_140
# Layers 164(-618): batch_normalization_142
# Layers 165(-617): batch_normalization_145
# Layers 166(-616): activation_136
# Layers 167(-615): activation_138
# Layers 168(-614): activation_141
# Layers 169(-613): block35_6_mixed
# Layers 170(-612): block35_6_conv
# Layers 171(-611): block35_6
# Layers 172(-610): block35_6_ac
# Layers 173(-609): conv2d_149
# Layers 174(-608): batch_normalization_149
# Layers 175(-607): activation_145
# Layers 176(-606): conv2d_147
# Layers 177(-605): conv2d_150
# Layers 178(-604): batch_normalization_147
# Layers 179(-603): batch_normalization_150
# Layers 180(-602): activation_143
# Layers 181(-601): activation_146
# Layers 182(-600): conv2d_146
# Layers 183(-599): conv2d_148
# Layers 184(-598): conv2d_151
# Layers 185(-597): batch_normalization_146
# Layers 186(-596): batch_normalization_148
# Layers 187(-595): batch_normalization_151
# Layers 188(-594): activation_142
# Layers 189(-593): activation_144
# Layers 190(-592): activation_147
# Layers 191(-591): block35_7_mixed
# Layers 192(-590): block35_7_conv
# Layers 193(-589): block35_7
# Layers 194(-588): block35_7_ac
# Layers 195(-587): conv2d_155
# Layers 196(-586): batch_normalization_155
# Layers 197(-585): activation_151
# Layers 198(-584): conv2d_153
# Layers 199(-583): conv2d_156
# Layers 200(-582): batch_normalization_153
# Layers 201(-581): batch_normalization_156
# Layers 202(-580): activation_149
# Layers 203(-579): activation_152
# Layers 204(-578): conv2d_152
# Layers 205(-577): conv2d_154
# Layers 206(-576): conv2d_157
# Layers 207(-575): batch_normalization_152
# Layers 208(-574): batch_normalization_154
# Layers 209(-573): batch_normalization_157
# Layers 210(-572): activation_148
# Layers 211(-571): activation_150
# Layers 212(-570): activation_153
# Layers 213(-569): block35_8_mixed
# Layers 214(-568): block35_8_conv
# Layers 215(-567): block35_8
# Layers 216(-566): block35_8_ac
# Layers 217(-565): conv2d_161
# Layers 218(-564): batch_normalization_161
# Layers 219(-563): activation_157
# Layers 220(-562): conv2d_159
# Layers 221(-561): conv2d_162
# Layers 222(-560): batch_normalization_159
# Layers 223(-559): batch_normalization_162
# Layers 224(-558): activation_155
# Layers 225(-557): activation_158
# Layers 226(-556): conv2d_158
# Layers 227(-555): conv2d_160
# Layers 228(-554): conv2d_163
# Layers 229(-553): batch_normalization_158
# Layers 230(-552): batch_normalization_160
# Layers 231(-551): batch_normalization_163
# Layers 232(-550): activation_154
# Layers 233(-549): activation_156
# Layers 234(-548): activation_159
# Layers 235(-547): block35_9_mixed
# Layers 236(-546): block35_9_conv
# Layers 237(-545): block35_9
# Layers 238(-544): block35_9_ac
# Layers 239(-543): conv2d_167
# Layers 240(-542): batch_normalization_167
# Layers 241(-541): activation_163
# Layers 242(-540): conv2d_165
# Layers 243(-539): conv2d_168
# Layers 244(-538): batch_normalization_165
# Layers 245(-537): batch_normalization_168
# Layers 246(-536): activation_161
# Layers 247(-535): activation_164
# Layers 248(-534): conv2d_164
# Layers 249(-533): conv2d_166
# Layers 250(-532): conv2d_169
# Layers 251(-531): batch_normalization_164
# Layers 252(-530): batch_normalization_166
# Layers 253(-529): batch_normalization_169
# Layers 254(-528): activation_160
# Layers 255(-527): activation_162
# Layers 256(-526): activation_165
# Layers 257(-525): block35_10_mixed
# Layers 258(-524): block35_10_conv
# Layers 259(-523): block35_10
# Layers 260(-522): block35_10_ac
# Layers 261(-521): conv2d_171
# Layers 262(-520): batch_normalization_171
# Layers 263(-519): activation_167
# Layers 264(-518): conv2d_172
# Layers 265(-517): batch_normalization_172
# Layers 266(-516): activation_168
# Layers 267(-515): conv2d_170
# Layers 268(-514): conv2d_173
# Layers 269(-513): batch_normalization_170
# Layers 270(-512): batch_normalization_173
# Layers 271(-511): activation_166
# Layers 272(-510): activation_169
# Layers 273(-509): max_pooling2d_15
# Layers 274(-508): mixed_6a
# Layers 275(-507): conv2d_175
# Layers 276(-506): batch_normalization_175
# Layers 277(-505): activation_171
# Layers 278(-504): conv2d_176
# Layers 279(-503): batch_normalization_176
# Layers 280(-502): activation_172
# Layers 281(-501): conv2d_174
# Layers 282(-500): conv2d_177
# Layers 283(-499): batch_normalization_174
# Layers 284(-498): batch_normalization_177
# Layers 285(-497): activation_170
# Layers 286(-496): activation_173
# Layers 287(-495): block17_1_mixed
# Layers 288(-494): block17_1_conv
# Layers 289(-493): block17_1
# Layers 290(-492): block17_1_ac
# Layers 291(-491): conv2d_179
# Layers 292(-490): batch_normalization_179
# Layers 293(-489): activation_175
# Layers 294(-488): conv2d_180
# Layers 295(-487): batch_normalization_180
# Layers 296(-486): activation_176
# Layers 297(-485): conv2d_178
# Layers 298(-484): conv2d_181
# Layers 299(-483): batch_normalization_178
# Layers 300(-482): batch_normalization_181
# Layers 301(-481): activation_174
# Layers 302(-480): activation_177
# Layers 303(-479): block17_2_mixed
# Layers 304(-478): block17_2_conv
# Layers 305(-477): block17_2
# Layers 306(-476): block17_2_ac
# Layers 307(-475): conv2d_183
# Layers 308(-474): batch_normalization_183
# Layers 309(-473): activation_179
# Layers 310(-472): conv2d_184
# Layers 311(-471): batch_normalization_184
# Layers 312(-470): activation_180
# Layers 313(-469): conv2d_182
# Layers 314(-468): conv2d_185
# Layers 315(-467): batch_normalization_182
# Layers 316(-466): batch_normalization_185
# Layers 317(-465): activation_178
# Layers 318(-464): activation_181
# Layers 319(-463): block17_3_mixed
# Layers 320(-462): block17_3_conv
# Layers 321(-461): block17_3
# Layers 322(-460): block17_3_ac
# Layers 323(-459): conv2d_187
# Layers 324(-458): batch_normalization_187
# Layers 325(-457): activation_183
# Layers 326(-456): conv2d_188
# Layers 327(-455): batch_normalization_188
# Layers 328(-454): activation_184
# Layers 329(-453): conv2d_186
# Layers 330(-452): conv2d_189
# Layers 331(-451): batch_normalization_186
# Layers 332(-450): batch_normalization_189
# Layers 333(-449): activation_182
# Layers 334(-448): activation_185
# Layers 335(-447): block17_4_mixed
# Layers 336(-446): block17_4_conv
# Layers 337(-445): block17_4
# Layers 338(-444): block17_4_ac
# Layers 339(-443): conv2d_191
# Layers 340(-442): batch_normalization_191
# Layers 341(-441): activation_187
# Layers 342(-440): conv2d_192
# Layers 343(-439): batch_normalization_192
# Layers 344(-438): activation_188
# Layers 345(-437): conv2d_190
# Layers 346(-436): conv2d_193
# Layers 347(-435): batch_normalization_190
# Layers 348(-434): batch_normalization_193
# Layers 349(-433): activation_186
# Layers 350(-432): activation_189
# Layers 351(-431): block17_5_mixed
# Layers 352(-430): block17_5_conv
# Layers 353(-429): block17_5
# Layers 354(-428): block17_5_ac
# Layers 355(-427): conv2d_195
# Layers 356(-426): batch_normalization_195
# Layers 357(-425): activation_191
# Layers 358(-424): conv2d_196
# Layers 359(-423): batch_normalization_196
# Layers 360(-422): activation_192
# Layers 361(-421): conv2d_194
# Layers 362(-420): conv2d_197
# Layers 363(-419): batch_normalization_194
# Layers 364(-418): batch_normalization_197
# Layers 365(-417): activation_190
# Layers 366(-416): activation_193
# Layers 367(-415): block17_6_mixed
# Layers 368(-414): block17_6_conv
# Layers 369(-413): block17_6
# Layers 370(-412): block17_6_ac
# Layers 371(-411): conv2d_199
# Layers 372(-410): batch_normalization_199
# Layers 373(-409): activation_195
# Layers 374(-408): conv2d_200
# Layers 375(-407): batch_normalization_200
# Layers 376(-406): activation_196
# Layers 377(-405): conv2d_198
# Layers 378(-404): conv2d_201
# Layers 379(-403): batch_normalization_198
# Layers 380(-402): batch_normalization_201
# Layers 381(-401): activation_194
# Layers 382(-400): activation_197
# Layers 383(-399): block17_7_mixed
# Layers 384(-398): block17_7_conv
# Layers 385(-397): block17_7
# Layers 386(-396): block17_7_ac
# Layers 387(-395): conv2d_203
# Layers 388(-394): batch_normalization_203
# Layers 389(-393): activation_199
# Layers 390(-392): conv2d_204
# Layers 391(-391): batch_normalization_204
# Layers 392(-390): activation_200
# Layers 393(-389): conv2d_202
# Layers 394(-388): conv2d_205
# Layers 395(-387): batch_normalization_202
# Layers 396(-386): batch_normalization_205
# Layers 397(-385): activation_198
# Layers 398(-384): activation_201
# Layers 399(-383): block17_8_mixed
# Layers 400(-382): block17_8_conv
# Layers 401(-381): block17_8
# Layers 402(-380): block17_8_ac
# Layers 403(-379): conv2d_207
# Layers 404(-378): batch_normalization_207
# Layers 405(-377): activation_203
# Layers 406(-376): conv2d_208
# Layers 407(-375): batch_normalization_208
# Layers 408(-374): activation_204
# Layers 409(-373): conv2d_206
# Layers 410(-372): conv2d_209
# Layers 411(-371): batch_normalization_206
# Layers 412(-370): batch_normalization_209
# Layers 413(-369): activation_202
# Layers 414(-368): activation_205
# Layers 415(-367): block17_9_mixed
# Layers 416(-366): block17_9_conv
# Layers 417(-365): block17_9
# Layers 418(-364): block17_9_ac
# Layers 419(-363): conv2d_211
# Layers 420(-362): batch_normalization_211
# Layers 421(-361): activation_207
# Layers 422(-360): conv2d_212
# Layers 423(-359): batch_normalization_212
# Layers 424(-358): activation_208
# Layers 425(-357): conv2d_210
# Layers 426(-356): conv2d_213
# Layers 427(-355): batch_normalization_210
# Layers 428(-354): batch_normalization_213
# Layers 429(-353): activation_206
# Layers 430(-352): activation_209
# Layers 431(-351): block17_10_mixed
# Layers 432(-350): block17_10_conv
# Layers 433(-349): block17_10
# Layers 434(-348): block17_10_ac
# Layers 435(-347): conv2d_215
# Layers 436(-346): batch_normalization_215
# Layers 437(-345): activation_211
# Layers 438(-344): conv2d_216
# Layers 439(-343): batch_normalization_216
# Layers 440(-342): activation_212
# Layers 441(-341): conv2d_214
# Layers 442(-340): conv2d_217
# Layers 443(-339): batch_normalization_214
# Layers 444(-338): batch_normalization_217
# Layers 445(-337): activation_210
# Layers 446(-336): activation_213
# Layers 447(-335): block17_11_mixed
# Layers 448(-334): block17_11_conv
# Layers 449(-333): block17_11
# Layers 450(-332): block17_11_ac
# Layers 451(-331): conv2d_219
# Layers 452(-330): batch_normalization_219
# Layers 453(-329): activation_215
# Layers 454(-328): conv2d_220
# Layers 455(-327): batch_normalization_220
# Layers 456(-326): activation_216
# Layers 457(-325): conv2d_218
# Layers 458(-324): conv2d_221
# Layers 459(-323): batch_normalization_218
# Layers 460(-322): batch_normalization_221
# Layers 461(-321): activation_214
# Layers 462(-320): activation_217
# Layers 463(-319): block17_12_mixed
# Layers 464(-318): block17_12_conv
# Layers 465(-317): block17_12
# Layers 466(-316): block17_12_ac
# Layers 467(-315): conv2d_223
# Layers 468(-314): batch_normalization_223
# Layers 469(-313): activation_219
# Layers 470(-312): conv2d_224
# Layers 471(-311): batch_normalization_224
# Layers 472(-310): activation_220
# Layers 473(-309): conv2d_222
# Layers 474(-308): conv2d_225
# Layers 475(-307): batch_normalization_222
# Layers 476(-306): batch_normalization_225
# Layers 477(-305): activation_218
# Layers 478(-304): activation_221
# Layers 479(-303): block17_13_mixed
# Layers 480(-302): block17_13_conv
# Layers 481(-301): block17_13
# Layers 482(-300): block17_13_ac
# Layers 483(-299): conv2d_227
# Layers 484(-298): batch_normalization_227
# Layers 485(-297): activation_223
# Layers 486(-296): conv2d_228
# Layers 487(-295): batch_normalization_228
# Layers 488(-294): activation_224
# Layers 489(-293): conv2d_226
# Layers 490(-292): conv2d_229
# Layers 491(-291): batch_normalization_226
# Layers 492(-290): batch_normalization_229
# Layers 493(-289): activation_222
# Layers 494(-288): activation_225
# Layers 495(-287): block17_14_mixed
# Layers 496(-286): block17_14_conv
# Layers 497(-285): block17_14
# Layers 498(-284): block17_14_ac
# Layers 499(-283): conv2d_231
# Layers 500(-282): batch_normalization_231
# Layers 501(-281): activation_227
# Layers 502(-280): conv2d_232
# Layers 503(-279): batch_normalization_232
# Layers 504(-278): activation_228
# Layers 505(-277): conv2d_230
# Layers 506(-276): conv2d_233
# Layers 507(-275): batch_normalization_230
# Layers 508(-274): batch_normalization_233
# Layers 509(-273): activation_226
# Layers 510(-272): activation_229
# Layers 511(-271): block17_15_mixed
# Layers 512(-270): block17_15_conv
# Layers 513(-269): block17_15
# Layers 514(-268): block17_15_ac
# Layers 515(-267): conv2d_235
# Layers 516(-266): batch_normalization_235
# Layers 517(-265): activation_231
# Layers 518(-264): conv2d_236
# Layers 519(-263): batch_normalization_236
# Layers 520(-262): activation_232
# Layers 521(-261): conv2d_234
# Layers 522(-260): conv2d_237
# Layers 523(-259): batch_normalization_234
# Layers 524(-258): batch_normalization_237
# Layers 525(-257): activation_230
# Layers 526(-256): activation_233
# Layers 527(-255): block17_16_mixed
# Layers 528(-254): block17_16_conv
# Layers 529(-253): block17_16
# Layers 530(-252): block17_16_ac
# Layers 531(-251): conv2d_239
# Layers 532(-250): batch_normalization_239
# Layers 533(-249): activation_235
# Layers 534(-248): conv2d_240
# Layers 535(-247): batch_normalization_240
# Layers 536(-246): activation_236
# Layers 537(-245): conv2d_238
# Layers 538(-244): conv2d_241
# Layers 539(-243): batch_normalization_238
# Layers 540(-242): batch_normalization_241
# Layers 541(-241): activation_234
# Layers 542(-240): activation_237
# Layers 543(-239): block17_17_mixed
# Layers 544(-238): block17_17_conv
# Layers 545(-237): block17_17
# Layers 546(-236): block17_17_ac
# Layers 547(-235): conv2d_243
# Layers 548(-234): batch_normalization_243
# Layers 549(-233): activation_239
# Layers 550(-232): conv2d_244
# Layers 551(-231): batch_normalization_244
# Layers 552(-230): activation_240
# Layers 553(-229): conv2d_242
# Layers 554(-228): conv2d_245
# Layers 555(-227): batch_normalization_242
# Layers 556(-226): batch_normalization_245
# Layers 557(-225): activation_238
# Layers 558(-224): activation_241
# Layers 559(-223): block17_18_mixed
# Layers 560(-222): block17_18_conv
# Layers 561(-221): block17_18
# Layers 562(-220): block17_18_ac
# Layers 563(-219): conv2d_247
# Layers 564(-218): batch_normalization_247
# Layers 565(-217): activation_243
# Layers 566(-216): conv2d_248
# Layers 567(-215): batch_normalization_248
# Layers 568(-214): activation_244
# Layers 569(-213): conv2d_246
# Layers 570(-212): conv2d_249
# Layers 571(-211): batch_normalization_246
# Layers 572(-210): batch_normalization_249
# Layers 573(-209): activation_242
# Layers 574(-208): activation_245
# Layers 575(-207): block17_19_mixed
# Layers 576(-206): block17_19_conv
# Layers 577(-205): block17_19
# Layers 578(-204): block17_19_ac
# Layers 579(-203): conv2d_251
# Layers 580(-202): batch_normalization_251
# Layers 581(-201): activation_247
# Layers 582(-200): conv2d_252
# Layers 583(-199): batch_normalization_252
# Layers 584(-198): activation_248
# Layers 585(-197): conv2d_250
# Layers 586(-196): conv2d_253
# Layers 587(-195): batch_normalization_250
# Layers 588(-194): batch_normalization_253
# Layers 589(-193): activation_246
# Layers 590(-192): activation_249
# Layers 591(-191): block17_20_mixed
# Layers 592(-190): block17_20_conv
# Layers 593(-189): block17_20
# Layers 594(-188): block17_20_ac
# Layers 595(-187): conv2d_258
# Layers 596(-186): batch_normalization_258
# Layers 597(-185): activation_254
# Layers 598(-184): conv2d_254
# Layers 599(-183): conv2d_256
# Layers 600(-182): conv2d_259
# Layers 601(-181): batch_normalization_254
# Layers 602(-180): batch_normalization_256
# Layers 603(-179): batch_normalization_259
# Layers 604(-178): activation_250
# Layers 605(-177): activation_252
# Layers 606(-176): activation_255
# Layers 607(-175): conv2d_255
# Layers 608(-174): conv2d_257
# Layers 609(-173): conv2d_260
# Layers 610(-172): batch_normalization_255
# Layers 611(-171): batch_normalization_257
# Layers 612(-170): batch_normalization_260
# Layers 613(-169): activation_251
# Layers 614(-168): activation_253
# Layers 615(-167): activation_256
# Layers 616(-166): max_pooling2d_16
# Layers 617(-165): mixed_7a
# Layers 618(-164): conv2d_262
# Layers 619(-163): batch_normalization_262
# Layers 620(-162): activation_258
# Layers 621(-161): conv2d_263
# Layers 622(-160): batch_normalization_263
# Layers 623(-159): activation_259
# Layers 624(-158): conv2d_261
# Layers 625(-157): conv2d_264
# Layers 626(-156): batch_normalization_261
# Layers 627(-155): batch_normalization_264
# Layers 628(-154): activation_257
# Layers 629(-153): activation_260
# Layers 630(-152): block8_1_mixed
# Layers 631(-151): block8_1_conv
# Layers 632(-150): block8_1
# Layers 633(-149): block8_1_ac
# Layers 634(-148): conv2d_266
# Layers 635(-147): batch_normalization_266
# Layers 636(-146): activation_262
# Layers 637(-145): conv2d_267
# Layers 638(-144): batch_normalization_267
# Layers 639(-143): activation_263
# Layers 640(-142): conv2d_265
# Layers 641(-141): conv2d_268
# Layers 642(-140): batch_normalization_265
# Layers 643(-139): batch_normalization_268
# Layers 644(-138): activation_261
# Layers 645(-137): activation_264
# Layers 646(-136): block8_2_mixed
# Layers 647(-135): block8_2_conv
# Layers 648(-134): block8_2
# Layers 649(-133): block8_2_ac
# Layers 650(-132): conv2d_270
# Layers 651(-131): batch_normalization_270
# Layers 652(-130): activation_266
# Layers 653(-129): conv2d_271
# Layers 654(-128): batch_normalization_271
# Layers 655(-127): activation_267
# Layers 656(-126): conv2d_269
# Layers 657(-125): conv2d_272
# Layers 658(-124): batch_normalization_269
# Layers 659(-123): batch_normalization_272
# Layers 660(-122): activation_265
# Layers 661(-121): activation_268
# Layers 662(-120): block8_3_mixed
# Layers 663(-119): block8_3_conv
# Layers 664(-118): block8_3
# Layers 665(-117): block8_3_ac
# Layers 666(-116): conv2d_274
# Layers 667(-115): batch_normalization_274
# Layers 668(-114): activation_270
# Layers 669(-113): conv2d_275
# Layers 670(-112): batch_normalization_275
# Layers 671(-111): activation_271
# Layers 672(-110): conv2d_273
# Layers 673(-109): conv2d_276
# Layers 674(-108): batch_normalization_273
# Layers 675(-107): batch_normalization_276
# Layers 676(-106): activation_269
# Layers 677(-105): activation_272
# Layers 678(-104): block8_4_mixed
# Layers 679(-103): block8_4_conv
# Layers 680(-102): block8_4
# Layers 681(-101): block8_4_ac
# Layers 682(-100): conv2d_278
# Layers 683(-99): batch_normalization_278
# Layers 684(-98): activation_274
# Layers 685(-97): conv2d_279
# Layers 686(-96): batch_normalization_279
# Layers 687(-95): activation_275
# Layers 688(-94): conv2d_277
# Layers 689(-93): conv2d_280
# Layers 690(-92): batch_normalization_277
# Layers 691(-91): batch_normalization_280
# Layers 692(-90): activation_273
# Layers 693(-89): activation_276
# Layers 694(-88): block8_5_mixed
# Layers 695(-87): block8_5_conv
# Layers 696(-86): block8_5
# Layers 697(-85): block8_5_ac
# Layers 698(-84): conv2d_282
# Layers 699(-83): batch_normalization_282
# Layers 700(-82): activation_278
# Layers 701(-81): conv2d_283
# Layers 702(-80): batch_normalization_283
# Layers 703(-79): activation_279
# Layers 704(-78): conv2d_281
# Layers 705(-77): conv2d_284
# Layers 706(-76): batch_normalization_281
# Layers 707(-75): batch_normalization_284
# Layers 708(-74): activation_277
# Layers 709(-73): activation_280
# Layers 710(-72): block8_6_mixed
# Layers 711(-71): block8_6_conv
# Layers 712(-70): block8_6
# Layers 713(-69): block8_6_ac
# Layers 714(-68): conv2d_286
# Layers 715(-67): batch_normalization_286
# Layers 716(-66): activation_282
# Layers 717(-65): conv2d_287
# Layers 718(-64): batch_normalization_287
# Layers 719(-63): activation_283
# Layers 720(-62): conv2d_285
# Layers 721(-61): conv2d_288
# Layers 722(-60): batch_normalization_285
# Layers 723(-59): batch_normalization_288
# Layers 724(-58): activation_281
# Layers 725(-57): activation_284
# Layers 726(-56): block8_7_mixed
# Layers 727(-55): block8_7_conv
# Layers 728(-54): block8_7
# Layers 729(-53): block8_7_ac
# Layers 730(-52): conv2d_290
# Layers 731(-51): batch_normalization_290
# Layers 732(-50): activation_286
# Layers 733(-49): conv2d_291
# Layers 734(-48): batch_normalization_291
# Layers 735(-47): activation_287
# Layers 736(-46): conv2d_289
# Layers 737(-45): conv2d_292
# Layers 738(-44): batch_normalization_289
# Layers 739(-43): batch_normalization_292
# Layers 740(-42): activation_285
# Layers 741(-41): activation_288
# Layers 742(-40): block8_8_mixed
# Layers 743(-39): block8_8_conv
# Layers 744(-38): block8_8
# Layers 745(-37): block8_8_ac
# Layers 746(-36): conv2d_294
# Layers 747(-35): batch_normalization_294
# Layers 748(-34): activation_290
# Layers 749(-33): conv2d_295
# Layers 750(-32): batch_normalization_295
# Layers 751(-31): activation_291
# Layers 752(-30): conv2d_293
# Layers 753(-29): conv2d_296
# Layers 754(-28): batch_normalization_293
# Layers 755(-27): batch_normalization_296
# Layers 756(-26): activation_289
# Layers 757(-25): activation_292
# Layers 758(-24): block8_9_mixed
# Layers 759(-23): block8_9_conv
# Layers 760(-22): block8_9
# Layers 761(-21): block8_9_ac
# Layers 762(-20): conv2d_298
# Layers 763(-19): batch_normalization_298
# Layers 764(-18): activation_294
# Layers 765(-17): conv2d_299
# Layers 766(-16): batch_normalization_299
# Layers 767(-15): activation_295
# Layers 768(-14): conv2d_297
# Layers 769(-13): conv2d_300
# Layers 770(-12): batch_normalization_297
# Layers 771(-11): batch_normalization_300
# Layers 772(-10): activation_293
# Layers 773(-9): activation_296
# Layers 774(-8): block8_10_mixed
# Layers 775(-7): block8_10_conv
# Layers 776(-6): block8_10
# Layers 777(-5): conv_7b
# Layers 778(-4): conv_7b_bn
# Layers 779(-3): conv_7b_ac
# Layers 780(-2): avg_pool
# Layers 781(-1): predictions

# %%
InceptionResNetV2.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_98 (Conv2D)             (None, 149, 149, 32  864         ['input_11[0][0]']
#                                 )
#
#  batch_normalization_98 (BatchN  (None, 149, 149, 32  96         ['conv2d_98[0][0]']
#  ormalization)                  )
#
#  activation_94 (Activation)     (None, 149, 149, 32  0           ['batch_normalization_98[0][0]']
#                                 )
#
#  conv2d_99 (Conv2D)             (None, 147, 147, 32  9216        ['activation_94[0][0]']
#                                 )
#
#  batch_normalization_99 (BatchN  (None, 147, 147, 32  96         ['conv2d_99[0][0]']
#  ormalization)                  )
#
#  activation_95 (Activation)     (None, 147, 147, 32  0           ['batch_normalization_99[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 147, 147, 64  18432       ['activation_95[0][0]']
#                                 )
#
#  batch_normalization_100 (Batch  (None, 147, 147, 64  192        ['conv2d_100[0][0]']
#  Normalization)                 )
#
#  activation_96 (Activation)     (None, 147, 147, 64  0           ['batch_normalization_100[0][0]']
#                                 )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_96[0][0]']
#  )
#
#  conv2d_101 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_101 (Batch  (None, 73, 73, 80)  240         ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_97 (Activation)     (None, 73, 73, 80)   0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_102 (Batch  (None, 71, 71, 192)  576        ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_98 (Activation)     (None, 71, 71, 192)  0           ['batch_normalization_102[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_98[0][0]']
#  )
#
#  conv2d_106 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_106 (Batch  (None, 35, 35, 64)  192         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_106[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_14[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_104 (Batch  (None, 35, 35, 48)  144         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_107 (Batch  (None, 35, 35, 96)  288         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_104[0][0]']
#
#  activation_103 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_107[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 35, 35, 192)  0          ['max_pooling2d_14[0][0]']
#  oling2D)
#
#  conv2d_103 (Conv2D)            (None, 35, 35, 96)   18432       ['max_pooling2d_14[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_103[0][0]']
#  conv2d_109 (Conv2D)            (None, 35, 35, 64)   12288       ['average_pooling2d_9[0][0]']
#
#  batch_normalization_103 (Batch  (None, 35, 35, 96)  288         ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 35, 35, 64)  192         ['conv2d_105[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 35, 35, 96)  288         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_109 (Batch  (None, 35, 35, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_103[0][0]']
#
#  activation_101 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_105[0][0]']
#
#  activation_104 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_108[0][0]']
#
#  activation_105 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_109[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_113 (Batch  (None, 35, 35, 32)  96          ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_113[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_109[0][0]']
#
#  batch_normalization_111 (Batch  (None, 35, 35, 32)  96          ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 35, 35, 48)  144         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_111[0][0]']
#
#  activation_110 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_114[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_107[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_110[0][0]']
#
#  batch_normalization_110 (Batch  (None, 35, 35, 32)  96          ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 35, 35, 32)  96          ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 35, 35, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_110[0][0]']
#
#  activation_108 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_112[0][0]']
#
#  activation_111 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_115[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 35, 35, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['block35_1[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_119 (Batch  (None, 35, 35, 32)  96          ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_119[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_115[0][0]']
#
#  batch_normalization_117 (Batch  (None, 35, 35, 32)  96          ['conv2d_117[0][0]']
#  Normalization)
#
#  batch_normalization_120 (Batch  (None, 35, 35, 48)  144         ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_117[0][0]']
#
#  activation_116 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_120[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_113[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_116[0][0]']
#
#  batch_normalization_116 (Batch  (None, 35, 35, 32)  96          ['conv2d_116[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 35, 35, 32)  96          ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_121 (Batch  (None, 35, 35, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_116[0][0]']
#
#  activation_114 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_118[0][0]']
#
#  activation_117 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_121[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_112[0][0]',
#                                                                   'activation_114[0][0]',
#                                                                   'activation_117[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 35, 35, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['block35_2[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_125 (Batch  (None, 35, 35, 32)  96          ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_125[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_121[0][0]']
#
#  batch_normalization_123 (Batch  (None, 35, 35, 32)  96          ['conv2d_123[0][0]']
#  Normalization)
#
#  batch_normalization_126 (Batch  (None, 35, 35, 48)  144         ['conv2d_126[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_123[0][0]']
#
#  activation_122 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_126[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_119[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_122[0][0]']
#
#  batch_normalization_122 (Batch  (None, 35, 35, 32)  96          ['conv2d_122[0][0]']
#  Normalization)
#
#  batch_normalization_124 (Batch  (None, 35, 35, 32)  96          ['conv2d_124[0][0]']
#  Normalization)
#  batch_normalization_127 (Batch  (None, 35, 35, 64)  192         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_122[0][0]']
#
#  activation_120 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_124[0][0]']
#
#  activation_123 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_127[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_118[0][0]',
#                                                                   'activation_120[0][0]',
#                                                                   'activation_123[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 35, 35, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['block35_3[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_131 (Batch  (None, 35, 35, 32)  96          ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_131[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_127[0][0]']
#
#  batch_normalization_129 (Batch  (None, 35, 35, 32)  96          ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 35, 35, 48)  144         ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_129[0][0]']
#
#  activation_128 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_132[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_125[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_128[0][0]']
#
#  batch_normalization_128 (Batch  (None, 35, 35, 32)  96          ['conv2d_128[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 35, 35, 32)  96          ['conv2d_130[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 35, 35, 64)  192         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_128[0][0]']
#
#  activation_126 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_130[0][0]']
#
#  activation_129 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_133[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_124[0][0]',
#                                                                   'activation_126[0][0]',
#                                                                   'activation_129[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 35, 35, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['block35_4[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_137 (Batch  (None, 35, 35, 32)  96          ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_137[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_133[0][0]']
#
#  batch_normalization_135 (Batch  (None, 35, 35, 32)  96          ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_138 (Batch  (None, 35, 35, 48)  144         ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_135[0][0]']
#
#  activation_134 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_138[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_131[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_134[0][0]']
#
#  batch_normalization_134 (Batch  (None, 35, 35, 32)  96          ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_136 (Batch  (None, 35, 35, 32)  96          ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_139 (Batch  (None, 35, 35, 64)  192         ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_134[0][0]']
#
#  activation_132 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_136[0][0]']
#
#  activation_135 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_139[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_130[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_135[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 35, 35, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['block35_5[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_143 (Batch  (None, 35, 35, 32)  96          ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_143[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_139[0][0]']
#
#  batch_normalization_141 (Batch  (None, 35, 35, 32)  96          ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_144 (Batch  (None, 35, 35, 48)  144         ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_141[0][0]']
#
#  activation_140 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_144[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_137[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_140[0][0]']
#
#  batch_normalization_140 (Batch  (None, 35, 35, 32)  96          ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 35, 35, 32)  96          ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 35, 35, 64)  192         ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_140[0][0]']
#
#  activation_138 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_142[0][0]']
#  activation_141 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_145[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_136[0][0]',
#                                                                   'activation_138[0][0]',
#                                                                   'activation_141[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 35, 35, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['block35_6[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_149 (Batch  (None, 35, 35, 32)  96          ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_149[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_145[0][0]']
#
#  batch_normalization_147 (Batch  (None, 35, 35, 32)  96          ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 35, 35, 48)  144         ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_147[0][0]']
#
#  activation_146 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_150[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_143[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_146[0][0]']
#
#  batch_normalization_146 (Batch  (None, 35, 35, 32)  96          ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_148 (Batch  (None, 35, 35, 32)  96          ['conv2d_148[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 35, 35, 64)  192         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_146[0][0]']
#
#  activation_144 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_148[0][0]']
#
#  activation_147 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_151[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_142[0][0]',
#                                                                   'activation_144[0][0]',
#                                                                   'activation_147[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 35, 35, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['block35_7[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_155 (Batch  (None, 35, 35, 32)  96          ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_155[0][0]']
#
# ...
#  Normalization)
#
#  activation_282 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_286[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_282[0][0]']
#
#  batch_normalization_287 (Batch  (None, 8, 8, 224)   672         ['conv2d_287[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_287[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_283[0][0]']
#
#  batch_normalization_285 (Batch  (None, 8, 8, 192)   576         ['conv2d_285[0][0]']
#  Normalization)
#
#  batch_normalization_288 (Batch  (None, 8, 8, 256)   768         ['conv2d_288[0][0]']
#  Normalization)
#
#  activation_281 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_285[0][0]']
#
#  activation_284 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_288[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_281[0][0]',
#                                                                   'activation_284[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 8, 8, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_290 (Batch  (None, 8, 8, 192)   576         ['conv2d_290[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_290[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_286[0][0]']
#
#  batch_normalization_291 (Batch  (None, 8, 8, 224)   672         ['conv2d_291[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_291[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_287[0][0]']
#
#  batch_normalization_289 (Batch  (None, 8, 8, 192)   576         ['conv2d_289[0][0]']
#  Normalization)
#
#  batch_normalization_292 (Batch  (None, 8, 8, 256)   768         ['conv2d_292[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_289[0][0]']
#
#  activation_288 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_292[0][0]']
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_285[0][0]',
#                                                                   'activation_288[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 8, 8, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_294 (Batch  (None, 8, 8, 192)   576         ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_294[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_290[0][0]']
#
#  batch_normalization_295 (Batch  (None, 8, 8, 224)   672         ['conv2d_295[0][0]']
#  Normalization)
#
#  activation_291 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_295[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_291[0][0]']
#
#  batch_normalization_293 (Batch  (None, 8, 8, 192)   576         ['conv2d_293[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 8, 8, 256)   768         ['conv2d_296[0][0]']
#  Normalization)
#
#  activation_289 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_293[0][0]']
#
#  activation_292 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_296[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_289[0][0]',
#                                                                   'activation_292[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 8, 8, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_298 (Batch  (None, 8, 8, 192)   576         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_298[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_294[0][0]']
#
#  batch_normalization_299 (Batch  (None, 8, 8, 224)   672         ['conv2d_299[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_299[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_295[0][0]']
#
#  batch_normalization_297 (Batch  (None, 8, 8, 192)   576         ['conv2d_297[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 8, 8, 256)   768         ['conv2d_300[0][0]']
#  Normalization)
#
#  activation_293 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_297[0][0]']
#
#  activation_296 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_300[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_293[0][0]',
#                                                                   'activation_296[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 8, 8, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         1537000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 55,873,736
# Trainable params: 55,813,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %% [markdown]
# # MobileNet

# %%
MobileNet = tf.keras.applications.MobileNet(
    input_shape=None,
    alpha=1.0,
    depth_multiplier=1,
    dropout=0.001,
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax"
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 2s 0us/step
# 17235968/17225924 [==============================] - 2s 0us/step

# %%
model_analyze(MobileNet)
# Out:
# Layers 0(-91): input_12
# Layers 1(-90): conv1
# Layers 2(-89): conv1_bn
# Layers 3(-88): conv1_relu
# Layers 4(-87): conv_dw_1
# Layers 5(-86): conv_dw_1_bn
# Layers 6(-85): conv_dw_1_relu
# Layers 7(-84): conv_pw_1
# Layers 8(-83): conv_pw_1_bn
# Layers 9(-82): conv_pw_1_relu
# Layers 10(-81): conv_pad_2
# Layers 11(-80): conv_dw_2
# Layers 12(-79): conv_dw_2_bn
# Layers 13(-78): conv_dw_2_relu
# Layers 14(-77): conv_pw_2
# Layers 15(-76): conv_pw_2_bn
# Layers 16(-75): conv_pw_2_relu
# Layers 17(-74): conv_dw_3
# Layers 18(-73): conv_dw_3_bn
# Layers 19(-72): conv_dw_3_relu
# Layers 20(-71): conv_pw_3
# Layers 21(-70): conv_pw_3_bn
# Layers 22(-69): conv_pw_3_relu
# Layers 23(-68): conv_pad_4
# Layers 24(-67): conv_dw_4
# Layers 25(-66): conv_dw_4_bn
# Layers 26(-65): conv_dw_4_relu
# Layers 27(-64): conv_pw_4
# Layers 28(-63): conv_pw_4_bn
# Layers 29(-62): conv_pw_4_relu
# Layers 30(-61): conv_dw_5
# Layers 31(-60): conv_dw_5_bn
# Layers 32(-59): conv_dw_5_relu
# Layers 33(-58): conv_pw_5
# Layers 34(-57): conv_pw_5_bn
# Layers 35(-56): conv_pw_5_relu
# Layers 36(-55): conv_pad_6
# Layers 37(-54): conv_dw_6
# Layers 38(-53): conv_dw_6_bn
# Layers 39(-52): conv_dw_6_relu
# Layers 40(-51): conv_pw_6
# Layers 41(-50): conv_pw_6_bn
# Layers 42(-49): conv_pw_6_relu
# Layers 43(-48): conv_dw_7
# Layers 44(-47): conv_dw_7_bn
# Layers 45(-46): conv_dw_7_relu
# Layers 46(-45): conv_pw_7
# Layers 47(-44): conv_pw_7_bn
# Layers 48(-43): conv_pw_7_relu
# Layers 49(-42): conv_dw_8
# Layers 50(-41): conv_dw_8_bn
# Layers 51(-40): conv_dw_8_relu
# Layers 52(-39): conv_pw_8
# Layers 53(-38): conv_pw_8_bn
# Layers 54(-37): conv_pw_8_relu
# Layers 55(-36): conv_dw_9
# Layers 56(-35): conv_dw_9_bn
# Layers 57(-34): conv_dw_9_relu
# Layers 58(-33): conv_pw_9
# Layers 59(-32): conv_pw_9_bn
# Layers 60(-31): conv_pw_9_relu
# Layers 61(-30): conv_dw_10
# Layers 62(-29): conv_dw_10_bn
# Layers 63(-28): conv_dw_10_relu
# Layers 64(-27): conv_pw_10
# Layers 65(-26): conv_pw_10_bn
# Layers 66(-25): conv_pw_10_relu
# Layers 67(-24): conv_dw_11
# Layers 68(-23): conv_dw_11_bn
# Layers 69(-22): conv_dw_11_relu
# Layers 70(-21): conv_pw_11
# Layers 71(-20): conv_pw_11_bn
# Layers 72(-19): conv_pw_11_relu
# Layers 73(-18): conv_pad_12
# Layers 74(-17): conv_dw_12
# Layers 75(-16): conv_dw_12_bn
# Layers 76(-15): conv_dw_12_relu
# Layers 77(-14): conv_pw_12
# Layers 78(-13): conv_pw_12_bn
# Layers 79(-12): conv_pw_12_relu
# Layers 80(-11): conv_dw_13
# Layers 81(-10): conv_dw_13_bn
# Layers 82(-9): conv_dw_13_relu
# Layers 83(-8): conv_pw_13
# Layers 84(-7): conv_pw_13_bn
# Layers 85(-6): conv_pw_13_relu
# Layers 86(-5): global_average_pooling2d
# Layers 87(-4): dropout
# Layers 88(-3): conv_preds
# Layers 89(-2): reshape_2
# Layers 90(-1): predictions

# %%
MobileNet.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1, 1, 1024)       0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)        0
#
#  conv_preds (Conv2D)         (None, 1, 1, 1000)        1025000
#
#  reshape_2 (Reshape)         (None, 1000)              0
#
#  predictions (Activation)    (None, 1000)              0
#
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# # MobileNetV2

# %%
MobileNetV2 = tf.keras.applications.MobileNetV2(
    input_shape=None,
    alpha=1.0,
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax"
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14540800/14536120 [==============================] - 2s 0us/step
# 14548992/14536120 [==============================] - 2s 0us/step

# %%
model_analyze(MobileNetV2)
# Out:
# Layers 0(-156): input_13
# Layers 1(-155): Conv1
# Layers 2(-154): bn_Conv1
# Layers 3(-153): Conv1_relu
# Layers 4(-152): expanded_conv_depthwise
# Layers 5(-151): expanded_conv_depthwise_BN
# Layers 6(-150): expanded_conv_depthwise_relu
# Layers 7(-149): expanded_conv_project
# Layers 8(-148): expanded_conv_project_BN
# Layers 9(-147): block_1_expand
# Layers 10(-146): block_1_expand_BN
# Layers 11(-145): block_1_expand_relu
# Layers 12(-144): block_1_pad
# Layers 13(-143): block_1_depthwise
# Layers 14(-142): block_1_depthwise_BN
# Layers 15(-141): block_1_depthwise_relu
# Layers 16(-140): block_1_project
# Layers 17(-139): block_1_project_BN
# Layers 18(-138): block_2_expand
# Layers 19(-137): block_2_expand_BN
# Layers 20(-136): block_2_expand_relu
# Layers 21(-135): block_2_depthwise
# Layers 22(-134): block_2_depthwise_BN
# Layers 23(-133): block_2_depthwise_relu
# Layers 24(-132): block_2_project
# Layers 25(-131): block_2_project_BN
# Layers 26(-130): block_2_add
# Layers 27(-129): block_3_expand
# Layers 28(-128): block_3_expand_BN
# Layers 29(-127): block_3_expand_relu
# Layers 30(-126): block_3_pad
# Layers 31(-125): block_3_depthwise
# Layers 32(-124): block_3_depthwise_BN
# Layers 33(-123): block_3_depthwise_relu
# Layers 34(-122): block_3_project
# Layers 35(-121): block_3_project_BN
# Layers 36(-120): block_4_expand
# Layers 37(-119): block_4_expand_BN
# Layers 38(-118): block_4_expand_relu
# Layers 39(-117): block_4_depthwise
# Layers 40(-116): block_4_depthwise_BN
# Layers 41(-115): block_4_depthwise_relu
# Layers 42(-114): block_4_project
# Layers 43(-113): block_4_project_BN
# Layers 44(-112): block_4_add
# Layers 45(-111): block_5_expand
# Layers 46(-110): block_5_expand_BN
# Layers 47(-109): block_5_expand_relu
# Layers 48(-108): block_5_depthwise
# Layers 49(-107): block_5_depthwise_BN
# Layers 50(-106): block_5_depthwise_relu
# Layers 51(-105): block_5_project
# Layers 52(-104): block_5_project_BN
# Layers 53(-103): block_5_add
# Layers 54(-102): block_6_expand
# Layers 55(-101): block_6_expand_BN
# Layers 56(-100): block_6_expand_relu
# Layers 57(-99): block_6_pad
# Layers 58(-98): block_6_depthwise
# Layers 59(-97): block_6_depthwise_BN
# Layers 60(-96): block_6_depthwise_relu
# Layers 61(-95): block_6_project
# Layers 62(-94): block_6_project_BN
# Layers 63(-93): block_7_expand
# Layers 64(-92): block_7_expand_BN
# Layers 65(-91): block_7_expand_relu
# Layers 66(-90): block_7_depthwise
# Layers 67(-89): block_7_depthwise_BN
# Layers 68(-88): block_7_depthwise_relu
# Layers 69(-87): block_7_project
# Layers 70(-86): block_7_project_BN
# Layers 71(-85): block_7_add
# Layers 72(-84): block_8_expand
# Layers 73(-83): block_8_expand_BN
# Layers 74(-82): block_8_expand_relu
# Layers 75(-81): block_8_depthwise
# Layers 76(-80): block_8_depthwise_BN
# Layers 77(-79): block_8_depthwise_relu
# Layers 78(-78): block_8_project
# Layers 79(-77): block_8_project_BN
# Layers 80(-76): block_8_add
# Layers 81(-75): block_9_expand
# Layers 82(-74): block_9_expand_BN
# Layers 83(-73): block_9_expand_relu
# Layers 84(-72): block_9_depthwise
# Layers 85(-71): block_9_depthwise_BN
# Layers 86(-70): block_9_depthwise_relu
# Layers 87(-69): block_9_project
# Layers 88(-68): block_9_project_BN
# Layers 89(-67): block_9_add
# Layers 90(-66): block_10_expand
# Layers 91(-65): block_10_expand_BN
# Layers 92(-64): block_10_expand_relu
# Layers 93(-63): block_10_depthwise
# Layers 94(-62): block_10_depthwise_BN
# Layers 95(-61): block_10_depthwise_relu
# Layers 96(-60): block_10_project
# Layers 97(-59): block_10_project_BN
# Layers 98(-58): block_11_expand
# Layers 99(-57): block_11_expand_BN
# Layers 100(-56): block_11_expand_relu
# Layers 101(-55): block_11_depthwise
# Layers 102(-54): block_11_depthwise_BN
# Layers 103(-53): block_11_depthwise_relu
# Layers 104(-52): block_11_project
# Layers 105(-51): block_11_project_BN
# Layers 106(-50): block_11_add
# Layers 107(-49): block_12_expand
# Layers 108(-48): block_12_expand_BN
# Layers 109(-47): block_12_expand_relu
# Layers 110(-46): block_12_depthwise
# Layers 111(-45): block_12_depthwise_BN
# Layers 112(-44): block_12_depthwise_relu
# Layers 113(-43): block_12_project
# Layers 114(-42): block_12_project_BN
# Layers 115(-41): block_12_add
# Layers 116(-40): block_13_expand
# Layers 117(-39): block_13_expand_BN
# Layers 118(-38): block_13_expand_relu
# Layers 119(-37): block_13_pad
# Layers 120(-36): block_13_depthwise
# Layers 121(-35): block_13_depthwise_BN
# Layers 122(-34): block_13_depthwise_relu
# Layers 123(-33): block_13_project
# Layers 124(-32): block_13_project_BN
# Layers 125(-31): block_14_expand
# Layers 126(-30): block_14_expand_BN
# Layers 127(-29): block_14_expand_relu
# Layers 128(-28): block_14_depthwise
# Layers 129(-27): block_14_depthwise_BN
# Layers 130(-26): block_14_depthwise_relu
# Layers 131(-25): block_14_project
# Layers 132(-24): block_14_project_BN
# Layers 133(-23): block_14_add
# Layers 134(-22): block_15_expand
# Layers 135(-21): block_15_expand_BN
# Layers 136(-20): block_15_expand_relu
# Layers 137(-19): block_15_depthwise
# Layers 138(-18): block_15_depthwise_BN
# Layers 139(-17): block_15_depthwise_relu
# Layers 140(-16): block_15_project
# Layers 141(-15): block_15_project_BN
# Layers 142(-14): block_15_add
# Layers 143(-13): block_16_expand
# Layers 144(-12): block_16_expand_BN
# Layers 145(-11): block_16_expand_relu
# Layers 146(-10): block_16_depthwise
# Layers 147(-9): block_16_depthwise_BN
# Layers 148(-8): block_16_depthwise_relu
# Layers 149(-7): block_16_project
# Layers 150(-6): block_16_project_BN
# Layers 151(-5): Conv_1
# Layers 152(-4): Conv_1_bn
# Layers 153(-3): out_relu
# Layers 154(-2): global_average_pooling2d_1
# Layers 155(-1): predictions

# %%
MobileNetV2.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_13[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1280)        0           ['out_relu[0][0]']
#  obalAveragePooling2D)
#
#  predictions (Dense)            (None, 1000)         1281000     ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 3,538,984
# Trainable params: 3,504,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %% [markdown]
# # DenseNet121

# %%
DenseNet121 = tf.keras.applications.DenseNet121(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels.h5
# 33193984/33188688 [==============================] - 3s 0us/step
# 33202176/33188688 [==============================] - 3s 0us/step

# %%
model_analyze(DenseNet121)
# Out:
# Layers 0(-429): input_14
# Layers 1(-428): zero_padding2d
# Layers 2(-427): conv1/conv
# Layers 3(-426): conv1/bn
# Layers 4(-425): conv1/relu
# Layers 5(-424): zero_padding2d_1
# Layers 6(-423): pool1
# Layers 7(-422): conv2_block1_0_bn
# Layers 8(-421): conv2_block1_0_relu
# Layers 9(-420): conv2_block1_1_conv
# Layers 10(-419): conv2_block1_1_bn
# Layers 11(-418): conv2_block1_1_relu
# Layers 12(-417): conv2_block1_2_conv
# Layers 13(-416): conv2_block1_concat
# Layers 14(-415): conv2_block2_0_bn
# Layers 15(-414): conv2_block2_0_relu
# Layers 16(-413): conv2_block2_1_conv
# Layers 17(-412): conv2_block2_1_bn
# Layers 18(-411): conv2_block2_1_relu
# Layers 19(-410): conv2_block2_2_conv
# Layers 20(-409): conv2_block2_concat
# Layers 21(-408): conv2_block3_0_bn
# Layers 22(-407): conv2_block3_0_relu
# Layers 23(-406): conv2_block3_1_conv
# Layers 24(-405): conv2_block3_1_bn
# Layers 25(-404): conv2_block3_1_relu
# Layers 26(-403): conv2_block3_2_conv
# Layers 27(-402): conv2_block3_concat
# Layers 28(-401): conv2_block4_0_bn
# Layers 29(-400): conv2_block4_0_relu
# Layers 30(-399): conv2_block4_1_conv
# Layers 31(-398): conv2_block4_1_bn
# Layers 32(-397): conv2_block4_1_relu
# Layers 33(-396): conv2_block4_2_conv
# Layers 34(-395): conv2_block4_concat
# Layers 35(-394): conv2_block5_0_bn
# Layers 36(-393): conv2_block5_0_relu
# Layers 37(-392): conv2_block5_1_conv
# Layers 38(-391): conv2_block5_1_bn
# Layers 39(-390): conv2_block5_1_relu
# Layers 40(-389): conv2_block5_2_conv
# Layers 41(-388): conv2_block5_concat
# Layers 42(-387): conv2_block6_0_bn
# Layers 43(-386): conv2_block6_0_relu
# Layers 44(-385): conv2_block6_1_conv
# Layers 45(-384): conv2_block6_1_bn
# Layers 46(-383): conv2_block6_1_relu
# Layers 47(-382): conv2_block6_2_conv
# Layers 48(-381): conv2_block6_concat
# Layers 49(-380): pool2_bn
# Layers 50(-379): pool2_relu
# Layers 51(-378): pool2_conv
# Layers 52(-377): pool2_pool
# Layers 53(-376): conv3_block1_0_bn
# Layers 54(-375): conv3_block1_0_relu
# Layers 55(-374): conv3_block1_1_conv
# Layers 56(-373): conv3_block1_1_bn
# Layers 57(-372): conv3_block1_1_relu
# Layers 58(-371): conv3_block1_2_conv
# Layers 59(-370): conv3_block1_concat
# Layers 60(-369): conv3_block2_0_bn
# Layers 61(-368): conv3_block2_0_relu
# Layers 62(-367): conv3_block2_1_conv
# Layers 63(-366): conv3_block2_1_bn
# Layers 64(-365): conv3_block2_1_relu
# Layers 65(-364): conv3_block2_2_conv
# Layers 66(-363): conv3_block2_concat
# Layers 67(-362): conv3_block3_0_bn
# Layers 68(-361): conv3_block3_0_relu
# Layers 69(-360): conv3_block3_1_conv
# Layers 70(-359): conv3_block3_1_bn
# Layers 71(-358): conv3_block3_1_relu
# Layers 72(-357): conv3_block3_2_conv
# Layers 73(-356): conv3_block3_concat
# Layers 74(-355): conv3_block4_0_bn
# Layers 75(-354): conv3_block4_0_relu
# Layers 76(-353): conv3_block4_1_conv
# Layers 77(-352): conv3_block4_1_bn
# Layers 78(-351): conv3_block4_1_relu
# Layers 79(-350): conv3_block4_2_conv
# Layers 80(-349): conv3_block4_concat
# Layers 81(-348): conv3_block5_0_bn
# Layers 82(-347): conv3_block5_0_relu
# Layers 83(-346): conv3_block5_1_conv
# Layers 84(-345): conv3_block5_1_bn
# Layers 85(-344): conv3_block5_1_relu
# Layers 86(-343): conv3_block5_2_conv
# Layers 87(-342): conv3_block5_concat
# Layers 88(-341): conv3_block6_0_bn
# Layers 89(-340): conv3_block6_0_relu
# Layers 90(-339): conv3_block6_1_conv
# Layers 91(-338): conv3_block6_1_bn
# Layers 92(-337): conv3_block6_1_relu
# Layers 93(-336): conv3_block6_2_conv
# Layers 94(-335): conv3_block6_concat
# Layers 95(-334): conv3_block7_0_bn
# Layers 96(-333): conv3_block7_0_relu
# Layers 97(-332): conv3_block7_1_conv
# Layers 98(-331): conv3_block7_1_bn
# Layers 99(-330): conv3_block7_1_relu
# Layers 100(-329): conv3_block7_2_conv
# Layers 101(-328): conv3_block7_concat
# Layers 102(-327): conv3_block8_0_bn
# Layers 103(-326): conv3_block8_0_relu
# Layers 104(-325): conv3_block8_1_conv
# Layers 105(-324): conv3_block8_1_bn
# Layers 106(-323): conv3_block8_1_relu
# Layers 107(-322): conv3_block8_2_conv
# Layers 108(-321): conv3_block8_concat
# Layers 109(-320): conv3_block9_0_bn
# Layers 110(-319): conv3_block9_0_relu
# Layers 111(-318): conv3_block9_1_conv
# Layers 112(-317): conv3_block9_1_bn
# Layers 113(-316): conv3_block9_1_relu
# Layers 114(-315): conv3_block9_2_conv
# Layers 115(-314): conv3_block9_concat
# Layers 116(-313): conv3_block10_0_bn
# Layers 117(-312): conv3_block10_0_relu
# Layers 118(-311): conv3_block10_1_conv
# Layers 119(-310): conv3_block10_1_bn
# Layers 120(-309): conv3_block10_1_relu
# Layers 121(-308): conv3_block10_2_conv
# Layers 122(-307): conv3_block10_concat
# Layers 123(-306): conv3_block11_0_bn
# Layers 124(-305): conv3_block11_0_relu
# Layers 125(-304): conv3_block11_1_conv
# Layers 126(-303): conv3_block11_1_bn
# Layers 127(-302): conv3_block11_1_relu
# Layers 128(-301): conv3_block11_2_conv
# Layers 129(-300): conv3_block11_concat
# Layers 130(-299): conv3_block12_0_bn
# Layers 131(-298): conv3_block12_0_relu
# Layers 132(-297): conv3_block12_1_conv
# Layers 133(-296): conv3_block12_1_bn
# Layers 134(-295): conv3_block12_1_relu
# Layers 135(-294): conv3_block12_2_conv
# Layers 136(-293): conv3_block12_concat
# Layers 137(-292): pool3_bn
# Layers 138(-291): pool3_relu
# Layers 139(-290): pool3_conv
# Layers 140(-289): pool3_pool
# Layers 141(-288): conv4_block1_0_bn
# Layers 142(-287): conv4_block1_0_relu
# Layers 143(-286): conv4_block1_1_conv
# Layers 144(-285): conv4_block1_1_bn
# Layers 145(-284): conv4_block1_1_relu
# Layers 146(-283): conv4_block1_2_conv
# Layers 147(-282): conv4_block1_concat
# Layers 148(-281): conv4_block2_0_bn
# Layers 149(-280): conv4_block2_0_relu
# Layers 150(-279): conv4_block2_1_conv
# Layers 151(-278): conv4_block2_1_bn
# Layers 152(-277): conv4_block2_1_relu
# Layers 153(-276): conv4_block2_2_conv
# Layers 154(-275): conv4_block2_concat
# Layers 155(-274): conv4_block3_0_bn
# Layers 156(-273): conv4_block3_0_relu
# Layers 157(-272): conv4_block3_1_conv
# Layers 158(-271): conv4_block3_1_bn
# Layers 159(-270): conv4_block3_1_relu
# Layers 160(-269): conv4_block3_2_conv
# Layers 161(-268): conv4_block3_concat
# Layers 162(-267): conv4_block4_0_bn
# Layers 163(-266): conv4_block4_0_relu
# Layers 164(-265): conv4_block4_1_conv
# Layers 165(-264): conv4_block4_1_bn
# Layers 166(-263): conv4_block4_1_relu
# Layers 167(-262): conv4_block4_2_conv
# Layers 168(-261): conv4_block4_concat
# Layers 169(-260): conv4_block5_0_bn
# Layers 170(-259): conv4_block5_0_relu
# Layers 171(-258): conv4_block5_1_conv
# Layers 172(-257): conv4_block5_1_bn
# Layers 173(-256): conv4_block5_1_relu
# Layers 174(-255): conv4_block5_2_conv
# Layers 175(-254): conv4_block5_concat
# Layers 176(-253): conv4_block6_0_bn
# Layers 177(-252): conv4_block6_0_relu
# Layers 178(-251): conv4_block6_1_conv
# Layers 179(-250): conv4_block6_1_bn
# Layers 180(-249): conv4_block6_1_relu
# Layers 181(-248): conv4_block6_2_conv
# Layers 182(-247): conv4_block6_concat
# Layers 183(-246): conv4_block7_0_bn
# Layers 184(-245): conv4_block7_0_relu
# Layers 185(-244): conv4_block7_1_conv
# Layers 186(-243): conv4_block7_1_bn
# Layers 187(-242): conv4_block7_1_relu
# Layers 188(-241): conv4_block7_2_conv
# Layers 189(-240): conv4_block7_concat
# Layers 190(-239): conv4_block8_0_bn
# Layers 191(-238): conv4_block8_0_relu
# Layers 192(-237): conv4_block8_1_conv
# Layers 193(-236): conv4_block8_1_bn
# Layers 194(-235): conv4_block8_1_relu
# Layers 195(-234): conv4_block8_2_conv
# Layers 196(-233): conv4_block8_concat
# Layers 197(-232): conv4_block9_0_bn
# Layers 198(-231): conv4_block9_0_relu
# Layers 199(-230): conv4_block9_1_conv
# Layers 200(-229): conv4_block9_1_bn
# Layers 201(-228): conv4_block9_1_relu
# Layers 202(-227): conv4_block9_2_conv
# Layers 203(-226): conv4_block9_concat
# Layers 204(-225): conv4_block10_0_bn
# Layers 205(-224): conv4_block10_0_relu
# Layers 206(-223): conv4_block10_1_conv
# Layers 207(-222): conv4_block10_1_bn
# Layers 208(-221): conv4_block10_1_relu
# Layers 209(-220): conv4_block10_2_conv
# Layers 210(-219): conv4_block10_concat
# Layers 211(-218): conv4_block11_0_bn
# Layers 212(-217): conv4_block11_0_relu
# Layers 213(-216): conv4_block11_1_conv
# Layers 214(-215): conv4_block11_1_bn
# Layers 215(-214): conv4_block11_1_relu
# Layers 216(-213): conv4_block11_2_conv
# Layers 217(-212): conv4_block11_concat
# Layers 218(-211): conv4_block12_0_bn
# Layers 219(-210): conv4_block12_0_relu
# Layers 220(-209): conv4_block12_1_conv
# Layers 221(-208): conv4_block12_1_bn
# Layers 222(-207): conv4_block12_1_relu
# Layers 223(-206): conv4_block12_2_conv
# Layers 224(-205): conv4_block12_concat
# Layers 225(-204): conv4_block13_0_bn
# Layers 226(-203): conv4_block13_0_relu
# Layers 227(-202): conv4_block13_1_conv
# Layers 228(-201): conv4_block13_1_bn
# Layers 229(-200): conv4_block13_1_relu
# Layers 230(-199): conv4_block13_2_conv
# Layers 231(-198): conv4_block13_concat
# Layers 232(-197): conv4_block14_0_bn
# Layers 233(-196): conv4_block14_0_relu
# Layers 234(-195): conv4_block14_1_conv
# Layers 235(-194): conv4_block14_1_bn
# Layers 236(-193): conv4_block14_1_relu
# Layers 237(-192): conv4_block14_2_conv
# Layers 238(-191): conv4_block14_concat
# Layers 239(-190): conv4_block15_0_bn
# Layers 240(-189): conv4_block15_0_relu
# Layers 241(-188): conv4_block15_1_conv
# Layers 242(-187): conv4_block15_1_bn
# Layers 243(-186): conv4_block15_1_relu
# Layers 244(-185): conv4_block15_2_conv
# Layers 245(-184): conv4_block15_concat
# Layers 246(-183): conv4_block16_0_bn
# Layers 247(-182): conv4_block16_0_relu
# Layers 248(-181): conv4_block16_1_conv
# Layers 249(-180): conv4_block16_1_bn
# Layers 250(-179): conv4_block16_1_relu
# Layers 251(-178): conv4_block16_2_conv
# Layers 252(-177): conv4_block16_concat
# Layers 253(-176): conv4_block17_0_bn
# Layers 254(-175): conv4_block17_0_relu
# Layers 255(-174): conv4_block17_1_conv
# Layers 256(-173): conv4_block17_1_bn
# Layers 257(-172): conv4_block17_1_relu
# Layers 258(-171): conv4_block17_2_conv
# Layers 259(-170): conv4_block17_concat
# Layers 260(-169): conv4_block18_0_bn
# Layers 261(-168): conv4_block18_0_relu
# Layers 262(-167): conv4_block18_1_conv
# Layers 263(-166): conv4_block18_1_bn
# Layers 264(-165): conv4_block18_1_relu
# Layers 265(-164): conv4_block18_2_conv
# Layers 266(-163): conv4_block18_concat
# Layers 267(-162): conv4_block19_0_bn
# Layers 268(-161): conv4_block19_0_relu
# Layers 269(-160): conv4_block19_1_conv
# Layers 270(-159): conv4_block19_1_bn
# Layers 271(-158): conv4_block19_1_relu
# Layers 272(-157): conv4_block19_2_conv
# Layers 273(-156): conv4_block19_concat
# Layers 274(-155): conv4_block20_0_bn
# Layers 275(-154): conv4_block20_0_relu
# Layers 276(-153): conv4_block20_1_conv
# Layers 277(-152): conv4_block20_1_bn
# Layers 278(-151): conv4_block20_1_relu
# Layers 279(-150): conv4_block20_2_conv
# Layers 280(-149): conv4_block20_concat
# Layers 281(-148): conv4_block21_0_bn
# Layers 282(-147): conv4_block21_0_relu
# Layers 283(-146): conv4_block21_1_conv
# Layers 284(-145): conv4_block21_1_bn
# Layers 285(-144): conv4_block21_1_relu
# Layers 286(-143): conv4_block21_2_conv
# Layers 287(-142): conv4_block21_concat
# Layers 288(-141): conv4_block22_0_bn
# Layers 289(-140): conv4_block22_0_relu
# Layers 290(-139): conv4_block22_1_conv
# Layers 291(-138): conv4_block22_1_bn
# Layers 292(-137): conv4_block22_1_relu
# Layers 293(-136): conv4_block22_2_conv
# Layers 294(-135): conv4_block22_concat
# Layers 295(-134): conv4_block23_0_bn
# Layers 296(-133): conv4_block23_0_relu
# Layers 297(-132): conv4_block23_1_conv
# Layers 298(-131): conv4_block23_1_bn
# Layers 299(-130): conv4_block23_1_relu
# Layers 300(-129): conv4_block23_2_conv
# Layers 301(-128): conv4_block23_concat
# Layers 302(-127): conv4_block24_0_bn
# Layers 303(-126): conv4_block24_0_relu
# Layers 304(-125): conv4_block24_1_conv
# Layers 305(-124): conv4_block24_1_bn
# Layers 306(-123): conv4_block24_1_relu
# Layers 307(-122): conv4_block24_2_conv
# Layers 308(-121): conv4_block24_concat
# Layers 309(-120): pool4_bn
# Layers 310(-119): pool4_relu
# Layers 311(-118): pool4_conv
# Layers 312(-117): pool4_pool
# Layers 313(-116): conv5_block1_0_bn
# Layers 314(-115): conv5_block1_0_relu
# Layers 315(-114): conv5_block1_1_conv
# Layers 316(-113): conv5_block1_1_bn
# Layers 317(-112): conv5_block1_1_relu
# Layers 318(-111): conv5_block1_2_conv
# Layers 319(-110): conv5_block1_concat
# Layers 320(-109): conv5_block2_0_bn
# Layers 321(-108): conv5_block2_0_relu
# Layers 322(-107): conv5_block2_1_conv
# Layers 323(-106): conv5_block2_1_bn
# Layers 324(-105): conv5_block2_1_relu
# Layers 325(-104): conv5_block2_2_conv
# Layers 326(-103): conv5_block2_concat
# Layers 327(-102): conv5_block3_0_bn
# Layers 328(-101): conv5_block3_0_relu
# Layers 329(-100): conv5_block3_1_conv
# Layers 330(-99): conv5_block3_1_bn
# Layers 331(-98): conv5_block3_1_relu
# Layers 332(-97): conv5_block3_2_conv
# Layers 333(-96): conv5_block3_concat
# Layers 334(-95): conv5_block4_0_bn
# Layers 335(-94): conv5_block4_0_relu
# Layers 336(-93): conv5_block4_1_conv
# Layers 337(-92): conv5_block4_1_bn
# Layers 338(-91): conv5_block4_1_relu
# Layers 339(-90): conv5_block4_2_conv
# Layers 340(-89): conv5_block4_concat
# Layers 341(-88): conv5_block5_0_bn
# Layers 342(-87): conv5_block5_0_relu
# Layers 343(-86): conv5_block5_1_conv
# Layers 344(-85): conv5_block5_1_bn
# Layers 345(-84): conv5_block5_1_relu
# Layers 346(-83): conv5_block5_2_conv
# Layers 347(-82): conv5_block5_concat
# Layers 348(-81): conv5_block6_0_bn
# Layers 349(-80): conv5_block6_0_relu
# Layers 350(-79): conv5_block6_1_conv
# Layers 351(-78): conv5_block6_1_bn
# Layers 352(-77): conv5_block6_1_relu
# Layers 353(-76): conv5_block6_2_conv
# Layers 354(-75): conv5_block6_concat
# Layers 355(-74): conv5_block7_0_bn
# Layers 356(-73): conv5_block7_0_relu
# Layers 357(-72): conv5_block7_1_conv
# Layers 358(-71): conv5_block7_1_bn
# Layers 359(-70): conv5_block7_1_relu
# Layers 360(-69): conv5_block7_2_conv
# Layers 361(-68): conv5_block7_concat
# Layers 362(-67): conv5_block8_0_bn
# Layers 363(-66): conv5_block8_0_relu
# Layers 364(-65): conv5_block8_1_conv
# Layers 365(-64): conv5_block8_1_bn
# Layers 366(-63): conv5_block8_1_relu
# Layers 367(-62): conv5_block8_2_conv
# Layers 368(-61): conv5_block8_concat
# Layers 369(-60): conv5_block9_0_bn
# Layers 370(-59): conv5_block9_0_relu
# Layers 371(-58): conv5_block9_1_conv
# Layers 372(-57): conv5_block9_1_bn
# Layers 373(-56): conv5_block9_1_relu
# Layers 374(-55): conv5_block9_2_conv
# Layers 375(-54): conv5_block9_concat
# Layers 376(-53): conv5_block10_0_bn
# Layers 377(-52): conv5_block10_0_relu
# Layers 378(-51): conv5_block10_1_conv
# Layers 379(-50): conv5_block10_1_bn
# Layers 380(-49): conv5_block10_1_relu
# Layers 381(-48): conv5_block10_2_conv
# Layers 382(-47): conv5_block10_concat
# Layers 383(-46): conv5_block11_0_bn
# Layers 384(-45): conv5_block11_0_relu
# Layers 385(-44): conv5_block11_1_conv
# Layers 386(-43): conv5_block11_1_bn
# Layers 387(-42): conv5_block11_1_relu
# Layers 388(-41): conv5_block11_2_conv
# Layers 389(-40): conv5_block11_concat
# Layers 390(-39): conv5_block12_0_bn
# Layers 391(-38): conv5_block12_0_relu
# Layers 392(-37): conv5_block12_1_conv
# Layers 393(-36): conv5_block12_1_bn
# Layers 394(-35): conv5_block12_1_relu
# Layers 395(-34): conv5_block12_2_conv
# Layers 396(-33): conv5_block12_concat
# Layers 397(-32): conv5_block13_0_bn
# Layers 398(-31): conv5_block13_0_relu
# Layers 399(-30): conv5_block13_1_conv
# Layers 400(-29): conv5_block13_1_bn
# Layers 401(-28): conv5_block13_1_relu
# Layers 402(-27): conv5_block13_2_conv
# Layers 403(-26): conv5_block13_concat
# Layers 404(-25): conv5_block14_0_bn
# Layers 405(-24): conv5_block14_0_relu
# Layers 406(-23): conv5_block14_1_conv
# Layers 407(-22): conv5_block14_1_bn
# Layers 408(-21): conv5_block14_1_relu
# Layers 409(-20): conv5_block14_2_conv
# Layers 410(-19): conv5_block14_concat
# Layers 411(-18): conv5_block15_0_bn
# Layers 412(-17): conv5_block15_0_relu
# Layers 413(-16): conv5_block15_1_conv
# Layers 414(-15): conv5_block15_1_bn
# Layers 415(-14): conv5_block15_1_relu
# Layers 416(-13): conv5_block15_2_conv
# Layers 417(-12): conv5_block15_concat
# Layers 418(-11): conv5_block16_0_bn
# Layers 419(-10): conv5_block16_0_relu
# Layers 420(-9): conv5_block16_1_conv
# Layers 421(-8): conv5_block16_1_bn
# Layers 422(-7): conv5_block16_1_relu
# Layers 423(-6): conv5_block16_2_conv
# Layers 424(-5): conv5_block16_concat
# Layers 425(-4): bn
# Layers 426(-3): relu
# Layers 427(-2): avg_pool
# Layers 428(-1): predictions

# %%
DenseNet121.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_14[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
#  n)
# ...
#
#  conv5_block9_0_relu (Activatio  (None, 7, 7, 768)   0           ['conv5_block9_0_bn[0][0]']
#  n)
#
#  conv5_block9_1_conv (Conv2D)   (None, 7, 7, 128)    98304       ['conv5_block9_0_relu[0][0]']
#
#  conv5_block9_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 7, 7, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 7, 7, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 7, 7, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 7, 7, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 7, 7, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 7, 7, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 7, 7, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 7, 7, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 7, 7, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 7, 7, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 7, 7, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 7, 7, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 7, 7, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 7, 7, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 7, 7, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 7, 7, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 7, 7, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 7, 7, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 7, 7, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 7, 7, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 7, 7, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 7, 7, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 7, 7, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 7, 7, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 7, 7, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 7, 7, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 7, 7, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 7, 7, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 7, 7, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1024)   0           ['bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1024)        0           ['relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         1025000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 8,062,504
# Trainable params: 7,978,856
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %% [markdown]
# # DenseNet169

# %%
DenseNet169 = tf.keras.applications.DenseNet169(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels.h5
# 58548224/58541896 [==============================] - 6s 0us/step
# 58556416/58541896 [==============================] - 6s 0us/step

# %%
model_analyze(DenseNet169)
# Out:
# Layers 0(-597): input_15
# Layers 1(-596): zero_padding2d_2
# Layers 2(-595): conv1/conv
# Layers 3(-594): conv1/bn
# Layers 4(-593): conv1/relu
# Layers 5(-592): zero_padding2d_3
# Layers 6(-591): pool1
# Layers 7(-590): conv2_block1_0_bn
# Layers 8(-589): conv2_block1_0_relu
# Layers 9(-588): conv2_block1_1_conv
# Layers 10(-587): conv2_block1_1_bn
# Layers 11(-586): conv2_block1_1_relu
# Layers 12(-585): conv2_block1_2_conv
# Layers 13(-584): conv2_block1_concat
# Layers 14(-583): conv2_block2_0_bn
# Layers 15(-582): conv2_block2_0_relu
# Layers 16(-581): conv2_block2_1_conv
# Layers 17(-580): conv2_block2_1_bn
# Layers 18(-579): conv2_block2_1_relu
# Layers 19(-578): conv2_block2_2_conv
# Layers 20(-577): conv2_block2_concat
# Layers 21(-576): conv2_block3_0_bn
# Layers 22(-575): conv2_block3_0_relu
# Layers 23(-574): conv2_block3_1_conv
# Layers 24(-573): conv2_block3_1_bn
# Layers 25(-572): conv2_block3_1_relu
# Layers 26(-571): conv2_block3_2_conv
# Layers 27(-570): conv2_block3_concat
# Layers 28(-569): conv2_block4_0_bn
# Layers 29(-568): conv2_block4_0_relu
# Layers 30(-567): conv2_block4_1_conv
# Layers 31(-566): conv2_block4_1_bn
# Layers 32(-565): conv2_block4_1_relu
# Layers 33(-564): conv2_block4_2_conv
# Layers 34(-563): conv2_block4_concat
# Layers 35(-562): conv2_block5_0_bn
# Layers 36(-561): conv2_block5_0_relu
# Layers 37(-560): conv2_block5_1_conv
# Layers 38(-559): conv2_block5_1_bn
# Layers 39(-558): conv2_block5_1_relu
# Layers 40(-557): conv2_block5_2_conv
# Layers 41(-556): conv2_block5_concat
# Layers 42(-555): conv2_block6_0_bn
# Layers 43(-554): conv2_block6_0_relu
# Layers 44(-553): conv2_block6_1_conv
# Layers 45(-552): conv2_block6_1_bn
# Layers 46(-551): conv2_block6_1_relu
# Layers 47(-550): conv2_block6_2_conv
# Layers 48(-549): conv2_block6_concat
# Layers 49(-548): pool2_bn
# Layers 50(-547): pool2_relu
# Layers 51(-546): pool2_conv
# Layers 52(-545): pool2_pool
# Layers 53(-544): conv3_block1_0_bn
# Layers 54(-543): conv3_block1_0_relu
# Layers 55(-542): conv3_block1_1_conv
# Layers 56(-541): conv3_block1_1_bn
# Layers 57(-540): conv3_block1_1_relu
# Layers 58(-539): conv3_block1_2_conv
# Layers 59(-538): conv3_block1_concat
# Layers 60(-537): conv3_block2_0_bn
# Layers 61(-536): conv3_block2_0_relu
# Layers 62(-535): conv3_block2_1_conv
# Layers 63(-534): conv3_block2_1_bn
# Layers 64(-533): conv3_block2_1_relu
# Layers 65(-532): conv3_block2_2_conv
# Layers 66(-531): conv3_block2_concat
# Layers 67(-530): conv3_block3_0_bn
# Layers 68(-529): conv3_block3_0_relu
# Layers 69(-528): conv3_block3_1_conv
# Layers 70(-527): conv3_block3_1_bn
# Layers 71(-526): conv3_block3_1_relu
# Layers 72(-525): conv3_block3_2_conv
# Layers 73(-524): conv3_block3_concat
# Layers 74(-523): conv3_block4_0_bn
# Layers 75(-522): conv3_block4_0_relu
# Layers 76(-521): conv3_block4_1_conv
# Layers 77(-520): conv3_block4_1_bn
# Layers 78(-519): conv3_block4_1_relu
# Layers 79(-518): conv3_block4_2_conv
# Layers 80(-517): conv3_block4_concat
# Layers 81(-516): conv3_block5_0_bn
# Layers 82(-515): conv3_block5_0_relu
# Layers 83(-514): conv3_block5_1_conv
# Layers 84(-513): conv3_block5_1_bn
# Layers 85(-512): conv3_block5_1_relu
# Layers 86(-511): conv3_block5_2_conv
# Layers 87(-510): conv3_block5_concat
# Layers 88(-509): conv3_block6_0_bn
# Layers 89(-508): conv3_block6_0_relu
# Layers 90(-507): conv3_block6_1_conv
# Layers 91(-506): conv3_block6_1_bn
# Layers 92(-505): conv3_block6_1_relu
# Layers 93(-504): conv3_block6_2_conv
# Layers 94(-503): conv3_block6_concat
# Layers 95(-502): conv3_block7_0_bn
# Layers 96(-501): conv3_block7_0_relu
# Layers 97(-500): conv3_block7_1_conv
# Layers 98(-499): conv3_block7_1_bn
# Layers 99(-498): conv3_block7_1_relu
# Layers 100(-497): conv3_block7_2_conv
# Layers 101(-496): conv3_block7_concat
# Layers 102(-495): conv3_block8_0_bn
# Layers 103(-494): conv3_block8_0_relu
# Layers 104(-493): conv3_block8_1_conv
# Layers 105(-492): conv3_block8_1_bn
# Layers 106(-491): conv3_block8_1_relu
# Layers 107(-490): conv3_block8_2_conv
# Layers 108(-489): conv3_block8_concat
# Layers 109(-488): conv3_block9_0_bn
# Layers 110(-487): conv3_block9_0_relu
# Layers 111(-486): conv3_block9_1_conv
# Layers 112(-485): conv3_block9_1_bn
# Layers 113(-484): conv3_block9_1_relu
# Layers 114(-483): conv3_block9_2_conv
# Layers 115(-482): conv3_block9_concat
# Layers 116(-481): conv3_block10_0_bn
# Layers 117(-480): conv3_block10_0_relu
# Layers 118(-479): conv3_block10_1_conv
# Layers 119(-478): conv3_block10_1_bn
# Layers 120(-477): conv3_block10_1_relu
# Layers 121(-476): conv3_block10_2_conv
# Layers 122(-475): conv3_block10_concat
# Layers 123(-474): conv3_block11_0_bn
# Layers 124(-473): conv3_block11_0_relu
# Layers 125(-472): conv3_block11_1_conv
# Layers 126(-471): conv3_block11_1_bn
# Layers 127(-470): conv3_block11_1_relu
# Layers 128(-469): conv3_block11_2_conv
# Layers 129(-468): conv3_block11_concat
# Layers 130(-467): conv3_block12_0_bn
# Layers 131(-466): conv3_block12_0_relu
# Layers 132(-465): conv3_block12_1_conv
# Layers 133(-464): conv3_block12_1_bn
# Layers 134(-463): conv3_block12_1_relu
# Layers 135(-462): conv3_block12_2_conv
# Layers 136(-461): conv3_block12_concat
# Layers 137(-460): pool3_bn
# Layers 138(-459): pool3_relu
# Layers 139(-458): pool3_conv
# Layers 140(-457): pool3_pool
# Layers 141(-456): conv4_block1_0_bn
# Layers 142(-455): conv4_block1_0_relu
# Layers 143(-454): conv4_block1_1_conv
# Layers 144(-453): conv4_block1_1_bn
# Layers 145(-452): conv4_block1_1_relu
# Layers 146(-451): conv4_block1_2_conv
# Layers 147(-450): conv4_block1_concat
# Layers 148(-449): conv4_block2_0_bn
# Layers 149(-448): conv4_block2_0_relu
# Layers 150(-447): conv4_block2_1_conv
# Layers 151(-446): conv4_block2_1_bn
# Layers 152(-445): conv4_block2_1_relu
# Layers 153(-444): conv4_block2_2_conv
# Layers 154(-443): conv4_block2_concat
# Layers 155(-442): conv4_block3_0_bn
# Layers 156(-441): conv4_block3_0_relu
# Layers 157(-440): conv4_block3_1_conv
# Layers 158(-439): conv4_block3_1_bn
# Layers 159(-438): conv4_block3_1_relu
# Layers 160(-437): conv4_block3_2_conv
# Layers 161(-436): conv4_block3_concat
# Layers 162(-435): conv4_block4_0_bn
# Layers 163(-434): conv4_block4_0_relu
# Layers 164(-433): conv4_block4_1_conv
# Layers 165(-432): conv4_block4_1_bn
# Layers 166(-431): conv4_block4_1_relu
# Layers 167(-430): conv4_block4_2_conv
# Layers 168(-429): conv4_block4_concat
# Layers 169(-428): conv4_block5_0_bn
# Layers 170(-427): conv4_block5_0_relu
# Layers 171(-426): conv4_block5_1_conv
# Layers 172(-425): conv4_block5_1_bn
# Layers 173(-424): conv4_block5_1_relu
# Layers 174(-423): conv4_block5_2_conv
# Layers 175(-422): conv4_block5_concat
# Layers 176(-421): conv4_block6_0_bn
# Layers 177(-420): conv4_block6_0_relu
# Layers 178(-419): conv4_block6_1_conv
# Layers 179(-418): conv4_block6_1_bn
# Layers 180(-417): conv4_block6_1_relu
# Layers 181(-416): conv4_block6_2_conv
# Layers 182(-415): conv4_block6_concat
# Layers 183(-414): conv4_block7_0_bn
# Layers 184(-413): conv4_block7_0_relu
# Layers 185(-412): conv4_block7_1_conv
# Layers 186(-411): conv4_block7_1_bn
# Layers 187(-410): conv4_block7_1_relu
# Layers 188(-409): conv4_block7_2_conv
# Layers 189(-408): conv4_block7_concat
# Layers 190(-407): conv4_block8_0_bn
# Layers 191(-406): conv4_block8_0_relu
# Layers 192(-405): conv4_block8_1_conv
# Layers 193(-404): conv4_block8_1_bn
# Layers 194(-403): conv4_block8_1_relu
# Layers 195(-402): conv4_block8_2_conv
# Layers 196(-401): conv4_block8_concat
# Layers 197(-400): conv4_block9_0_bn
# Layers 198(-399): conv4_block9_0_relu
# Layers 199(-398): conv4_block9_1_conv
# Layers 200(-397): conv4_block9_1_bn
# Layers 201(-396): conv4_block9_1_relu
# Layers 202(-395): conv4_block9_2_conv
# Layers 203(-394): conv4_block9_concat
# Layers 204(-393): conv4_block10_0_bn
# Layers 205(-392): conv4_block10_0_relu
# Layers 206(-391): conv4_block10_1_conv
# Layers 207(-390): conv4_block10_1_bn
# Layers 208(-389): conv4_block10_1_relu
# Layers 209(-388): conv4_block10_2_conv
# Layers 210(-387): conv4_block10_concat
# Layers 211(-386): conv4_block11_0_bn
# Layers 212(-385): conv4_block11_0_relu
# Layers 213(-384): conv4_block11_1_conv
# Layers 214(-383): conv4_block11_1_bn
# Layers 215(-382): conv4_block11_1_relu
# Layers 216(-381): conv4_block11_2_conv
# Layers 217(-380): conv4_block11_concat
# Layers 218(-379): conv4_block12_0_bn
# Layers 219(-378): conv4_block12_0_relu
# Layers 220(-377): conv4_block12_1_conv
# Layers 221(-376): conv4_block12_1_bn
# Layers 222(-375): conv4_block12_1_relu
# Layers 223(-374): conv4_block12_2_conv
# Layers 224(-373): conv4_block12_concat
# Layers 225(-372): conv4_block13_0_bn
# Layers 226(-371): conv4_block13_0_relu
# Layers 227(-370): conv4_block13_1_conv
# Layers 228(-369): conv4_block13_1_bn
# Layers 229(-368): conv4_block13_1_relu
# Layers 230(-367): conv4_block13_2_conv
# Layers 231(-366): conv4_block13_concat
# Layers 232(-365): conv4_block14_0_bn
# Layers 233(-364): conv4_block14_0_relu
# Layers 234(-363): conv4_block14_1_conv
# Layers 235(-362): conv4_block14_1_bn
# Layers 236(-361): conv4_block14_1_relu
# Layers 237(-360): conv4_block14_2_conv
# Layers 238(-359): conv4_block14_concat
# Layers 239(-358): conv4_block15_0_bn
# Layers 240(-357): conv4_block15_0_relu
# Layers 241(-356): conv4_block15_1_conv
# Layers 242(-355): conv4_block15_1_bn
# Layers 243(-354): conv4_block15_1_relu
# Layers 244(-353): conv4_block15_2_conv
# Layers 245(-352): conv4_block15_concat
# Layers 246(-351): conv4_block16_0_bn
# Layers 247(-350): conv4_block16_0_relu
# Layers 248(-349): conv4_block16_1_conv
# Layers 249(-348): conv4_block16_1_bn
# Layers 250(-347): conv4_block16_1_relu
# Layers 251(-346): conv4_block16_2_conv
# Layers 252(-345): conv4_block16_concat
# Layers 253(-344): conv4_block17_0_bn
# Layers 254(-343): conv4_block17_0_relu
# Layers 255(-342): conv4_block17_1_conv
# Layers 256(-341): conv4_block17_1_bn
# Layers 257(-340): conv4_block17_1_relu
# Layers 258(-339): conv4_block17_2_conv
# Layers 259(-338): conv4_block17_concat
# Layers 260(-337): conv4_block18_0_bn
# Layers 261(-336): conv4_block18_0_relu
# Layers 262(-335): conv4_block18_1_conv
# Layers 263(-334): conv4_block18_1_bn
# Layers 264(-333): conv4_block18_1_relu
# Layers 265(-332): conv4_block18_2_conv
# Layers 266(-331): conv4_block18_concat
# Layers 267(-330): conv4_block19_0_bn
# Layers 268(-329): conv4_block19_0_relu
# Layers 269(-328): conv4_block19_1_conv
# Layers 270(-327): conv4_block19_1_bn
# Layers 271(-326): conv4_block19_1_relu
# Layers 272(-325): conv4_block19_2_conv
# Layers 273(-324): conv4_block19_concat
# Layers 274(-323): conv4_block20_0_bn
# Layers 275(-322): conv4_block20_0_relu
# Layers 276(-321): conv4_block20_1_conv
# Layers 277(-320): conv4_block20_1_bn
# Layers 278(-319): conv4_block20_1_relu
# Layers 279(-318): conv4_block20_2_conv
# Layers 280(-317): conv4_block20_concat
# Layers 281(-316): conv4_block21_0_bn
# Layers 282(-315): conv4_block21_0_relu
# Layers 283(-314): conv4_block21_1_conv
# Layers 284(-313): conv4_block21_1_bn
# Layers 285(-312): conv4_block21_1_relu
# Layers 286(-311): conv4_block21_2_conv
# Layers 287(-310): conv4_block21_concat
# Layers 288(-309): conv4_block22_0_bn
# Layers 289(-308): conv4_block22_0_relu
# Layers 290(-307): conv4_block22_1_conv
# Layers 291(-306): conv4_block22_1_bn
# Layers 292(-305): conv4_block22_1_relu
# Layers 293(-304): conv4_block22_2_conv
# Layers 294(-303): conv4_block22_concat
# Layers 295(-302): conv4_block23_0_bn
# Layers 296(-301): conv4_block23_0_relu
# Layers 297(-300): conv4_block23_1_conv
# Layers 298(-299): conv4_block23_1_bn
# Layers 299(-298): conv4_block23_1_relu
# Layers 300(-297): conv4_block23_2_conv
# Layers 301(-296): conv4_block23_concat
# Layers 302(-295): conv4_block24_0_bn
# Layers 303(-294): conv4_block24_0_relu
# Layers 304(-293): conv4_block24_1_conv
# Layers 305(-292): conv4_block24_1_bn
# Layers 306(-291): conv4_block24_1_relu
# Layers 307(-290): conv4_block24_2_conv
# Layers 308(-289): conv4_block24_concat
# Layers 309(-288): conv4_block25_0_bn
# Layers 310(-287): conv4_block25_0_relu
# Layers 311(-286): conv4_block25_1_conv
# Layers 312(-285): conv4_block25_1_bn
# Layers 313(-284): conv4_block25_1_relu
# Layers 314(-283): conv4_block25_2_conv
# Layers 315(-282): conv4_block25_concat
# Layers 316(-281): conv4_block26_0_bn
# Layers 317(-280): conv4_block26_0_relu
# Layers 318(-279): conv4_block26_1_conv
# Layers 319(-278): conv4_block26_1_bn
# Layers 320(-277): conv4_block26_1_relu
# Layers 321(-276): conv4_block26_2_conv
# Layers 322(-275): conv4_block26_concat
# Layers 323(-274): conv4_block27_0_bn
# Layers 324(-273): conv4_block27_0_relu
# Layers 325(-272): conv4_block27_1_conv
# Layers 326(-271): conv4_block27_1_bn
# Layers 327(-270): conv4_block27_1_relu
# Layers 328(-269): conv4_block27_2_conv
# Layers 329(-268): conv4_block27_concat
# Layers 330(-267): conv4_block28_0_bn
# Layers 331(-266): conv4_block28_0_relu
# Layers 332(-265): conv4_block28_1_conv
# Layers 333(-264): conv4_block28_1_bn
# Layers 334(-263): conv4_block28_1_relu
# Layers 335(-262): conv4_block28_2_conv
# Layers 336(-261): conv4_block28_concat
# Layers 337(-260): conv4_block29_0_bn
# Layers 338(-259): conv4_block29_0_relu
# Layers 339(-258): conv4_block29_1_conv
# Layers 340(-257): conv4_block29_1_bn
# Layers 341(-256): conv4_block29_1_relu
# Layers 342(-255): conv4_block29_2_conv
# Layers 343(-254): conv4_block29_concat
# Layers 344(-253): conv4_block30_0_bn
# Layers 345(-252): conv4_block30_0_relu
# Layers 346(-251): conv4_block30_1_conv
# Layers 347(-250): conv4_block30_1_bn
# Layers 348(-249): conv4_block30_1_relu
# Layers 349(-248): conv4_block30_2_conv
# Layers 350(-247): conv4_block30_concat
# Layers 351(-246): conv4_block31_0_bn
# Layers 352(-245): conv4_block31_0_relu
# Layers 353(-244): conv4_block31_1_conv
# Layers 354(-243): conv4_block31_1_bn
# Layers 355(-242): conv4_block31_1_relu
# Layers 356(-241): conv4_block31_2_conv
# Layers 357(-240): conv4_block31_concat
# Layers 358(-239): conv4_block32_0_bn
# Layers 359(-238): conv4_block32_0_relu
# Layers 360(-237): conv4_block32_1_conv
# Layers 361(-236): conv4_block32_1_bn
# Layers 362(-235): conv4_block32_1_relu
# Layers 363(-234): conv4_block32_2_conv
# Layers 364(-233): conv4_block32_concat
# Layers 365(-232): pool4_bn
# Layers 366(-231): pool4_relu
# Layers 367(-230): pool4_conv
# Layers 368(-229): pool4_pool
# Layers 369(-228): conv5_block1_0_bn
# Layers 370(-227): conv5_block1_0_relu
# Layers 371(-226): conv5_block1_1_conv
# Layers 372(-225): conv5_block1_1_bn
# Layers 373(-224): conv5_block1_1_relu
# Layers 374(-223): conv5_block1_2_conv
# Layers 375(-222): conv5_block1_concat
# Layers 376(-221): conv5_block2_0_bn
# Layers 377(-220): conv5_block2_0_relu
# Layers 378(-219): conv5_block2_1_conv
# Layers 379(-218): conv5_block2_1_bn
# Layers 380(-217): conv5_block2_1_relu
# Layers 381(-216): conv5_block2_2_conv
# Layers 382(-215): conv5_block2_concat
# Layers 383(-214): conv5_block3_0_bn
# Layers 384(-213): conv5_block3_0_relu
# Layers 385(-212): conv5_block3_1_conv
# Layers 386(-211): conv5_block3_1_bn
# Layers 387(-210): conv5_block3_1_relu
# Layers 388(-209): conv5_block3_2_conv
# Layers 389(-208): conv5_block3_concat
# Layers 390(-207): conv5_block4_0_bn
# Layers 391(-206): conv5_block4_0_relu
# Layers 392(-205): conv5_block4_1_conv
# Layers 393(-204): conv5_block4_1_bn
# Layers 394(-203): conv5_block4_1_relu
# Layers 395(-202): conv5_block4_2_conv
# Layers 396(-201): conv5_block4_concat
# Layers 397(-200): conv5_block5_0_bn
# Layers 398(-199): conv5_block5_0_relu
# Layers 399(-198): conv5_block5_1_conv
# Layers 400(-197): conv5_block5_1_bn
# Layers 401(-196): conv5_block5_1_relu
# Layers 402(-195): conv5_block5_2_conv
# Layers 403(-194): conv5_block5_concat
# Layers 404(-193): conv5_block6_0_bn
# Layers 405(-192): conv5_block6_0_relu
# Layers 406(-191): conv5_block6_1_conv
# Layers 407(-190): conv5_block6_1_bn
# Layers 408(-189): conv5_block6_1_relu
# Layers 409(-188): conv5_block6_2_conv
# Layers 410(-187): conv5_block6_concat
# Layers 411(-186): conv5_block7_0_bn
# Layers 412(-185): conv5_block7_0_relu
# Layers 413(-184): conv5_block7_1_conv
# Layers 414(-183): conv5_block7_1_bn
# Layers 415(-182): conv5_block7_1_relu
# Layers 416(-181): conv5_block7_2_conv
# Layers 417(-180): conv5_block7_concat
# Layers 418(-179): conv5_block8_0_bn
# Layers 419(-178): conv5_block8_0_relu
# Layers 420(-177): conv5_block8_1_conv
# Layers 421(-176): conv5_block8_1_bn
# Layers 422(-175): conv5_block8_1_relu
# Layers 423(-174): conv5_block8_2_conv
# Layers 424(-173): conv5_block8_concat
# Layers 425(-172): conv5_block9_0_bn
# Layers 426(-171): conv5_block9_0_relu
# Layers 427(-170): conv5_block9_1_conv
# Layers 428(-169): conv5_block9_1_bn
# Layers 429(-168): conv5_block9_1_relu
# Layers 430(-167): conv5_block9_2_conv
# Layers 431(-166): conv5_block9_concat
# Layers 432(-165): conv5_block10_0_bn
# Layers 433(-164): conv5_block10_0_relu
# Layers 434(-163): conv5_block10_1_conv
# Layers 435(-162): conv5_block10_1_bn
# Layers 436(-161): conv5_block10_1_relu
# Layers 437(-160): conv5_block10_2_conv
# Layers 438(-159): conv5_block10_concat
# Layers 439(-158): conv5_block11_0_bn
# Layers 440(-157): conv5_block11_0_relu
# Layers 441(-156): conv5_block11_1_conv
# Layers 442(-155): conv5_block11_1_bn
# Layers 443(-154): conv5_block11_1_relu
# Layers 444(-153): conv5_block11_2_conv
# Layers 445(-152): conv5_block11_concat
# Layers 446(-151): conv5_block12_0_bn
# Layers 447(-150): conv5_block12_0_relu
# Layers 448(-149): conv5_block12_1_conv
# Layers 449(-148): conv5_block12_1_bn
# Layers 450(-147): conv5_block12_1_relu
# Layers 451(-146): conv5_block12_2_conv
# Layers 452(-145): conv5_block12_concat
# Layers 453(-144): conv5_block13_0_bn
# Layers 454(-143): conv5_block13_0_relu
# Layers 455(-142): conv5_block13_1_conv
# Layers 456(-141): conv5_block13_1_bn
# Layers 457(-140): conv5_block13_1_relu
# Layers 458(-139): conv5_block13_2_conv
# Layers 459(-138): conv5_block13_concat
# Layers 460(-137): conv5_block14_0_bn
# Layers 461(-136): conv5_block14_0_relu
# Layers 462(-135): conv5_block14_1_conv
# Layers 463(-134): conv5_block14_1_bn
# Layers 464(-133): conv5_block14_1_relu
# Layers 465(-132): conv5_block14_2_conv
# Layers 466(-131): conv5_block14_concat
# Layers 467(-130): conv5_block15_0_bn
# Layers 468(-129): conv5_block15_0_relu
# Layers 469(-128): conv5_block15_1_conv
# Layers 470(-127): conv5_block15_1_bn
# Layers 471(-126): conv5_block15_1_relu
# Layers 472(-125): conv5_block15_2_conv
# Layers 473(-124): conv5_block15_concat
# Layers 474(-123): conv5_block16_0_bn
# Layers 475(-122): conv5_block16_0_relu
# Layers 476(-121): conv5_block16_1_conv
# Layers 477(-120): conv5_block16_1_bn
# Layers 478(-119): conv5_block16_1_relu
# Layers 479(-118): conv5_block16_2_conv
# Layers 480(-117): conv5_block16_concat
# Layers 481(-116): conv5_block17_0_bn
# Layers 482(-115): conv5_block17_0_relu
# Layers 483(-114): conv5_block17_1_conv
# Layers 484(-113): conv5_block17_1_bn
# Layers 485(-112): conv5_block17_1_relu
# Layers 486(-111): conv5_block17_2_conv
# Layers 487(-110): conv5_block17_concat
# Layers 488(-109): conv5_block18_0_bn
# Layers 489(-108): conv5_block18_0_relu
# Layers 490(-107): conv5_block18_1_conv
# Layers 491(-106): conv5_block18_1_bn
# Layers 492(-105): conv5_block18_1_relu
# Layers 493(-104): conv5_block18_2_conv
# Layers 494(-103): conv5_block18_concat
# Layers 495(-102): conv5_block19_0_bn
# Layers 496(-101): conv5_block19_0_relu
# Layers 497(-100): conv5_block19_1_conv
# Layers 498(-99): conv5_block19_1_bn
# Layers 499(-98): conv5_block19_1_relu
# Layers 500(-97): conv5_block19_2_conv
# Layers 501(-96): conv5_block19_concat
# Layers 502(-95): conv5_block20_0_bn
# Layers 503(-94): conv5_block20_0_relu
# Layers 504(-93): conv5_block20_1_conv
# Layers 505(-92): conv5_block20_1_bn
# Layers 506(-91): conv5_block20_1_relu
# Layers 507(-90): conv5_block20_2_conv
# Layers 508(-89): conv5_block20_concat
# Layers 509(-88): conv5_block21_0_bn
# Layers 510(-87): conv5_block21_0_relu
# Layers 511(-86): conv5_block21_1_conv
# Layers 512(-85): conv5_block21_1_bn
# Layers 513(-84): conv5_block21_1_relu
# Layers 514(-83): conv5_block21_2_conv
# Layers 515(-82): conv5_block21_concat
# Layers 516(-81): conv5_block22_0_bn
# Layers 517(-80): conv5_block22_0_relu
# Layers 518(-79): conv5_block22_1_conv
# Layers 519(-78): conv5_block22_1_bn
# Layers 520(-77): conv5_block22_1_relu
# Layers 521(-76): conv5_block22_2_conv
# Layers 522(-75): conv5_block22_concat
# Layers 523(-74): conv5_block23_0_bn
# Layers 524(-73): conv5_block23_0_relu
# Layers 525(-72): conv5_block23_1_conv
# Layers 526(-71): conv5_block23_1_bn
# Layers 527(-70): conv5_block23_1_relu
# Layers 528(-69): conv5_block23_2_conv
# Layers 529(-68): conv5_block23_concat
# Layers 530(-67): conv5_block24_0_bn
# Layers 531(-66): conv5_block24_0_relu
# Layers 532(-65): conv5_block24_1_conv
# Layers 533(-64): conv5_block24_1_bn
# Layers 534(-63): conv5_block24_1_relu
# Layers 535(-62): conv5_block24_2_conv
# Layers 536(-61): conv5_block24_concat
# Layers 537(-60): conv5_block25_0_bn
# Layers 538(-59): conv5_block25_0_relu
# Layers 539(-58): conv5_block25_1_conv
# Layers 540(-57): conv5_block25_1_bn
# Layers 541(-56): conv5_block25_1_relu
# Layers 542(-55): conv5_block25_2_conv
# Layers 543(-54): conv5_block25_concat
# Layers 544(-53): conv5_block26_0_bn
# Layers 545(-52): conv5_block26_0_relu
# Layers 546(-51): conv5_block26_1_conv
# Layers 547(-50): conv5_block26_1_bn
# Layers 548(-49): conv5_block26_1_relu
# Layers 549(-48): conv5_block26_2_conv
# Layers 550(-47): conv5_block26_concat
# Layers 551(-46): conv5_block27_0_bn
# Layers 552(-45): conv5_block27_0_relu
# Layers 553(-44): conv5_block27_1_conv
# Layers 554(-43): conv5_block27_1_bn
# Layers 555(-42): conv5_block27_1_relu
# Layers 556(-41): conv5_block27_2_conv
# Layers 557(-40): conv5_block27_concat
# Layers 558(-39): conv5_block28_0_bn
# Layers 559(-38): conv5_block28_0_relu
# Layers 560(-37): conv5_block28_1_conv
# Layers 561(-36): conv5_block28_1_bn
# Layers 562(-35): conv5_block28_1_relu
# Layers 563(-34): conv5_block28_2_conv
# Layers 564(-33): conv5_block28_concat
# Layers 565(-32): conv5_block29_0_bn
# Layers 566(-31): conv5_block29_0_relu
# Layers 567(-30): conv5_block29_1_conv
# Layers 568(-29): conv5_block29_1_bn
# Layers 569(-28): conv5_block29_1_relu
# Layers 570(-27): conv5_block29_2_conv
# Layers 571(-26): conv5_block29_concat
# Layers 572(-25): conv5_block30_0_bn
# Layers 573(-24): conv5_block30_0_relu
# Layers 574(-23): conv5_block30_1_conv
# Layers 575(-22): conv5_block30_1_bn
# Layers 576(-21): conv5_block30_1_relu
# Layers 577(-20): conv5_block30_2_conv
# Layers 578(-19): conv5_block30_concat
# Layers 579(-18): conv5_block31_0_bn
# Layers 580(-17): conv5_block31_0_relu
# Layers 581(-16): conv5_block31_1_conv
# Layers 582(-15): conv5_block31_1_bn
# Layers 583(-14): conv5_block31_1_relu
# Layers 584(-13): conv5_block31_2_conv
# Layers 585(-12): conv5_block31_concat
# Layers 586(-11): conv5_block32_0_bn
# Layers 587(-10): conv5_block32_0_relu
# Layers 588(-9): conv5_block32_1_conv
# Layers 589(-8): conv5_block32_1_bn
# Layers 590(-7): conv5_block32_1_relu
# Layers 591(-6): conv5_block32_2_conv
# Layers 592(-5): conv5_block32_concat
# Layers 593(-4): bn
# Layers 594(-3): relu
# Layers 595(-2): avg_pool
# Layers 596(-1): predictions

# %%
DenseNet169.summary()
# Out:
# Model: "densenet169"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_15[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_2[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
# ...
#
#  conv5_block25_0_relu (Activati  (None, 7, 7, 1408)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 7, 7, 128)    180224      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 7, 7, 1440)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 7, 7, 1440)  5760        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 7, 7, 1440)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 7, 7, 128)    184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 7, 7, 1472)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 7, 7, 1472)  5888        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 7, 7, 1472)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 7, 7, 128)    188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 7, 7, 1504)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 7, 7, 1504)  6016        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 7, 7, 1504)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 7, 7, 128)    192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 7, 7, 1536)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 7, 7, 1536)  6144        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 7, 7, 1536)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 7, 7, 128)    196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 7, 7, 1568)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 7, 7, 1568)  6272        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 7, 7, 1568)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 7, 7, 128)    200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 7, 7, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 7, 7, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 7, 7, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 7, 7, 128)    204800      ['conv5_block31_0_relu[0][0]']
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 7, 7, 1664)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1664)   6656        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1664)   0           ['bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1664)        0           ['relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         1665000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 14,307,880
# Trainable params: 14,149,480
# Non-trainable params: 158,400
# __________________________________________________________________________________________________

# %% [markdown]
# # DenseNet201

# %%
DenseNet201 = tf.keras.applications.DenseNet201(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
)

# %%
model_analyze(DenseNet201)
# Out:
# Layers 0(-709): input_16
# Layers 1(-708): zero_padding2d_4
# Layers 2(-707): conv1/conv
# Layers 3(-706): conv1/bn
# Layers 4(-705): conv1/relu
# Layers 5(-704): zero_padding2d_5
# Layers 6(-703): pool1
# Layers 7(-702): conv2_block1_0_bn
# Layers 8(-701): conv2_block1_0_relu
# Layers 9(-700): conv2_block1_1_conv
# Layers 10(-699): conv2_block1_1_bn
# Layers 11(-698): conv2_block1_1_relu
# Layers 12(-697): conv2_block1_2_conv
# Layers 13(-696): conv2_block1_concat
# Layers 14(-695): conv2_block2_0_bn
# Layers 15(-694): conv2_block2_0_relu
# Layers 16(-693): conv2_block2_1_conv
# Layers 17(-692): conv2_block2_1_bn
# Layers 18(-691): conv2_block2_1_relu
# Layers 19(-690): conv2_block2_2_conv
# Layers 20(-689): conv2_block2_concat
# Layers 21(-688): conv2_block3_0_bn
# Layers 22(-687): conv2_block3_0_relu
# Layers 23(-686): conv2_block3_1_conv
# Layers 24(-685): conv2_block3_1_bn
# Layers 25(-684): conv2_block3_1_relu
# Layers 26(-683): conv2_block3_2_conv
# Layers 27(-682): conv2_block3_concat
# Layers 28(-681): conv2_block4_0_bn
# Layers 29(-680): conv2_block4_0_relu
# Layers 30(-679): conv2_block4_1_conv
# Layers 31(-678): conv2_block4_1_bn
# Layers 32(-677): conv2_block4_1_relu
# Layers 33(-676): conv2_block4_2_conv
# Layers 34(-675): conv2_block4_concat
# Layers 35(-674): conv2_block5_0_bn
# Layers 36(-673): conv2_block5_0_relu
# Layers 37(-672): conv2_block5_1_conv
# Layers 38(-671): conv2_block5_1_bn
# Layers 39(-670): conv2_block5_1_relu
# Layers 40(-669): conv2_block5_2_conv
# Layers 41(-668): conv2_block5_concat
# Layers 42(-667): conv2_block6_0_bn
# Layers 43(-666): conv2_block6_0_relu
# Layers 44(-665): conv2_block6_1_conv
# Layers 45(-664): conv2_block6_1_bn
# Layers 46(-663): conv2_block6_1_relu
# Layers 47(-662): conv2_block6_2_conv
# Layers 48(-661): conv2_block6_concat
# Layers 49(-660): pool2_bn
# Layers 50(-659): pool2_relu
# Layers 51(-658): pool2_conv
# Layers 52(-657): pool2_pool
# Layers 53(-656): conv3_block1_0_bn
# Layers 54(-655): conv3_block1_0_relu
# Layers 55(-654): conv3_block1_1_conv
# Layers 56(-653): conv3_block1_1_bn
# Layers 57(-652): conv3_block1_1_relu
# Layers 58(-651): conv3_block1_2_conv
# Layers 59(-650): conv3_block1_concat
# Layers 60(-649): conv3_block2_0_bn
# Layers 61(-648): conv3_block2_0_relu
# Layers 62(-647): conv3_block2_1_conv
# Layers 63(-646): conv3_block2_1_bn
# Layers 64(-645): conv3_block2_1_relu
# Layers 65(-644): conv3_block2_2_conv
# Layers 66(-643): conv3_block2_concat
# Layers 67(-642): conv3_block3_0_bn
# Layers 68(-641): conv3_block3_0_relu
# Layers 69(-640): conv3_block3_1_conv
# Layers 70(-639): conv3_block3_1_bn
# Layers 71(-638): conv3_block3_1_relu
# Layers 72(-637): conv3_block3_2_conv
# Layers 73(-636): conv3_block3_concat
# Layers 74(-635): conv3_block4_0_bn
# Layers 75(-634): conv3_block4_0_relu
# Layers 76(-633): conv3_block4_1_conv
# Layers 77(-632): conv3_block4_1_bn
# Layers 78(-631): conv3_block4_1_relu
# Layers 79(-630): conv3_block4_2_conv
# Layers 80(-629): conv3_block4_concat
# Layers 81(-628): conv3_block5_0_bn
# Layers 82(-627): conv3_block5_0_relu
# Layers 83(-626): conv3_block5_1_conv
# Layers 84(-625): conv3_block5_1_bn
# Layers 85(-624): conv3_block5_1_relu
# Layers 86(-623): conv3_block5_2_conv
# Layers 87(-622): conv3_block5_concat
# Layers 88(-621): conv3_block6_0_bn
# Layers 89(-620): conv3_block6_0_relu
# Layers 90(-619): conv3_block6_1_conv
# Layers 91(-618): conv3_block6_1_bn
# Layers 92(-617): conv3_block6_1_relu
# Layers 93(-616): conv3_block6_2_conv
# Layers 94(-615): conv3_block6_concat
# Layers 95(-614): conv3_block7_0_bn
# Layers 96(-613): conv3_block7_0_relu
# Layers 97(-612): conv3_block7_1_conv
# Layers 98(-611): conv3_block7_1_bn
# Layers 99(-610): conv3_block7_1_relu
# Layers 100(-609): conv3_block7_2_conv
# Layers 101(-608): conv3_block7_concat
# Layers 102(-607): conv3_block8_0_bn
# Layers 103(-606): conv3_block8_0_relu
# Layers 104(-605): conv3_block8_1_conv
# Layers 105(-604): conv3_block8_1_bn
# Layers 106(-603): conv3_block8_1_relu
# Layers 107(-602): conv3_block8_2_conv
# Layers 108(-601): conv3_block8_concat
# Layers 109(-600): conv3_block9_0_bn
# Layers 110(-599): conv3_block9_0_relu
# Layers 111(-598): conv3_block9_1_conv
# Layers 112(-597): conv3_block9_1_bn
# Layers 113(-596): conv3_block9_1_relu
# Layers 114(-595): conv3_block9_2_conv
# Layers 115(-594): conv3_block9_concat
# Layers 116(-593): conv3_block10_0_bn
# Layers 117(-592): conv3_block10_0_relu
# Layers 118(-591): conv3_block10_1_conv
# Layers 119(-590): conv3_block10_1_bn
# Layers 120(-589): conv3_block10_1_relu
# Layers 121(-588): conv3_block10_2_conv
# Layers 122(-587): conv3_block10_concat
# Layers 123(-586): conv3_block11_0_bn
# Layers 124(-585): conv3_block11_0_relu
# Layers 125(-584): conv3_block11_1_conv
# Layers 126(-583): conv3_block11_1_bn
# Layers 127(-582): conv3_block11_1_relu
# Layers 128(-581): conv3_block11_2_conv
# Layers 129(-580): conv3_block11_concat
# Layers 130(-579): conv3_block12_0_bn
# Layers 131(-578): conv3_block12_0_relu
# Layers 132(-577): conv3_block12_1_conv
# Layers 133(-576): conv3_block12_1_bn
# Layers 134(-575): conv3_block12_1_relu
# Layers 135(-574): conv3_block12_2_conv
# Layers 136(-573): conv3_block12_concat
# Layers 137(-572): pool3_bn
# Layers 138(-571): pool3_relu
# Layers 139(-570): pool3_conv
# Layers 140(-569): pool3_pool
# Layers 141(-568): conv4_block1_0_bn
# Layers 142(-567): conv4_block1_0_relu
# Layers 143(-566): conv4_block1_1_conv
# Layers 144(-565): conv4_block1_1_bn
# Layers 145(-564): conv4_block1_1_relu
# Layers 146(-563): conv4_block1_2_conv
# Layers 147(-562): conv4_block1_concat
# Layers 148(-561): conv4_block2_0_bn
# Layers 149(-560): conv4_block2_0_relu
# Layers 150(-559): conv4_block2_1_conv
# Layers 151(-558): conv4_block2_1_bn
# Layers 152(-557): conv4_block2_1_relu
# Layers 153(-556): conv4_block2_2_conv
# Layers 154(-555): conv4_block2_concat
# Layers 155(-554): conv4_block3_0_bn
# Layers 156(-553): conv4_block3_0_relu
# Layers 157(-552): conv4_block3_1_conv
# Layers 158(-551): conv4_block3_1_bn
# Layers 159(-550): conv4_block3_1_relu
# Layers 160(-549): conv4_block3_2_conv
# Layers 161(-548): conv4_block3_concat
# Layers 162(-547): conv4_block4_0_bn
# Layers 163(-546): conv4_block4_0_relu
# Layers 164(-545): conv4_block4_1_conv
# Layers 165(-544): conv4_block4_1_bn
# Layers 166(-543): conv4_block4_1_relu
# Layers 167(-542): conv4_block4_2_conv
# Layers 168(-541): conv4_block4_concat
# Layers 169(-540): conv4_block5_0_bn
# Layers 170(-539): conv4_block5_0_relu
# Layers 171(-538): conv4_block5_1_conv
# Layers 172(-537): conv4_block5_1_bn
# Layers 173(-536): conv4_block5_1_relu
# Layers 174(-535): conv4_block5_2_conv
# Layers 175(-534): conv4_block5_concat
# Layers 176(-533): conv4_block6_0_bn
# Layers 177(-532): conv4_block6_0_relu
# Layers 178(-531): conv4_block6_1_conv
# Layers 179(-530): conv4_block6_1_bn
# Layers 180(-529): conv4_block6_1_relu
# Layers 181(-528): conv4_block6_2_conv
# Layers 182(-527): conv4_block6_concat
# Layers 183(-526): conv4_block7_0_bn
# Layers 184(-525): conv4_block7_0_relu
# Layers 185(-524): conv4_block7_1_conv
# Layers 186(-523): conv4_block7_1_bn
# Layers 187(-522): conv4_block7_1_relu
# Layers 188(-521): conv4_block7_2_conv
# Layers 189(-520): conv4_block7_concat
# Layers 190(-519): conv4_block8_0_bn
# Layers 191(-518): conv4_block8_0_relu
# Layers 192(-517): conv4_block8_1_conv
# Layers 193(-516): conv4_block8_1_bn
# Layers 194(-515): conv4_block8_1_relu
# Layers 195(-514): conv4_block8_2_conv
# Layers 196(-513): conv4_block8_concat
# Layers 197(-512): conv4_block9_0_bn
# Layers 198(-511): conv4_block9_0_relu
# Layers 199(-510): conv4_block9_1_conv
# Layers 200(-509): conv4_block9_1_bn
# Layers 201(-508): conv4_block9_1_relu
# Layers 202(-507): conv4_block9_2_conv
# Layers 203(-506): conv4_block9_concat
# Layers 204(-505): conv4_block10_0_bn
# Layers 205(-504): conv4_block10_0_relu
# Layers 206(-503): conv4_block10_1_conv
# Layers 207(-502): conv4_block10_1_bn
# Layers 208(-501): conv4_block10_1_relu
# Layers 209(-500): conv4_block10_2_conv
# Layers 210(-499): conv4_block10_concat
# Layers 211(-498): conv4_block11_0_bn
# Layers 212(-497): conv4_block11_0_relu
# Layers 213(-496): conv4_block11_1_conv
# Layers 214(-495): conv4_block11_1_bn
# Layers 215(-494): conv4_block11_1_relu
# Layers 216(-493): conv4_block11_2_conv
# Layers 217(-492): conv4_block11_concat
# Layers 218(-491): conv4_block12_0_bn
# Layers 219(-490): conv4_block12_0_relu
# Layers 220(-489): conv4_block12_1_conv
# Layers 221(-488): conv4_block12_1_bn
# Layers 222(-487): conv4_block12_1_relu
# Layers 223(-486): conv4_block12_2_conv
# Layers 224(-485): conv4_block12_concat
# Layers 225(-484): conv4_block13_0_bn
# Layers 226(-483): conv4_block13_0_relu
# Layers 227(-482): conv4_block13_1_conv
# Layers 228(-481): conv4_block13_1_bn
# Layers 229(-480): conv4_block13_1_relu
# Layers 230(-479): conv4_block13_2_conv
# Layers 231(-478): conv4_block13_concat
# Layers 232(-477): conv4_block14_0_bn
# Layers 233(-476): conv4_block14_0_relu
# Layers 234(-475): conv4_block14_1_conv
# Layers 235(-474): conv4_block14_1_bn
# Layers 236(-473): conv4_block14_1_relu
# Layers 237(-472): conv4_block14_2_conv
# Layers 238(-471): conv4_block14_concat
# Layers 239(-470): conv4_block15_0_bn
# Layers 240(-469): conv4_block15_0_relu
# Layers 241(-468): conv4_block15_1_conv
# Layers 242(-467): conv4_block15_1_bn
# Layers 243(-466): conv4_block15_1_relu
# Layers 244(-465): conv4_block15_2_conv
# Layers 245(-464): conv4_block15_concat
# Layers 246(-463): conv4_block16_0_bn
# Layers 247(-462): conv4_block16_0_relu
# Layers 248(-461): conv4_block16_1_conv
# Layers 249(-460): conv4_block16_1_bn
# Layers 250(-459): conv4_block16_1_relu
# Layers 251(-458): conv4_block16_2_conv
# Layers 252(-457): conv4_block16_concat
# Layers 253(-456): conv4_block17_0_bn
# Layers 254(-455): conv4_block17_0_relu
# Layers 255(-454): conv4_block17_1_conv
# Layers 256(-453): conv4_block17_1_bn
# Layers 257(-452): conv4_block17_1_relu
# Layers 258(-451): conv4_block17_2_conv
# Layers 259(-450): conv4_block17_concat
# Layers 260(-449): conv4_block18_0_bn
# Layers 261(-448): conv4_block18_0_relu
# Layers 262(-447): conv4_block18_1_conv
# Layers 263(-446): conv4_block18_1_bn
# Layers 264(-445): conv4_block18_1_relu
# Layers 265(-444): conv4_block18_2_conv
# Layers 266(-443): conv4_block18_concat
# Layers 267(-442): conv4_block19_0_bn
# Layers 268(-441): conv4_block19_0_relu
# Layers 269(-440): conv4_block19_1_conv
# Layers 270(-439): conv4_block19_1_bn
# Layers 271(-438): conv4_block19_1_relu
# Layers 272(-437): conv4_block19_2_conv
# Layers 273(-436): conv4_block19_concat
# Layers 274(-435): conv4_block20_0_bn
# Layers 275(-434): conv4_block20_0_relu
# Layers 276(-433): conv4_block20_1_conv
# Layers 277(-432): conv4_block20_1_bn
# Layers 278(-431): conv4_block20_1_relu
# Layers 279(-430): conv4_block20_2_conv
# Layers 280(-429): conv4_block20_concat
# Layers 281(-428): conv4_block21_0_bn
# Layers 282(-427): conv4_block21_0_relu
# Layers 283(-426): conv4_block21_1_conv
# Layers 284(-425): conv4_block21_1_bn
# Layers 285(-424): conv4_block21_1_relu
# Layers 286(-423): conv4_block21_2_conv
# Layers 287(-422): conv4_block21_concat
# Layers 288(-421): conv4_block22_0_bn
# Layers 289(-420): conv4_block22_0_relu
# Layers 290(-419): conv4_block22_1_conv
# Layers 291(-418): conv4_block22_1_bn
# Layers 292(-417): conv4_block22_1_relu
# Layers 293(-416): conv4_block22_2_conv
# Layers 294(-415): conv4_block22_concat
# Layers 295(-414): conv4_block23_0_bn
# Layers 296(-413): conv4_block23_0_relu
# Layers 297(-412): conv4_block23_1_conv
# Layers 298(-411): conv4_block23_1_bn
# Layers 299(-410): conv4_block23_1_relu
# Layers 300(-409): conv4_block23_2_conv
# Layers 301(-408): conv4_block23_concat
# Layers 302(-407): conv4_block24_0_bn
# Layers 303(-406): conv4_block24_0_relu
# Layers 304(-405): conv4_block24_1_conv
# Layers 305(-404): conv4_block24_1_bn
# Layers 306(-403): conv4_block24_1_relu
# Layers 307(-402): conv4_block24_2_conv
# Layers 308(-401): conv4_block24_concat
# Layers 309(-400): conv4_block25_0_bn
# Layers 310(-399): conv4_block25_0_relu
# Layers 311(-398): conv4_block25_1_conv
# Layers 312(-397): conv4_block25_1_bn
# Layers 313(-396): conv4_block25_1_relu
# Layers 314(-395): conv4_block25_2_conv
# Layers 315(-394): conv4_block25_concat
# Layers 316(-393): conv4_block26_0_bn
# Layers 317(-392): conv4_block26_0_relu
# Layers 318(-391): conv4_block26_1_conv
# Layers 319(-390): conv4_block26_1_bn
# Layers 320(-389): conv4_block26_1_relu
# Layers 321(-388): conv4_block26_2_conv
# Layers 322(-387): conv4_block26_concat
# Layers 323(-386): conv4_block27_0_bn
# Layers 324(-385): conv4_block27_0_relu
# Layers 325(-384): conv4_block27_1_conv
# Layers 326(-383): conv4_block27_1_bn
# Layers 327(-382): conv4_block27_1_relu
# Layers 328(-381): conv4_block27_2_conv
# Layers 329(-380): conv4_block27_concat
# Layers 330(-379): conv4_block28_0_bn
# Layers 331(-378): conv4_block28_0_relu
# Layers 332(-377): conv4_block28_1_conv
# Layers 333(-376): conv4_block28_1_bn
# Layers 334(-375): conv4_block28_1_relu
# Layers 335(-374): conv4_block28_2_conv
# Layers 336(-373): conv4_block28_concat
# Layers 337(-372): conv4_block29_0_bn
# Layers 338(-371): conv4_block29_0_relu
# Layers 339(-370): conv4_block29_1_conv
# Layers 340(-369): conv4_block29_1_bn
# Layers 341(-368): conv4_block29_1_relu
# Layers 342(-367): conv4_block29_2_conv
# Layers 343(-366): conv4_block29_concat
# Layers 344(-365): conv4_block30_0_bn
# Layers 345(-364): conv4_block30_0_relu
# Layers 346(-363): conv4_block30_1_conv
# Layers 347(-362): conv4_block30_1_bn
# Layers 348(-361): conv4_block30_1_relu
# Layers 349(-360): conv4_block30_2_conv
# Layers 350(-359): conv4_block30_concat
# Layers 351(-358): conv4_block31_0_bn
# Layers 352(-357): conv4_block31_0_relu
# Layers 353(-356): conv4_block31_1_conv
# Layers 354(-355): conv4_block31_1_bn
# Layers 355(-354): conv4_block31_1_relu
# Layers 356(-353): conv4_block31_2_conv
# Layers 357(-352): conv4_block31_concat
# Layers 358(-351): conv4_block32_0_bn
# Layers 359(-350): conv4_block32_0_relu
# Layers 360(-349): conv4_block32_1_conv
# Layers 361(-348): conv4_block32_1_bn
# Layers 362(-347): conv4_block32_1_relu
# Layers 363(-346): conv4_block32_2_conv
# Layers 364(-345): conv4_block32_concat
# Layers 365(-344): conv4_block33_0_bn
# Layers 366(-343): conv4_block33_0_relu
# Layers 367(-342): conv4_block33_1_conv
# Layers 368(-341): conv4_block33_1_bn
# Layers 369(-340): conv4_block33_1_relu
# Layers 370(-339): conv4_block33_2_conv
# Layers 371(-338): conv4_block33_concat
# Layers 372(-337): conv4_block34_0_bn
# Layers 373(-336): conv4_block34_0_relu
# Layers 374(-335): conv4_block34_1_conv
# Layers 375(-334): conv4_block34_1_bn
# Layers 376(-333): conv4_block34_1_relu
# Layers 377(-332): conv4_block34_2_conv
# Layers 378(-331): conv4_block34_concat
# Layers 379(-330): conv4_block35_0_bn
# Layers 380(-329): conv4_block35_0_relu
# Layers 381(-328): conv4_block35_1_conv
# Layers 382(-327): conv4_block35_1_bn
# Layers 383(-326): conv4_block35_1_relu
# Layers 384(-325): conv4_block35_2_conv
# Layers 385(-324): conv4_block35_concat
# Layers 386(-323): conv4_block36_0_bn
# Layers 387(-322): conv4_block36_0_relu
# Layers 388(-321): conv4_block36_1_conv
# Layers 389(-320): conv4_block36_1_bn
# Layers 390(-319): conv4_block36_1_relu
# Layers 391(-318): conv4_block36_2_conv
# Layers 392(-317): conv4_block36_concat
# Layers 393(-316): conv4_block37_0_bn
# Layers 394(-315): conv4_block37_0_relu
# Layers 395(-314): conv4_block37_1_conv
# Layers 396(-313): conv4_block37_1_bn
# Layers 397(-312): conv4_block37_1_relu
# Layers 398(-311): conv4_block37_2_conv
# Layers 399(-310): conv4_block37_concat
# Layers 400(-309): conv4_block38_0_bn
# Layers 401(-308): conv4_block38_0_relu
# Layers 402(-307): conv4_block38_1_conv
# Layers 403(-306): conv4_block38_1_bn
# Layers 404(-305): conv4_block38_1_relu
# Layers 405(-304): conv4_block38_2_conv
# Layers 406(-303): conv4_block38_concat
# Layers 407(-302): conv4_block39_0_bn
# Layers 408(-301): conv4_block39_0_relu
# Layers 409(-300): conv4_block39_1_conv
# Layers 410(-299): conv4_block39_1_bn
# Layers 411(-298): conv4_block39_1_relu
# Layers 412(-297): conv4_block39_2_conv
# Layers 413(-296): conv4_block39_concat
# Layers 414(-295): conv4_block40_0_bn
# Layers 415(-294): conv4_block40_0_relu
# Layers 416(-293): conv4_block40_1_conv
# Layers 417(-292): conv4_block40_1_bn
# Layers 418(-291): conv4_block40_1_relu
# Layers 419(-290): conv4_block40_2_conv
# Layers 420(-289): conv4_block40_concat
# Layers 421(-288): conv4_block41_0_bn
# Layers 422(-287): conv4_block41_0_relu
# Layers 423(-286): conv4_block41_1_conv
# Layers 424(-285): conv4_block41_1_bn
# Layers 425(-284): conv4_block41_1_relu
# Layers 426(-283): conv4_block41_2_conv
# Layers 427(-282): conv4_block41_concat
# Layers 428(-281): conv4_block42_0_bn
# Layers 429(-280): conv4_block42_0_relu
# Layers 430(-279): conv4_block42_1_conv
# Layers 431(-278): conv4_block42_1_bn
# Layers 432(-277): conv4_block42_1_relu
# Layers 433(-276): conv4_block42_2_conv
# Layers 434(-275): conv4_block42_concat
# Layers 435(-274): conv4_block43_0_bn
# Layers 436(-273): conv4_block43_0_relu
# Layers 437(-272): conv4_block43_1_conv
# Layers 438(-271): conv4_block43_1_bn
# Layers 439(-270): conv4_block43_1_relu
# Layers 440(-269): conv4_block43_2_conv
# Layers 441(-268): conv4_block43_concat
# Layers 442(-267): conv4_block44_0_bn
# Layers 443(-266): conv4_block44_0_relu
# Layers 444(-265): conv4_block44_1_conv
# Layers 445(-264): conv4_block44_1_bn
# Layers 446(-263): conv4_block44_1_relu
# Layers 447(-262): conv4_block44_2_conv
# Layers 448(-261): conv4_block44_concat
# Layers 449(-260): conv4_block45_0_bn
# Layers 450(-259): conv4_block45_0_relu
# Layers 451(-258): conv4_block45_1_conv
# Layers 452(-257): conv4_block45_1_bn
# Layers 453(-256): conv4_block45_1_relu
# Layers 454(-255): conv4_block45_2_conv
# Layers 455(-254): conv4_block45_concat
# Layers 456(-253): conv4_block46_0_bn
# Layers 457(-252): conv4_block46_0_relu
# Layers 458(-251): conv4_block46_1_conv
# Layers 459(-250): conv4_block46_1_bn
# Layers 460(-249): conv4_block46_1_relu
# Layers 461(-248): conv4_block46_2_conv
# Layers 462(-247): conv4_block46_concat
# Layers 463(-246): conv4_block47_0_bn
# Layers 464(-245): conv4_block47_0_relu
# Layers 465(-244): conv4_block47_1_conv
# Layers 466(-243): conv4_block47_1_bn
# Layers 467(-242): conv4_block47_1_relu
# Layers 468(-241): conv4_block47_2_conv
# Layers 469(-240): conv4_block47_concat
# Layers 470(-239): conv4_block48_0_bn
# Layers 471(-238): conv4_block48_0_relu
# Layers 472(-237): conv4_block48_1_conv
# Layers 473(-236): conv4_block48_1_bn
# Layers 474(-235): conv4_block48_1_relu
# Layers 475(-234): conv4_block48_2_conv
# Layers 476(-233): conv4_block48_concat
# Layers 477(-232): pool4_bn
# Layers 478(-231): pool4_relu
# Layers 479(-230): pool4_conv
# Layers 480(-229): pool4_pool
# Layers 481(-228): conv5_block1_0_bn
# Layers 482(-227): conv5_block1_0_relu
# Layers 483(-226): conv5_block1_1_conv
# Layers 484(-225): conv5_block1_1_bn
# Layers 485(-224): conv5_block1_1_relu
# Layers 486(-223): conv5_block1_2_conv
# Layers 487(-222): conv5_block1_concat
# Layers 488(-221): conv5_block2_0_bn
# Layers 489(-220): conv5_block2_0_relu
# Layers 490(-219): conv5_block2_1_conv
# Layers 491(-218): conv5_block2_1_bn
# Layers 492(-217): conv5_block2_1_relu
# Layers 493(-216): conv5_block2_2_conv
# Layers 494(-215): conv5_block2_concat
# Layers 495(-214): conv5_block3_0_bn
# Layers 496(-213): conv5_block3_0_relu
# Layers 497(-212): conv5_block3_1_conv
# Layers 498(-211): conv5_block3_1_bn
# Layers 499(-210): conv5_block3_1_relu
# Layers 500(-209): conv5_block3_2_conv
# Layers 501(-208): conv5_block3_concat
# Layers 502(-207): conv5_block4_0_bn
# Layers 503(-206): conv5_block4_0_relu
# Layers 504(-205): conv5_block4_1_conv
# Layers 505(-204): conv5_block4_1_bn
# Layers 506(-203): conv5_block4_1_relu
# Layers 507(-202): conv5_block4_2_conv
# Layers 508(-201): conv5_block4_concat
# Layers 509(-200): conv5_block5_0_bn
# Layers 510(-199): conv5_block5_0_relu
# Layers 511(-198): conv5_block5_1_conv
# Layers 512(-197): conv5_block5_1_bn
# Layers 513(-196): conv5_block5_1_relu
# Layers 514(-195): conv5_block5_2_conv
# Layers 515(-194): conv5_block5_concat
# Layers 516(-193): conv5_block6_0_bn
# Layers 517(-192): conv5_block6_0_relu
# Layers 518(-191): conv5_block6_1_conv
# Layers 519(-190): conv5_block6_1_bn
# Layers 520(-189): conv5_block6_1_relu
# Layers 521(-188): conv5_block6_2_conv
# Layers 522(-187): conv5_block6_concat
# Layers 523(-186): conv5_block7_0_bn
# Layers 524(-185): conv5_block7_0_relu
# Layers 525(-184): conv5_block7_1_conv
# Layers 526(-183): conv5_block7_1_bn
# Layers 527(-182): conv5_block7_1_relu
# Layers 528(-181): conv5_block7_2_conv
# Layers 529(-180): conv5_block7_concat
# Layers 530(-179): conv5_block8_0_bn
# Layers 531(-178): conv5_block8_0_relu
# Layers 532(-177): conv5_block8_1_conv
# Layers 533(-176): conv5_block8_1_bn
# Layers 534(-175): conv5_block8_1_relu
# Layers 535(-174): conv5_block8_2_conv
# Layers 536(-173): conv5_block8_concat
# Layers 537(-172): conv5_block9_0_bn
# Layers 538(-171): conv5_block9_0_relu
# Layers 539(-170): conv5_block9_1_conv
# Layers 540(-169): conv5_block9_1_bn
# Layers 541(-168): conv5_block9_1_relu
# Layers 542(-167): conv5_block9_2_conv
# Layers 543(-166): conv5_block9_concat
# Layers 544(-165): conv5_block10_0_bn
# Layers 545(-164): conv5_block10_0_relu
# Layers 546(-163): conv5_block10_1_conv
# Layers 547(-162): conv5_block10_1_bn
# Layers 548(-161): conv5_block10_1_relu
# Layers 549(-160): conv5_block10_2_conv
# Layers 550(-159): conv5_block10_concat
# Layers 551(-158): conv5_block11_0_bn
# Layers 552(-157): conv5_block11_0_relu
# Layers 553(-156): conv5_block11_1_conv
# Layers 554(-155): conv5_block11_1_bn
# Layers 555(-154): conv5_block11_1_relu
# Layers 556(-153): conv5_block11_2_conv
# Layers 557(-152): conv5_block11_concat
# Layers 558(-151): conv5_block12_0_bn
# Layers 559(-150): conv5_block12_0_relu
# Layers 560(-149): conv5_block12_1_conv
# Layers 561(-148): conv5_block12_1_bn
# Layers 562(-147): conv5_block12_1_relu
# Layers 563(-146): conv5_block12_2_conv
# Layers 564(-145): conv5_block12_concat
# Layers 565(-144): conv5_block13_0_bn
# Layers 566(-143): conv5_block13_0_relu
# Layers 567(-142): conv5_block13_1_conv
# Layers 568(-141): conv5_block13_1_bn
# Layers 569(-140): conv5_block13_1_relu
# Layers 570(-139): conv5_block13_2_conv
# Layers 571(-138): conv5_block13_concat
# Layers 572(-137): conv5_block14_0_bn
# Layers 573(-136): conv5_block14_0_relu
# Layers 574(-135): conv5_block14_1_conv
# Layers 575(-134): conv5_block14_1_bn
# Layers 576(-133): conv5_block14_1_relu
# Layers 577(-132): conv5_block14_2_conv
# Layers 578(-131): conv5_block14_concat
# Layers 579(-130): conv5_block15_0_bn
# Layers 580(-129): conv5_block15_0_relu
# Layers 581(-128): conv5_block15_1_conv
# Layers 582(-127): conv5_block15_1_bn
# Layers 583(-126): conv5_block15_1_relu
# Layers 584(-125): conv5_block15_2_conv
# Layers 585(-124): conv5_block15_concat
# Layers 586(-123): conv5_block16_0_bn
# Layers 587(-122): conv5_block16_0_relu
# Layers 588(-121): conv5_block16_1_conv
# Layers 589(-120): conv5_block16_1_bn
# Layers 590(-119): conv5_block16_1_relu
# Layers 591(-118): conv5_block16_2_conv
# Layers 592(-117): conv5_block16_concat
# Layers 593(-116): conv5_block17_0_bn
# Layers 594(-115): conv5_block17_0_relu
# Layers 595(-114): conv5_block17_1_conv
# Layers 596(-113): conv5_block17_1_bn
# Layers 597(-112): conv5_block17_1_relu
# Layers 598(-111): conv5_block17_2_conv
# Layers 599(-110): conv5_block17_concat
# Layers 600(-109): conv5_block18_0_bn
# Layers 601(-108): conv5_block18_0_relu
# Layers 602(-107): conv5_block18_1_conv
# Layers 603(-106): conv5_block18_1_bn
# Layers 604(-105): conv5_block18_1_relu
# Layers 605(-104): conv5_block18_2_conv
# Layers 606(-103): conv5_block18_concat
# Layers 607(-102): conv5_block19_0_bn
# Layers 608(-101): conv5_block19_0_relu
# Layers 609(-100): conv5_block19_1_conv
# Layers 610(-99): conv5_block19_1_bn
# Layers 611(-98): conv5_block19_1_relu
# Layers 612(-97): conv5_block19_2_conv
# Layers 613(-96): conv5_block19_concat
# Layers 614(-95): conv5_block20_0_bn
# Layers 615(-94): conv5_block20_0_relu
# Layers 616(-93): conv5_block20_1_conv
# Layers 617(-92): conv5_block20_1_bn
# Layers 618(-91): conv5_block20_1_relu
# Layers 619(-90): conv5_block20_2_conv
# Layers 620(-89): conv5_block20_concat
# Layers 621(-88): conv5_block21_0_bn
# Layers 622(-87): conv5_block21_0_relu
# Layers 623(-86): conv5_block21_1_conv
# Layers 624(-85): conv5_block21_1_bn
# Layers 625(-84): conv5_block21_1_relu
# Layers 626(-83): conv5_block21_2_conv
# Layers 627(-82): conv5_block21_concat
# Layers 628(-81): conv5_block22_0_bn
# Layers 629(-80): conv5_block22_0_relu
# Layers 630(-79): conv5_block22_1_conv
# Layers 631(-78): conv5_block22_1_bn
# Layers 632(-77): conv5_block22_1_relu
# Layers 633(-76): conv5_block22_2_conv
# Layers 634(-75): conv5_block22_concat
# Layers 635(-74): conv5_block23_0_bn
# Layers 636(-73): conv5_block23_0_relu
# Layers 637(-72): conv5_block23_1_conv
# Layers 638(-71): conv5_block23_1_bn
# Layers 639(-70): conv5_block23_1_relu
# Layers 640(-69): conv5_block23_2_conv
# Layers 641(-68): conv5_block23_concat
# Layers 642(-67): conv5_block24_0_bn
# Layers 643(-66): conv5_block24_0_relu
# Layers 644(-65): conv5_block24_1_conv
# Layers 645(-64): conv5_block24_1_bn
# Layers 646(-63): conv5_block24_1_relu
# Layers 647(-62): conv5_block24_2_conv
# Layers 648(-61): conv5_block24_concat
# Layers 649(-60): conv5_block25_0_bn
# Layers 650(-59): conv5_block25_0_relu
# Layers 651(-58): conv5_block25_1_conv
# Layers 652(-57): conv5_block25_1_bn
# Layers 653(-56): conv5_block25_1_relu
# Layers 654(-55): conv5_block25_2_conv
# Layers 655(-54): conv5_block25_concat
# Layers 656(-53): conv5_block26_0_bn
# Layers 657(-52): conv5_block26_0_relu
# Layers 658(-51): conv5_block26_1_conv
# Layers 659(-50): conv5_block26_1_bn
# Layers 660(-49): conv5_block26_1_relu
# Layers 661(-48): conv5_block26_2_conv
# Layers 662(-47): conv5_block26_concat
# Layers 663(-46): conv5_block27_0_bn
# Layers 664(-45): conv5_block27_0_relu
# Layers 665(-44): conv5_block27_1_conv
# Layers 666(-43): conv5_block27_1_bn
# Layers 667(-42): conv5_block27_1_relu
# Layers 668(-41): conv5_block27_2_conv
# Layers 669(-40): conv5_block27_concat
# Layers 670(-39): conv5_block28_0_bn
# Layers 671(-38): conv5_block28_0_relu
# Layers 672(-37): conv5_block28_1_conv
# Layers 673(-36): conv5_block28_1_bn
# Layers 674(-35): conv5_block28_1_relu
# Layers 675(-34): conv5_block28_2_conv
# Layers 676(-33): conv5_block28_concat
# Layers 677(-32): conv5_block29_0_bn
# Layers 678(-31): conv5_block29_0_relu
# Layers 679(-30): conv5_block29_1_conv
# Layers 680(-29): conv5_block29_1_bn
# Layers 681(-28): conv5_block29_1_relu
# Layers 682(-27): conv5_block29_2_conv
# Layers 683(-26): conv5_block29_concat
# Layers 684(-25): conv5_block30_0_bn
# Layers 685(-24): conv5_block30_0_relu
# Layers 686(-23): conv5_block30_1_conv
# Layers 687(-22): conv5_block30_1_bn
# Layers 688(-21): conv5_block30_1_relu
# Layers 689(-20): conv5_block30_2_conv
# Layers 690(-19): conv5_block30_concat
# Layers 691(-18): conv5_block31_0_bn
# Layers 692(-17): conv5_block31_0_relu
# Layers 693(-16): conv5_block31_1_conv
# Layers 694(-15): conv5_block31_1_bn
# Layers 695(-14): conv5_block31_1_relu
# Layers 696(-13): conv5_block31_2_conv
# Layers 697(-12): conv5_block31_concat
# Layers 698(-11): conv5_block32_0_bn
# Layers 699(-10): conv5_block32_0_relu
# Layers 700(-9): conv5_block32_1_conv
# Layers 701(-8): conv5_block32_1_bn
# Layers 702(-7): conv5_block32_1_relu
# Layers 703(-6): conv5_block32_2_conv
# Layers 704(-5): conv5_block32_concat
# Layers 705(-4): bn
# Layers 706(-3): relu
# Layers 707(-2): avg_pool
# Layers 708(-1): predictions

# %%
DenseNet201.summary()
# Out:
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_4 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_16[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_4[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_5[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
# ...
#
#  conv5_block25_0_relu (Activati  (None, 7, 7, 1664)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 7, 7, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 7, 7, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 7, 7, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 7, 7, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 7, 7, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 7, 7, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 7, 7, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 7, 7, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 7, 7, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 7, 7, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 7, 7, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 7, 7, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 7, 7, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 7, 7, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 7, 7, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 7, 7, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 7, 7, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 7, 7, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 7, 7, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 7, 7, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 7, 7, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 7, 7, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 7, 7, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 7, 7, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 7, 7, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 7, 7, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1920)   0           ['bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1920)        0           ['relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         1921000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 20,242,984
# Trainable params: 20,013,928
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %% [markdown]
# # NASNetMobile

# %%
NASNetMobile = tf.keras.applications.NASNetMobile(
    input_shape=None,
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    classes=1000,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile.h5
# 24231936/24227760 [==============================] - 2s 0us/step
# 24240128/24227760 [==============================] - 2s 0us/step

# %%
model_analyze(NASNetMobile)
# Out:
# Layers 0(-771): input_17
# Layers 1(-770): stem_conv1
# Layers 2(-769): stem_bn1
# Layers 3(-768): activation_297
# Layers 4(-767): reduction_conv_1_stem_1
# Layers 5(-766): reduction_bn_1_stem_1
# Layers 6(-765): activation_298
# Layers 7(-764): activation_300
# Layers 8(-763): separable_conv_1_pad_reduction_left1_stem_1
# Layers 9(-762): separable_conv_1_pad_reduction_right1_stem_1
# Layers 10(-761): separable_conv_1_reduction_left1_stem_1
# Layers 11(-760): separable_conv_1_reduction_right1_stem_1
# Layers 12(-759): separable_conv_1_bn_reduction_left1_stem_1
# Layers 13(-758): separable_conv_1_bn_reduction_right1_stem_1
# Layers 14(-757): activation_299
# Layers 15(-756): activation_301
# Layers 16(-755): separable_conv_2_reduction_left1_stem_1
# Layers 17(-754): separable_conv_2_reduction_right1_stem_1
# Layers 18(-753): activation_302
# Layers 19(-752): separable_conv_2_bn_reduction_left1_stem_1
# Layers 20(-751): separable_conv_2_bn_reduction_right1_stem_1
# Layers 21(-750): separable_conv_1_pad_reduction_right2_stem_1
# Layers 22(-749): activation_304
# Layers 23(-748): reduction_add_1_stem_1
# Layers 24(-747): separable_conv_1_reduction_right2_stem_1
# Layers 25(-746): separable_conv_1_pad_reduction_right3_stem_1
# Layers 26(-745): activation_306
# Layers 27(-744): separable_conv_1_bn_reduction_right2_stem_1
# Layers 28(-743): separable_conv_1_reduction_right3_stem_1
# Layers 29(-742): separable_conv_1_reduction_left4_stem_1
# Layers 30(-741): activation_303
# Layers 31(-740): separable_conv_1_bn_reduction_right3_stem_1
# Layers 32(-739): separable_conv_1_bn_reduction_left4_stem_1
# Layers 33(-738): reduction_pad_1_stem_1
# Layers 34(-737): separable_conv_2_reduction_right2_stem_1
# Layers 35(-736): activation_305
# Layers 36(-735): activation_307
# Layers 37(-734): reduction_left2_stem_1
# Layers 38(-733): separable_conv_2_bn_reduction_right2_stem_1
# Layers 39(-732): separable_conv_2_reduction_right3_stem_1
# Layers 40(-731): separable_conv_2_reduction_left4_stem_1
# Layers 41(-730): adjust_relu_1_stem_2
# Layers 42(-729): reduction_add_2_stem_1
# Layers 43(-728): reduction_left3_stem_1
# Layers 44(-727): separable_conv_2_bn_reduction_right3_stem_1
# Layers 45(-726): reduction_left4_stem_1
# Layers 46(-725): separable_conv_2_bn_reduction_left4_stem_1
# Layers 47(-724): reduction_right5_stem_1
# Layers 48(-723): zero_padding2d_6
# Layers 49(-722): reduction_add3_stem_1
# Layers 50(-721): add_12
# Layers 51(-720): reduction_add4_stem_1
# Layers 52(-719): cropping2d
# Layers 53(-718): reduction_concat_stem_1
# Layers 54(-717): adjust_avg_pool_1_stem_2
# Layers 55(-716): adjust_avg_pool_2_stem_2
# Layers 56(-715): activation_308
# Layers 57(-714): adjust_conv_1_stem_2
# Layers 58(-713): adjust_conv_2_stem_2
# Layers 59(-712): reduction_conv_1_stem_2
# Layers 60(-711): concatenate_2
# Layers 61(-710): reduction_bn_1_stem_2
# Layers 62(-709): adjust_bn_stem_2
# Layers 63(-708): activation_309
# Layers 64(-707): activation_311
# Layers 65(-706): separable_conv_1_pad_reduction_left1_stem_2
# Layers 66(-705): separable_conv_1_pad_reduction_right1_stem_2
# Layers 67(-704): separable_conv_1_reduction_left1_stem_2
# Layers 68(-703): separable_conv_1_reduction_right1_stem_2
# Layers 69(-702): separable_conv_1_bn_reduction_left1_stem_2
# Layers 70(-701): separable_conv_1_bn_reduction_right1_stem_2
# Layers 71(-700): activation_310
# Layers 72(-699): activation_312
# Layers 73(-698): separable_conv_2_reduction_left1_stem_2
# Layers 74(-697): separable_conv_2_reduction_right1_stem_2
# Layers 75(-696): activation_313
# Layers 76(-695): separable_conv_2_bn_reduction_left1_stem_2
# Layers 77(-694): separable_conv_2_bn_reduction_right1_stem_2
# Layers 78(-693): separable_conv_1_pad_reduction_right2_stem_2
# Layers 79(-692): activation_315
# Layers 80(-691): reduction_add_1_stem_2
# Layers 81(-690): separable_conv_1_reduction_right2_stem_2
# Layers 82(-689): separable_conv_1_pad_reduction_right3_stem_2
# Layers 83(-688): activation_317
# Layers 84(-687): separable_conv_1_bn_reduction_right2_stem_2
# Layers 85(-686): separable_conv_1_reduction_right3_stem_2
# Layers 86(-685): separable_conv_1_reduction_left4_stem_2
# Layers 87(-684): activation_314
# Layers 88(-683): separable_conv_1_bn_reduction_right3_stem_2
# Layers 89(-682): separable_conv_1_bn_reduction_left4_stem_2
# Layers 90(-681): reduction_pad_1_stem_2
# Layers 91(-680): separable_conv_2_reduction_right2_stem_2
# Layers 92(-679): activation_316
# Layers 93(-678): activation_318
# Layers 94(-677): reduction_left2_stem_2
# Layers 95(-676): separable_conv_2_bn_reduction_right2_stem_2
# Layers 96(-675): separable_conv_2_reduction_right3_stem_2
# Layers 97(-674): separable_conv_2_reduction_left4_stem_2
# Layers 98(-673): adjust_relu_1_0
# Layers 99(-672): reduction_add_2_stem_2
# Layers 100(-671): reduction_left3_stem_2
# Layers 101(-670): separable_conv_2_bn_reduction_right3_stem_2
# Layers 102(-669): reduction_left4_stem_2
# Layers 103(-668): separable_conv_2_bn_reduction_left4_stem_2
# Layers 104(-667): reduction_right5_stem_2
# Layers 105(-666): zero_padding2d_7
# Layers 106(-665): reduction_add3_stem_2
# Layers 107(-664): add_13
# Layers 108(-663): reduction_add4_stem_2
# Layers 109(-662): cropping2d_1
# Layers 110(-661): reduction_concat_stem_2
# Layers 111(-660): adjust_avg_pool_1_0
# Layers 112(-659): adjust_avg_pool_2_0
# Layers 113(-658): adjust_conv_1_0
# Layers 114(-657): adjust_conv_2_0
# Layers 115(-656): activation_319
# Layers 116(-655): concatenate_3
# Layers 117(-654): normal_conv_1_0
# Layers 118(-653): adjust_bn_0
# Layers 119(-652): normal_bn_1_0
# Layers 120(-651): activation_320
# Layers 121(-650): activation_322
# Layers 122(-649): activation_324
# Layers 123(-648): activation_326
# Layers 124(-647): activation_328
# Layers 125(-646): separable_conv_1_normal_left1_0
# Layers 126(-645): separable_conv_1_normal_right1_0
# Layers 127(-644): separable_conv_1_normal_left2_0
# Layers 128(-643): separable_conv_1_normal_right2_0
# Layers 129(-642): separable_conv_1_normal_left5_0
# Layers 130(-641): separable_conv_1_bn_normal_left1_0
# Layers 131(-640): separable_conv_1_bn_normal_right1_0
# Layers 132(-639): separable_conv_1_bn_normal_left2_0
# Layers 133(-638): separable_conv_1_bn_normal_right2_0
# Layers 134(-637): separable_conv_1_bn_normal_left5_0
# Layers 135(-636): activation_321
# Layers 136(-635): activation_323
# Layers 137(-634): activation_325
# Layers 138(-633): activation_327
# Layers 139(-632): activation_329
# Layers 140(-631): separable_conv_2_normal_left1_0
# Layers 141(-630): separable_conv_2_normal_right1_0
# Layers 142(-629): separable_conv_2_normal_left2_0
# Layers 143(-628): separable_conv_2_normal_right2_0
# Layers 144(-627): separable_conv_2_normal_left5_0
# Layers 145(-626): separable_conv_2_bn_normal_left1_0
# Layers 146(-625): separable_conv_2_bn_normal_right1_0
# Layers 147(-624): separable_conv_2_bn_normal_left2_0
# Layers 148(-623): separable_conv_2_bn_normal_right2_0
# Layers 149(-622): normal_left3_0
# Layers 150(-621): normal_left4_0
# Layers 151(-620): normal_right4_0
# Layers 152(-619): separable_conv_2_bn_normal_left5_0
# Layers 153(-618): normal_add_1_0
# Layers 154(-617): normal_add_2_0
# Layers 155(-616): normal_add_3_0
# Layers 156(-615): normal_add_4_0
# Layers 157(-614): normal_add_5_0
# Layers 158(-613): normal_concat_0
# Layers 159(-612): activation_330
# Layers 160(-611): activation_331
# Layers 161(-610): adjust_conv_projection_1
# Layers 162(-609): normal_conv_1_1
# Layers 163(-608): adjust_bn_1
# Layers 164(-607): normal_bn_1_1
# Layers 165(-606): activation_332
# Layers 166(-605): activation_334
# Layers 167(-604): activation_336
# Layers 168(-603): activation_338
# Layers 169(-602): activation_340
# Layers 170(-601): separable_conv_1_normal_left1_1
# Layers 171(-600): separable_conv_1_normal_right1_1
# Layers 172(-599): separable_conv_1_normal_left2_1
# Layers 173(-598): separable_conv_1_normal_right2_1
# Layers 174(-597): separable_conv_1_normal_left5_1
# Layers 175(-596): separable_conv_1_bn_normal_left1_1
# Layers 176(-595): separable_conv_1_bn_normal_right1_1
# Layers 177(-594): separable_conv_1_bn_normal_left2_1
# Layers 178(-593): separable_conv_1_bn_normal_right2_1
# Layers 179(-592): separable_conv_1_bn_normal_left5_1
# Layers 180(-591): activation_333
# Layers 181(-590): activation_335
# Layers 182(-589): activation_337
# Layers 183(-588): activation_339
# Layers 184(-587): activation_341
# Layers 185(-586): separable_conv_2_normal_left1_1
# Layers 186(-585): separable_conv_2_normal_right1_1
# Layers 187(-584): separable_conv_2_normal_left2_1
# Layers 188(-583): separable_conv_2_normal_right2_1
# Layers 189(-582): separable_conv_2_normal_left5_1
# Layers 190(-581): separable_conv_2_bn_normal_left1_1
# Layers 191(-580): separable_conv_2_bn_normal_right1_1
# Layers 192(-579): separable_conv_2_bn_normal_left2_1
# Layers 193(-578): separable_conv_2_bn_normal_right2_1
# Layers 194(-577): normal_left3_1
# Layers 195(-576): normal_left4_1
# Layers 196(-575): normal_right4_1
# Layers 197(-574): separable_conv_2_bn_normal_left5_1
# Layers 198(-573): normal_add_1_1
# Layers 199(-572): normal_add_2_1
# Layers 200(-571): normal_add_3_1
# Layers 201(-570): normal_add_4_1
# Layers 202(-569): normal_add_5_1
# Layers 203(-568): normal_concat_1
# Layers 204(-567): activation_342
# Layers 205(-566): activation_343
# Layers 206(-565): adjust_conv_projection_2
# Layers 207(-564): normal_conv_1_2
# Layers 208(-563): adjust_bn_2
# Layers 209(-562): normal_bn_1_2
# Layers 210(-561): activation_344
# Layers 211(-560): activation_346
# Layers 212(-559): activation_348
# Layers 213(-558): activation_350
# Layers 214(-557): activation_352
# Layers 215(-556): separable_conv_1_normal_left1_2
# Layers 216(-555): separable_conv_1_normal_right1_2
# Layers 217(-554): separable_conv_1_normal_left2_2
# Layers 218(-553): separable_conv_1_normal_right2_2
# Layers 219(-552): separable_conv_1_normal_left5_2
# Layers 220(-551): separable_conv_1_bn_normal_left1_2
# Layers 221(-550): separable_conv_1_bn_normal_right1_2
# Layers 222(-549): separable_conv_1_bn_normal_left2_2
# Layers 223(-548): separable_conv_1_bn_normal_right2_2
# Layers 224(-547): separable_conv_1_bn_normal_left5_2
# Layers 225(-546): activation_345
# Layers 226(-545): activation_347
# Layers 227(-544): activation_349
# Layers 228(-543): activation_351
# Layers 229(-542): activation_353
# Layers 230(-541): separable_conv_2_normal_left1_2
# Layers 231(-540): separable_conv_2_normal_right1_2
# Layers 232(-539): separable_conv_2_normal_left2_2
# Layers 233(-538): separable_conv_2_normal_right2_2
# Layers 234(-537): separable_conv_2_normal_left5_2
# Layers 235(-536): separable_conv_2_bn_normal_left1_2
# Layers 236(-535): separable_conv_2_bn_normal_right1_2
# Layers 237(-534): separable_conv_2_bn_normal_left2_2
# Layers 238(-533): separable_conv_2_bn_normal_right2_2
# Layers 239(-532): normal_left3_2
# Layers 240(-531): normal_left4_2
# Layers 241(-530): normal_right4_2
# Layers 242(-529): separable_conv_2_bn_normal_left5_2
# Layers 243(-528): normal_add_1_2
# Layers 244(-527): normal_add_2_2
# Layers 245(-526): normal_add_3_2
# Layers 246(-525): normal_add_4_2
# Layers 247(-524): normal_add_5_2
# Layers 248(-523): normal_concat_2
# Layers 249(-522): activation_354
# Layers 250(-521): activation_355
# Layers 251(-520): adjust_conv_projection_3
# Layers 252(-519): normal_conv_1_3
# Layers 253(-518): adjust_bn_3
# Layers 254(-517): normal_bn_1_3
# Layers 255(-516): activation_356
# Layers 256(-515): activation_358
# Layers 257(-514): activation_360
# Layers 258(-513): activation_362
# Layers 259(-512): activation_364
# Layers 260(-511): separable_conv_1_normal_left1_3
# Layers 261(-510): separable_conv_1_normal_right1_3
# Layers 262(-509): separable_conv_1_normal_left2_3
# Layers 263(-508): separable_conv_1_normal_right2_3
# Layers 264(-507): separable_conv_1_normal_left5_3
# Layers 265(-506): separable_conv_1_bn_normal_left1_3
# Layers 266(-505): separable_conv_1_bn_normal_right1_3
# Layers 267(-504): separable_conv_1_bn_normal_left2_3
# Layers 268(-503): separable_conv_1_bn_normal_right2_3
# Layers 269(-502): separable_conv_1_bn_normal_left5_3
# Layers 270(-501): activation_357
# Layers 271(-500): activation_359
# Layers 272(-499): activation_361
# Layers 273(-498): activation_363
# Layers 274(-497): activation_365
# Layers 275(-496): separable_conv_2_normal_left1_3
# Layers 276(-495): separable_conv_2_normal_right1_3
# Layers 277(-494): separable_conv_2_normal_left2_3
# Layers 278(-493): separable_conv_2_normal_right2_3
# Layers 279(-492): separable_conv_2_normal_left5_3
# Layers 280(-491): separable_conv_2_bn_normal_left1_3
# Layers 281(-490): separable_conv_2_bn_normal_right1_3
# Layers 282(-489): separable_conv_2_bn_normal_left2_3
# Layers 283(-488): separable_conv_2_bn_normal_right2_3
# Layers 284(-487): normal_left3_3
# Layers 285(-486): normal_left4_3
# Layers 286(-485): normal_right4_3
# Layers 287(-484): separable_conv_2_bn_normal_left5_3
# Layers 288(-483): normal_add_1_3
# Layers 289(-482): normal_add_2_3
# Layers 290(-481): normal_add_3_3
# Layers 291(-480): normal_add_4_3
# Layers 292(-479): normal_add_5_3
# Layers 293(-478): normal_concat_3
# Layers 294(-477): activation_367
# Layers 295(-476): activation_366
# Layers 296(-475): reduction_conv_1_reduce_4
# Layers 297(-474): adjust_conv_projection_reduce_4
# Layers 298(-473): reduction_bn_1_reduce_4
# Layers 299(-472): adjust_bn_reduce_4
# Layers 300(-471): activation_368
# Layers 301(-470): activation_370
# Layers 302(-469): separable_conv_1_pad_reduction_left1_reduce_4
# Layers 303(-468): separable_conv_1_pad_reduction_right1_reduce_4
# Layers 304(-467): separable_conv_1_reduction_left1_reduce_4
# Layers 305(-466): separable_conv_1_reduction_right1_reduce_4
# Layers 306(-465): separable_conv_1_bn_reduction_left1_reduce_4
# Layers 307(-464): separable_conv_1_bn_reduction_right1_reduce_4
# Layers 308(-463): activation_369
# Layers 309(-462): activation_371
# Layers 310(-461): separable_conv_2_reduction_left1_reduce_4
# Layers 311(-460): separable_conv_2_reduction_right1_reduce_4
# Layers 312(-459): activation_372
# Layers 313(-458): separable_conv_2_bn_reduction_left1_reduce_4
# Layers 314(-457): separable_conv_2_bn_reduction_right1_reduce_4
# Layers 315(-456): separable_conv_1_pad_reduction_right2_reduce_4
# Layers 316(-455): activation_374
# Layers 317(-454): reduction_add_1_reduce_4
# Layers 318(-453): separable_conv_1_reduction_right2_reduce_4
# Layers 319(-452): separable_conv_1_pad_reduction_right3_reduce_4
# Layers 320(-451): activation_376
# Layers 321(-450): separable_conv_1_bn_reduction_right2_reduce_4
# Layers 322(-449): separable_conv_1_reduction_right3_reduce_4
# Layers 323(-448): separable_conv_1_reduction_left4_reduce_4
# Layers 324(-447): activation_373
# Layers 325(-446): separable_conv_1_bn_reduction_right3_reduce_4
# Layers 326(-445): separable_conv_1_bn_reduction_left4_reduce_4
# Layers 327(-444): reduction_pad_1_reduce_4
# Layers 328(-443): separable_conv_2_reduction_right2_reduce_4
# Layers 329(-442): activation_375
# Layers 330(-441): activation_377
# Layers 331(-440): reduction_left2_reduce_4
# Layers 332(-439): separable_conv_2_bn_reduction_right2_reduce_4
# Layers 333(-438): separable_conv_2_reduction_right3_reduce_4
# Layers 334(-437): separable_conv_2_reduction_left4_reduce_4
# Layers 335(-436): adjust_relu_1_5
# Layers 336(-435): reduction_add_2_reduce_4
# Layers 337(-434): reduction_left3_reduce_4
# Layers 338(-433): separable_conv_2_bn_reduction_right3_reduce_4
# Layers 339(-432): reduction_left4_reduce_4
# Layers 340(-431): separable_conv_2_bn_reduction_left4_reduce_4
# Layers 341(-430): reduction_right5_reduce_4
# Layers 342(-429): zero_padding2d_8
# Layers 343(-428): reduction_add3_reduce_4
# Layers 344(-427): add_14
# Layers 345(-426): reduction_add4_reduce_4
# Layers 346(-425): cropping2d_2
# Layers 347(-424): reduction_concat_reduce_4
# Layers 348(-423): adjust_avg_pool_1_5
# Layers 349(-422): adjust_avg_pool_2_5
# Layers 350(-421): adjust_conv_1_5
# Layers 351(-420): adjust_conv_2_5
# Layers 352(-419): activation_378
# Layers 353(-418): concatenate_4
# Layers 354(-417): normal_conv_1_5
# Layers 355(-416): adjust_bn_5
# Layers 356(-415): normal_bn_1_5
# Layers 357(-414): activation_379
# Layers 358(-413): activation_381
# Layers 359(-412): activation_383
# Layers 360(-411): activation_385
# Layers 361(-410): activation_387
# Layers 362(-409): separable_conv_1_normal_left1_5
# Layers 363(-408): separable_conv_1_normal_right1_5
# Layers 364(-407): separable_conv_1_normal_left2_5
# Layers 365(-406): separable_conv_1_normal_right2_5
# Layers 366(-405): separable_conv_1_normal_left5_5
# Layers 367(-404): separable_conv_1_bn_normal_left1_5
# Layers 368(-403): separable_conv_1_bn_normal_right1_5
# Layers 369(-402): separable_conv_1_bn_normal_left2_5
# Layers 370(-401): separable_conv_1_bn_normal_right2_5
# Layers 371(-400): separable_conv_1_bn_normal_left5_5
# Layers 372(-399): activation_380
# Layers 373(-398): activation_382
# Layers 374(-397): activation_384
# Layers 375(-396): activation_386
# Layers 376(-395): activation_388
# Layers 377(-394): separable_conv_2_normal_left1_5
# Layers 378(-393): separable_conv_2_normal_right1_5
# Layers 379(-392): separable_conv_2_normal_left2_5
# Layers 380(-391): separable_conv_2_normal_right2_5
# Layers 381(-390): separable_conv_2_normal_left5_5
# Layers 382(-389): separable_conv_2_bn_normal_left1_5
# Layers 383(-388): separable_conv_2_bn_normal_right1_5
# Layers 384(-387): separable_conv_2_bn_normal_left2_5
# Layers 385(-386): separable_conv_2_bn_normal_right2_5
# Layers 386(-385): normal_left3_5
# Layers 387(-384): normal_left4_5
# Layers 388(-383): normal_right4_5
# Layers 389(-382): separable_conv_2_bn_normal_left5_5
# Layers 390(-381): normal_add_1_5
# Layers 391(-380): normal_add_2_5
# Layers 392(-379): normal_add_3_5
# Layers 393(-378): normal_add_4_5
# Layers 394(-377): normal_add_5_5
# Layers 395(-376): normal_concat_5
# Layers 396(-375): activation_389
# Layers 397(-374): activation_390
# Layers 398(-373): adjust_conv_projection_6
# Layers 399(-372): normal_conv_1_6
# Layers 400(-371): adjust_bn_6
# Layers 401(-370): normal_bn_1_6
# Layers 402(-369): activation_391
# Layers 403(-368): activation_393
# Layers 404(-367): activation_395
# Layers 405(-366): activation_397
# Layers 406(-365): activation_399
# Layers 407(-364): separable_conv_1_normal_left1_6
# Layers 408(-363): separable_conv_1_normal_right1_6
# Layers 409(-362): separable_conv_1_normal_left2_6
# Layers 410(-361): separable_conv_1_normal_right2_6
# Layers 411(-360): separable_conv_1_normal_left5_6
# Layers 412(-359): separable_conv_1_bn_normal_left1_6
# Layers 413(-358): separable_conv_1_bn_normal_right1_6
# Layers 414(-357): separable_conv_1_bn_normal_left2_6
# Layers 415(-356): separable_conv_1_bn_normal_right2_6
# Layers 416(-355): separable_conv_1_bn_normal_left5_6
# Layers 417(-354): activation_392
# Layers 418(-353): activation_394
# Layers 419(-352): activation_396
# Layers 420(-351): activation_398
# Layers 421(-350): activation_400
# Layers 422(-349): separable_conv_2_normal_left1_6
# Layers 423(-348): separable_conv_2_normal_right1_6
# Layers 424(-347): separable_conv_2_normal_left2_6
# Layers 425(-346): separable_conv_2_normal_right2_6
# Layers 426(-345): separable_conv_2_normal_left5_6
# Layers 427(-344): separable_conv_2_bn_normal_left1_6
# Layers 428(-343): separable_conv_2_bn_normal_right1_6
# Layers 429(-342): separable_conv_2_bn_normal_left2_6
# Layers 430(-341): separable_conv_2_bn_normal_right2_6
# Layers 431(-340): normal_left3_6
# Layers 432(-339): normal_left4_6
# Layers 433(-338): normal_right4_6
# Layers 434(-337): separable_conv_2_bn_normal_left5_6
# Layers 435(-336): normal_add_1_6
# Layers 436(-335): normal_add_2_6
# Layers 437(-334): normal_add_3_6
# Layers 438(-333): normal_add_4_6
# Layers 439(-332): normal_add_5_6
# Layers 440(-331): normal_concat_6
# Layers 441(-330): activation_401
# Layers 442(-329): activation_402
# Layers 443(-328): adjust_conv_projection_7
# Layers 444(-327): normal_conv_1_7
# Layers 445(-326): adjust_bn_7
# Layers 446(-325): normal_bn_1_7
# Layers 447(-324): activation_403
# Layers 448(-323): activation_405
# Layers 449(-322): activation_407
# Layers 450(-321): activation_409
# Layers 451(-320): activation_411
# Layers 452(-319): separable_conv_1_normal_left1_7
# Layers 453(-318): separable_conv_1_normal_right1_7
# Layers 454(-317): separable_conv_1_normal_left2_7
# Layers 455(-316): separable_conv_1_normal_right2_7
# Layers 456(-315): separable_conv_1_normal_left5_7
# Layers 457(-314): separable_conv_1_bn_normal_left1_7
# Layers 458(-313): separable_conv_1_bn_normal_right1_7
# Layers 459(-312): separable_conv_1_bn_normal_left2_7
# Layers 460(-311): separable_conv_1_bn_normal_right2_7
# Layers 461(-310): separable_conv_1_bn_normal_left5_7
# Layers 462(-309): activation_404
# Layers 463(-308): activation_406
# Layers 464(-307): activation_408
# Layers 465(-306): activation_410
# Layers 466(-305): activation_412
# Layers 467(-304): separable_conv_2_normal_left1_7
# Layers 468(-303): separable_conv_2_normal_right1_7
# Layers 469(-302): separable_conv_2_normal_left2_7
# Layers 470(-301): separable_conv_2_normal_right2_7
# Layers 471(-300): separable_conv_2_normal_left5_7
# Layers 472(-299): separable_conv_2_bn_normal_left1_7
# Layers 473(-298): separable_conv_2_bn_normal_right1_7
# Layers 474(-297): separable_conv_2_bn_normal_left2_7
# Layers 475(-296): separable_conv_2_bn_normal_right2_7
# Layers 476(-295): normal_left3_7
# Layers 477(-294): normal_left4_7
# Layers 478(-293): normal_right4_7
# Layers 479(-292): separable_conv_2_bn_normal_left5_7
# Layers 480(-291): normal_add_1_7
# Layers 481(-290): normal_add_2_7
# Layers 482(-289): normal_add_3_7
# Layers 483(-288): normal_add_4_7
# Layers 484(-287): normal_add_5_7
# Layers 485(-286): normal_concat_7
# Layers 486(-285): activation_413
# Layers 487(-284): activation_414
# Layers 488(-283): adjust_conv_projection_8
# Layers 489(-282): normal_conv_1_8
# Layers 490(-281): adjust_bn_8
# Layers 491(-280): normal_bn_1_8
# Layers 492(-279): activation_415
# Layers 493(-278): activation_417
# Layers 494(-277): activation_419
# Layers 495(-276): activation_421
# Layers 496(-275): activation_423
# Layers 497(-274): separable_conv_1_normal_left1_8
# Layers 498(-273): separable_conv_1_normal_right1_8
# Layers 499(-272): separable_conv_1_normal_left2_8
# Layers 500(-271): separable_conv_1_normal_right2_8
# Layers 501(-270): separable_conv_1_normal_left5_8
# Layers 502(-269): separable_conv_1_bn_normal_left1_8
# Layers 503(-268): separable_conv_1_bn_normal_right1_8
# Layers 504(-267): separable_conv_1_bn_normal_left2_8
# Layers 505(-266): separable_conv_1_bn_normal_right2_8
# Layers 506(-265): separable_conv_1_bn_normal_left5_8
# Layers 507(-264): activation_416
# Layers 508(-263): activation_418
# Layers 509(-262): activation_420
# Layers 510(-261): activation_422
# Layers 511(-260): activation_424
# Layers 512(-259): separable_conv_2_normal_left1_8
# Layers 513(-258): separable_conv_2_normal_right1_8
# Layers 514(-257): separable_conv_2_normal_left2_8
# Layers 515(-256): separable_conv_2_normal_right2_8
# Layers 516(-255): separable_conv_2_normal_left5_8
# Layers 517(-254): separable_conv_2_bn_normal_left1_8
# Layers 518(-253): separable_conv_2_bn_normal_right1_8
# Layers 519(-252): separable_conv_2_bn_normal_left2_8
# Layers 520(-251): separable_conv_2_bn_normal_right2_8
# Layers 521(-250): normal_left3_8
# Layers 522(-249): normal_left4_8
# Layers 523(-248): normal_right4_8
# Layers 524(-247): separable_conv_2_bn_normal_left5_8
# Layers 525(-246): normal_add_1_8
# Layers 526(-245): normal_add_2_8
# Layers 527(-244): normal_add_3_8
# Layers 528(-243): normal_add_4_8
# Layers 529(-242): normal_add_5_8
# Layers 530(-241): normal_concat_8
# Layers 531(-240): activation_426
# Layers 532(-239): activation_425
# Layers 533(-238): reduction_conv_1_reduce_8
# Layers 534(-237): adjust_conv_projection_reduce_8
# Layers 535(-236): reduction_bn_1_reduce_8
# Layers 536(-235): adjust_bn_reduce_8
# Layers 537(-234): activation_427
# Layers 538(-233): activation_429
# Layers 539(-232): separable_conv_1_pad_reduction_left1_reduce_8
# Layers 540(-231): separable_conv_1_pad_reduction_right1_reduce_8
# Layers 541(-230): separable_conv_1_reduction_left1_reduce_8
# Layers 542(-229): separable_conv_1_reduction_right1_reduce_8
# Layers 543(-228): separable_conv_1_bn_reduction_left1_reduce_8
# Layers 544(-227): separable_conv_1_bn_reduction_right1_reduce_8
# Layers 545(-226): activation_428
# Layers 546(-225): activation_430
# Layers 547(-224): separable_conv_2_reduction_left1_reduce_8
# Layers 548(-223): separable_conv_2_reduction_right1_reduce_8
# Layers 549(-222): activation_431
# Layers 550(-221): separable_conv_2_bn_reduction_left1_reduce_8
# Layers 551(-220): separable_conv_2_bn_reduction_right1_reduce_8
# Layers 552(-219): separable_conv_1_pad_reduction_right2_reduce_8
# Layers 553(-218): activation_433
# Layers 554(-217): reduction_add_1_reduce_8
# Layers 555(-216): separable_conv_1_reduction_right2_reduce_8
# Layers 556(-215): separable_conv_1_pad_reduction_right3_reduce_8
# Layers 557(-214): activation_435
# Layers 558(-213): separable_conv_1_bn_reduction_right2_reduce_8
# Layers 559(-212): separable_conv_1_reduction_right3_reduce_8
# Layers 560(-211): separable_conv_1_reduction_left4_reduce_8
# Layers 561(-210): activation_432
# Layers 562(-209): separable_conv_1_bn_reduction_right3_reduce_8
# Layers 563(-208): separable_conv_1_bn_reduction_left4_reduce_8
# Layers 564(-207): reduction_pad_1_reduce_8
# Layers 565(-206): separable_conv_2_reduction_right2_reduce_8
# Layers 566(-205): activation_434
# Layers 567(-204): activation_436
# Layers 568(-203): reduction_left2_reduce_8
# Layers 569(-202): separable_conv_2_bn_reduction_right2_reduce_8
# Layers 570(-201): separable_conv_2_reduction_right3_reduce_8
# Layers 571(-200): separable_conv_2_reduction_left4_reduce_8
# Layers 572(-199): adjust_relu_1_9
# Layers 573(-198): reduction_add_2_reduce_8
# Layers 574(-197): reduction_left3_reduce_8
# Layers 575(-196): separable_conv_2_bn_reduction_right3_reduce_8
# Layers 576(-195): reduction_left4_reduce_8
# Layers 577(-194): separable_conv_2_bn_reduction_left4_reduce_8
# Layers 578(-193): reduction_right5_reduce_8
# Layers 579(-192): zero_padding2d_9
# Layers 580(-191): reduction_add3_reduce_8
# Layers 581(-190): add_15
# Layers 582(-189): reduction_add4_reduce_8
# Layers 583(-188): cropping2d_3
# Layers 584(-187): reduction_concat_reduce_8
# Layers 585(-186): adjust_avg_pool_1_9
# Layers 586(-185): adjust_avg_pool_2_9
# Layers 587(-184): adjust_conv_1_9
# Layers 588(-183): adjust_conv_2_9
# Layers 589(-182): activation_437
# Layers 590(-181): concatenate_5
# Layers 591(-180): normal_conv_1_9
# Layers 592(-179): adjust_bn_9
# Layers 593(-178): normal_bn_1_9
# Layers 594(-177): activation_438
# Layers 595(-176): activation_440
# Layers 596(-175): activation_442
# Layers 597(-174): activation_444
# Layers 598(-173): activation_446
# Layers 599(-172): separable_conv_1_normal_left1_9
# Layers 600(-171): separable_conv_1_normal_right1_9
# Layers 601(-170): separable_conv_1_normal_left2_9
# Layers 602(-169): separable_conv_1_normal_right2_9
# Layers 603(-168): separable_conv_1_normal_left5_9
# Layers 604(-167): separable_conv_1_bn_normal_left1_9
# Layers 605(-166): separable_conv_1_bn_normal_right1_9
# Layers 606(-165): separable_conv_1_bn_normal_left2_9
# Layers 607(-164): separable_conv_1_bn_normal_right2_9
# Layers 608(-163): separable_conv_1_bn_normal_left5_9
# Layers 609(-162): activation_439
# Layers 610(-161): activation_441
# Layers 611(-160): activation_443
# Layers 612(-159): activation_445
# Layers 613(-158): activation_447
# Layers 614(-157): separable_conv_2_normal_left1_9
# Layers 615(-156): separable_conv_2_normal_right1_9
# Layers 616(-155): separable_conv_2_normal_left2_9
# Layers 617(-154): separable_conv_2_normal_right2_9
# Layers 618(-153): separable_conv_2_normal_left5_9
# Layers 619(-152): separable_conv_2_bn_normal_left1_9
# Layers 620(-151): separable_conv_2_bn_normal_right1_9
# Layers 621(-150): separable_conv_2_bn_normal_left2_9
# Layers 622(-149): separable_conv_2_bn_normal_right2_9
# Layers 623(-148): normal_left3_9
# Layers 624(-147): normal_left4_9
# Layers 625(-146): normal_right4_9
# Layers 626(-145): separable_conv_2_bn_normal_left5_9
# Layers 627(-144): normal_add_1_9
# Layers 628(-143): normal_add_2_9
# Layers 629(-142): normal_add_3_9
# Layers 630(-141): normal_add_4_9
# Layers 631(-140): normal_add_5_9
# Layers 632(-139): normal_concat_9
# Layers 633(-138): activation_448
# Layers 634(-137): activation_449
# Layers 635(-136): adjust_conv_projection_10
# Layers 636(-135): normal_conv_1_10
# Layers 637(-134): adjust_bn_10
# Layers 638(-133): normal_bn_1_10
# Layers 639(-132): activation_450
# Layers 640(-131): activation_452
# Layers 641(-130): activation_454
# Layers 642(-129): activation_456
# Layers 643(-128): activation_458
# Layers 644(-127): separable_conv_1_normal_left1_10
# Layers 645(-126): separable_conv_1_normal_right1_10
# Layers 646(-125): separable_conv_1_normal_left2_10
# Layers 647(-124): separable_conv_1_normal_right2_10
# Layers 648(-123): separable_conv_1_normal_left5_10
# Layers 649(-122): separable_conv_1_bn_normal_left1_10
# Layers 650(-121): separable_conv_1_bn_normal_right1_10
# Layers 651(-120): separable_conv_1_bn_normal_left2_10
# Layers 652(-119): separable_conv_1_bn_normal_right2_10
# Layers 653(-118): separable_conv_1_bn_normal_left5_10
# Layers 654(-117): activation_451
# Layers 655(-116): activation_453
# Layers 656(-115): activation_455
# Layers 657(-114): activation_457
# Layers 658(-113): activation_459
# Layers 659(-112): separable_conv_2_normal_left1_10
# Layers 660(-111): separable_conv_2_normal_right1_10
# Layers 661(-110): separable_conv_2_normal_left2_10
# Layers 662(-109): separable_conv_2_normal_right2_10
# Layers 663(-108): separable_conv_2_normal_left5_10
# Layers 664(-107): separable_conv_2_bn_normal_left1_10
# Layers 665(-106): separable_conv_2_bn_normal_right1_10
# Layers 666(-105): separable_conv_2_bn_normal_left2_10
# Layers 667(-104): separable_conv_2_bn_normal_right2_10
# Layers 668(-103): normal_left3_10
# Layers 669(-102): normal_left4_10
# Layers 670(-101): normal_right4_10
# Layers 671(-100): separable_conv_2_bn_normal_left5_10
# Layers 672(-99): normal_add_1_10
# Layers 673(-98): normal_add_2_10
# Layers 674(-97): normal_add_3_10
# Layers 675(-96): normal_add_4_10
# Layers 676(-95): normal_add_5_10
# Layers 677(-94): normal_concat_10
# Layers 678(-93): activation_460
# Layers 679(-92): activation_461
# Layers 680(-91): adjust_conv_projection_11
# Layers 681(-90): normal_conv_1_11
# Layers 682(-89): adjust_bn_11
# Layers 683(-88): normal_bn_1_11
# Layers 684(-87): activation_462
# Layers 685(-86): activation_464
# Layers 686(-85): activation_466
# Layers 687(-84): activation_468
# Layers 688(-83): activation_470
# Layers 689(-82): separable_conv_1_normal_left1_11
# Layers 690(-81): separable_conv_1_normal_right1_11
# Layers 691(-80): separable_conv_1_normal_left2_11
# Layers 692(-79): separable_conv_1_normal_right2_11
# Layers 693(-78): separable_conv_1_normal_left5_11
# Layers 694(-77): separable_conv_1_bn_normal_left1_11
# Layers 695(-76): separable_conv_1_bn_normal_right1_11
# Layers 696(-75): separable_conv_1_bn_normal_left2_11
# Layers 697(-74): separable_conv_1_bn_normal_right2_11
# Layers 698(-73): separable_conv_1_bn_normal_left5_11
# Layers 699(-72): activation_463
# Layers 700(-71): activation_465
# Layers 701(-70): activation_467
# Layers 702(-69): activation_469
# Layers 703(-68): activation_471
# Layers 704(-67): separable_conv_2_normal_left1_11
# Layers 705(-66): separable_conv_2_normal_right1_11
# Layers 706(-65): separable_conv_2_normal_left2_11
# Layers 707(-64): separable_conv_2_normal_right2_11
# Layers 708(-63): separable_conv_2_normal_left5_11
# Layers 709(-62): separable_conv_2_bn_normal_left1_11
# Layers 710(-61): separable_conv_2_bn_normal_right1_11
# Layers 711(-60): separable_conv_2_bn_normal_left2_11
# Layers 712(-59): separable_conv_2_bn_normal_right2_11
# Layers 713(-58): normal_left3_11
# Layers 714(-57): normal_left4_11
# Layers 715(-56): normal_right4_11
# Layers 716(-55): separable_conv_2_bn_normal_left5_11
# Layers 717(-54): normal_add_1_11
# Layers 718(-53): normal_add_2_11
# Layers 719(-52): normal_add_3_11
# Layers 720(-51): normal_add_4_11
# Layers 721(-50): normal_add_5_11
# Layers 722(-49): normal_concat_11
# Layers 723(-48): activation_472
# Layers 724(-47): activation_473
# Layers 725(-46): adjust_conv_projection_12
# Layers 726(-45): normal_conv_1_12
# Layers 727(-44): adjust_bn_12
# Layers 728(-43): normal_bn_1_12
# Layers 729(-42): activation_474
# Layers 730(-41): activation_476
# Layers 731(-40): activation_478
# Layers 732(-39): activation_480
# Layers 733(-38): activation_482
# Layers 734(-37): separable_conv_1_normal_left1_12
# Layers 735(-36): separable_conv_1_normal_right1_12
# Layers 736(-35): separable_conv_1_normal_left2_12
# Layers 737(-34): separable_conv_1_normal_right2_12
# Layers 738(-33): separable_conv_1_normal_left5_12
# Layers 739(-32): separable_conv_1_bn_normal_left1_12
# Layers 740(-31): separable_conv_1_bn_normal_right1_12
# Layers 741(-30): separable_conv_1_bn_normal_left2_12
# Layers 742(-29): separable_conv_1_bn_normal_right2_12
# Layers 743(-28): separable_conv_1_bn_normal_left5_12
# Layers 744(-27): activation_475
# Layers 745(-26): activation_477
# Layers 746(-25): activation_479
# Layers 747(-24): activation_481
# Layers 748(-23): activation_483
# Layers 749(-22): separable_conv_2_normal_left1_12
# Layers 750(-21): separable_conv_2_normal_right1_12
# Layers 751(-20): separable_conv_2_normal_left2_12
# Layers 752(-19): separable_conv_2_normal_right2_12
# Layers 753(-18): separable_conv_2_normal_left5_12
# Layers 754(-17): separable_conv_2_bn_normal_left1_12
# Layers 755(-16): separable_conv_2_bn_normal_right1_12
# Layers 756(-15): separable_conv_2_bn_normal_left2_12
# Layers 757(-14): separable_conv_2_bn_normal_right2_12
# Layers 758(-13): normal_left3_12
# Layers 759(-12): normal_left4_12
# Layers 760(-11): normal_right4_12
# Layers 761(-10): separable_conv_2_bn_normal_left5_12
# Layers 762(-9): normal_add_1_12
# Layers 763(-8): normal_add_2_12
# Layers 764(-7): normal_add_3_12
# Layers 765(-6): normal_add_4_12
# Layers 766(-5): normal_add_5_12
# Layers 767(-4): normal_concat_12
# Layers 768(-3): activation_484
# Layers 769(-2): global_average_pooling2d_2
# Layers 770(-1): predictions

# %%
NASNetMobile.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_conv1 (Conv2D)            (None, 111, 111, 32  864         ['input_17[0][0]']
#                                 )
#
#  stem_bn1 (BatchNormalization)  (None, 111, 111, 32  128         ['stem_conv1[0][0]']
#                                 )
#
#  activation_297 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_conv_1_stem_1 (Conv2  (None, 111, 111, 11  352        ['activation_297[0][0]']
#  D)                             )
#
#  reduction_bn_1_stem_1 (BatchNo  (None, 111, 111, 11  44         ['reduction_conv_1_stem_1[0][0]']
#  rmalization)                   )
#
#  activation_298 (Activation)    (None, 111, 111, 11  0           ['reduction_bn_1_stem_1[0][0]']
#                                 )
#
#  activation_300 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_1_pad_reduction  (None, 115, 115, 11  0          ['activation_298[0][0]']
#  _left1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_pad_reduction  (None, 117, 117, 32  0          ['activation_300[0][0]']
#  _right1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_reduction_lef  (None, 56, 56, 11)  396         ['separable_conv_1_pad_reduction_
#  t1_stem_1 (SeparableConv2D)                                     left1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 11)  1920        ['separable_conv_1_pad_reduction_
#  ht1_stem_1 (SeparableConv2D)                                    right1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  activation_299 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_1[0][0]']
#
#  activation_301 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 56, 56, 11)  396         ['activation_299[0][0]']
#  t1_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 11)  660         ['activation_301[0][0]']
#  ht1_stem_1 (SeparableConv2D)
#
#  activation_302 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 117, 117, 32  0          ['activation_302[0][0]']
#  _right2_stem_1 (ZeroPadding2D)  )
#
#  activation_304 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_add_1_stem_1 (Add)   (None, 56, 56, 11)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 11)  1920        ['separable_conv_1_pad_reduction_
#  ht2_stem_1 (SeparableConv2D)                                    right2_stem_1[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 115, 115, 32  0          ['activation_304[0][0]']
#  _right3_stem_1 (ZeroPadding2D)  )
#
#  activation_306 (Activation)    (None, 56, 56, 11)   0           ['reduction_add_1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 11)  1152        ['separable_conv_1_pad_reduction_
#  ht3_stem_1 (SeparableConv2D)                                    right3_stem_1[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 56, 56, 11)  220         ['activation_306[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  activation_303 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_pad_1_stem_1 (ZeroPa  (None, 113, 113, 11  0          ['reduction_bn_1_stem_1[0][0]']
#  dding2D)                       )
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 11)  660         ['activation_303[0][0]']
#  ht2_stem_1 (SeparableConv2D)
#
#  activation_305 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  activation_307 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (MaxPoo  (None, 56, 56, 11)  0           ['reduction_pad_1_stem_1[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 11)  396         ['activation_305[0][0]']
#  ht3_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 56, 56, 11)  220         ['activation_307[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  adjust_relu_1_stem_2 (Activati  (None, 111, 111, 32  0          ['stem_bn1[0][0]']
#  on)                            )
#
#  reduction_add_2_stem_1 (Add)   (None, 56, 56, 11)   0           ['reduction_left2_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Averag  (None, 56, 56, 11)  0           ['reduction_pad_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  reduction_left4_stem_1 (Averag  (None, 56, 56, 11)  0           ['reduction_add_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_right5_stem_1 (MaxPo  (None, 56, 56, 11)  0           ['reduction_pad_1_stem_1[0][0]']
#  oling2D)
#
#  zero_padding2d_6 (ZeroPadding2  (None, 112, 112, 32  0          ['adjust_relu_1_stem_2[0][0]']
#  D)                             )
#
#  reduction_add3_stem_1 (Add)    (None, 56, 56, 11)   0           ['reduction_left3_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#  add_12 (Add)                   (None, 56, 56, 11)   0           ['reduction_add_2_stem_1[0][0]',
#                                                                   'reduction_left4_stem_1[0][0]']
#
#  reduction_add4_stem_1 (Add)    (None, 56, 56, 11)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_1[0][0]',
#                                                                   'reduction_right5_stem_1[0][0]']
#
#  cropping2d (Cropping2D)        (None, 111, 111, 32  0           ['zero_padding2d_6[0][0]']
#                                 )
#
#  reduction_concat_stem_1 (Conca  (None, 56, 56, 44)  0           ['reduction_add_2_stem_1[0][0]',
#  tenate)                                                          'reduction_add3_stem_1[0][0]',
#                                                                   'add_12[0][0]',
#                                                                   'reduction_add4_stem_1[0][0]']
#
#  adjust_avg_pool_1_stem_2 (Aver  (None, 56, 56, 32)  0           ['adjust_relu_1_stem_2[0][0]']
#  agePooling2D)
#
#  adjust_avg_pool_2_stem_2 (Aver  (None, 56, 56, 32)  0           ['cropping2d[0][0]']
#  agePooling2D)
#
#  activation_308 (Activation)    (None, 56, 56, 44)   0           ['reduction_concat_stem_1[0][0]']
#
#  adjust_conv_1_stem_2 (Conv2D)  (None, 56, 56, 11)   352         ['adjust_avg_pool_1_stem_2[0][0]'
#                                                                  ]
#
#  adjust_conv_2_stem_2 (Conv2D)  (None, 56, 56, 11)   352         ['adjust_avg_pool_2_stem_2[0][0]'
#                                                                  ]
#
#  reduction_conv_1_stem_2 (Conv2  (None, 56, 56, 22)  968         ['activation_308[0][0]']
#  D)
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 22)   0           ['adjust_conv_1_stem_2[0][0]',
#                                                                   'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (BatchNo  (None, 56, 56, 22)  88          ['reduction_conv_1_stem_2[0][0]']
#  rmalization)
#
#  adjust_bn_stem_2 (BatchNormali  (None, 56, 56, 22)  88          ['concatenate_2[0][0]']
#  zation)
#
#  activation_309 (Activation)    (None, 56, 56, 22)   0           ['reduction_bn_1_stem_2[0][0]']
#
#  activation_311 (Activation)    (None, 56, 56, 22)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 59, 59, 22)  0           ['activation_309[0][0]']
#  _left1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_pad_reduction  (None, 61, 61, 22)  0           ['activation_311[0][0]']
#  _right1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_reduction_lef  (None, 28, 28, 22)  1034        ['separable_conv_1_pad_reduction_
#  t1_stem_2 (SeparableConv2D)                                     left1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 22)  1562        ['separable_conv_1_pad_reduction_
#  ht1_stem_2 (SeparableConv2D)                                    right1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  activation_310 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_2[0][0]']
#
#  activation_312 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 28, 28, 22)  1034        ['activation_310[0][0]']
#  t1_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 22)  1562        ['activation_312[0][0]']
#  ht1_stem_2 (SeparableConv2D)
#
#  activation_313 (Activation)    (None, 56, 56, 22)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 61, 61, 22)  0           ['activation_313[0][0]']
#  _right2_stem_2 (ZeroPadding2D)
#
#  activation_315 (Activation)    (None, 56, 56, 22)   0           ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Add)   (None, 28, 28, 22)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 22)  1562        ['separable_conv_1_pad_reduction_
#  ht2_stem_2 (SeparableConv2D)                                    right2_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 59, 59, 22)  0           ['activation_315[0][0]']
#  _right3_stem_2 (ZeroPadding2D)
#
#  activation_317 (Activation)    (None, 28, 28, 22)   0           ['reduction_add_1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 22)  1034        ['separable_conv_1_pad_reduction_
#  ht3_stem_2 (SeparableConv2D)                                    right3_stem_2[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 28, 28, 22)  682         ['activation_317[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  activation_314 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_pad_1_stem_2 (ZeroPa  (None, 57, 57, 22)  0           ['reduction_bn_1_stem_2[0][0]']
#  dding2D)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 22)  1562        ['activation_314[0][0]']
#  ht2_stem_2 (SeparableConv2D)
#
#  activation_316 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  activation_318 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (MaxPoo  (None, 28, 28, 22)  0           ['reduction_pad_1_stem_2[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 22)  1034        ['activation_316[0][0]']
#  ht3_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 28, 28, 22)  682         ['activation_318[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  adjust_relu_1_0 (Activation)   (None, 56, 56, 44)   0           ['reduction_concat_stem_1[0][0]']
#
#  reduction_add_2_stem_2 (Add)   (None, 28, 28, 22)   0           ['reduction_left2_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Averag  (None, 28, 28, 22)  0           ['reduction_pad_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  reduction_left4_stem_2 (Averag  (None, 28, 28, 22)  0           ['reduction_add_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_right5_stem_2 (MaxPo  (None, 28, 28, 22)  0           ['reduction_pad_1_stem_2[0][0]']
#  oling2D)
#
#  zero_padding2d_7 (ZeroPadding2  (None, 57, 57, 44)  0           ['adjust_relu_1_0[0][0]']
#  D)
#
#  reduction_add3_stem_2 (Add)    (None, 28, 28, 22)   0           ['reduction_left3_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  add_13 (Add)                   (None, 28, 28, 22)   0           ['reduction_add_2_stem_2[0][0]',
#                                                                   'reduction_left4_stem_2[0][0]']
#
#  reduction_add4_stem_2 (Add)    (None, 28, 28, 22)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_2[0][0]',
#                                                                   'reduction_right5_stem_2[0][0]']
#
#  cropping2d_1 (Cropping2D)      (None, 56, 56, 44)   0           ['zero_padding2d_7[0][0]']
#
#  reduction_concat_stem_2 (Conca  (None, 28, 28, 88)  0           ['reduction_add_2_stem_2[0][0]',
#  tenate)                                                          'reduction_add3_stem_2[0][0]',
#                                                                   'add_13[0][0]',
#                                                                   'reduction_add4_stem_2[0][0]']
#
#  adjust_avg_pool_1_0 (AveragePo  (None, 28, 28, 44)  0           ['adjust_relu_1_0[0][0]']
#  oling2D)
#
#  adjust_avg_pool_2_0 (AveragePo  (None, 28, 28, 44)  0           ['cropping2d_1[0][0]']
#  oling2D)
#
#  adjust_conv_1_0 (Conv2D)       (None, 28, 28, 22)   968         ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)       (None, 28, 28, 22)   968         ['adjust_avg_pool_2_0[0][0]']
#
#  activation_319 (Activation)    (None, 28, 28, 88)   0           ['reduction_concat_stem_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 44)   0           ['adjust_conv_1_0[0][0]',
#                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)       (None, 28, 28, 44)   3872        ['activation_319[0][0]']
#
#  adjust_bn_0 (BatchNormalizatio  (None, 28, 28, 44)  176         ['concatenate_3[0][0]']
#  n)
#
#  normal_bn_1_0 (BatchNormalizat  (None, 28, 28, 44)  176         ['normal_conv_1_0[0][0]']
#  ion)
#
#  activation_320 (Activation)    (None, 28, 28, 44)   0           ['normal_bn_1_0[0][0]']
#
#  activation_322 (Activation)    (None, 28, 28, 44)   0           ['adjust_bn_0[0][0]']
#
#  activation_324 (Activation)    (None, 28, 28, 44)   0           ['adjust_bn_0[0][0]']
#
#  activation_326 (Activation)    (None, 28, 28, 44)   0           ['adjust_bn_0[0][0]']
#
#  activation_328 (Activation)    (None, 28, 28, 44)   0           ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 28, 28, 44)  3036        ['activation_320[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 28, 28, 44)  2332        ['activation_322[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 28, 28, 44)  3036        ['activation_324[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 28, 28, 44)  2332        ['activation_326[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 28, 28, 44)  2332        ['activation_328[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_1_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_1_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_1_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_1_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_1_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  activation_321 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_left
#                                                                  1_0[0][0]']
#
#  activation_323 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  activation_325 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_left
#                                                                  2_0[0][0]']
#
#  activation_327 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  activation_329 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_left
#                                                                  5_0[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 28, 28, 44)  3036        ['activation_321[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 28, 28, 44)  2332        ['activation_323[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 28, 28, 44)  3036        ['activation_325[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 28, 28, 44)  2332        ['activation_327[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 28, 28, 44)  2332        ['activation_329[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_2_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_2_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_2_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_2_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  normal_left3_0 (AveragePooling  (None, 28, 28, 44)  0           ['normal_bn_1_0[0][0]']
#  2D)
#
#  normal_left4_0 (AveragePooling  (None, 28, 28, 44)  0           ['adjust_bn_0[0][0]']
#  2D)
#
#  normal_right4_0 (AveragePoolin  (None, 28, 28, 44)  0           ['adjust_bn_0[0][0]']
#  g2D)
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_2_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  normal_add_1_0 (Add)           (None, 28, 28, 44)   0           ['separable_conv_2_bn_normal_left
#                                                                  1_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  normal_add_2_0 (Add)           (None, 28, 28, 44)   0           ['separable_conv_2_bn_normal_left
#                                                                  2_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  normal_add_3_0 (Add)           (None, 28, 28, 44)   0           ['normal_left3_0[0][0]',
#                                                                   'adjust_bn_0[0][0]']
# ...
#  normal_add_3_11 (Add)          (None, 7, 7, 176)    0           ['normal_left3_11[0][0]',
#                                                                   'adjust_bn_11[0][0]']
#
#  normal_add_4_11 (Add)          (None, 7, 7, 176)    0           ['normal_left4_11[0][0]',
#                                                                   'normal_right4_11[0][0]']
#
#  normal_add_5_11 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  5_11[0][0]',
#                                                                   'normal_bn_1_11[0][0]']
#
#  normal_concat_11 (Concatenate)  (None, 7, 7, 1056)  0           ['adjust_bn_11[0][0]',
#                                                                   'normal_add_1_11[0][0]',
#                                                                   'normal_add_2_11[0][0]',
#                                                                   'normal_add_3_11[0][0]',
#                                                                   'normal_add_4_11[0][0]',
#                                                                   'normal_add_5_11[0][0]']
#
#  activation_472 (Activation)    (None, 7, 7, 1056)   0           ['normal_concat_10[0][0]']
#  activation_473 (Activation)    (None, 7, 7, 1056)   0           ['normal_concat_11[0][0]']
#
#  adjust_conv_projection_12 (Con  (None, 7, 7, 176)   185856      ['activation_472[0][0]']
#  v2D)
#
#  normal_conv_1_12 (Conv2D)      (None, 7, 7, 176)    185856      ['activation_473[0][0]']
#
#  adjust_bn_12 (BatchNormalizati  (None, 7, 7, 176)   704         ['adjust_conv_projection_12[0][0]
#  on)                                                             ']
#
#  normal_bn_1_12 (BatchNormaliza  (None, 7, 7, 176)   704         ['normal_conv_1_12[0][0]']
#  tion)
#
#  activation_474 (Activation)    (None, 7, 7, 176)    0           ['normal_bn_1_12[0][0]']
#
#  activation_476 (Activation)    (None, 7, 7, 176)    0           ['adjust_bn_12[0][0]']
#
#  activation_478 (Activation)    (None, 7, 7, 176)    0           ['adjust_bn_12[0][0]']
#
#  activation_480 (Activation)    (None, 7, 7, 176)    0           ['adjust_bn_12[0][0]']
#
#  activation_482 (Activation)    (None, 7, 7, 176)    0           ['normal_bn_1_12[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 7, 7, 176)   35376       ['activation_474[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 7, 7, 176)   32560       ['activation_476[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 7, 7, 176)   35376       ['activation_478[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 7, 7, 176)   32560       ['activation_480[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 7, 7, 176)   32560       ['activation_482[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_1_normal_left1_1
#  t1_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_1_normal_right1_
#  ht1_12 (BatchNormalization)                                     12[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_1_normal_left2_1
#  t2_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_1_normal_right2_
#  ht2_12 (BatchNormalization)                                     12[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_1_normal_left5_1
#  t5_12 (BatchNormalization)                                      2[0][0]']
#
#  activation_475 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_left
#                                                                  1_12[0][0]']
#
#  activation_477 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_12[0][0]']
#
#  activation_479 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_left
#                                                                  2_12[0][0]']
#
#  activation_481 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_12[0][0]']
#
#  activation_483 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_left
#                                                                  5_12[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 7, 7, 176)   35376       ['activation_475[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 7, 7, 176)   32560       ['activation_477[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 7, 7, 176)   35376       ['activation_479[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 7, 7, 176)   32560       ['activation_481[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 7, 7, 176)   32560       ['activation_483[0][0]']
#  12 (SeparableConv2D)
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_2_normal_left1_1
#  t1_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_2_normal_right1_
#  ht1_12 (BatchNormalization)                                     12[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_2_normal_left2_1
#  t2_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_2_normal_right2_
#  ht2_12 (BatchNormalization)                                     12[0][0]']
#
#  normal_left3_12 (AveragePoolin  (None, 7, 7, 176)   0           ['normal_bn_1_12[0][0]']
#  g2D)
#
#  normal_left4_12 (AveragePoolin  (None, 7, 7, 176)   0           ['adjust_bn_12[0][0]']
#  g2D)
#
#  normal_right4_12 (AveragePooli  (None, 7, 7, 176)   0           ['adjust_bn_12[0][0]']
#  ng2D)
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_2_normal_left5_1
#  t5_12 (BatchNormalization)                                      2[0][0]']
#
#  normal_add_1_12 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  1_12[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_12[0][0]']
#
#  normal_add_2_12 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  2_12[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_12[0][0]']
#
#  normal_add_3_12 (Add)          (None, 7, 7, 176)    0           ['normal_left3_12[0][0]',
#                                                                   'adjust_bn_12[0][0]']
#
#  normal_add_4_12 (Add)          (None, 7, 7, 176)    0           ['normal_left4_12[0][0]',
#                                                                   'normal_right4_12[0][0]']
#
#  normal_add_5_12 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  5_12[0][0]',
#                                                                   'normal_bn_1_12[0][0]']
#
#  normal_concat_12 (Concatenate)  (None, 7, 7, 1056)  0           ['adjust_bn_12[0][0]',
#                                                                   'normal_add_1_12[0][0]',
#                                                                   'normal_add_2_12[0][0]',
#                                                                   'normal_add_3_12[0][0]',
#                                                                   'normal_add_4_12[0][0]',
#                                                                   'normal_add_5_12[0][0]']
#
#  activation_484 (Activation)    (None, 7, 7, 1056)   0           ['normal_concat_12[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1056)        0           ['activation_484[0][0]']
#  obalAveragePooling2D)
#
#  predictions (Dense)            (None, 1000)         1057000     ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 5,326,716
# Trainable params: 5,289,978
# Non-trainable params: 36,738
# __________________________________________________________________________________________________

# %% [markdown]
# # NASNetLarge

# %%
NASNetLarge = tf.keras.applications.NASNetLarge(
    input_shape=None,
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    classes=1000,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large.h5
# 359751680/359748576 [==============================] - 38s 0us/step
# 359759872/359748576 [==============================] - 38s 0us/step

# %%
model_analyze(NASNetLarge)
# Out:
# Layers 0(-1041): input_18
# Layers 1(-1040): stem_conv1
# Layers 2(-1039): stem_bn1
# Layers 3(-1038): activation_485
# Layers 4(-1037): reduction_conv_1_stem_1
# Layers 5(-1036): reduction_bn_1_stem_1
# Layers 6(-1035): activation_486
# Layers 7(-1034): activation_488
# Layers 8(-1033): separable_conv_1_pad_reduction_left1_stem_1
# Layers 9(-1032): separable_conv_1_pad_reduction_right1_stem_1
# Layers 10(-1031): separable_conv_1_reduction_left1_stem_1
# Layers 11(-1030): separable_conv_1_reduction_right1_stem_1
# Layers 12(-1029): separable_conv_1_bn_reduction_left1_stem_1
# Layers 13(-1028): separable_conv_1_bn_reduction_right1_stem_1
# Layers 14(-1027): activation_487
# Layers 15(-1026): activation_489
# Layers 16(-1025): separable_conv_2_reduction_left1_stem_1
# Layers 17(-1024): separable_conv_2_reduction_right1_stem_1
# Layers 18(-1023): activation_490
# Layers 19(-1022): separable_conv_2_bn_reduction_left1_stem_1
# Layers 20(-1021): separable_conv_2_bn_reduction_right1_stem_1
# Layers 21(-1020): separable_conv_1_pad_reduction_right2_stem_1
# Layers 22(-1019): activation_492
# Layers 23(-1018): reduction_add_1_stem_1
# Layers 24(-1017): separable_conv_1_reduction_right2_stem_1
# Layers 25(-1016): separable_conv_1_pad_reduction_right3_stem_1
# Layers 26(-1015): activation_494
# Layers 27(-1014): separable_conv_1_bn_reduction_right2_stem_1
# Layers 28(-1013): separable_conv_1_reduction_right3_stem_1
# Layers 29(-1012): separable_conv_1_reduction_left4_stem_1
# Layers 30(-1011): activation_491
# Layers 31(-1010): separable_conv_1_bn_reduction_right3_stem_1
# Layers 32(-1009): separable_conv_1_bn_reduction_left4_stem_1
# Layers 33(-1008): reduction_pad_1_stem_1
# Layers 34(-1007): separable_conv_2_reduction_right2_stem_1
# Layers 35(-1006): activation_493
# Layers 36(-1005): activation_495
# Layers 37(-1004): reduction_left2_stem_1
# Layers 38(-1003): separable_conv_2_bn_reduction_right2_stem_1
# Layers 39(-1002): separable_conv_2_reduction_right3_stem_1
# Layers 40(-1001): separable_conv_2_reduction_left4_stem_1
# Layers 41(-1000): adjust_relu_1_stem_2
# Layers 42(-999): reduction_add_2_stem_1
# Layers 43(-998): reduction_left3_stem_1
# Layers 44(-997): separable_conv_2_bn_reduction_right3_stem_1
# Layers 45(-996): reduction_left4_stem_1
# Layers 46(-995): separable_conv_2_bn_reduction_left4_stem_1
# Layers 47(-994): reduction_right5_stem_1
# Layers 48(-993): zero_padding2d_10
# Layers 49(-992): reduction_add3_stem_1
# Layers 50(-991): add_16
# Layers 51(-990): reduction_add4_stem_1
# Layers 52(-989): cropping2d_4
# Layers 53(-988): reduction_concat_stem_1
# Layers 54(-987): adjust_avg_pool_1_stem_2
# Layers 55(-986): adjust_avg_pool_2_stem_2
# Layers 56(-985): activation_496
# Layers 57(-984): adjust_conv_1_stem_2
# Layers 58(-983): adjust_conv_2_stem_2
# Layers 59(-982): reduction_conv_1_stem_2
# Layers 60(-981): concatenate_6
# Layers 61(-980): reduction_bn_1_stem_2
# Layers 62(-979): adjust_bn_stem_2
# Layers 63(-978): activation_497
# Layers 64(-977): activation_499
# Layers 65(-976): separable_conv_1_pad_reduction_left1_stem_2
# Layers 66(-975): separable_conv_1_pad_reduction_right1_stem_2
# Layers 67(-974): separable_conv_1_reduction_left1_stem_2
# Layers 68(-973): separable_conv_1_reduction_right1_stem_2
# Layers 69(-972): separable_conv_1_bn_reduction_left1_stem_2
# Layers 70(-971): separable_conv_1_bn_reduction_right1_stem_2
# Layers 71(-970): activation_498
# Layers 72(-969): activation_500
# Layers 73(-968): separable_conv_2_reduction_left1_stem_2
# Layers 74(-967): separable_conv_2_reduction_right1_stem_2
# Layers 75(-966): activation_501
# Layers 76(-965): separable_conv_2_bn_reduction_left1_stem_2
# Layers 77(-964): separable_conv_2_bn_reduction_right1_stem_2
# Layers 78(-963): separable_conv_1_pad_reduction_right2_stem_2
# Layers 79(-962): activation_503
# Layers 80(-961): reduction_add_1_stem_2
# Layers 81(-960): separable_conv_1_reduction_right2_stem_2
# Layers 82(-959): separable_conv_1_pad_reduction_right3_stem_2
# Layers 83(-958): activation_505
# Layers 84(-957): separable_conv_1_bn_reduction_right2_stem_2
# Layers 85(-956): separable_conv_1_reduction_right3_stem_2
# Layers 86(-955): separable_conv_1_reduction_left4_stem_2
# Layers 87(-954): activation_502
# Layers 88(-953): separable_conv_1_bn_reduction_right3_stem_2
# Layers 89(-952): separable_conv_1_bn_reduction_left4_stem_2
# Layers 90(-951): reduction_pad_1_stem_2
# Layers 91(-950): separable_conv_2_reduction_right2_stem_2
# Layers 92(-949): activation_504
# Layers 93(-948): activation_506
# Layers 94(-947): reduction_left2_stem_2
# Layers 95(-946): separable_conv_2_bn_reduction_right2_stem_2
# Layers 96(-945): separable_conv_2_reduction_right3_stem_2
# Layers 97(-944): separable_conv_2_reduction_left4_stem_2
# Layers 98(-943): adjust_relu_1_0
# Layers 99(-942): reduction_add_2_stem_2
# Layers 100(-941): reduction_left3_stem_2
# Layers 101(-940): separable_conv_2_bn_reduction_right3_stem_2
# Layers 102(-939): reduction_left4_stem_2
# Layers 103(-938): separable_conv_2_bn_reduction_left4_stem_2
# Layers 104(-937): reduction_right5_stem_2
# Layers 105(-936): zero_padding2d_11
# Layers 106(-935): reduction_add3_stem_2
# Layers 107(-934): add_17
# Layers 108(-933): reduction_add4_stem_2
# Layers 109(-932): cropping2d_5
# Layers 110(-931): reduction_concat_stem_2
# Layers 111(-930): adjust_avg_pool_1_0
# Layers 112(-929): adjust_avg_pool_2_0
# Layers 113(-928): adjust_conv_1_0
# Layers 114(-927): adjust_conv_2_0
# Layers 115(-926): activation_507
# Layers 116(-925): concatenate_7
# Layers 117(-924): normal_conv_1_0
# Layers 118(-923): adjust_bn_0
# Layers 119(-922): normal_bn_1_0
# Layers 120(-921): activation_508
# Layers 121(-920): activation_510
# Layers 122(-919): activation_512
# Layers 123(-918): activation_514
# Layers 124(-917): activation_516
# Layers 125(-916): separable_conv_1_normal_left1_0
# Layers 126(-915): separable_conv_1_normal_right1_0
# Layers 127(-914): separable_conv_1_normal_left2_0
# Layers 128(-913): separable_conv_1_normal_right2_0
# Layers 129(-912): separable_conv_1_normal_left5_0
# Layers 130(-911): separable_conv_1_bn_normal_left1_0
# Layers 131(-910): separable_conv_1_bn_normal_right1_0
# Layers 132(-909): separable_conv_1_bn_normal_left2_0
# Layers 133(-908): separable_conv_1_bn_normal_right2_0
# Layers 134(-907): separable_conv_1_bn_normal_left5_0
# Layers 135(-906): activation_509
# Layers 136(-905): activation_511
# Layers 137(-904): activation_513
# Layers 138(-903): activation_515
# Layers 139(-902): activation_517
# Layers 140(-901): separable_conv_2_normal_left1_0
# Layers 141(-900): separable_conv_2_normal_right1_0
# Layers 142(-899): separable_conv_2_normal_left2_0
# Layers 143(-898): separable_conv_2_normal_right2_0
# Layers 144(-897): separable_conv_2_normal_left5_0
# Layers 145(-896): separable_conv_2_bn_normal_left1_0
# Layers 146(-895): separable_conv_2_bn_normal_right1_0
# Layers 147(-894): separable_conv_2_bn_normal_left2_0
# Layers 148(-893): separable_conv_2_bn_normal_right2_0
# Layers 149(-892): normal_left3_0
# Layers 150(-891): normal_left4_0
# Layers 151(-890): normal_right4_0
# Layers 152(-889): separable_conv_2_bn_normal_left5_0
# Layers 153(-888): normal_add_1_0
# Layers 154(-887): normal_add_2_0
# Layers 155(-886): normal_add_3_0
# Layers 156(-885): normal_add_4_0
# Layers 157(-884): normal_add_5_0
# Layers 158(-883): normal_concat_0
# Layers 159(-882): activation_518
# Layers 160(-881): activation_519
# Layers 161(-880): adjust_conv_projection_1
# Layers 162(-879): normal_conv_1_1
# Layers 163(-878): adjust_bn_1
# Layers 164(-877): normal_bn_1_1
# Layers 165(-876): activation_520
# Layers 166(-875): activation_522
# Layers 167(-874): activation_524
# Layers 168(-873): activation_526
# Layers 169(-872): activation_528
# Layers 170(-871): separable_conv_1_normal_left1_1
# Layers 171(-870): separable_conv_1_normal_right1_1
# Layers 172(-869): separable_conv_1_normal_left2_1
# Layers 173(-868): separable_conv_1_normal_right2_1
# Layers 174(-867): separable_conv_1_normal_left5_1
# Layers 175(-866): separable_conv_1_bn_normal_left1_1
# Layers 176(-865): separable_conv_1_bn_normal_right1_1
# Layers 177(-864): separable_conv_1_bn_normal_left2_1
# Layers 178(-863): separable_conv_1_bn_normal_right2_1
# Layers 179(-862): separable_conv_1_bn_normal_left5_1
# Layers 180(-861): activation_521
# Layers 181(-860): activation_523
# Layers 182(-859): activation_525
# Layers 183(-858): activation_527
# Layers 184(-857): activation_529
# Layers 185(-856): separable_conv_2_normal_left1_1
# Layers 186(-855): separable_conv_2_normal_right1_1
# Layers 187(-854): separable_conv_2_normal_left2_1
# Layers 188(-853): separable_conv_2_normal_right2_1
# Layers 189(-852): separable_conv_2_normal_left5_1
# Layers 190(-851): separable_conv_2_bn_normal_left1_1
# Layers 191(-850): separable_conv_2_bn_normal_right1_1
# Layers 192(-849): separable_conv_2_bn_normal_left2_1
# Layers 193(-848): separable_conv_2_bn_normal_right2_1
# Layers 194(-847): normal_left3_1
# Layers 195(-846): normal_left4_1
# Layers 196(-845): normal_right4_1
# Layers 197(-844): separable_conv_2_bn_normal_left5_1
# Layers 198(-843): normal_add_1_1
# Layers 199(-842): normal_add_2_1
# Layers 200(-841): normal_add_3_1
# Layers 201(-840): normal_add_4_1
# Layers 202(-839): normal_add_5_1
# Layers 203(-838): normal_concat_1
# Layers 204(-837): activation_530
# Layers 205(-836): activation_531
# Layers 206(-835): adjust_conv_projection_2
# Layers 207(-834): normal_conv_1_2
# Layers 208(-833): adjust_bn_2
# Layers 209(-832): normal_bn_1_2
# Layers 210(-831): activation_532
# Layers 211(-830): activation_534
# Layers 212(-829): activation_536
# Layers 213(-828): activation_538
# Layers 214(-827): activation_540
# Layers 215(-826): separable_conv_1_normal_left1_2
# Layers 216(-825): separable_conv_1_normal_right1_2
# Layers 217(-824): separable_conv_1_normal_left2_2
# Layers 218(-823): separable_conv_1_normal_right2_2
# Layers 219(-822): separable_conv_1_normal_left5_2
# Layers 220(-821): separable_conv_1_bn_normal_left1_2
# Layers 221(-820): separable_conv_1_bn_normal_right1_2
# Layers 222(-819): separable_conv_1_bn_normal_left2_2
# Layers 223(-818): separable_conv_1_bn_normal_right2_2
# Layers 224(-817): separable_conv_1_bn_normal_left5_2
# Layers 225(-816): activation_533
# Layers 226(-815): activation_535
# Layers 227(-814): activation_537
# Layers 228(-813): activation_539
# Layers 229(-812): activation_541
# Layers 230(-811): separable_conv_2_normal_left1_2
# Layers 231(-810): separable_conv_2_normal_right1_2
# Layers 232(-809): separable_conv_2_normal_left2_2
# Layers 233(-808): separable_conv_2_normal_right2_2
# Layers 234(-807): separable_conv_2_normal_left5_2
# Layers 235(-806): separable_conv_2_bn_normal_left1_2
# Layers 236(-805): separable_conv_2_bn_normal_right1_2
# Layers 237(-804): separable_conv_2_bn_normal_left2_2
# Layers 238(-803): separable_conv_2_bn_normal_right2_2
# Layers 239(-802): normal_left3_2
# Layers 240(-801): normal_left4_2
# Layers 241(-800): normal_right4_2
# Layers 242(-799): separable_conv_2_bn_normal_left5_2
# Layers 243(-798): normal_add_1_2
# Layers 244(-797): normal_add_2_2
# Layers 245(-796): normal_add_3_2
# Layers 246(-795): normal_add_4_2
# Layers 247(-794): normal_add_5_2
# Layers 248(-793): normal_concat_2
# Layers 249(-792): activation_542
# Layers 250(-791): activation_543
# Layers 251(-790): adjust_conv_projection_3
# Layers 252(-789): normal_conv_1_3
# Layers 253(-788): adjust_bn_3
# Layers 254(-787): normal_bn_1_3
# Layers 255(-786): activation_544
# Layers 256(-785): activation_546
# Layers 257(-784): activation_548
# Layers 258(-783): activation_550
# Layers 259(-782): activation_552
# Layers 260(-781): separable_conv_1_normal_left1_3
# Layers 261(-780): separable_conv_1_normal_right1_3
# Layers 262(-779): separable_conv_1_normal_left2_3
# Layers 263(-778): separable_conv_1_normal_right2_3
# Layers 264(-777): separable_conv_1_normal_left5_3
# Layers 265(-776): separable_conv_1_bn_normal_left1_3
# Layers 266(-775): separable_conv_1_bn_normal_right1_3
# Layers 267(-774): separable_conv_1_bn_normal_left2_3
# Layers 268(-773): separable_conv_1_bn_normal_right2_3
# Layers 269(-772): separable_conv_1_bn_normal_left5_3
# Layers 270(-771): activation_545
# Layers 271(-770): activation_547
# Layers 272(-769): activation_549
# Layers 273(-768): activation_551
# Layers 274(-767): activation_553
# Layers 275(-766): separable_conv_2_normal_left1_3
# Layers 276(-765): separable_conv_2_normal_right1_3
# Layers 277(-764): separable_conv_2_normal_left2_3
# Layers 278(-763): separable_conv_2_normal_right2_3
# Layers 279(-762): separable_conv_2_normal_left5_3
# Layers 280(-761): separable_conv_2_bn_normal_left1_3
# Layers 281(-760): separable_conv_2_bn_normal_right1_3
# Layers 282(-759): separable_conv_2_bn_normal_left2_3
# Layers 283(-758): separable_conv_2_bn_normal_right2_3
# Layers 284(-757): normal_left3_3
# Layers 285(-756): normal_left4_3
# Layers 286(-755): normal_right4_3
# Layers 287(-754): separable_conv_2_bn_normal_left5_3
# Layers 288(-753): normal_add_1_3
# Layers 289(-752): normal_add_2_3
# Layers 290(-751): normal_add_3_3
# Layers 291(-750): normal_add_4_3
# Layers 292(-749): normal_add_5_3
# Layers 293(-748): normal_concat_3
# Layers 294(-747): activation_554
# Layers 295(-746): activation_555
# Layers 296(-745): adjust_conv_projection_4
# Layers 297(-744): normal_conv_1_4
# Layers 298(-743): adjust_bn_4
# Layers 299(-742): normal_bn_1_4
# Layers 300(-741): activation_556
# Layers 301(-740): activation_558
# Layers 302(-739): activation_560
# Layers 303(-738): activation_562
# Layers 304(-737): activation_564
# Layers 305(-736): separable_conv_1_normal_left1_4
# Layers 306(-735): separable_conv_1_normal_right1_4
# Layers 307(-734): separable_conv_1_normal_left2_4
# Layers 308(-733): separable_conv_1_normal_right2_4
# Layers 309(-732): separable_conv_1_normal_left5_4
# Layers 310(-731): separable_conv_1_bn_normal_left1_4
# Layers 311(-730): separable_conv_1_bn_normal_right1_4
# Layers 312(-729): separable_conv_1_bn_normal_left2_4
# Layers 313(-728): separable_conv_1_bn_normal_right2_4
# Layers 314(-727): separable_conv_1_bn_normal_left5_4
# Layers 315(-726): activation_557
# Layers 316(-725): activation_559
# Layers 317(-724): activation_561
# Layers 318(-723): activation_563
# Layers 319(-722): activation_565
# Layers 320(-721): separable_conv_2_normal_left1_4
# Layers 321(-720): separable_conv_2_normal_right1_4
# Layers 322(-719): separable_conv_2_normal_left2_4
# Layers 323(-718): separable_conv_2_normal_right2_4
# Layers 324(-717): separable_conv_2_normal_left5_4
# Layers 325(-716): separable_conv_2_bn_normal_left1_4
# Layers 326(-715): separable_conv_2_bn_normal_right1_4
# Layers 327(-714): separable_conv_2_bn_normal_left2_4
# Layers 328(-713): separable_conv_2_bn_normal_right2_4
# Layers 329(-712): normal_left3_4
# Layers 330(-711): normal_left4_4
# Layers 331(-710): normal_right4_4
# Layers 332(-709): separable_conv_2_bn_normal_left5_4
# Layers 333(-708): normal_add_1_4
# Layers 334(-707): normal_add_2_4
# Layers 335(-706): normal_add_3_4
# Layers 336(-705): normal_add_4_4
# Layers 337(-704): normal_add_5_4
# Layers 338(-703): normal_concat_4
# Layers 339(-702): activation_566
# Layers 340(-701): activation_567
# Layers 341(-700): adjust_conv_projection_5
# Layers 342(-699): normal_conv_1_5
# Layers 343(-698): adjust_bn_5
# Layers 344(-697): normal_bn_1_5
# Layers 345(-696): activation_568
# Layers 346(-695): activation_570
# Layers 347(-694): activation_572
# Layers 348(-693): activation_574
# Layers 349(-692): activation_576
# Layers 350(-691): separable_conv_1_normal_left1_5
# Layers 351(-690): separable_conv_1_normal_right1_5
# Layers 352(-689): separable_conv_1_normal_left2_5
# Layers 353(-688): separable_conv_1_normal_right2_5
# Layers 354(-687): separable_conv_1_normal_left5_5
# Layers 355(-686): separable_conv_1_bn_normal_left1_5
# Layers 356(-685): separable_conv_1_bn_normal_right1_5
# Layers 357(-684): separable_conv_1_bn_normal_left2_5
# Layers 358(-683): separable_conv_1_bn_normal_right2_5
# Layers 359(-682): separable_conv_1_bn_normal_left5_5
# Layers 360(-681): activation_569
# Layers 361(-680): activation_571
# Layers 362(-679): activation_573
# Layers 363(-678): activation_575
# Layers 364(-677): activation_577
# Layers 365(-676): separable_conv_2_normal_left1_5
# Layers 366(-675): separable_conv_2_normal_right1_5
# Layers 367(-674): separable_conv_2_normal_left2_5
# Layers 368(-673): separable_conv_2_normal_right2_5
# Layers 369(-672): separable_conv_2_normal_left5_5
# Layers 370(-671): separable_conv_2_bn_normal_left1_5
# Layers 371(-670): separable_conv_2_bn_normal_right1_5
# Layers 372(-669): separable_conv_2_bn_normal_left2_5
# Layers 373(-668): separable_conv_2_bn_normal_right2_5
# Layers 374(-667): normal_left3_5
# Layers 375(-666): normal_left4_5
# Layers 376(-665): normal_right4_5
# Layers 377(-664): separable_conv_2_bn_normal_left5_5
# Layers 378(-663): normal_add_1_5
# Layers 379(-662): normal_add_2_5
# Layers 380(-661): normal_add_3_5
# Layers 381(-660): normal_add_4_5
# Layers 382(-659): normal_add_5_5
# Layers 383(-658): normal_concat_5
# Layers 384(-657): activation_579
# Layers 385(-656): activation_578
# Layers 386(-655): reduction_conv_1_reduce_6
# Layers 387(-654): adjust_conv_projection_reduce_6
# Layers 388(-653): reduction_bn_1_reduce_6
# Layers 389(-652): adjust_bn_reduce_6
# Layers 390(-651): activation_580
# Layers 391(-650): activation_582
# Layers 392(-649): separable_conv_1_pad_reduction_left1_reduce_6
# Layers 393(-648): separable_conv_1_pad_reduction_right1_reduce_6
# Layers 394(-647): separable_conv_1_reduction_left1_reduce_6
# Layers 395(-646): separable_conv_1_reduction_right1_reduce_6
# Layers 396(-645): separable_conv_1_bn_reduction_left1_reduce_6
# Layers 397(-644): separable_conv_1_bn_reduction_right1_reduce_6
# Layers 398(-643): activation_581
# Layers 399(-642): activation_583
# Layers 400(-641): separable_conv_2_reduction_left1_reduce_6
# Layers 401(-640): separable_conv_2_reduction_right1_reduce_6
# Layers 402(-639): activation_584
# Layers 403(-638): separable_conv_2_bn_reduction_left1_reduce_6
# Layers 404(-637): separable_conv_2_bn_reduction_right1_reduce_6
# Layers 405(-636): separable_conv_1_pad_reduction_right2_reduce_6
# Layers 406(-635): activation_586
# Layers 407(-634): reduction_add_1_reduce_6
# Layers 408(-633): separable_conv_1_reduction_right2_reduce_6
# Layers 409(-632): separable_conv_1_pad_reduction_right3_reduce_6
# Layers 410(-631): activation_588
# Layers 411(-630): separable_conv_1_bn_reduction_right2_reduce_6
# Layers 412(-629): separable_conv_1_reduction_right3_reduce_6
# Layers 413(-628): separable_conv_1_reduction_left4_reduce_6
# Layers 414(-627): activation_585
# Layers 415(-626): separable_conv_1_bn_reduction_right3_reduce_6
# Layers 416(-625): separable_conv_1_bn_reduction_left4_reduce_6
# Layers 417(-624): reduction_pad_1_reduce_6
# Layers 418(-623): separable_conv_2_reduction_right2_reduce_6
# Layers 419(-622): activation_587
# Layers 420(-621): activation_589
# Layers 421(-620): reduction_left2_reduce_6
# Layers 422(-619): separable_conv_2_bn_reduction_right2_reduce_6
# Layers 423(-618): separable_conv_2_reduction_right3_reduce_6
# Layers 424(-617): separable_conv_2_reduction_left4_reduce_6
# Layers 425(-616): adjust_relu_1_7
# Layers 426(-615): reduction_add_2_reduce_6
# Layers 427(-614): reduction_left3_reduce_6
# Layers 428(-613): separable_conv_2_bn_reduction_right3_reduce_6
# Layers 429(-612): reduction_left4_reduce_6
# Layers 430(-611): separable_conv_2_bn_reduction_left4_reduce_6
# Layers 431(-610): reduction_right5_reduce_6
# Layers 432(-609): zero_padding2d_12
# Layers 433(-608): reduction_add3_reduce_6
# Layers 434(-607): add_18
# Layers 435(-606): reduction_add4_reduce_6
# Layers 436(-605): cropping2d_6
# Layers 437(-604): reduction_concat_reduce_6
# Layers 438(-603): adjust_avg_pool_1_7
# Layers 439(-602): adjust_avg_pool_2_7
# Layers 440(-601): adjust_conv_1_7
# Layers 441(-600): adjust_conv_2_7
# Layers 442(-599): activation_590
# Layers 443(-598): concatenate_8
# Layers 444(-597): normal_conv_1_7
# Layers 445(-596): adjust_bn_7
# Layers 446(-595): normal_bn_1_7
# Layers 447(-594): activation_591
# Layers 448(-593): activation_593
# Layers 449(-592): activation_595
# Layers 450(-591): activation_597
# Layers 451(-590): activation_599
# Layers 452(-589): separable_conv_1_normal_left1_7
# Layers 453(-588): separable_conv_1_normal_right1_7
# Layers 454(-587): separable_conv_1_normal_left2_7
# Layers 455(-586): separable_conv_1_normal_right2_7
# Layers 456(-585): separable_conv_1_normal_left5_7
# Layers 457(-584): separable_conv_1_bn_normal_left1_7
# Layers 458(-583): separable_conv_1_bn_normal_right1_7
# Layers 459(-582): separable_conv_1_bn_normal_left2_7
# Layers 460(-581): separable_conv_1_bn_normal_right2_7
# Layers 461(-580): separable_conv_1_bn_normal_left5_7
# Layers 462(-579): activation_592
# Layers 463(-578): activation_594
# Layers 464(-577): activation_596
# Layers 465(-576): activation_598
# Layers 466(-575): activation_600
# Layers 467(-574): separable_conv_2_normal_left1_7
# Layers 468(-573): separable_conv_2_normal_right1_7
# Layers 469(-572): separable_conv_2_normal_left2_7
# Layers 470(-571): separable_conv_2_normal_right2_7
# Layers 471(-570): separable_conv_2_normal_left5_7
# Layers 472(-569): separable_conv_2_bn_normal_left1_7
# Layers 473(-568): separable_conv_2_bn_normal_right1_7
# Layers 474(-567): separable_conv_2_bn_normal_left2_7
# Layers 475(-566): separable_conv_2_bn_normal_right2_7
# Layers 476(-565): normal_left3_7
# Layers 477(-564): normal_left4_7
# Layers 478(-563): normal_right4_7
# Layers 479(-562): separable_conv_2_bn_normal_left5_7
# Layers 480(-561): normal_add_1_7
# Layers 481(-560): normal_add_2_7
# Layers 482(-559): normal_add_3_7
# Layers 483(-558): normal_add_4_7
# Layers 484(-557): normal_add_5_7
# Layers 485(-556): normal_concat_7
# Layers 486(-555): activation_601
# Layers 487(-554): activation_602
# Layers 488(-553): adjust_conv_projection_8
# Layers 489(-552): normal_conv_1_8
# Layers 490(-551): adjust_bn_8
# Layers 491(-550): normal_bn_1_8
# Layers 492(-549): activation_603
# Layers 493(-548): activation_605
# Layers 494(-547): activation_607
# Layers 495(-546): activation_609
# Layers 496(-545): activation_611
# Layers 497(-544): separable_conv_1_normal_left1_8
# Layers 498(-543): separable_conv_1_normal_right1_8
# Layers 499(-542): separable_conv_1_normal_left2_8
# Layers 500(-541): separable_conv_1_normal_right2_8
# Layers 501(-540): separable_conv_1_normal_left5_8
# Layers 502(-539): separable_conv_1_bn_normal_left1_8
# Layers 503(-538): separable_conv_1_bn_normal_right1_8
# Layers 504(-537): separable_conv_1_bn_normal_left2_8
# Layers 505(-536): separable_conv_1_bn_normal_right2_8
# Layers 506(-535): separable_conv_1_bn_normal_left5_8
# Layers 507(-534): activation_604
# Layers 508(-533): activation_606
# Layers 509(-532): activation_608
# Layers 510(-531): activation_610
# Layers 511(-530): activation_612
# Layers 512(-529): separable_conv_2_normal_left1_8
# Layers 513(-528): separable_conv_2_normal_right1_8
# Layers 514(-527): separable_conv_2_normal_left2_8
# Layers 515(-526): separable_conv_2_normal_right2_8
# Layers 516(-525): separable_conv_2_normal_left5_8
# Layers 517(-524): separable_conv_2_bn_normal_left1_8
# Layers 518(-523): separable_conv_2_bn_normal_right1_8
# Layers 519(-522): separable_conv_2_bn_normal_left2_8
# Layers 520(-521): separable_conv_2_bn_normal_right2_8
# Layers 521(-520): normal_left3_8
# Layers 522(-519): normal_left4_8
# Layers 523(-518): normal_right4_8
# Layers 524(-517): separable_conv_2_bn_normal_left5_8
# Layers 525(-516): normal_add_1_8
# Layers 526(-515): normal_add_2_8
# Layers 527(-514): normal_add_3_8
# Layers 528(-513): normal_add_4_8
# Layers 529(-512): normal_add_5_8
# Layers 530(-511): normal_concat_8
# Layers 531(-510): activation_613
# Layers 532(-509): activation_614
# Layers 533(-508): adjust_conv_projection_9
# Layers 534(-507): normal_conv_1_9
# Layers 535(-506): adjust_bn_9
# Layers 536(-505): normal_bn_1_9
# Layers 537(-504): activation_615
# Layers 538(-503): activation_617
# Layers 539(-502): activation_619
# Layers 540(-501): activation_621
# Layers 541(-500): activation_623
# Layers 542(-499): separable_conv_1_normal_left1_9
# Layers 543(-498): separable_conv_1_normal_right1_9
# Layers 544(-497): separable_conv_1_normal_left2_9
# Layers 545(-496): separable_conv_1_normal_right2_9
# Layers 546(-495): separable_conv_1_normal_left5_9
# Layers 547(-494): separable_conv_1_bn_normal_left1_9
# Layers 548(-493): separable_conv_1_bn_normal_right1_9
# Layers 549(-492): separable_conv_1_bn_normal_left2_9
# Layers 550(-491): separable_conv_1_bn_normal_right2_9
# Layers 551(-490): separable_conv_1_bn_normal_left5_9
# Layers 552(-489): activation_616
# Layers 553(-488): activation_618
# Layers 554(-487): activation_620
# Layers 555(-486): activation_622
# Layers 556(-485): activation_624
# Layers 557(-484): separable_conv_2_normal_left1_9
# Layers 558(-483): separable_conv_2_normal_right1_9
# Layers 559(-482): separable_conv_2_normal_left2_9
# Layers 560(-481): separable_conv_2_normal_right2_9
# Layers 561(-480): separable_conv_2_normal_left5_9
# Layers 562(-479): separable_conv_2_bn_normal_left1_9
# Layers 563(-478): separable_conv_2_bn_normal_right1_9
# Layers 564(-477): separable_conv_2_bn_normal_left2_9
# Layers 565(-476): separable_conv_2_bn_normal_right2_9
# Layers 566(-475): normal_left3_9
# Layers 567(-474): normal_left4_9
# Layers 568(-473): normal_right4_9
# Layers 569(-472): separable_conv_2_bn_normal_left5_9
# Layers 570(-471): normal_add_1_9
# Layers 571(-470): normal_add_2_9
# Layers 572(-469): normal_add_3_9
# Layers 573(-468): normal_add_4_9
# Layers 574(-467): normal_add_5_9
# Layers 575(-466): normal_concat_9
# Layers 576(-465): activation_625
# Layers 577(-464): activation_626
# Layers 578(-463): adjust_conv_projection_10
# Layers 579(-462): normal_conv_1_10
# Layers 580(-461): adjust_bn_10
# Layers 581(-460): normal_bn_1_10
# Layers 582(-459): activation_627
# Layers 583(-458): activation_629
# Layers 584(-457): activation_631
# Layers 585(-456): activation_633
# Layers 586(-455): activation_635
# Layers 587(-454): separable_conv_1_normal_left1_10
# Layers 588(-453): separable_conv_1_normal_right1_10
# Layers 589(-452): separable_conv_1_normal_left2_10
# Layers 590(-451): separable_conv_1_normal_right2_10
# Layers 591(-450): separable_conv_1_normal_left5_10
# Layers 592(-449): separable_conv_1_bn_normal_left1_10
# Layers 593(-448): separable_conv_1_bn_normal_right1_10
# Layers 594(-447): separable_conv_1_bn_normal_left2_10
# Layers 595(-446): separable_conv_1_bn_normal_right2_10
# Layers 596(-445): separable_conv_1_bn_normal_left5_10
# Layers 597(-444): activation_628
# Layers 598(-443): activation_630
# Layers 599(-442): activation_632
# Layers 600(-441): activation_634
# Layers 601(-440): activation_636
# Layers 602(-439): separable_conv_2_normal_left1_10
# Layers 603(-438): separable_conv_2_normal_right1_10
# Layers 604(-437): separable_conv_2_normal_left2_10
# Layers 605(-436): separable_conv_2_normal_right2_10
# Layers 606(-435): separable_conv_2_normal_left5_10
# Layers 607(-434): separable_conv_2_bn_normal_left1_10
# Layers 608(-433): separable_conv_2_bn_normal_right1_10
# Layers 609(-432): separable_conv_2_bn_normal_left2_10
# Layers 610(-431): separable_conv_2_bn_normal_right2_10
# Layers 611(-430): normal_left3_10
# Layers 612(-429): normal_left4_10
# Layers 613(-428): normal_right4_10
# Layers 614(-427): separable_conv_2_bn_normal_left5_10
# Layers 615(-426): normal_add_1_10
# Layers 616(-425): normal_add_2_10
# Layers 617(-424): normal_add_3_10
# Layers 618(-423): normal_add_4_10
# Layers 619(-422): normal_add_5_10
# Layers 620(-421): normal_concat_10
# Layers 621(-420): activation_637
# Layers 622(-419): activation_638
# Layers 623(-418): adjust_conv_projection_11
# Layers 624(-417): normal_conv_1_11
# Layers 625(-416): adjust_bn_11
# Layers 626(-415): normal_bn_1_11
# Layers 627(-414): activation_639
# Layers 628(-413): activation_641
# Layers 629(-412): activation_643
# Layers 630(-411): activation_645
# Layers 631(-410): activation_647
# Layers 632(-409): separable_conv_1_normal_left1_11
# Layers 633(-408): separable_conv_1_normal_right1_11
# Layers 634(-407): separable_conv_1_normal_left2_11
# Layers 635(-406): separable_conv_1_normal_right2_11
# Layers 636(-405): separable_conv_1_normal_left5_11
# Layers 637(-404): separable_conv_1_bn_normal_left1_11
# Layers 638(-403): separable_conv_1_bn_normal_right1_11
# Layers 639(-402): separable_conv_1_bn_normal_left2_11
# Layers 640(-401): separable_conv_1_bn_normal_right2_11
# Layers 641(-400): separable_conv_1_bn_normal_left5_11
# Layers 642(-399): activation_640
# Layers 643(-398): activation_642
# Layers 644(-397): activation_644
# Layers 645(-396): activation_646
# Layers 646(-395): activation_648
# Layers 647(-394): separable_conv_2_normal_left1_11
# Layers 648(-393): separable_conv_2_normal_right1_11
# Layers 649(-392): separable_conv_2_normal_left2_11
# Layers 650(-391): separable_conv_2_normal_right2_11
# Layers 651(-390): separable_conv_2_normal_left5_11
# Layers 652(-389): separable_conv_2_bn_normal_left1_11
# Layers 653(-388): separable_conv_2_bn_normal_right1_11
# Layers 654(-387): separable_conv_2_bn_normal_left2_11
# Layers 655(-386): separable_conv_2_bn_normal_right2_11
# Layers 656(-385): normal_left3_11
# Layers 657(-384): normal_left4_11
# Layers 658(-383): normal_right4_11
# Layers 659(-382): separable_conv_2_bn_normal_left5_11
# Layers 660(-381): normal_add_1_11
# Layers 661(-380): normal_add_2_11
# Layers 662(-379): normal_add_3_11
# Layers 663(-378): normal_add_4_11
# Layers 664(-377): normal_add_5_11
# Layers 665(-376): normal_concat_11
# Layers 666(-375): activation_649
# Layers 667(-374): activation_650
# Layers 668(-373): adjust_conv_projection_12
# Layers 669(-372): normal_conv_1_12
# Layers 670(-371): adjust_bn_12
# Layers 671(-370): normal_bn_1_12
# Layers 672(-369): activation_651
# Layers 673(-368): activation_653
# Layers 674(-367): activation_655
# Layers 675(-366): activation_657
# Layers 676(-365): activation_659
# Layers 677(-364): separable_conv_1_normal_left1_12
# Layers 678(-363): separable_conv_1_normal_right1_12
# Layers 679(-362): separable_conv_1_normal_left2_12
# Layers 680(-361): separable_conv_1_normal_right2_12
# Layers 681(-360): separable_conv_1_normal_left5_12
# Layers 682(-359): separable_conv_1_bn_normal_left1_12
# Layers 683(-358): separable_conv_1_bn_normal_right1_12
# Layers 684(-357): separable_conv_1_bn_normal_left2_12
# Layers 685(-356): separable_conv_1_bn_normal_right2_12
# Layers 686(-355): separable_conv_1_bn_normal_left5_12
# Layers 687(-354): activation_652
# Layers 688(-353): activation_654
# Layers 689(-352): activation_656
# Layers 690(-351): activation_658
# Layers 691(-350): activation_660
# Layers 692(-349): separable_conv_2_normal_left1_12
# Layers 693(-348): separable_conv_2_normal_right1_12
# Layers 694(-347): separable_conv_2_normal_left2_12
# Layers 695(-346): separable_conv_2_normal_right2_12
# Layers 696(-345): separable_conv_2_normal_left5_12
# Layers 697(-344): separable_conv_2_bn_normal_left1_12
# Layers 698(-343): separable_conv_2_bn_normal_right1_12
# Layers 699(-342): separable_conv_2_bn_normal_left2_12
# Layers 700(-341): separable_conv_2_bn_normal_right2_12
# Layers 701(-340): normal_left3_12
# Layers 702(-339): normal_left4_12
# Layers 703(-338): normal_right4_12
# Layers 704(-337): separable_conv_2_bn_normal_left5_12
# Layers 705(-336): normal_add_1_12
# Layers 706(-335): normal_add_2_12
# Layers 707(-334): normal_add_3_12
# Layers 708(-333): normal_add_4_12
# Layers 709(-332): normal_add_5_12
# Layers 710(-331): normal_concat_12
# Layers 711(-330): activation_662
# Layers 712(-329): activation_661
# Layers 713(-328): reduction_conv_1_reduce_12
# Layers 714(-327): adjust_conv_projection_reduce_12
# Layers 715(-326): reduction_bn_1_reduce_12
# Layers 716(-325): adjust_bn_reduce_12
# Layers 717(-324): activation_663
# Layers 718(-323): activation_665
# Layers 719(-322): separable_conv_1_pad_reduction_left1_reduce_12
# Layers 720(-321): separable_conv_1_pad_reduction_right1_reduce_12
# Layers 721(-320): separable_conv_1_reduction_left1_reduce_12
# Layers 722(-319): separable_conv_1_reduction_right1_reduce_12
# Layers 723(-318): separable_conv_1_bn_reduction_left1_reduce_12
# Layers 724(-317): separable_conv_1_bn_reduction_right1_reduce_12
# Layers 725(-316): activation_664
# Layers 726(-315): activation_666
# Layers 727(-314): separable_conv_2_reduction_left1_reduce_12
# Layers 728(-313): separable_conv_2_reduction_right1_reduce_12
# Layers 729(-312): activation_667
# Layers 730(-311): separable_conv_2_bn_reduction_left1_reduce_12
# Layers 731(-310): separable_conv_2_bn_reduction_right1_reduce_12
# Layers 732(-309): separable_conv_1_pad_reduction_right2_reduce_12
# Layers 733(-308): activation_669
# Layers 734(-307): reduction_add_1_reduce_12
# Layers 735(-306): separable_conv_1_reduction_right2_reduce_12
# Layers 736(-305): separable_conv_1_pad_reduction_right3_reduce_12
# Layers 737(-304): activation_671
# Layers 738(-303): separable_conv_1_bn_reduction_right2_reduce_12
# Layers 739(-302): separable_conv_1_reduction_right3_reduce_12
# Layers 740(-301): separable_conv_1_reduction_left4_reduce_12
# Layers 741(-300): activation_668
# Layers 742(-299): separable_conv_1_bn_reduction_right3_reduce_12
# Layers 743(-298): separable_conv_1_bn_reduction_left4_reduce_12
# Layers 744(-297): reduction_pad_1_reduce_12
# Layers 745(-296): separable_conv_2_reduction_right2_reduce_12
# Layers 746(-295): activation_670
# Layers 747(-294): activation_672
# Layers 748(-293): reduction_left2_reduce_12
# Layers 749(-292): separable_conv_2_bn_reduction_right2_reduce_12
# Layers 750(-291): separable_conv_2_reduction_right3_reduce_12
# Layers 751(-290): separable_conv_2_reduction_left4_reduce_12
# Layers 752(-289): adjust_relu_1_13
# Layers 753(-288): reduction_add_2_reduce_12
# Layers 754(-287): reduction_left3_reduce_12
# Layers 755(-286): separable_conv_2_bn_reduction_right3_reduce_12
# Layers 756(-285): reduction_left4_reduce_12
# Layers 757(-284): separable_conv_2_bn_reduction_left4_reduce_12
# Layers 758(-283): reduction_right5_reduce_12
# Layers 759(-282): zero_padding2d_13
# Layers 760(-281): reduction_add3_reduce_12
# Layers 761(-280): add_19
# Layers 762(-279): reduction_add4_reduce_12
# Layers 763(-278): cropping2d_7
# Layers 764(-277): reduction_concat_reduce_12
# Layers 765(-276): adjust_avg_pool_1_13
# Layers 766(-275): adjust_avg_pool_2_13
# Layers 767(-274): adjust_conv_1_13
# Layers 768(-273): adjust_conv_2_13
# Layers 769(-272): activation_673
# Layers 770(-271): concatenate_9
# Layers 771(-270): normal_conv_1_13
# Layers 772(-269): adjust_bn_13
# Layers 773(-268): normal_bn_1_13
# Layers 774(-267): activation_674
# Layers 775(-266): activation_676
# Layers 776(-265): activation_678
# Layers 777(-264): activation_680
# Layers 778(-263): activation_682
# Layers 779(-262): separable_conv_1_normal_left1_13
# Layers 780(-261): separable_conv_1_normal_right1_13
# Layers 781(-260): separable_conv_1_normal_left2_13
# Layers 782(-259): separable_conv_1_normal_right2_13
# Layers 783(-258): separable_conv_1_normal_left5_13
# Layers 784(-257): separable_conv_1_bn_normal_left1_13
# Layers 785(-256): separable_conv_1_bn_normal_right1_13
# Layers 786(-255): separable_conv_1_bn_normal_left2_13
# Layers 787(-254): separable_conv_1_bn_normal_right2_13
# Layers 788(-253): separable_conv_1_bn_normal_left5_13
# Layers 789(-252): activation_675
# Layers 790(-251): activation_677
# Layers 791(-250): activation_679
# Layers 792(-249): activation_681
# Layers 793(-248): activation_683
# Layers 794(-247): separable_conv_2_normal_left1_13
# Layers 795(-246): separable_conv_2_normal_right1_13
# Layers 796(-245): separable_conv_2_normal_left2_13
# Layers 797(-244): separable_conv_2_normal_right2_13
# Layers 798(-243): separable_conv_2_normal_left5_13
# Layers 799(-242): separable_conv_2_bn_normal_left1_13
# Layers 800(-241): separable_conv_2_bn_normal_right1_13
# Layers 801(-240): separable_conv_2_bn_normal_left2_13
# Layers 802(-239): separable_conv_2_bn_normal_right2_13
# Layers 803(-238): normal_left3_13
# Layers 804(-237): normal_left4_13
# Layers 805(-236): normal_right4_13
# Layers 806(-235): separable_conv_2_bn_normal_left5_13
# Layers 807(-234): normal_add_1_13
# Layers 808(-233): normal_add_2_13
# Layers 809(-232): normal_add_3_13
# Layers 810(-231): normal_add_4_13
# Layers 811(-230): normal_add_5_13
# Layers 812(-229): normal_concat_13
# Layers 813(-228): activation_684
# Layers 814(-227): activation_685
# Layers 815(-226): adjust_conv_projection_14
# Layers 816(-225): normal_conv_1_14
# Layers 817(-224): adjust_bn_14
# Layers 818(-223): normal_bn_1_14
# Layers 819(-222): activation_686
# Layers 820(-221): activation_688
# Layers 821(-220): activation_690
# Layers 822(-219): activation_692
# Layers 823(-218): activation_694
# Layers 824(-217): separable_conv_1_normal_left1_14
# Layers 825(-216): separable_conv_1_normal_right1_14
# Layers 826(-215): separable_conv_1_normal_left2_14
# Layers 827(-214): separable_conv_1_normal_right2_14
# Layers 828(-213): separable_conv_1_normal_left5_14
# Layers 829(-212): separable_conv_1_bn_normal_left1_14
# Layers 830(-211): separable_conv_1_bn_normal_right1_14
# Layers 831(-210): separable_conv_1_bn_normal_left2_14
# Layers 832(-209): separable_conv_1_bn_normal_right2_14
# Layers 833(-208): separable_conv_1_bn_normal_left5_14
# Layers 834(-207): activation_687
# Layers 835(-206): activation_689
# Layers 836(-205): activation_691
# Layers 837(-204): activation_693
# Layers 838(-203): activation_695
# Layers 839(-202): separable_conv_2_normal_left1_14
# Layers 840(-201): separable_conv_2_normal_right1_14
# Layers 841(-200): separable_conv_2_normal_left2_14
# Layers 842(-199): separable_conv_2_normal_right2_14
# Layers 843(-198): separable_conv_2_normal_left5_14
# Layers 844(-197): separable_conv_2_bn_normal_left1_14
# Layers 845(-196): separable_conv_2_bn_normal_right1_14
# Layers 846(-195): separable_conv_2_bn_normal_left2_14
# Layers 847(-194): separable_conv_2_bn_normal_right2_14
# Layers 848(-193): normal_left3_14
# Layers 849(-192): normal_left4_14
# Layers 850(-191): normal_right4_14
# Layers 851(-190): separable_conv_2_bn_normal_left5_14
# Layers 852(-189): normal_add_1_14
# Layers 853(-188): normal_add_2_14
# Layers 854(-187): normal_add_3_14
# Layers 855(-186): normal_add_4_14
# Layers 856(-185): normal_add_5_14
# Layers 857(-184): normal_concat_14
# Layers 858(-183): activation_696
# Layers 859(-182): activation_697
# Layers 860(-181): adjust_conv_projection_15
# Layers 861(-180): normal_conv_1_15
# Layers 862(-179): adjust_bn_15
# Layers 863(-178): normal_bn_1_15
# Layers 864(-177): activation_698
# Layers 865(-176): activation_700
# Layers 866(-175): activation_702
# Layers 867(-174): activation_704
# Layers 868(-173): activation_706
# Layers 869(-172): separable_conv_1_normal_left1_15
# Layers 870(-171): separable_conv_1_normal_right1_15
# Layers 871(-170): separable_conv_1_normal_left2_15
# Layers 872(-169): separable_conv_1_normal_right2_15
# Layers 873(-168): separable_conv_1_normal_left5_15
# Layers 874(-167): separable_conv_1_bn_normal_left1_15
# Layers 875(-166): separable_conv_1_bn_normal_right1_15
# Layers 876(-165): separable_conv_1_bn_normal_left2_15
# Layers 877(-164): separable_conv_1_bn_normal_right2_15
# Layers 878(-163): separable_conv_1_bn_normal_left5_15
# Layers 879(-162): activation_699
# Layers 880(-161): activation_701
# Layers 881(-160): activation_703
# Layers 882(-159): activation_705
# Layers 883(-158): activation_707
# Layers 884(-157): separable_conv_2_normal_left1_15
# Layers 885(-156): separable_conv_2_normal_right1_15
# Layers 886(-155): separable_conv_2_normal_left2_15
# Layers 887(-154): separable_conv_2_normal_right2_15
# Layers 888(-153): separable_conv_2_normal_left5_15
# Layers 889(-152): separable_conv_2_bn_normal_left1_15
# Layers 890(-151): separable_conv_2_bn_normal_right1_15
# Layers 891(-150): separable_conv_2_bn_normal_left2_15
# Layers 892(-149): separable_conv_2_bn_normal_right2_15
# Layers 893(-148): normal_left3_15
# Layers 894(-147): normal_left4_15
# Layers 895(-146): normal_right4_15
# Layers 896(-145): separable_conv_2_bn_normal_left5_15
# Layers 897(-144): normal_add_1_15
# Layers 898(-143): normal_add_2_15
# Layers 899(-142): normal_add_3_15
# Layers 900(-141): normal_add_4_15
# Layers 901(-140): normal_add_5_15
# Layers 902(-139): normal_concat_15
# Layers 903(-138): activation_708
# Layers 904(-137): activation_709
# Layers 905(-136): adjust_conv_projection_16
# Layers 906(-135): normal_conv_1_16
# Layers 907(-134): adjust_bn_16
# Layers 908(-133): normal_bn_1_16
# Layers 909(-132): activation_710
# Layers 910(-131): activation_712
# Layers 911(-130): activation_714
# Layers 912(-129): activation_716
# Layers 913(-128): activation_718
# Layers 914(-127): separable_conv_1_normal_left1_16
# Layers 915(-126): separable_conv_1_normal_right1_16
# Layers 916(-125): separable_conv_1_normal_left2_16
# Layers 917(-124): separable_conv_1_normal_right2_16
# Layers 918(-123): separable_conv_1_normal_left5_16
# Layers 919(-122): separable_conv_1_bn_normal_left1_16
# Layers 920(-121): separable_conv_1_bn_normal_right1_16
# Layers 921(-120): separable_conv_1_bn_normal_left2_16
# Layers 922(-119): separable_conv_1_bn_normal_right2_16
# Layers 923(-118): separable_conv_1_bn_normal_left5_16
# Layers 924(-117): activation_711
# Layers 925(-116): activation_713
# Layers 926(-115): activation_715
# Layers 927(-114): activation_717
# Layers 928(-113): activation_719
# Layers 929(-112): separable_conv_2_normal_left1_16
# Layers 930(-111): separable_conv_2_normal_right1_16
# Layers 931(-110): separable_conv_2_normal_left2_16
# Layers 932(-109): separable_conv_2_normal_right2_16
# Layers 933(-108): separable_conv_2_normal_left5_16
# Layers 934(-107): separable_conv_2_bn_normal_left1_16
# Layers 935(-106): separable_conv_2_bn_normal_right1_16
# Layers 936(-105): separable_conv_2_bn_normal_left2_16
# Layers 937(-104): separable_conv_2_bn_normal_right2_16
# Layers 938(-103): normal_left3_16
# Layers 939(-102): normal_left4_16
# Layers 940(-101): normal_right4_16
# Layers 941(-100): separable_conv_2_bn_normal_left5_16
# Layers 942(-99): normal_add_1_16
# Layers 943(-98): normal_add_2_16
# Layers 944(-97): normal_add_3_16
# Layers 945(-96): normal_add_4_16
# Layers 946(-95): normal_add_5_16
# Layers 947(-94): normal_concat_16
# Layers 948(-93): activation_720
# Layers 949(-92): activation_721
# Layers 950(-91): adjust_conv_projection_17
# Layers 951(-90): normal_conv_1_17
# Layers 952(-89): adjust_bn_17
# Layers 953(-88): normal_bn_1_17
# Layers 954(-87): activation_722
# Layers 955(-86): activation_724
# Layers 956(-85): activation_726
# Layers 957(-84): activation_728
# Layers 958(-83): activation_730
# Layers 959(-82): separable_conv_1_normal_left1_17
# Layers 960(-81): separable_conv_1_normal_right1_17
# Layers 961(-80): separable_conv_1_normal_left2_17
# Layers 962(-79): separable_conv_1_normal_right2_17
# Layers 963(-78): separable_conv_1_normal_left5_17
# Layers 964(-77): separable_conv_1_bn_normal_left1_17
# Layers 965(-76): separable_conv_1_bn_normal_right1_17
# Layers 966(-75): separable_conv_1_bn_normal_left2_17
# Layers 967(-74): separable_conv_1_bn_normal_right2_17
# Layers 968(-73): separable_conv_1_bn_normal_left5_17
# Layers 969(-72): activation_723
# Layers 970(-71): activation_725
# Layers 971(-70): activation_727
# Layers 972(-69): activation_729
# Layers 973(-68): activation_731
# Layers 974(-67): separable_conv_2_normal_left1_17
# Layers 975(-66): separable_conv_2_normal_right1_17
# Layers 976(-65): separable_conv_2_normal_left2_17
# Layers 977(-64): separable_conv_2_normal_right2_17
# Layers 978(-63): separable_conv_2_normal_left5_17
# Layers 979(-62): separable_conv_2_bn_normal_left1_17
# Layers 980(-61): separable_conv_2_bn_normal_right1_17
# Layers 981(-60): separable_conv_2_bn_normal_left2_17
# Layers 982(-59): separable_conv_2_bn_normal_right2_17
# Layers 983(-58): normal_left3_17
# Layers 984(-57): normal_left4_17
# Layers 985(-56): normal_right4_17
# Layers 986(-55): separable_conv_2_bn_normal_left5_17
# Layers 987(-54): normal_add_1_17
# Layers 988(-53): normal_add_2_17
# Layers 989(-52): normal_add_3_17
# Layers 990(-51): normal_add_4_17
# Layers 991(-50): normal_add_5_17
# Layers 992(-49): normal_concat_17
# Layers 993(-48): activation_732
# Layers 994(-47): activation_733
# Layers 995(-46): adjust_conv_projection_18
# Layers 996(-45): normal_conv_1_18
# Layers 997(-44): adjust_bn_18
# Layers 998(-43): normal_bn_1_18
# Layers 999(-42): activation_734
# Layers 1000(-41): activation_736
# Layers 1001(-40): activation_738
# Layers 1002(-39): activation_740
# Layers 1003(-38): activation_742
# Layers 1004(-37): separable_conv_1_normal_left1_18
# Layers 1005(-36): separable_conv_1_normal_right1_18
# Layers 1006(-35): separable_conv_1_normal_left2_18
# Layers 1007(-34): separable_conv_1_normal_right2_18
# Layers 1008(-33): separable_conv_1_normal_left5_18
# Layers 1009(-32): separable_conv_1_bn_normal_left1_18
# Layers 1010(-31): separable_conv_1_bn_normal_right1_18
# Layers 1011(-30): separable_conv_1_bn_normal_left2_18
# Layers 1012(-29): separable_conv_1_bn_normal_right2_18
# Layers 1013(-28): separable_conv_1_bn_normal_left5_18
# Layers 1014(-27): activation_735
# Layers 1015(-26): activation_737
# Layers 1016(-25): activation_739
# Layers 1017(-24): activation_741
# Layers 1018(-23): activation_743
# Layers 1019(-22): separable_conv_2_normal_left1_18
# Layers 1020(-21): separable_conv_2_normal_right1_18
# Layers 1021(-20): separable_conv_2_normal_left2_18
# Layers 1022(-19): separable_conv_2_normal_right2_18
# Layers 1023(-18): separable_conv_2_normal_left5_18
# Layers 1024(-17): separable_conv_2_bn_normal_left1_18
# Layers 1025(-16): separable_conv_2_bn_normal_right1_18
# Layers 1026(-15): separable_conv_2_bn_normal_left2_18
# Layers 1027(-14): separable_conv_2_bn_normal_right2_18
# Layers 1028(-13): normal_left3_18
# Layers 1029(-12): normal_left4_18
# Layers 1030(-11): normal_right4_18
# Layers 1031(-10): separable_conv_2_bn_normal_left5_18
# Layers 1032(-9): normal_add_1_18
# Layers 1033(-8): normal_add_2_18
# Layers 1034(-7): normal_add_3_18
# Layers 1035(-6): normal_add_4_18
# Layers 1036(-5): normal_add_5_18
# Layers 1037(-4): normal_concat_18
# Layers 1038(-3): activation_744
# Layers 1039(-2): global_average_pooling2d_3
# Layers 1040(-1): predictions

# %%
NASNetLarge.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 331, 331, 3  0           []
#                                 )]
#
#  stem_conv1 (Conv2D)            (None, 165, 165, 96  2592        ['input_18[0][0]']
#                                 )
#
#  stem_bn1 (BatchNormalization)  (None, 165, 165, 96  384         ['stem_conv1[0][0]']
#                                 )
#
#  activation_485 (Activation)    (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_conv_1_stem_1 (Conv2  (None, 165, 165, 42  4032       ['activation_485[0][0]']
#  D)                             )
#
#  reduction_bn_1_stem_1 (BatchNo  (None, 165, 165, 42  168        ['reduction_conv_1_stem_1[0][0]']
#  rmalization)                   )
#
#  activation_486 (Activation)    (None, 165, 165, 42  0           ['reduction_bn_1_stem_1[0][0]']
#                                 )
#
#  activation_488 (Activation)    (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_1_pad_reduction  (None, 169, 169, 42  0          ['activation_486[0][0]']
#  _left1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_pad_reduction  (None, 171, 171, 96  0          ['activation_488[0][0]']
#  _right1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_reduction_lef  (None, 83, 83, 42)  2814        ['separable_conv_1_pad_reduction_
#  t1_stem_1 (SeparableConv2D)                                     left1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 83, 83, 42)  8736        ['separable_conv_1_pad_reduction_
#  ht1_stem_1 (SeparableConv2D)                                    right1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  activation_487 (Activation)    (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_1[0][0]']
#
#  activation_489 (Activation)    (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 83, 83, 42)  2814        ['activation_487[0][0]']
#  t1_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 83, 83, 42)  3822        ['activation_489[0][0]']
#  ht1_stem_1 (SeparableConv2D)
#
#  activation_490 (Activation)    (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 171, 171, 96  0          ['activation_490[0][0]']
#  _right2_stem_1 (ZeroPadding2D)  )
#
#  activation_492 (Activation)    (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_add_1_stem_1 (Add)   (None, 83, 83, 42)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 83, 83, 42)  8736        ['separable_conv_1_pad_reduction_
#  ht2_stem_1 (SeparableConv2D)                                    right2_stem_1[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 169, 169, 96  0          ['activation_492[0][0]']
#  _right3_stem_1 (ZeroPadding2D)  )
#
#  activation_494 (Activation)    (None, 83, 83, 42)   0           ['reduction_add_1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 83, 83, 42)  6432        ['separable_conv_1_pad_reduction_
#  ht3_stem_1 (SeparableConv2D)                                    right3_stem_1[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 83, 83, 42)  2142        ['activation_494[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  activation_491 (Activation)    (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_pad_1_stem_1 (ZeroPa  (None, 167, 167, 42  0          ['reduction_bn_1_stem_1[0][0]']
#  dding2D)                       )
#
#  separable_conv_2_reduction_rig  (None, 83, 83, 42)  3822        ['activation_491[0][0]']
#  ht2_stem_1 (SeparableConv2D)
#
#  activation_493 (Activation)    (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  activation_495 (Activation)    (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (MaxPoo  (None, 83, 83, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 83, 83, 42)  2814        ['activation_493[0][0]']
#  ht3_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 83, 83, 42)  2142        ['activation_495[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  adjust_relu_1_stem_2 (Activati  (None, 165, 165, 96  0          ['stem_bn1[0][0]']
#  on)                            )
#
#  reduction_add_2_stem_1 (Add)   (None, 83, 83, 42)   0           ['reduction_left2_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Averag  (None, 83, 83, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  reduction_left4_stem_1 (Averag  (None, 83, 83, 42)  0           ['reduction_add_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_right5_stem_1 (MaxPo  (None, 83, 83, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  oling2D)
#
#  zero_padding2d_10 (ZeroPadding  (None, 166, 166, 96  0          ['adjust_relu_1_stem_2[0][0]']
#  2D)                            )
#
#  reduction_add3_stem_1 (Add)    (None, 83, 83, 42)   0           ['reduction_left3_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#  add_16 (Add)                   (None, 83, 83, 42)   0           ['reduction_add_2_stem_1[0][0]',
#                                                                   'reduction_left4_stem_1[0][0]']
#
#  reduction_add4_stem_1 (Add)    (None, 83, 83, 42)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_1[0][0]',
#                                                                   'reduction_right5_stem_1[0][0]']
#
#  cropping2d_4 (Cropping2D)      (None, 165, 165, 96  0           ['zero_padding2d_10[0][0]']
#                                 )
#
#  reduction_concat_stem_1 (Conca  (None, 83, 83, 168)  0          ['reduction_add_2_stem_1[0][0]',
#  tenate)                                                          'reduction_add3_stem_1[0][0]',
#                                                                   'add_16[0][0]',
#                                                                   'reduction_add4_stem_1[0][0]']
#
#  adjust_avg_pool_1_stem_2 (Aver  (None, 83, 83, 96)  0           ['adjust_relu_1_stem_2[0][0]']
#  agePooling2D)
#
#  adjust_avg_pool_2_stem_2 (Aver  (None, 83, 83, 96)  0           ['cropping2d_4[0][0]']
#  agePooling2D)
#
#  activation_496 (Activation)    (None, 83, 83, 168)  0           ['reduction_concat_stem_1[0][0]']
#
#  adjust_conv_1_stem_2 (Conv2D)  (None, 83, 83, 42)   4032        ['adjust_avg_pool_1_stem_2[0][0]'
#                                                                  ]
#
#  adjust_conv_2_stem_2 (Conv2D)  (None, 83, 83, 42)   4032        ['adjust_avg_pool_2_stem_2[0][0]'
#                                                                  ]
#
#  reduction_conv_1_stem_2 (Conv2  (None, 83, 83, 84)  14112       ['activation_496[0][0]']
#  D)
#
#  concatenate_6 (Concatenate)    (None, 83, 83, 84)   0           ['adjust_conv_1_stem_2[0][0]',
#                                                                   'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (BatchNo  (None, 83, 83, 84)  336         ['reduction_conv_1_stem_2[0][0]']
#  rmalization)
#
#  adjust_bn_stem_2 (BatchNormali  (None, 83, 83, 84)  336         ['concatenate_6[0][0]']
#  zation)
#
#  activation_497 (Activation)    (None, 83, 83, 84)   0           ['reduction_bn_1_stem_2[0][0]']
#
#  activation_499 (Activation)    (None, 83, 83, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 87, 87, 84)  0           ['activation_497[0][0]']
#  _left1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_pad_reduction  (None, 89, 89, 84)  0           ['activation_499[0][0]']
#  _right1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_reduction_lef  (None, 42, 42, 84)  9156        ['separable_conv_1_pad_reduction_
#  t1_stem_2 (SeparableConv2D)                                     left1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 42, 42, 84)  11172       ['separable_conv_1_pad_reduction_
#  ht1_stem_2 (SeparableConv2D)                                    right1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  activation_498 (Activation)    (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_2[0][0]']
#
#  activation_500 (Activation)    (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 42, 42, 84)  9156        ['activation_498[0][0]']
#  t1_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 42, 42, 84)  11172       ['activation_500[0][0]']
#  ht1_stem_2 (SeparableConv2D)
#
#  activation_501 (Activation)    (None, 83, 83, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 89, 89, 84)  0           ['activation_501[0][0]']
#  _right2_stem_2 (ZeroPadding2D)
#
#  activation_503 (Activation)    (None, 83, 83, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Add)   (None, 42, 42, 84)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 42, 42, 84)  11172       ['separable_conv_1_pad_reduction_
#  ht2_stem_2 (SeparableConv2D)                                    right2_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 87, 87, 84)  0           ['activation_503[0][0]']
#  _right3_stem_2 (ZeroPadding2D)
#
#  activation_505 (Activation)    (None, 42, 42, 84)   0           ['reduction_add_1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 42, 42, 84)  9156        ['separable_conv_1_pad_reduction_
#  ht3_stem_2 (SeparableConv2D)                                    right3_stem_2[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 42, 42, 84)  7812        ['activation_505[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  activation_502 (Activation)    (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_pad_1_stem_2 (ZeroPa  (None, 85, 85, 84)  0           ['reduction_bn_1_stem_2[0][0]']
#  dding2D)
#
#  separable_conv_2_reduction_rig  (None, 42, 42, 84)  11172       ['activation_502[0][0]']
#  ht2_stem_2 (SeparableConv2D)
#
#  activation_504 (Activation)    (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  activation_506 (Activation)    (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (MaxPoo  (None, 42, 42, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 42, 42, 84)  9156        ['activation_504[0][0]']
#  ht3_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 42, 42, 84)  7812        ['activation_506[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  adjust_relu_1_0 (Activation)   (None, 83, 83, 168)  0           ['reduction_concat_stem_1[0][0]']
#
#  reduction_add_2_stem_2 (Add)   (None, 42, 42, 84)   0           ['reduction_left2_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Averag  (None, 42, 42, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  reduction_left4_stem_2 (Averag  (None, 42, 42, 84)  0           ['reduction_add_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_right5_stem_2 (MaxPo  (None, 42, 42, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  oling2D)
#
#  zero_padding2d_11 (ZeroPadding  (None, 84, 84, 168)  0          ['adjust_relu_1_0[0][0]']
#  2D)
#
#  reduction_add3_stem_2 (Add)    (None, 42, 42, 84)   0           ['reduction_left3_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  add_17 (Add)                   (None, 42, 42, 84)   0           ['reduction_add_2_stem_2[0][0]',
#                                                                   'reduction_left4_stem_2[0][0]']
#
#  reduction_add4_stem_2 (Add)    (None, 42, 42, 84)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_2[0][0]',
#                                                                   'reduction_right5_stem_2[0][0]']
#
#  cropping2d_5 (Cropping2D)      (None, 83, 83, 168)  0           ['zero_padding2d_11[0][0]']
#
#  reduction_concat_stem_2 (Conca  (None, 42, 42, 336)  0          ['reduction_add_2_stem_2[0][0]',
#  tenate)                                                          'reduction_add3_stem_2[0][0]',
#                                                                   'add_17[0][0]',
#                                                                   'reduction_add4_stem_2[0][0]']
#
#  adjust_avg_pool_1_0 (AveragePo  (None, 42, 42, 168)  0          ['adjust_relu_1_0[0][0]']
#  oling2D)
#
#  adjust_avg_pool_2_0 (AveragePo  (None, 42, 42, 168)  0          ['cropping2d_5[0][0]']
#  oling2D)
#
#  adjust_conv_1_0 (Conv2D)       (None, 42, 42, 84)   14112       ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)       (None, 42, 42, 84)   14112       ['adjust_avg_pool_2_0[0][0]']
#
#  activation_507 (Activation)    (None, 42, 42, 336)  0           ['reduction_concat_stem_2[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 42, 42, 168)  0           ['adjust_conv_1_0[0][0]',
#                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)       (None, 42, 42, 168)  56448       ['activation_507[0][0]']
#
#  adjust_bn_0 (BatchNormalizatio  (None, 42, 42, 168)  672        ['concatenate_7[0][0]']
#  n)
#
#  normal_bn_1_0 (BatchNormalizat  (None, 42, 42, 168)  672        ['normal_conv_1_0[0][0]']
#  ion)
#
#  activation_508 (Activation)    (None, 42, 42, 168)  0           ['normal_bn_1_0[0][0]']
#
#  activation_510 (Activation)    (None, 42, 42, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_512 (Activation)    (None, 42, 42, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_514 (Activation)    (None, 42, 42, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_516 (Activation)    (None, 42, 42, 168)  0           ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 42, 42, 168)  32424      ['activation_508[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 42, 42, 168)  29736      ['activation_510[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 42, 42, 168)  32424      ['activation_512[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 42, 42, 168)  29736      ['activation_514[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 42, 42, 168)  29736      ['activation_516[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_1_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_1_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#  separable_conv_1_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_1_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_1_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_1_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  activation_509 (Activation)    (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  1_0[0][0]']
#
#  activation_511 (Activation)    (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  activation_513 (Activation)    (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  2_0[0][0]']
#
#  activation_515 (Activation)    (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  activation_517 (Activation)    (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  5_0[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 42, 42, 168)  32424      ['activation_509[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 42, 42, 168)  29736      ['activation_511[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 42, 42, 168)  32424      ['activation_513[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 42, 42, 168)  29736      ['activation_515[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 42, 42, 168)  29736      ['activation_517[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_2_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_2_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_2_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_2_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  normal_left3_0 (AveragePooling  (None, 42, 42, 168)  0          ['normal_bn_1_0[0][0]']
#  2D)
#
#  normal_left4_0 (AveragePooling  (None, 42, 42, 168)  0          ['adjust_bn_0[0][0]']
#  2D)
#
#  normal_right4_0 (AveragePoolin  (None, 42, 42, 168)  0          ['adjust_bn_0[0][0]']
#  g2D)
#
#  separable_conv_2_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_2_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  normal_add_1_0 (Add)           (None, 42, 42, 168)  0           ['separable_conv_2_bn_normal_left
#                                                                  1_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  normal_add_2_0 (Add)           (None, 42, 42, 168)  0           ['separable_conv_2_bn_normal_left
#                                                                  2_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  normal_add_3_0 (Add)           (None, 42, 42, 168)  0           ['normal_left3_0[0][0]',
#                                                                   'adjust_bn_0[0][0]']
# ...
#                                                                   'normal_right4_17[0][0]']
#
#  normal_add_5_17 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  5_17[0][0]',
#                                                                   'normal_bn_1_17[0][0]']
#
#  normal_concat_17 (Concatenate)  (None, 11, 11, 4032  0          ['adjust_bn_17[0][0]',
#                                 )                                 'normal_add_1_17[0][0]',
#                                                                   'normal_add_2_17[0][0]',
#                                                                   'normal_add_3_17[0][0]',
#                                                                   'normal_add_4_17[0][0]',
#                                                                   'normal_add_5_17[0][0]']
#
#  activation_732 (Activation)    (None, 11, 11, 4032  0           ['normal_concat_16[0][0]']
#                                 )
#
#  activation_733 (Activation)    (None, 11, 11, 4032  0           ['normal_concat_17[0][0]']
#                                 )
#
#  adjust_conv_projection_18 (Con  (None, 11, 11, 672)  2709504    ['activation_732[0][0]']
#  v2D)
#
#  normal_conv_1_18 (Conv2D)      (None, 11, 11, 672)  2709504     ['activation_733[0][0]']
#
#  adjust_bn_18 (BatchNormalizati  (None, 11, 11, 672)  2688       ['adjust_conv_projection_18[0][0]
#  on)                                                             ']
#
#  normal_bn_1_18 (BatchNormaliza  (None, 11, 11, 672)  2688       ['normal_conv_1_18[0][0]']
#  tion)
#
#  activation_734 (Activation)    (None, 11, 11, 672)  0           ['normal_bn_1_18[0][0]']
#
#  activation_736 (Activation)    (None, 11, 11, 672)  0           ['adjust_bn_18[0][0]']
#
#  activation_738 (Activation)    (None, 11, 11, 672)  0           ['adjust_bn_18[0][0]']
#
#  activation_740 (Activation)    (None, 11, 11, 672)  0           ['adjust_bn_18[0][0]']
#
#  activation_742 (Activation)    (None, 11, 11, 672)  0           ['normal_bn_1_18[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 11, 11, 672)  468384     ['activation_734[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 11, 11, 672)  457632     ['activation_736[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 11, 11, 672)  468384     ['activation_738[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 11, 11, 672)  457632     ['activation_740[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 11, 11, 672)  457632     ['activation_742[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_left1_1
#  t1_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_right1_
#  ht1_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_left2_1
#  t2_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_right2_
#  ht2_18 (BatchNormalization)                                     18[0][0]']
#  separable_conv_1_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_left5_1
#  t5_18 (BatchNormalization)                                      8[0][0]']
#
#  activation_735 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_left
#                                                                  1_18[0][0]']
#
#  activation_737 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_18[0][0]']
#
#  activation_739 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_left
#                                                                  2_18[0][0]']
#
#  activation_741 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_18[0][0]']
#
#  activation_743 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_left
#                                                                  5_18[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 11, 11, 672)  468384     ['activation_735[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 11, 11, 672)  457632     ['activation_737[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 11, 11, 672)  468384     ['activation_739[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 11, 11, 672)  457632     ['activation_741[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 11, 11, 672)  457632     ['activation_743[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_left1_1
#  t1_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_right1_
#  ht1_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_left2_1
#  t2_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_right2_
#  ht2_18 (BatchNormalization)                                     18[0][0]']
#
#  normal_left3_18 (AveragePoolin  (None, 11, 11, 672)  0          ['normal_bn_1_18[0][0]']
#  g2D)
#
#  normal_left4_18 (AveragePoolin  (None, 11, 11, 672)  0          ['adjust_bn_18[0][0]']
#  g2D)
#
#  normal_right4_18 (AveragePooli  (None, 11, 11, 672)  0          ['adjust_bn_18[0][0]']
#  ng2D)
#
#  separable_conv_2_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_left5_1
#  t5_18 (BatchNormalization)                                      8[0][0]']
#
#  normal_add_1_18 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  1_18[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_18[0][0]']
#
#  normal_add_2_18 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  2_18[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_18[0][0]']
#
#  normal_add_3_18 (Add)          (None, 11, 11, 672)  0           ['normal_left3_18[0][0]',
#                                                                   'adjust_bn_18[0][0]']
#
#  normal_add_4_18 (Add)          (None, 11, 11, 672)  0           ['normal_left4_18[0][0]',
#                                                                   'normal_right4_18[0][0]']
#
#  normal_add_5_18 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  5_18[0][0]',
#                                                                   'normal_bn_1_18[0][0]']
#
#  normal_concat_18 (Concatenate)  (None, 11, 11, 4032  0          ['adjust_bn_18[0][0]',
#                                 )                                 'normal_add_1_18[0][0]',
#                                                                   'normal_add_2_18[0][0]',
#                                                                   'normal_add_3_18[0][0]',
#                                                                   'normal_add_4_18[0][0]',
#                                                                   'normal_add_5_18[0][0]']
#
#  activation_744 (Activation)    (None, 11, 11, 4032  0           ['normal_concat_18[0][0]']
#                                 )
#
#  global_average_pooling2d_3 (Gl  (None, 4032)        0           ['activation_744[0][0]']
#  obalAveragePooling2D)
#
#  predictions (Dense)            (None, 1000)         4033000     ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 88,949,818
# Trainable params: 88,753,150
# Non-trainable params: 196,668
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB0

# %%
EfficientNetB0 = tf.keras.applications.EfficientNetB0(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0.h5
# 21839872/21834768 [==============================] - 2s 0us/step
# 21848064/21834768 [==============================] - 2s 0us/step

# %%
model_analyze(EfficientNetB0)
# Out:
# Layers 0(-240): input_19
# Layers 1(-239): rescaling
# Layers 2(-238): normalization
# Layers 3(-237): stem_conv_pad
# Layers 4(-236): stem_conv
# Layers 5(-235): stem_bn
# Layers 6(-234): stem_activation
# Layers 7(-233): block1a_dwconv
# Layers 8(-232): block1a_bn
# Layers 9(-231): block1a_activation
# Layers 10(-230): block1a_se_squeeze
# Layers 11(-229): block1a_se_reshape
# Layers 12(-228): block1a_se_reduce
# Layers 13(-227): block1a_se_expand
# Layers 14(-226): block1a_se_excite
# Layers 15(-225): block1a_project_conv
# Layers 16(-224): block1a_project_bn
# Layers 17(-223): block2a_expand_conv
# Layers 18(-222): block2a_expand_bn
# Layers 19(-221): block2a_expand_activation
# Layers 20(-220): block2a_dwconv_pad
# Layers 21(-219): block2a_dwconv
# Layers 22(-218): block2a_bn
# Layers 23(-217): block2a_activation
# Layers 24(-216): block2a_se_squeeze
# Layers 25(-215): block2a_se_reshape
# Layers 26(-214): block2a_se_reduce
# Layers 27(-213): block2a_se_expand
# Layers 28(-212): block2a_se_excite
# Layers 29(-211): block2a_project_conv
# Layers 30(-210): block2a_project_bn
# Layers 31(-209): block2b_expand_conv
# Layers 32(-208): block2b_expand_bn
# Layers 33(-207): block2b_expand_activation
# Layers 34(-206): block2b_dwconv
# Layers 35(-205): block2b_bn
# Layers 36(-204): block2b_activation
# Layers 37(-203): block2b_se_squeeze
# Layers 38(-202): block2b_se_reshape
# Layers 39(-201): block2b_se_reduce
# Layers 40(-200): block2b_se_expand
# Layers 41(-199): block2b_se_excite
# Layers 42(-198): block2b_project_conv
# Layers 43(-197): block2b_project_bn
# Layers 44(-196): block2b_drop
# Layers 45(-195): block2b_add
# Layers 46(-194): block3a_expand_conv
# Layers 47(-193): block3a_expand_bn
# Layers 48(-192): block3a_expand_activation
# Layers 49(-191): block3a_dwconv_pad
# Layers 50(-190): block3a_dwconv
# Layers 51(-189): block3a_bn
# Layers 52(-188): block3a_activation
# Layers 53(-187): block3a_se_squeeze
# Layers 54(-186): block3a_se_reshape
# Layers 55(-185): block3a_se_reduce
# Layers 56(-184): block3a_se_expand
# Layers 57(-183): block3a_se_excite
# Layers 58(-182): block3a_project_conv
# Layers 59(-181): block3a_project_bn
# Layers 60(-180): block3b_expand_conv
# Layers 61(-179): block3b_expand_bn
# Layers 62(-178): block3b_expand_activation
# Layers 63(-177): block3b_dwconv
# Layers 64(-176): block3b_bn
# Layers 65(-175): block3b_activation
# Layers 66(-174): block3b_se_squeeze
# Layers 67(-173): block3b_se_reshape
# Layers 68(-172): block3b_se_reduce
# Layers 69(-171): block3b_se_expand
# Layers 70(-170): block3b_se_excite
# Layers 71(-169): block3b_project_conv
# Layers 72(-168): block3b_project_bn
# Layers 73(-167): block3b_drop
# Layers 74(-166): block3b_add
# Layers 75(-165): block4a_expand_conv
# Layers 76(-164): block4a_expand_bn
# Layers 77(-163): block4a_expand_activation
# Layers 78(-162): block4a_dwconv_pad
# Layers 79(-161): block4a_dwconv
# Layers 80(-160): block4a_bn
# Layers 81(-159): block4a_activation
# Layers 82(-158): block4a_se_squeeze
# Layers 83(-157): block4a_se_reshape
# Layers 84(-156): block4a_se_reduce
# Layers 85(-155): block4a_se_expand
# Layers 86(-154): block4a_se_excite
# Layers 87(-153): block4a_project_conv
# Layers 88(-152): block4a_project_bn
# Layers 89(-151): block4b_expand_conv
# Layers 90(-150): block4b_expand_bn
# Layers 91(-149): block4b_expand_activation
# Layers 92(-148): block4b_dwconv
# Layers 93(-147): block4b_bn
# Layers 94(-146): block4b_activation
# Layers 95(-145): block4b_se_squeeze
# Layers 96(-144): block4b_se_reshape
# Layers 97(-143): block4b_se_reduce
# Layers 98(-142): block4b_se_expand
# Layers 99(-141): block4b_se_excite
# Layers 100(-140): block4b_project_conv
# Layers 101(-139): block4b_project_bn
# Layers 102(-138): block4b_drop
# Layers 103(-137): block4b_add
# Layers 104(-136): block4c_expand_conv
# Layers 105(-135): block4c_expand_bn
# Layers 106(-134): block4c_expand_activation
# Layers 107(-133): block4c_dwconv
# Layers 108(-132): block4c_bn
# Layers 109(-131): block4c_activation
# Layers 110(-130): block4c_se_squeeze
# Layers 111(-129): block4c_se_reshape
# Layers 112(-128): block4c_se_reduce
# Layers 113(-127): block4c_se_expand
# Layers 114(-126): block4c_se_excite
# Layers 115(-125): block4c_project_conv
# Layers 116(-124): block4c_project_bn
# Layers 117(-123): block4c_drop
# Layers 118(-122): block4c_add
# Layers 119(-121): block5a_expand_conv
# Layers 120(-120): block5a_expand_bn
# Layers 121(-119): block5a_expand_activation
# Layers 122(-118): block5a_dwconv
# Layers 123(-117): block5a_bn
# Layers 124(-116): block5a_activation
# Layers 125(-115): block5a_se_squeeze
# Layers 126(-114): block5a_se_reshape
# Layers 127(-113): block5a_se_reduce
# Layers 128(-112): block5a_se_expand
# Layers 129(-111): block5a_se_excite
# Layers 130(-110): block5a_project_conv
# Layers 131(-109): block5a_project_bn
# Layers 132(-108): block5b_expand_conv
# Layers 133(-107): block5b_expand_bn
# Layers 134(-106): block5b_expand_activation
# Layers 135(-105): block5b_dwconv
# Layers 136(-104): block5b_bn
# Layers 137(-103): block5b_activation
# Layers 138(-102): block5b_se_squeeze
# Layers 139(-101): block5b_se_reshape
# Layers 140(-100): block5b_se_reduce
# Layers 141(-99): block5b_se_expand
# Layers 142(-98): block5b_se_excite
# Layers 143(-97): block5b_project_conv
# Layers 144(-96): block5b_project_bn
# Layers 145(-95): block5b_drop
# Layers 146(-94): block5b_add
# Layers 147(-93): block5c_expand_conv
# Layers 148(-92): block5c_expand_bn
# Layers 149(-91): block5c_expand_activation
# Layers 150(-90): block5c_dwconv
# Layers 151(-89): block5c_bn
# Layers 152(-88): block5c_activation
# Layers 153(-87): block5c_se_squeeze
# Layers 154(-86): block5c_se_reshape
# Layers 155(-85): block5c_se_reduce
# Layers 156(-84): block5c_se_expand
# Layers 157(-83): block5c_se_excite
# Layers 158(-82): block5c_project_conv
# Layers 159(-81): block5c_project_bn
# Layers 160(-80): block5c_drop
# Layers 161(-79): block5c_add
# Layers 162(-78): block6a_expand_conv
# Layers 163(-77): block6a_expand_bn
# Layers 164(-76): block6a_expand_activation
# Layers 165(-75): block6a_dwconv_pad
# Layers 166(-74): block6a_dwconv
# Layers 167(-73): block6a_bn
# Layers 168(-72): block6a_activation
# Layers 169(-71): block6a_se_squeeze
# Layers 170(-70): block6a_se_reshape
# Layers 171(-69): block6a_se_reduce
# Layers 172(-68): block6a_se_expand
# Layers 173(-67): block6a_se_excite
# Layers 174(-66): block6a_project_conv
# Layers 175(-65): block6a_project_bn
# Layers 176(-64): block6b_expand_conv
# Layers 177(-63): block6b_expand_bn
# Layers 178(-62): block6b_expand_activation
# Layers 179(-61): block6b_dwconv
# Layers 180(-60): block6b_bn
# Layers 181(-59): block6b_activation
# Layers 182(-58): block6b_se_squeeze
# Layers 183(-57): block6b_se_reshape
# Layers 184(-56): block6b_se_reduce
# Layers 185(-55): block6b_se_expand
# Layers 186(-54): block6b_se_excite
# Layers 187(-53): block6b_project_conv
# Layers 188(-52): block6b_project_bn
# Layers 189(-51): block6b_drop
# Layers 190(-50): block6b_add
# Layers 191(-49): block6c_expand_conv
# Layers 192(-48): block6c_expand_bn
# Layers 193(-47): block6c_expand_activation
# Layers 194(-46): block6c_dwconv
# Layers 195(-45): block6c_bn
# Layers 196(-44): block6c_activation
# Layers 197(-43): block6c_se_squeeze
# Layers 198(-42): block6c_se_reshape
# Layers 199(-41): block6c_se_reduce
# Layers 200(-40): block6c_se_expand
# Layers 201(-39): block6c_se_excite
# Layers 202(-38): block6c_project_conv
# Layers 203(-37): block6c_project_bn
# Layers 204(-36): block6c_drop
# Layers 205(-35): block6c_add
# Layers 206(-34): block6d_expand_conv
# Layers 207(-33): block6d_expand_bn
# Layers 208(-32): block6d_expand_activation
# Layers 209(-31): block6d_dwconv
# Layers 210(-30): block6d_bn
# Layers 211(-29): block6d_activation
# Layers 212(-28): block6d_se_squeeze
# Layers 213(-27): block6d_se_reshape
# Layers 214(-26): block6d_se_reduce
# Layers 215(-25): block6d_se_expand
# Layers 216(-24): block6d_se_excite
# Layers 217(-23): block6d_project_conv
# Layers 218(-22): block6d_project_bn
# Layers 219(-21): block6d_drop
# Layers 220(-20): block6d_add
# Layers 221(-19): block7a_expand_conv
# Layers 222(-18): block7a_expand_bn
# Layers 223(-17): block7a_expand_activation
# Layers 224(-16): block7a_dwconv
# Layers 225(-15): block7a_bn
# Layers 226(-14): block7a_activation
# Layers 227(-13): block7a_se_squeeze
# Layers 228(-12): block7a_se_reshape
# Layers 229(-11): block7a_se_reduce
# Layers 230(-10): block7a_se_expand
# Layers 231(-9): block7a_se_excite
# Layers 232(-8): block7a_project_conv
# Layers 233(-7): block7a_project_bn
# Layers 234(-6): top_conv
# Layers 235(-5): top_bn
# Layers 236(-4): top_activation
# Layers 237(-3): avg_pool
# Layers 238(-2): top_dropout
# Layers 239(-1): predictions

# %%
EfficientNetB0.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_19[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 112, 112, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block2a_expand_conv (Conv2D)   (None, 112, 112, 96  1536        ['block1a_project_bn[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 112, 112, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 112, 112, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 113, 113, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 56, 56, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 56, 56, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 56, 56, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 56, 56, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 24)   2304        ['block2a_se_excite[0][0]']
#  block2a_project_bn (BatchNorma  (None, 56, 56, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 56, 56, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 56, 56, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 56, 56, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 56, 56, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 56, 56, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 56, 56, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 56, 56, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 59, 59, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 28, 28, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 28, 28, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 28, 28, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 28, 28, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 28, 28, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 28, 28, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 28, 28, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 28, 28, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 29, 29, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 14, 14, 240)  2160       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 240)  960        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 240)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 240)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 80)   19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 80)  320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 480)  38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 480)  1920       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 480)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 14, 14, 480)  4320       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#  block4b_bn (BatchNormalization  (None, 14, 14, 480)  1920       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 480)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 480)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 80)   38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 80)  320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 14, 14, 80)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 14, 14, 80)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 480)  38400       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 480)  1920       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 480)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 14, 14, 480)  4320       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 480)  1920       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 480)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 14, 14, 480)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 14, 14, 80)   38400       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 14, 14, 80)  320         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 14, 14, 80)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 14, 14, 80)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 14, 14, 480)  38400       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 14, 14, 480)  1920       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 14, 14, 480)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 14, 14, 480)  12000      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 14, 14, 480)  1920       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 14, 14, 480)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 14, 14, 480)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 14, 14, 112)  53760       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 14, 14, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv (DepthwiseConv2  (None, 14, 14, 672)  16800      ['block5b_expand_activation[0][0]
#  D)                                                              ']
#
#  block5b_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5b_dwconv[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 14, 14, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 14, 14, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 14, 14, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 14, 14, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv (DepthwiseConv2  (None, 14, 14, 672)  16800      ['block5c_expand_activation[0][0]
#  D)                                                              ']
#
#  block5c_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5c_dwconv[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 14, 14, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#  block5c_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 14, 14, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 14, 14, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5c_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 14, 14, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, 17, 17, 672)  0          ['block6a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block6a_dwconv (DepthwiseConv2  (None, 7, 7, 672)   16800       ['block6a_dwconv_pad[0][0]']
#  D)
#
#  block6a_bn (BatchNormalization  (None, 7, 7, 672)   2688        ['block6a_dwconv[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 7, 7, 672)   0           ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 7, 7, 672)    0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 7, 7, 192)    129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6a_project_bn[0][0]']
#
#  block6b_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6b_expand_conv[0][0]']
#  ization)
#
#  block6b_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6b_expand_bn[0][0]']
#  ivation)
#
#  block6b_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  28800       ['block6b_expand_activation[0][0]
#  D)                                                              ']
#
#  block6b_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6b_dwconv[0][0]']
#  )
#
#  block6b_activation (Activation  (None, 7, 7, 1152)  0           ['block6b_bn[0][0]']
#  )
#
#  block6b_se_squeeze (GlobalAver  (None, 1152)        0           ['block6b_activation[0][0]']
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6b_activation[0][0]',
#                                                                   'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6b_se_excite[0][0]']
#
#  block6b_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6b_project_conv[0][0]']
#  lization)
#
#  block6b_drop (Dropout)         (None, 7, 7, 192)    0           ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)              (None, 7, 7, 192)    0           ['block6b_drop[0][0]',
#                                                                   'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6b_add[0][0]']
#
#  block6c_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6c_expand_conv[0][0]']
#  ization)
#
#  block6c_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6c_expand_bn[0][0]']
#  ivation)
#
#  block6c_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  28800       ['block6c_expand_activation[0][0]
#  D)                                                              ']
#
#  block6c_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6c_dwconv[0][0]']
#  )
#
#  block6c_activation (Activation  (None, 7, 7, 1152)  0           ['block6c_bn[0][0]']
#  )
#
#  block6c_se_squeeze (GlobalAver  (None, 1152)        0           ['block6c_activation[0][0]']
#  agePooling2D)
#
#  block6c_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6c_se_squeeze[0][0]']
#
#  block6c_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6c_activation[0][0]',
#                                                                   'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6c_se_excite[0][0]']
#
#  block6c_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6c_project_conv[0][0]']
#  lization)
#
#  block6c_drop (Dropout)         (None, 7, 7, 192)    0           ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)              (None, 7, 7, 192)    0           ['block6c_drop[0][0]',
#                                                                   'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6c_add[0][0]']
#
#  block6d_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6d_expand_conv[0][0]']
#  ization)
#
#  block6d_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6d_expand_bn[0][0]']
#  ivation)
#
#  block6d_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  28800       ['block6d_expand_activation[0][0]
#  D)                                                              ']
#
#  block6d_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6d_dwconv[0][0]']
#  )
#
#  block6d_activation (Activation  (None, 7, 7, 1152)  0           ['block6d_bn[0][0]']
#  )
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6d_activation[0][0]',
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 7, 7, 192)    0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 7, 7, 192)    0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6d_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 7, 7, 1152)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  10368       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 7, 7, 1152)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 7, 7, 320)    368640      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 7, 7, 320)   1280        ['block7a_project_conv[0][0]']
#  lization)
#
#  top_conv (Conv2D)              (None, 7, 7, 1280)   409600      ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1280)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1280)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         1281000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,330,571
# Trainable params: 5,288,548
# Non-trainable params: 42,023
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB1

# %%
EfficientNetB1 = tf.keras.applications.EfficientNetB1(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax"
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1.h5
# 32153600/32148312 [==============================] - 3s 0us/step
# 32161792/32148312 [==============================] - 3s 0us/step

# %%
model_analyze(EfficientNetB1)
# Out:
# Layers 0(-342): input_20
# Layers 1(-341): rescaling_1
# Layers 2(-340): normalization_1
# Layers 3(-339): stem_conv_pad
# Layers 4(-338): stem_conv
# Layers 5(-337): stem_bn
# Layers 6(-336): stem_activation
# Layers 7(-335): block1a_dwconv
# Layers 8(-334): block1a_bn
# Layers 9(-333): block1a_activation
# Layers 10(-332): block1a_se_squeeze
# Layers 11(-331): block1a_se_reshape
# Layers 12(-330): block1a_se_reduce
# Layers 13(-329): block1a_se_expand
# Layers 14(-328): block1a_se_excite
# Layers 15(-327): block1a_project_conv
# Layers 16(-326): block1a_project_bn
# Layers 17(-325): block1b_dwconv
# Layers 18(-324): block1b_bn
# Layers 19(-323): block1b_activation
# Layers 20(-322): block1b_se_squeeze
# Layers 21(-321): block1b_se_reshape
# Layers 22(-320): block1b_se_reduce
# Layers 23(-319): block1b_se_expand
# Layers 24(-318): block1b_se_excite
# Layers 25(-317): block1b_project_conv
# Layers 26(-316): block1b_project_bn
# Layers 27(-315): block1b_drop
# Layers 28(-314): block1b_add
# Layers 29(-313): block2a_expand_conv
# Layers 30(-312): block2a_expand_bn
# Layers 31(-311): block2a_expand_activation
# Layers 32(-310): block2a_dwconv_pad
# Layers 33(-309): block2a_dwconv
# Layers 34(-308): block2a_bn
# Layers 35(-307): block2a_activation
# Layers 36(-306): block2a_se_squeeze
# Layers 37(-305): block2a_se_reshape
# Layers 38(-304): block2a_se_reduce
# Layers 39(-303): block2a_se_expand
# Layers 40(-302): block2a_se_excite
# Layers 41(-301): block2a_project_conv
# Layers 42(-300): block2a_project_bn
# Layers 43(-299): block2b_expand_conv
# Layers 44(-298): block2b_expand_bn
# Layers 45(-297): block2b_expand_activation
# Layers 46(-296): block2b_dwconv
# Layers 47(-295): block2b_bn
# Layers 48(-294): block2b_activation
# Layers 49(-293): block2b_se_squeeze
# Layers 50(-292): block2b_se_reshape
# Layers 51(-291): block2b_se_reduce
# Layers 52(-290): block2b_se_expand
# Layers 53(-289): block2b_se_excite
# Layers 54(-288): block2b_project_conv
# Layers 55(-287): block2b_project_bn
# Layers 56(-286): block2b_drop
# Layers 57(-285): block2b_add
# Layers 58(-284): block2c_expand_conv
# Layers 59(-283): block2c_expand_bn
# Layers 60(-282): block2c_expand_activation
# Layers 61(-281): block2c_dwconv
# Layers 62(-280): block2c_bn
# Layers 63(-279): block2c_activation
# Layers 64(-278): block2c_se_squeeze
# Layers 65(-277): block2c_se_reshape
# Layers 66(-276): block2c_se_reduce
# Layers 67(-275): block2c_se_expand
# Layers 68(-274): block2c_se_excite
# Layers 69(-273): block2c_project_conv
# Layers 70(-272): block2c_project_bn
# Layers 71(-271): block2c_drop
# Layers 72(-270): block2c_add
# Layers 73(-269): block3a_expand_conv
# Layers 74(-268): block3a_expand_bn
# Layers 75(-267): block3a_expand_activation
# Layers 76(-266): block3a_dwconv_pad
# Layers 77(-265): block3a_dwconv
# Layers 78(-264): block3a_bn
# Layers 79(-263): block3a_activation
# Layers 80(-262): block3a_se_squeeze
# Layers 81(-261): block3a_se_reshape
# Layers 82(-260): block3a_se_reduce
# Layers 83(-259): block3a_se_expand
# Layers 84(-258): block3a_se_excite
# Layers 85(-257): block3a_project_conv
# Layers 86(-256): block3a_project_bn
# Layers 87(-255): block3b_expand_conv
# Layers 88(-254): block3b_expand_bn
# Layers 89(-253): block3b_expand_activation
# Layers 90(-252): block3b_dwconv
# Layers 91(-251): block3b_bn
# Layers 92(-250): block3b_activation
# Layers 93(-249): block3b_se_squeeze
# Layers 94(-248): block3b_se_reshape
# Layers 95(-247): block3b_se_reduce
# Layers 96(-246): block3b_se_expand
# Layers 97(-245): block3b_se_excite
# Layers 98(-244): block3b_project_conv
# Layers 99(-243): block3b_project_bn
# Layers 100(-242): block3b_drop
# Layers 101(-241): block3b_add
# Layers 102(-240): block3c_expand_conv
# Layers 103(-239): block3c_expand_bn
# Layers 104(-238): block3c_expand_activation
# Layers 105(-237): block3c_dwconv
# Layers 106(-236): block3c_bn
# Layers 107(-235): block3c_activation
# Layers 108(-234): block3c_se_squeeze
# Layers 109(-233): block3c_se_reshape
# Layers 110(-232): block3c_se_reduce
# Layers 111(-231): block3c_se_expand
# Layers 112(-230): block3c_se_excite
# Layers 113(-229): block3c_project_conv
# Layers 114(-228): block3c_project_bn
# Layers 115(-227): block3c_drop
# Layers 116(-226): block3c_add
# Layers 117(-225): block4a_expand_conv
# Layers 118(-224): block4a_expand_bn
# Layers 119(-223): block4a_expand_activation
# Layers 120(-222): block4a_dwconv_pad
# Layers 121(-221): block4a_dwconv
# Layers 122(-220): block4a_bn
# Layers 123(-219): block4a_activation
# Layers 124(-218): block4a_se_squeeze
# Layers 125(-217): block4a_se_reshape
# Layers 126(-216): block4a_se_reduce
# Layers 127(-215): block4a_se_expand
# Layers 128(-214): block4a_se_excite
# Layers 129(-213): block4a_project_conv
# Layers 130(-212): block4a_project_bn
# Layers 131(-211): block4b_expand_conv
# Layers 132(-210): block4b_expand_bn
# Layers 133(-209): block4b_expand_activation
# Layers 134(-208): block4b_dwconv
# Layers 135(-207): block4b_bn
# Layers 136(-206): block4b_activation
# Layers 137(-205): block4b_se_squeeze
# Layers 138(-204): block4b_se_reshape
# Layers 139(-203): block4b_se_reduce
# Layers 140(-202): block4b_se_expand
# Layers 141(-201): block4b_se_excite
# Layers 142(-200): block4b_project_conv
# Layers 143(-199): block4b_project_bn
# Layers 144(-198): block4b_drop
# Layers 145(-197): block4b_add
# Layers 146(-196): block4c_expand_conv
# Layers 147(-195): block4c_expand_bn
# Layers 148(-194): block4c_expand_activation
# Layers 149(-193): block4c_dwconv
# Layers 150(-192): block4c_bn
# Layers 151(-191): block4c_activation
# Layers 152(-190): block4c_se_squeeze
# Layers 153(-189): block4c_se_reshape
# Layers 154(-188): block4c_se_reduce
# Layers 155(-187): block4c_se_expand
# Layers 156(-186): block4c_se_excite
# Layers 157(-185): block4c_project_conv
# Layers 158(-184): block4c_project_bn
# Layers 159(-183): block4c_drop
# Layers 160(-182): block4c_add
# Layers 161(-181): block4d_expand_conv
# Layers 162(-180): block4d_expand_bn
# Layers 163(-179): block4d_expand_activation
# Layers 164(-178): block4d_dwconv
# Layers 165(-177): block4d_bn
# Layers 166(-176): block4d_activation
# Layers 167(-175): block4d_se_squeeze
# Layers 168(-174): block4d_se_reshape
# Layers 169(-173): block4d_se_reduce
# Layers 170(-172): block4d_se_expand
# Layers 171(-171): block4d_se_excite
# Layers 172(-170): block4d_project_conv
# Layers 173(-169): block4d_project_bn
# Layers 174(-168): block4d_drop
# Layers 175(-167): block4d_add
# Layers 176(-166): block5a_expand_conv
# Layers 177(-165): block5a_expand_bn
# Layers 178(-164): block5a_expand_activation
# Layers 179(-163): block5a_dwconv
# Layers 180(-162): block5a_bn
# Layers 181(-161): block5a_activation
# Layers 182(-160): block5a_se_squeeze
# Layers 183(-159): block5a_se_reshape
# Layers 184(-158): block5a_se_reduce
# Layers 185(-157): block5a_se_expand
# Layers 186(-156): block5a_se_excite
# Layers 187(-155): block5a_project_conv
# Layers 188(-154): block5a_project_bn
# Layers 189(-153): block5b_expand_conv
# Layers 190(-152): block5b_expand_bn
# Layers 191(-151): block5b_expand_activation
# Layers 192(-150): block5b_dwconv
# Layers 193(-149): block5b_bn
# Layers 194(-148): block5b_activation
# Layers 195(-147): block5b_se_squeeze
# Layers 196(-146): block5b_se_reshape
# Layers 197(-145): block5b_se_reduce
# Layers 198(-144): block5b_se_expand
# Layers 199(-143): block5b_se_excite
# Layers 200(-142): block5b_project_conv
# Layers 201(-141): block5b_project_bn
# Layers 202(-140): block5b_drop
# Layers 203(-139): block5b_add
# Layers 204(-138): block5c_expand_conv
# Layers 205(-137): block5c_expand_bn
# Layers 206(-136): block5c_expand_activation
# Layers 207(-135): block5c_dwconv
# Layers 208(-134): block5c_bn
# Layers 209(-133): block5c_activation
# Layers 210(-132): block5c_se_squeeze
# Layers 211(-131): block5c_se_reshape
# Layers 212(-130): block5c_se_reduce
# Layers 213(-129): block5c_se_expand
# Layers 214(-128): block5c_se_excite
# Layers 215(-127): block5c_project_conv
# Layers 216(-126): block5c_project_bn
# Layers 217(-125): block5c_drop
# Layers 218(-124): block5c_add
# Layers 219(-123): block5d_expand_conv
# Layers 220(-122): block5d_expand_bn
# Layers 221(-121): block5d_expand_activation
# Layers 222(-120): block5d_dwconv
# Layers 223(-119): block5d_bn
# Layers 224(-118): block5d_activation
# Layers 225(-117): block5d_se_squeeze
# Layers 226(-116): block5d_se_reshape
# Layers 227(-115): block5d_se_reduce
# Layers 228(-114): block5d_se_expand
# Layers 229(-113): block5d_se_excite
# Layers 230(-112): block5d_project_conv
# Layers 231(-111): block5d_project_bn
# Layers 232(-110): block5d_drop
# Layers 233(-109): block5d_add
# Layers 234(-108): block6a_expand_conv
# Layers 235(-107): block6a_expand_bn
# Layers 236(-106): block6a_expand_activation
# Layers 237(-105): block6a_dwconv_pad
# Layers 238(-104): block6a_dwconv
# Layers 239(-103): block6a_bn
# Layers 240(-102): block6a_activation
# Layers 241(-101): block6a_se_squeeze
# Layers 242(-100): block6a_se_reshape
# Layers 243(-99): block6a_se_reduce
# Layers 244(-98): block6a_se_expand
# Layers 245(-97): block6a_se_excite
# Layers 246(-96): block6a_project_conv
# Layers 247(-95): block6a_project_bn
# Layers 248(-94): block6b_expand_conv
# Layers 249(-93): block6b_expand_bn
# Layers 250(-92): block6b_expand_activation
# Layers 251(-91): block6b_dwconv
# Layers 252(-90): block6b_bn
# Layers 253(-89): block6b_activation
# Layers 254(-88): block6b_se_squeeze
# Layers 255(-87): block6b_se_reshape
# Layers 256(-86): block6b_se_reduce
# Layers 257(-85): block6b_se_expand
# Layers 258(-84): block6b_se_excite
# Layers 259(-83): block6b_project_conv
# Layers 260(-82): block6b_project_bn
# Layers 261(-81): block6b_drop
# Layers 262(-80): block6b_add
# Layers 263(-79): block6c_expand_conv
# Layers 264(-78): block6c_expand_bn
# Layers 265(-77): block6c_expand_activation
# Layers 266(-76): block6c_dwconv
# Layers 267(-75): block6c_bn
# Layers 268(-74): block6c_activation
# Layers 269(-73): block6c_se_squeeze
# Layers 270(-72): block6c_se_reshape
# Layers 271(-71): block6c_se_reduce
# Layers 272(-70): block6c_se_expand
# Layers 273(-69): block6c_se_excite
# Layers 274(-68): block6c_project_conv
# Layers 275(-67): block6c_project_bn
# Layers 276(-66): block6c_drop
# Layers 277(-65): block6c_add
# Layers 278(-64): block6d_expand_conv
# Layers 279(-63): block6d_expand_bn
# Layers 280(-62): block6d_expand_activation
# Layers 281(-61): block6d_dwconv
# Layers 282(-60): block6d_bn
# Layers 283(-59): block6d_activation
# Layers 284(-58): block6d_se_squeeze
# Layers 285(-57): block6d_se_reshape
# Layers 286(-56): block6d_se_reduce
# Layers 287(-55): block6d_se_expand
# Layers 288(-54): block6d_se_excite
# Layers 289(-53): block6d_project_conv
# Layers 290(-52): block6d_project_bn
# Layers 291(-51): block6d_drop
# Layers 292(-50): block6d_add
# Layers 293(-49): block6e_expand_conv
# Layers 294(-48): block6e_expand_bn
# Layers 295(-47): block6e_expand_activation
# Layers 296(-46): block6e_dwconv
# Layers 297(-45): block6e_bn
# Layers 298(-44): block6e_activation
# Layers 299(-43): block6e_se_squeeze
# Layers 300(-42): block6e_se_reshape
# Layers 301(-41): block6e_se_reduce
# Layers 302(-40): block6e_se_expand
# Layers 303(-39): block6e_se_excite
# Layers 304(-38): block6e_project_conv
# Layers 305(-37): block6e_project_bn
# Layers 306(-36): block6e_drop
# Layers 307(-35): block6e_add
# Layers 308(-34): block7a_expand_conv
# Layers 309(-33): block7a_expand_bn
# Layers 310(-32): block7a_expand_activation
# Layers 311(-31): block7a_dwconv
# Layers 312(-30): block7a_bn
# Layers 313(-29): block7a_activation
# Layers 314(-28): block7a_se_squeeze
# Layers 315(-27): block7a_se_reshape
# Layers 316(-26): block7a_se_reduce
# Layers 317(-25): block7a_se_expand
# Layers 318(-24): block7a_se_excite
# Layers 319(-23): block7a_project_conv
# Layers 320(-22): block7a_project_bn
# Layers 321(-21): block7b_expand_conv
# Layers 322(-20): block7b_expand_bn
# Layers 323(-19): block7b_expand_activation
# Layers 324(-18): block7b_dwconv
# Layers 325(-17): block7b_bn
# Layers 326(-16): block7b_activation
# Layers 327(-15): block7b_se_squeeze
# Layers 328(-14): block7b_se_reshape
# Layers 329(-13): block7b_se_reduce
# Layers 330(-12): block7b_se_expand
# Layers 331(-11): block7b_se_excite
# Layers 332(-10): block7b_project_conv
# Layers 333(-9): block7b_project_bn
# Layers 334(-8): block7b_drop
# Layers 335(-7): block7b_add
# Layers 336(-6): top_conv
# Layers 337(-5): top_bn
# Layers 338(-4): top_activation
# Layers 339(-3): avg_pool
# Layers 340(-2): top_dropout
# Layers 341(-1): predictions

# %%
EfficientNetB1.summary()
# Out:
# Model: "efficientnetb1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 240, 240, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 240, 240, 3)  0           ['input_20[0][0]']
#
#  normalization_1 (Normalization  (None, 240, 240, 3)  7          ['rescaling_1[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 241, 241, 3)  0           ['normalization_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 120, 120, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 120, 120, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 120, 120, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 120, 120, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 120, 120, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 120, 120, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 120, 120, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 120, 120, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 120, 120, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 120, 120, 16  144        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 120, 120, 16  64         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 120, 120, 16  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 16)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 16)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 4)      68          ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 16)     80          ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 120, 120, 16  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 120, 120, 16  256         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 120, 120, 16  64         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 120, 120, 16  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 120, 120, 16  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 120, 120, 96  1536        ['block1b_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 120, 120, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 120, 120, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 121, 121, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 60, 60, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 60, 60, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 60, 60, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 60, 60, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 60, 60, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 60, 60, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 60, 60, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 60, 60, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 60, 60, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 60, 60, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 60, 60, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 60, 60, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 60, 60, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 60, 60, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 60, 60, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 60, 60, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 60, 60, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 60, 60, 144)  3456        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 60, 60, 144)  576        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 60, 60, 144)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 60, 60, 144)  1296       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 60, 60, 144)  576        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 60, 60, 144)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 144)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 60, 60, 144)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 60, 60, 24)   3456        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 60, 60, 24)  96          ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 60, 60, 24)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 60, 60, 24)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 60, 60, 144)  3456        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 60, 60, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 60, 60, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 63, 63, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 30, 30, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 30, 30, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 30, 30, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 30, 30, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 30, 30, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 30, 30, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 30, 30, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 30, 30, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 30, 30, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 30, 30, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 30, 30, 240)  960        ['block3b_dwconv[0][0]']
#  )
#  block3b_activation (Activation  (None, 30, 30, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 30, 30, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 30, 30, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 30, 30, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 30, 30, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 30, 30, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 30, 30, 240)  9600        ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 30, 30, 240)  960        ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 30, 30, 240)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 30, 30, 240)  6000       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 30, 30, 240)  960        ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 30, 30, 240)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 240)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 30, 30, 240)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 30, 30, 40)   9600        ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 30, 30, 40)  160         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 30, 30, 40)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 30, 30, 40)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 30, 30, 240)  9600        ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 30, 30, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 30, 30, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 31, 31, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 15, 15, 240)  2160       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 15, 15, 240)  960        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 15, 15, 240)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 15, 15, 240)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 15, 15, 80)   19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 15, 15, 80)  320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 15, 15, 480)  38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 15, 15, 480)  1920       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 15, 15, 480)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 15, 15, 480)  4320       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 15, 15, 480)  1920       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 15, 15, 480)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 15, 15, 480)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 15, 15, 80)   38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 15, 15, 80)  320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 15, 15, 80)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 15, 15, 80)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 15, 15, 480)  38400       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 15, 15, 480)  1920       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 15, 15, 480)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 15, 15, 480)  4320       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 15, 15, 480)  1920       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 15, 15, 480)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#  block4c_se_excite (Multiply)   (None, 15, 15, 480)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 15, 15, 80)   38400       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 15, 15, 80)  320         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 15, 15, 80)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 15, 15, 80)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 15, 15, 480)  38400       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 15, 15, 480)  1920       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 15, 15, 480)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 15, 15, 480)  4320       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 15, 15, 480)  1920       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 15, 15, 480)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 480)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 15, 15, 480)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 15, 15, 80)   38400       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 15, 15, 80)  320         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 15, 15, 80)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 15, 15, 80)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 15, 15, 480)  38400       ['block4d_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 15, 15, 480)  1920       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 15, 15, 480)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 15, 15, 480)  12000      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 15, 15, 480)  1920       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 15, 15, 480)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
# ...
#  ization)
#
#  block6d_expand_activation (Act  (None, 8, 8, 1152)  0           ['block6d_expand_bn[0][0]']
#  ivation)
#
#  block6d_dwconv (DepthwiseConv2  (None, 8, 8, 1152)  28800       ['block6d_expand_activation[0][0]
#  D)                                                              ']
#
#  block6d_bn (BatchNormalization  (None, 8, 8, 1152)  4608        ['block6d_dwconv[0][0]']
#  )
#  block6d_activation (Activation  (None, 8, 8, 1152)  0           ['block6d_bn[0][0]']
#  )
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 8, 8, 1152)   0           ['block6d_activation[0][0]',
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 8, 8, 192)    221184      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 8, 8, 192)   768         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 8, 8, 192)    0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 8, 8, 192)    0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2D)   (None, 8, 8, 1152)   221184      ['block6d_add[0][0]']
#
#  block6e_expand_bn (BatchNormal  (None, 8, 8, 1152)  4608        ['block6e_expand_conv[0][0]']
#  ization)
#
#  block6e_expand_activation (Act  (None, 8, 8, 1152)  0           ['block6e_expand_bn[0][0]']
#  ivation)
#
#  block6e_dwconv (DepthwiseConv2  (None, 8, 8, 1152)  28800       ['block6e_expand_activation[0][0]
#  D)                                                              ']
#
#  block6e_bn (BatchNormalization  (None, 8, 8, 1152)  4608        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 8, 8, 1152)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1152)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 8, 8, 1152)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 8, 8, 192)    221184      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 8, 8, 192)   768         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 8, 8, 192)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 8, 8, 192)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 8, 8, 1152)   221184      ['block6e_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 8, 8, 1152)  4608        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 8, 8, 1152)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 8, 8, 1152)  10368       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 8, 8, 1152)  4608        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 8, 8, 1152)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 8, 8, 1152)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 8, 8, 320)    368640      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 8, 8, 320)   1280        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 8, 8, 1920)   614400      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 8, 8, 1920)  7680        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 8, 8, 1920)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 8, 8, 1920)  17280       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 8, 8, 1920)  7680        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 8, 8, 1920)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 1920)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 1920)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 80)     153680      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 1920)   155520      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 8, 8, 1920)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 8, 8, 320)    614400      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 8, 8, 320)   1280        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 8, 8, 320)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 8, 8, 320)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 8, 8, 1280)   409600      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 8, 8, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 8, 8, 1280)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1280)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         1281000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,856,239
# Trainable params: 7,794,184
# Non-trainable params: 62,055
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB2

# %%
EfficientNetB2 = tf.keras.applications.EfficientNetB2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2.h5
# 37437440/37432240 [==============================] - 4s 0us/step
# 37445632/37432240 [==============================] - 4s 0us/step

# %%
model_analyze(EfficientNetB2)
# Out:
# Layers 0(-342): input_21
# Layers 1(-341): rescaling_2
# Layers 2(-340): normalization_2
# Layers 3(-339): stem_conv_pad
# Layers 4(-338): stem_conv
# Layers 5(-337): stem_bn
# Layers 6(-336): stem_activation
# Layers 7(-335): block1a_dwconv
# Layers 8(-334): block1a_bn
# Layers 9(-333): block1a_activation
# Layers 10(-332): block1a_se_squeeze
# Layers 11(-331): block1a_se_reshape
# Layers 12(-330): block1a_se_reduce
# Layers 13(-329): block1a_se_expand
# Layers 14(-328): block1a_se_excite
# Layers 15(-327): block1a_project_conv
# Layers 16(-326): block1a_project_bn
# Layers 17(-325): block1b_dwconv
# Layers 18(-324): block1b_bn
# Layers 19(-323): block1b_activation
# Layers 20(-322): block1b_se_squeeze
# Layers 21(-321): block1b_se_reshape
# Layers 22(-320): block1b_se_reduce
# Layers 23(-319): block1b_se_expand
# Layers 24(-318): block1b_se_excite
# Layers 25(-317): block1b_project_conv
# Layers 26(-316): block1b_project_bn
# Layers 27(-315): block1b_drop
# Layers 28(-314): block1b_add
# Layers 29(-313): block2a_expand_conv
# Layers 30(-312): block2a_expand_bn
# Layers 31(-311): block2a_expand_activation
# Layers 32(-310): block2a_dwconv_pad
# Layers 33(-309): block2a_dwconv
# Layers 34(-308): block2a_bn
# Layers 35(-307): block2a_activation
# Layers 36(-306): block2a_se_squeeze
# Layers 37(-305): block2a_se_reshape
# Layers 38(-304): block2a_se_reduce
# Layers 39(-303): block2a_se_expand
# Layers 40(-302): block2a_se_excite
# Layers 41(-301): block2a_project_conv
# Layers 42(-300): block2a_project_bn
# Layers 43(-299): block2b_expand_conv
# Layers 44(-298): block2b_expand_bn
# Layers 45(-297): block2b_expand_activation
# Layers 46(-296): block2b_dwconv
# Layers 47(-295): block2b_bn
# Layers 48(-294): block2b_activation
# Layers 49(-293): block2b_se_squeeze
# Layers 50(-292): block2b_se_reshape
# Layers 51(-291): block2b_se_reduce
# Layers 52(-290): block2b_se_expand
# Layers 53(-289): block2b_se_excite
# Layers 54(-288): block2b_project_conv
# Layers 55(-287): block2b_project_bn
# Layers 56(-286): block2b_drop
# Layers 57(-285): block2b_add
# Layers 58(-284): block2c_expand_conv
# Layers 59(-283): block2c_expand_bn
# Layers 60(-282): block2c_expand_activation
# Layers 61(-281): block2c_dwconv
# Layers 62(-280): block2c_bn
# Layers 63(-279): block2c_activation
# Layers 64(-278): block2c_se_squeeze
# Layers 65(-277): block2c_se_reshape
# Layers 66(-276): block2c_se_reduce
# Layers 67(-275): block2c_se_expand
# Layers 68(-274): block2c_se_excite
# Layers 69(-273): block2c_project_conv
# Layers 70(-272): block2c_project_bn
# Layers 71(-271): block2c_drop
# Layers 72(-270): block2c_add
# Layers 73(-269): block3a_expand_conv
# Layers 74(-268): block3a_expand_bn
# Layers 75(-267): block3a_expand_activation
# Layers 76(-266): block3a_dwconv_pad
# Layers 77(-265): block3a_dwconv
# Layers 78(-264): block3a_bn
# Layers 79(-263): block3a_activation
# Layers 80(-262): block3a_se_squeeze
# Layers 81(-261): block3a_se_reshape
# Layers 82(-260): block3a_se_reduce
# Layers 83(-259): block3a_se_expand
# Layers 84(-258): block3a_se_excite
# Layers 85(-257): block3a_project_conv
# Layers 86(-256): block3a_project_bn
# Layers 87(-255): block3b_expand_conv
# Layers 88(-254): block3b_expand_bn
# Layers 89(-253): block3b_expand_activation
# Layers 90(-252): block3b_dwconv
# Layers 91(-251): block3b_bn
# Layers 92(-250): block3b_activation
# Layers 93(-249): block3b_se_squeeze
# Layers 94(-248): block3b_se_reshape
# Layers 95(-247): block3b_se_reduce
# Layers 96(-246): block3b_se_expand
# Layers 97(-245): block3b_se_excite
# Layers 98(-244): block3b_project_conv
# Layers 99(-243): block3b_project_bn
# Layers 100(-242): block3b_drop
# Layers 101(-241): block3b_add
# Layers 102(-240): block3c_expand_conv
# Layers 103(-239): block3c_expand_bn
# Layers 104(-238): block3c_expand_activation
# Layers 105(-237): block3c_dwconv
# Layers 106(-236): block3c_bn
# Layers 107(-235): block3c_activation
# Layers 108(-234): block3c_se_squeeze
# Layers 109(-233): block3c_se_reshape
# Layers 110(-232): block3c_se_reduce
# Layers 111(-231): block3c_se_expand
# Layers 112(-230): block3c_se_excite
# Layers 113(-229): block3c_project_conv
# Layers 114(-228): block3c_project_bn
# Layers 115(-227): block3c_drop
# Layers 116(-226): block3c_add
# Layers 117(-225): block4a_expand_conv
# Layers 118(-224): block4a_expand_bn
# Layers 119(-223): block4a_expand_activation
# Layers 120(-222): block4a_dwconv_pad
# Layers 121(-221): block4a_dwconv
# Layers 122(-220): block4a_bn
# Layers 123(-219): block4a_activation
# Layers 124(-218): block4a_se_squeeze
# Layers 125(-217): block4a_se_reshape
# Layers 126(-216): block4a_se_reduce
# Layers 127(-215): block4a_se_expand
# Layers 128(-214): block4a_se_excite
# Layers 129(-213): block4a_project_conv
# Layers 130(-212): block4a_project_bn
# Layers 131(-211): block4b_expand_conv
# Layers 132(-210): block4b_expand_bn
# Layers 133(-209): block4b_expand_activation
# Layers 134(-208): block4b_dwconv
# Layers 135(-207): block4b_bn
# Layers 136(-206): block4b_activation
# Layers 137(-205): block4b_se_squeeze
# Layers 138(-204): block4b_se_reshape
# Layers 139(-203): block4b_se_reduce
# Layers 140(-202): block4b_se_expand
# Layers 141(-201): block4b_se_excite
# Layers 142(-200): block4b_project_conv
# Layers 143(-199): block4b_project_bn
# Layers 144(-198): block4b_drop
# Layers 145(-197): block4b_add
# Layers 146(-196): block4c_expand_conv
# Layers 147(-195): block4c_expand_bn
# Layers 148(-194): block4c_expand_activation
# Layers 149(-193): block4c_dwconv
# Layers 150(-192): block4c_bn
# Layers 151(-191): block4c_activation
# Layers 152(-190): block4c_se_squeeze
# Layers 153(-189): block4c_se_reshape
# Layers 154(-188): block4c_se_reduce
# Layers 155(-187): block4c_se_expand
# Layers 156(-186): block4c_se_excite
# Layers 157(-185): block4c_project_conv
# Layers 158(-184): block4c_project_bn
# Layers 159(-183): block4c_drop
# Layers 160(-182): block4c_add
# Layers 161(-181): block4d_expand_conv
# Layers 162(-180): block4d_expand_bn
# Layers 163(-179): block4d_expand_activation
# Layers 164(-178): block4d_dwconv
# Layers 165(-177): block4d_bn
# Layers 166(-176): block4d_activation
# Layers 167(-175): block4d_se_squeeze
# Layers 168(-174): block4d_se_reshape
# Layers 169(-173): block4d_se_reduce
# Layers 170(-172): block4d_se_expand
# Layers 171(-171): block4d_se_excite
# Layers 172(-170): block4d_project_conv
# Layers 173(-169): block4d_project_bn
# Layers 174(-168): block4d_drop
# Layers 175(-167): block4d_add
# Layers 176(-166): block5a_expand_conv
# Layers 177(-165): block5a_expand_bn
# Layers 178(-164): block5a_expand_activation
# Layers 179(-163): block5a_dwconv
# Layers 180(-162): block5a_bn
# Layers 181(-161): block5a_activation
# Layers 182(-160): block5a_se_squeeze
# Layers 183(-159): block5a_se_reshape
# Layers 184(-158): block5a_se_reduce
# Layers 185(-157): block5a_se_expand
# Layers 186(-156): block5a_se_excite
# Layers 187(-155): block5a_project_conv
# Layers 188(-154): block5a_project_bn
# Layers 189(-153): block5b_expand_conv
# Layers 190(-152): block5b_expand_bn
# Layers 191(-151): block5b_expand_activation
# Layers 192(-150): block5b_dwconv
# Layers 193(-149): block5b_bn
# Layers 194(-148): block5b_activation
# Layers 195(-147): block5b_se_squeeze
# Layers 196(-146): block5b_se_reshape
# Layers 197(-145): block5b_se_reduce
# Layers 198(-144): block5b_se_expand
# Layers 199(-143): block5b_se_excite
# Layers 200(-142): block5b_project_conv
# Layers 201(-141): block5b_project_bn
# Layers 202(-140): block5b_drop
# Layers 203(-139): block5b_add
# Layers 204(-138): block5c_expand_conv
# Layers 205(-137): block5c_expand_bn
# Layers 206(-136): block5c_expand_activation
# Layers 207(-135): block5c_dwconv
# Layers 208(-134): block5c_bn
# Layers 209(-133): block5c_activation
# Layers 210(-132): block5c_se_squeeze
# Layers 211(-131): block5c_se_reshape
# Layers 212(-130): block5c_se_reduce
# Layers 213(-129): block5c_se_expand
# Layers 214(-128): block5c_se_excite
# Layers 215(-127): block5c_project_conv
# Layers 216(-126): block5c_project_bn
# Layers 217(-125): block5c_drop
# Layers 218(-124): block5c_add
# Layers 219(-123): block5d_expand_conv
# Layers 220(-122): block5d_expand_bn
# Layers 221(-121): block5d_expand_activation
# Layers 222(-120): block5d_dwconv
# Layers 223(-119): block5d_bn
# Layers 224(-118): block5d_activation
# Layers 225(-117): block5d_se_squeeze
# Layers 226(-116): block5d_se_reshape
# Layers 227(-115): block5d_se_reduce
# Layers 228(-114): block5d_se_expand
# Layers 229(-113): block5d_se_excite
# Layers 230(-112): block5d_project_conv
# Layers 231(-111): block5d_project_bn
# Layers 232(-110): block5d_drop
# Layers 233(-109): block5d_add
# Layers 234(-108): block6a_expand_conv
# Layers 235(-107): block6a_expand_bn
# Layers 236(-106): block6a_expand_activation
# Layers 237(-105): block6a_dwconv_pad
# Layers 238(-104): block6a_dwconv
# Layers 239(-103): block6a_bn
# Layers 240(-102): block6a_activation
# Layers 241(-101): block6a_se_squeeze
# Layers 242(-100): block6a_se_reshape
# Layers 243(-99): block6a_se_reduce
# Layers 244(-98): block6a_se_expand
# Layers 245(-97): block6a_se_excite
# Layers 246(-96): block6a_project_conv
# Layers 247(-95): block6a_project_bn
# Layers 248(-94): block6b_expand_conv
# Layers 249(-93): block6b_expand_bn
# Layers 250(-92): block6b_expand_activation
# Layers 251(-91): block6b_dwconv
# Layers 252(-90): block6b_bn
# Layers 253(-89): block6b_activation
# Layers 254(-88): block6b_se_squeeze
# Layers 255(-87): block6b_se_reshape
# Layers 256(-86): block6b_se_reduce
# Layers 257(-85): block6b_se_expand
# Layers 258(-84): block6b_se_excite
# Layers 259(-83): block6b_project_conv
# Layers 260(-82): block6b_project_bn
# Layers 261(-81): block6b_drop
# Layers 262(-80): block6b_add
# Layers 263(-79): block6c_expand_conv
# Layers 264(-78): block6c_expand_bn
# Layers 265(-77): block6c_expand_activation
# Layers 266(-76): block6c_dwconv
# Layers 267(-75): block6c_bn
# Layers 268(-74): block6c_activation
# Layers 269(-73): block6c_se_squeeze
# Layers 270(-72): block6c_se_reshape
# Layers 271(-71): block6c_se_reduce
# Layers 272(-70): block6c_se_expand
# Layers 273(-69): block6c_se_excite
# Layers 274(-68): block6c_project_conv
# Layers 275(-67): block6c_project_bn
# Layers 276(-66): block6c_drop
# Layers 277(-65): block6c_add
# Layers 278(-64): block6d_expand_conv
# Layers 279(-63): block6d_expand_bn
# Layers 280(-62): block6d_expand_activation
# Layers 281(-61): block6d_dwconv
# Layers 282(-60): block6d_bn
# Layers 283(-59): block6d_activation
# Layers 284(-58): block6d_se_squeeze
# Layers 285(-57): block6d_se_reshape
# Layers 286(-56): block6d_se_reduce
# Layers 287(-55): block6d_se_expand
# Layers 288(-54): block6d_se_excite
# Layers 289(-53): block6d_project_conv
# Layers 290(-52): block6d_project_bn
# Layers 291(-51): block6d_drop
# Layers 292(-50): block6d_add
# Layers 293(-49): block6e_expand_conv
# Layers 294(-48): block6e_expand_bn
# Layers 295(-47): block6e_expand_activation
# Layers 296(-46): block6e_dwconv
# Layers 297(-45): block6e_bn
# Layers 298(-44): block6e_activation
# Layers 299(-43): block6e_se_squeeze
# Layers 300(-42): block6e_se_reshape
# Layers 301(-41): block6e_se_reduce
# Layers 302(-40): block6e_se_expand
# Layers 303(-39): block6e_se_excite
# Layers 304(-38): block6e_project_conv
# Layers 305(-37): block6e_project_bn
# Layers 306(-36): block6e_drop
# Layers 307(-35): block6e_add
# Layers 308(-34): block7a_expand_conv
# Layers 309(-33): block7a_expand_bn
# Layers 310(-32): block7a_expand_activation
# Layers 311(-31): block7a_dwconv
# Layers 312(-30): block7a_bn
# Layers 313(-29): block7a_activation
# Layers 314(-28): block7a_se_squeeze
# Layers 315(-27): block7a_se_reshape
# Layers 316(-26): block7a_se_reduce
# Layers 317(-25): block7a_se_expand
# Layers 318(-24): block7a_se_excite
# Layers 319(-23): block7a_project_conv
# Layers 320(-22): block7a_project_bn
# Layers 321(-21): block7b_expand_conv
# Layers 322(-20): block7b_expand_bn
# Layers 323(-19): block7b_expand_activation
# Layers 324(-18): block7b_dwconv
# Layers 325(-17): block7b_bn
# Layers 326(-16): block7b_activation
# Layers 327(-15): block7b_se_squeeze
# Layers 328(-14): block7b_se_reshape
# Layers 329(-13): block7b_se_reduce
# Layers 330(-12): block7b_se_expand
# Layers 331(-11): block7b_se_excite
# Layers 332(-10): block7b_project_conv
# Layers 333(-9): block7b_project_bn
# Layers 334(-8): block7b_drop
# Layers 335(-7): block7b_add
# Layers 336(-6): top_conv
# Layers 337(-5): top_bn
# Layers 338(-4): top_activation
# Layers 339(-3): avg_pool
# Layers 340(-2): top_dropout
# Layers 341(-1): predictions

# %%
EfficientNetB2.summary()
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_21 (InputLayer)          [(None, 260, 260, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 260, 260, 3)  0           ['input_21[0][0]']
#
#  normalization_2 (Normalization  (None, 260, 260, 3)  7          ['rescaling_2[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 261, 261, 3)  0           ['normalization_2[0][0]']
#
#  stem_conv (Conv2D)             (None, 130, 130, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 130, 130, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 130, 130, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 130, 130, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 130, 130, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 130, 130, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 130, 130, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 130, 130, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 130, 130, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 130, 130, 16  144        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 130, 130, 16  64         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 130, 130, 16  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 16)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 16)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 4)      68          ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 16)     80          ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 130, 130, 16  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 130, 130, 16  256         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 130, 130, 16  64         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 130, 130, 16  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 130, 130, 16  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 130, 130, 96  1536        ['block1b_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 130, 130, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 130, 130, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 131, 131, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 65, 65, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 65, 65, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 65, 65, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 65, 65, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 65, 65, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 65, 65, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 65, 65, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 65, 65, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 65, 65, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 65, 65, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 65, 65, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 65, 65, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 65, 65, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 65, 65, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 65, 65, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 65, 65, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 65, 65, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 65, 65, 144)  3456        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 65, 65, 144)  576        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 65, 65, 144)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 65, 65, 144)  1296       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 65, 65, 144)  576        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 65, 65, 144)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 144)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 65, 65, 144)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 65, 65, 24)   3456        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 65, 65, 24)  96          ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 65, 65, 24)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 65, 65, 24)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 65, 65, 144)  3456        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 65, 65, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 65, 65, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 69, 69, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 33, 33, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 33, 33, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 33, 33, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 33, 33, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 33, 33, 48)   6912        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 33, 33, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 33, 33, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 33, 33, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 33, 33, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 33, 33, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 33, 33, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#  block3b_activation (Activation  (None, 33, 33, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 33, 33, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 33, 33, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 33, 33, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 33, 33, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 33, 33, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 33, 33, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 33, 33, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 33, 33, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 33, 33, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 33, 33, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 33, 33, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 33, 33, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 33, 33, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 33, 33, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 33, 33, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 33, 33, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 33, 33, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 33, 33, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 33, 33, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 35, 35, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 17, 17, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 17, 17, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 17, 17, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 17, 17, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 17, 17, 88)   25344       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 17, 17, 88)  352         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 17, 17, 528)  46464       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 17, 17, 528)  2112       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 17, 17, 528)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 17, 17, 528)  4752       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 17, 17, 528)  2112       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 17, 17, 528)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 528)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 17, 17, 528)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 17, 17, 88)   46464       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 17, 17, 88)  352         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 17, 17, 88)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 17, 17, 88)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 17, 17, 528)  46464       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 17, 17, 528)  2112       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 17, 17, 528)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 17, 17, 528)  4752       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 17, 17, 528)  2112       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 17, 17, 528)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 528)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4c_se_reduce[0][0]']
#  block4c_se_excite (Multiply)   (None, 17, 17, 528)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 17, 17, 88)   46464       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 17, 17, 88)  352         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 17, 17, 88)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 17, 17, 88)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 17, 17, 528)  46464       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 17, 17, 528)  2112       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 17, 17, 528)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 17, 17, 528)  4752       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 17, 17, 528)  2112       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 17, 17, 528)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 528)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 17, 17, 528)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 17, 17, 88)   46464       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 17, 17, 88)  352         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 17, 17, 88)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 17, 17, 88)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 17, 17, 528)  46464       ['block4d_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 17, 17, 528)  2112       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 17, 17, 528)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 17, 17, 528)  13200      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 17, 17, 528)  2112       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 17, 17, 528)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 528)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block5a_se_squeeze[0][0]']
#
# ...
#  ization)
#
#  block6d_expand_activation (Act  (None, 9, 9, 1248)  0           ['block6d_expand_bn[0][0]']
#  ivation)
#
#  block6d_dwconv (DepthwiseConv2  (None, 9, 9, 1248)  31200       ['block6d_expand_activation[0][0]
#  D)                                                              ']
#
#  block6d_bn (BatchNormalization  (None, 9, 9, 1248)  4992        ['block6d_dwconv[0][0]']
#  )
#  block6d_activation (Activation  (None, 9, 9, 1248)  0           ['block6d_bn[0][0]']
#  )
#
#  block6d_se_squeeze (GlobalAver  (None, 1248)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 9, 9, 1248)   0           ['block6d_activation[0][0]',
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 9, 9, 208)    259584      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 9, 9, 208)   832         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 9, 9, 208)    0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 9, 9, 208)    0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2D)   (None, 9, 9, 1248)   259584      ['block6d_add[0][0]']
#
#  block6e_expand_bn (BatchNormal  (None, 9, 9, 1248)  4992        ['block6e_expand_conv[0][0]']
#  ization)
#
#  block6e_expand_activation (Act  (None, 9, 9, 1248)  0           ['block6e_expand_bn[0][0]']
#  ivation)
#
#  block6e_dwconv (DepthwiseConv2  (None, 9, 9, 1248)  31200       ['block6e_expand_activation[0][0]
#  D)                                                              ']
#
#  block6e_bn (BatchNormalization  (None, 9, 9, 1248)  4992        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 9, 9, 1248)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1248)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 9, 9, 1248)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 9, 9, 208)    259584      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 9, 9, 208)   832         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 9, 9, 208)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 9, 9, 208)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 9, 9, 1248)   259584      ['block6e_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 9, 9, 1248)  4992        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 9, 9, 1248)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 9, 9, 1248)  11232       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 9, 9, 1248)  4992        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 9, 9, 1248)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1248)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 9, 9, 1248)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 9, 9, 352)    439296      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 9, 9, 352)   1408        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 9, 9, 2112)   743424      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 9, 9, 2112)  8448        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 9, 9, 2112)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 9, 9, 2112)  19008       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 9, 9, 2112)  8448        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 9, 9, 2112)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2112)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2112)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 88)     185944      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2112)   187968      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 9, 9, 2112)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 9, 9, 352)    743424      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 9, 9, 352)   1408        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 9, 9, 352)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 9, 9, 352)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 9, 9, 1408)   495616      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 9, 9, 1408)   5632        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 9, 9, 1408)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1408)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1408)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         1409000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 9,177,569
# Trainable params: 9,109,994
# Non-trainable params: 67,575
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB3

# %%
EfficientNetB3 = tf.keras.applications.EfficientNetB3(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3.h5
# 50102272/50095040 [==============================] - 6s 0us/step
# 50110464/50095040 [==============================] - 6s 0us/step

# %%
model_analyze(EfficientNetB3)
# Out:
# Layers 0(-387): input_22
# Layers 1(-386): rescaling_3
# Layers 2(-385): normalization_3
# Layers 3(-384): stem_conv_pad
# Layers 4(-383): stem_conv
# Layers 5(-382): stem_bn
# Layers 6(-381): stem_activation
# Layers 7(-380): block1a_dwconv
# Layers 8(-379): block1a_bn
# Layers 9(-378): block1a_activation
# Layers 10(-377): block1a_se_squeeze
# Layers 11(-376): block1a_se_reshape
# Layers 12(-375): block1a_se_reduce
# Layers 13(-374): block1a_se_expand
# Layers 14(-373): block1a_se_excite
# Layers 15(-372): block1a_project_conv
# Layers 16(-371): block1a_project_bn
# Layers 17(-370): block1b_dwconv
# Layers 18(-369): block1b_bn
# Layers 19(-368): block1b_activation
# Layers 20(-367): block1b_se_squeeze
# Layers 21(-366): block1b_se_reshape
# Layers 22(-365): block1b_se_reduce
# Layers 23(-364): block1b_se_expand
# Layers 24(-363): block1b_se_excite
# Layers 25(-362): block1b_project_conv
# Layers 26(-361): block1b_project_bn
# Layers 27(-360): block1b_drop
# Layers 28(-359): block1b_add
# Layers 29(-358): block2a_expand_conv
# Layers 30(-357): block2a_expand_bn
# Layers 31(-356): block2a_expand_activation
# Layers 32(-355): block2a_dwconv_pad
# Layers 33(-354): block2a_dwconv
# Layers 34(-353): block2a_bn
# Layers 35(-352): block2a_activation
# Layers 36(-351): block2a_se_squeeze
# Layers 37(-350): block2a_se_reshape
# Layers 38(-349): block2a_se_reduce
# Layers 39(-348): block2a_se_expand
# Layers 40(-347): block2a_se_excite
# Layers 41(-346): block2a_project_conv
# Layers 42(-345): block2a_project_bn
# Layers 43(-344): block2b_expand_conv
# Layers 44(-343): block2b_expand_bn
# Layers 45(-342): block2b_expand_activation
# Layers 46(-341): block2b_dwconv
# Layers 47(-340): block2b_bn
# Layers 48(-339): block2b_activation
# Layers 49(-338): block2b_se_squeeze
# Layers 50(-337): block2b_se_reshape
# Layers 51(-336): block2b_se_reduce
# Layers 52(-335): block2b_se_expand
# Layers 53(-334): block2b_se_excite
# Layers 54(-333): block2b_project_conv
# Layers 55(-332): block2b_project_bn
# Layers 56(-331): block2b_drop
# Layers 57(-330): block2b_add
# Layers 58(-329): block2c_expand_conv
# Layers 59(-328): block2c_expand_bn
# Layers 60(-327): block2c_expand_activation
# Layers 61(-326): block2c_dwconv
# Layers 62(-325): block2c_bn
# Layers 63(-324): block2c_activation
# Layers 64(-323): block2c_se_squeeze
# Layers 65(-322): block2c_se_reshape
# Layers 66(-321): block2c_se_reduce
# Layers 67(-320): block2c_se_expand
# Layers 68(-319): block2c_se_excite
# Layers 69(-318): block2c_project_conv
# Layers 70(-317): block2c_project_bn
# Layers 71(-316): block2c_drop
# Layers 72(-315): block2c_add
# Layers 73(-314): block3a_expand_conv
# Layers 74(-313): block3a_expand_bn
# Layers 75(-312): block3a_expand_activation
# Layers 76(-311): block3a_dwconv_pad
# Layers 77(-310): block3a_dwconv
# Layers 78(-309): block3a_bn
# Layers 79(-308): block3a_activation
# Layers 80(-307): block3a_se_squeeze
# Layers 81(-306): block3a_se_reshape
# Layers 82(-305): block3a_se_reduce
# Layers 83(-304): block3a_se_expand
# Layers 84(-303): block3a_se_excite
# Layers 85(-302): block3a_project_conv
# Layers 86(-301): block3a_project_bn
# Layers 87(-300): block3b_expand_conv
# Layers 88(-299): block3b_expand_bn
# Layers 89(-298): block3b_expand_activation
# Layers 90(-297): block3b_dwconv
# Layers 91(-296): block3b_bn
# Layers 92(-295): block3b_activation
# Layers 93(-294): block3b_se_squeeze
# Layers 94(-293): block3b_se_reshape
# Layers 95(-292): block3b_se_reduce
# Layers 96(-291): block3b_se_expand
# Layers 97(-290): block3b_se_excite
# Layers 98(-289): block3b_project_conv
# Layers 99(-288): block3b_project_bn
# Layers 100(-287): block3b_drop
# Layers 101(-286): block3b_add
# Layers 102(-285): block3c_expand_conv
# Layers 103(-284): block3c_expand_bn
# Layers 104(-283): block3c_expand_activation
# Layers 105(-282): block3c_dwconv
# Layers 106(-281): block3c_bn
# Layers 107(-280): block3c_activation
# Layers 108(-279): block3c_se_squeeze
# Layers 109(-278): block3c_se_reshape
# Layers 110(-277): block3c_se_reduce
# Layers 111(-276): block3c_se_expand
# Layers 112(-275): block3c_se_excite
# Layers 113(-274): block3c_project_conv
# Layers 114(-273): block3c_project_bn
# Layers 115(-272): block3c_drop
# Layers 116(-271): block3c_add
# Layers 117(-270): block4a_expand_conv
# Layers 118(-269): block4a_expand_bn
# Layers 119(-268): block4a_expand_activation
# Layers 120(-267): block4a_dwconv_pad
# Layers 121(-266): block4a_dwconv
# Layers 122(-265): block4a_bn
# Layers 123(-264): block4a_activation
# Layers 124(-263): block4a_se_squeeze
# Layers 125(-262): block4a_se_reshape
# Layers 126(-261): block4a_se_reduce
# Layers 127(-260): block4a_se_expand
# Layers 128(-259): block4a_se_excite
# Layers 129(-258): block4a_project_conv
# Layers 130(-257): block4a_project_bn
# Layers 131(-256): block4b_expand_conv
# Layers 132(-255): block4b_expand_bn
# Layers 133(-254): block4b_expand_activation
# Layers 134(-253): block4b_dwconv
# Layers 135(-252): block4b_bn
# Layers 136(-251): block4b_activation
# Layers 137(-250): block4b_se_squeeze
# Layers 138(-249): block4b_se_reshape
# Layers 139(-248): block4b_se_reduce
# Layers 140(-247): block4b_se_expand
# Layers 141(-246): block4b_se_excite
# Layers 142(-245): block4b_project_conv
# Layers 143(-244): block4b_project_bn
# Layers 144(-243): block4b_drop
# Layers 145(-242): block4b_add
# Layers 146(-241): block4c_expand_conv
# Layers 147(-240): block4c_expand_bn
# Layers 148(-239): block4c_expand_activation
# Layers 149(-238): block4c_dwconv
# Layers 150(-237): block4c_bn
# Layers 151(-236): block4c_activation
# Layers 152(-235): block4c_se_squeeze
# Layers 153(-234): block4c_se_reshape
# Layers 154(-233): block4c_se_reduce
# Layers 155(-232): block4c_se_expand
# Layers 156(-231): block4c_se_excite
# Layers 157(-230): block4c_project_conv
# Layers 158(-229): block4c_project_bn
# Layers 159(-228): block4c_drop
# Layers 160(-227): block4c_add
# Layers 161(-226): block4d_expand_conv
# Layers 162(-225): block4d_expand_bn
# Layers 163(-224): block4d_expand_activation
# Layers 164(-223): block4d_dwconv
# Layers 165(-222): block4d_bn
# Layers 166(-221): block4d_activation
# Layers 167(-220): block4d_se_squeeze
# Layers 168(-219): block4d_se_reshape
# Layers 169(-218): block4d_se_reduce
# Layers 170(-217): block4d_se_expand
# Layers 171(-216): block4d_se_excite
# Layers 172(-215): block4d_project_conv
# Layers 173(-214): block4d_project_bn
# Layers 174(-213): block4d_drop
# Layers 175(-212): block4d_add
# Layers 176(-211): block4e_expand_conv
# Layers 177(-210): block4e_expand_bn
# Layers 178(-209): block4e_expand_activation
# Layers 179(-208): block4e_dwconv
# Layers 180(-207): block4e_bn
# Layers 181(-206): block4e_activation
# Layers 182(-205): block4e_se_squeeze
# Layers 183(-204): block4e_se_reshape
# Layers 184(-203): block4e_se_reduce
# Layers 185(-202): block4e_se_expand
# Layers 186(-201): block4e_se_excite
# Layers 187(-200): block4e_project_conv
# Layers 188(-199): block4e_project_bn
# Layers 189(-198): block4e_drop
# Layers 190(-197): block4e_add
# Layers 191(-196): block5a_expand_conv
# Layers 192(-195): block5a_expand_bn
# Layers 193(-194): block5a_expand_activation
# Layers 194(-193): block5a_dwconv
# Layers 195(-192): block5a_bn
# Layers 196(-191): block5a_activation
# Layers 197(-190): block5a_se_squeeze
# Layers 198(-189): block5a_se_reshape
# Layers 199(-188): block5a_se_reduce
# Layers 200(-187): block5a_se_expand
# Layers 201(-186): block5a_se_excite
# Layers 202(-185): block5a_project_conv
# Layers 203(-184): block5a_project_bn
# Layers 204(-183): block5b_expand_conv
# Layers 205(-182): block5b_expand_bn
# Layers 206(-181): block5b_expand_activation
# Layers 207(-180): block5b_dwconv
# Layers 208(-179): block5b_bn
# Layers 209(-178): block5b_activation
# Layers 210(-177): block5b_se_squeeze
# Layers 211(-176): block5b_se_reshape
# Layers 212(-175): block5b_se_reduce
# Layers 213(-174): block5b_se_expand
# Layers 214(-173): block5b_se_excite
# Layers 215(-172): block5b_project_conv
# Layers 216(-171): block5b_project_bn
# Layers 217(-170): block5b_drop
# Layers 218(-169): block5b_add
# Layers 219(-168): block5c_expand_conv
# Layers 220(-167): block5c_expand_bn
# Layers 221(-166): block5c_expand_activation
# Layers 222(-165): block5c_dwconv
# Layers 223(-164): block5c_bn
# Layers 224(-163): block5c_activation
# Layers 225(-162): block5c_se_squeeze
# Layers 226(-161): block5c_se_reshape
# Layers 227(-160): block5c_se_reduce
# Layers 228(-159): block5c_se_expand
# Layers 229(-158): block5c_se_excite
# Layers 230(-157): block5c_project_conv
# Layers 231(-156): block5c_project_bn
# Layers 232(-155): block5c_drop
# Layers 233(-154): block5c_add
# Layers 234(-153): block5d_expand_conv
# Layers 235(-152): block5d_expand_bn
# Layers 236(-151): block5d_expand_activation
# Layers 237(-150): block5d_dwconv
# Layers 238(-149): block5d_bn
# Layers 239(-148): block5d_activation
# Layers 240(-147): block5d_se_squeeze
# Layers 241(-146): block5d_se_reshape
# Layers 242(-145): block5d_se_reduce
# Layers 243(-144): block5d_se_expand
# Layers 244(-143): block5d_se_excite
# Layers 245(-142): block5d_project_conv
# Layers 246(-141): block5d_project_bn
# Layers 247(-140): block5d_drop
# Layers 248(-139): block5d_add
# Layers 249(-138): block5e_expand_conv
# Layers 250(-137): block5e_expand_bn
# Layers 251(-136): block5e_expand_activation
# Layers 252(-135): block5e_dwconv
# Layers 253(-134): block5e_bn
# Layers 254(-133): block5e_activation
# Layers 255(-132): block5e_se_squeeze
# Layers 256(-131): block5e_se_reshape
# Layers 257(-130): block5e_se_reduce
# Layers 258(-129): block5e_se_expand
# Layers 259(-128): block5e_se_excite
# Layers 260(-127): block5e_project_conv
# Layers 261(-126): block5e_project_bn
# Layers 262(-125): block5e_drop
# Layers 263(-124): block5e_add
# Layers 264(-123): block6a_expand_conv
# Layers 265(-122): block6a_expand_bn
# Layers 266(-121): block6a_expand_activation
# Layers 267(-120): block6a_dwconv_pad
# Layers 268(-119): block6a_dwconv
# Layers 269(-118): block6a_bn
# Layers 270(-117): block6a_activation
# Layers 271(-116): block6a_se_squeeze
# Layers 272(-115): block6a_se_reshape
# Layers 273(-114): block6a_se_reduce
# Layers 274(-113): block6a_se_expand
# Layers 275(-112): block6a_se_excite
# Layers 276(-111): block6a_project_conv
# Layers 277(-110): block6a_project_bn
# Layers 278(-109): block6b_expand_conv
# Layers 279(-108): block6b_expand_bn
# Layers 280(-107): block6b_expand_activation
# Layers 281(-106): block6b_dwconv
# Layers 282(-105): block6b_bn
# Layers 283(-104): block6b_activation
# Layers 284(-103): block6b_se_squeeze
# Layers 285(-102): block6b_se_reshape
# Layers 286(-101): block6b_se_reduce
# Layers 287(-100): block6b_se_expand
# Layers 288(-99): block6b_se_excite
# Layers 289(-98): block6b_project_conv
# Layers 290(-97): block6b_project_bn
# Layers 291(-96): block6b_drop
# Layers 292(-95): block6b_add
# Layers 293(-94): block6c_expand_conv
# Layers 294(-93): block6c_expand_bn
# Layers 295(-92): block6c_expand_activation
# Layers 296(-91): block6c_dwconv
# Layers 297(-90): block6c_bn
# Layers 298(-89): block6c_activation
# Layers 299(-88): block6c_se_squeeze
# Layers 300(-87): block6c_se_reshape
# Layers 301(-86): block6c_se_reduce
# Layers 302(-85): block6c_se_expand
# Layers 303(-84): block6c_se_excite
# Layers 304(-83): block6c_project_conv
# Layers 305(-82): block6c_project_bn
# Layers 306(-81): block6c_drop
# Layers 307(-80): block6c_add
# Layers 308(-79): block6d_expand_conv
# Layers 309(-78): block6d_expand_bn
# Layers 310(-77): block6d_expand_activation
# Layers 311(-76): block6d_dwconv
# Layers 312(-75): block6d_bn
# Layers 313(-74): block6d_activation
# Layers 314(-73): block6d_se_squeeze
# Layers 315(-72): block6d_se_reshape
# Layers 316(-71): block6d_se_reduce
# Layers 317(-70): block6d_se_expand
# Layers 318(-69): block6d_se_excite
# Layers 319(-68): block6d_project_conv
# Layers 320(-67): block6d_project_bn
# Layers 321(-66): block6d_drop
# Layers 322(-65): block6d_add
# Layers 323(-64): block6e_expand_conv
# Layers 324(-63): block6e_expand_bn
# Layers 325(-62): block6e_expand_activation
# Layers 326(-61): block6e_dwconv
# Layers 327(-60): block6e_bn
# Layers 328(-59): block6e_activation
# Layers 329(-58): block6e_se_squeeze
# Layers 330(-57): block6e_se_reshape
# Layers 331(-56): block6e_se_reduce
# Layers 332(-55): block6e_se_expand
# Layers 333(-54): block6e_se_excite
# Layers 334(-53): block6e_project_conv
# Layers 335(-52): block6e_project_bn
# Layers 336(-51): block6e_drop
# Layers 337(-50): block6e_add
# Layers 338(-49): block6f_expand_conv
# Layers 339(-48): block6f_expand_bn
# Layers 340(-47): block6f_expand_activation
# Layers 341(-46): block6f_dwconv
# Layers 342(-45): block6f_bn
# Layers 343(-44): block6f_activation
# Layers 344(-43): block6f_se_squeeze
# Layers 345(-42): block6f_se_reshape
# Layers 346(-41): block6f_se_reduce
# Layers 347(-40): block6f_se_expand
# Layers 348(-39): block6f_se_excite
# Layers 349(-38): block6f_project_conv
# Layers 350(-37): block6f_project_bn
# Layers 351(-36): block6f_drop
# Layers 352(-35): block6f_add
# Layers 353(-34): block7a_expand_conv
# Layers 354(-33): block7a_expand_bn
# Layers 355(-32): block7a_expand_activation
# Layers 356(-31): block7a_dwconv
# Layers 357(-30): block7a_bn
# Layers 358(-29): block7a_activation
# Layers 359(-28): block7a_se_squeeze
# Layers 360(-27): block7a_se_reshape
# Layers 361(-26): block7a_se_reduce
# Layers 362(-25): block7a_se_expand
# Layers 363(-24): block7a_se_excite
# Layers 364(-23): block7a_project_conv
# Layers 365(-22): block7a_project_bn
# Layers 366(-21): block7b_expand_conv
# Layers 367(-20): block7b_expand_bn
# Layers 368(-19): block7b_expand_activation
# Layers 369(-18): block7b_dwconv
# Layers 370(-17): block7b_bn
# Layers 371(-16): block7b_activation
# Layers 372(-15): block7b_se_squeeze
# Layers 373(-14): block7b_se_reshape
# Layers 374(-13): block7b_se_reduce
# Layers 375(-12): block7b_se_expand
# Layers 376(-11): block7b_se_excite
# Layers 377(-10): block7b_project_conv
# Layers 378(-9): block7b_project_bn
# Layers 379(-8): block7b_drop
# Layers 380(-7): block7b_add
# Layers 381(-6): top_conv
# Layers 382(-5): top_bn
# Layers 383(-4): top_activation
# Layers 384(-3): avg_pool
# Layers 385(-2): top_dropout
# Layers 386(-1): predictions

# %%
EfficientNetB3.summary()
# Out:
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 300, 300, 3  0           []
#                                 )]
#
#  rescaling_3 (Rescaling)        (None, 300, 300, 3)  0           ['input_22[0][0]']
#
#  normalization_3 (Normalization  (None, 300, 300, 3)  7          ['rescaling_3[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 301, 301, 3)  0           ['normalization_3[0][0]']
#
#  stem_conv (Conv2D)             (None, 150, 150, 40  1080        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 150, 150, 40  160         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 150, 150, 40  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 150, 150, 40  360        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 150, 150, 40  160        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 150, 150, 40  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 150, 150, 40  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 150, 150, 24  960         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 150, 150, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 150, 150, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 150, 150, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 150, 150, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 150, 150, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 150, 150, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 150, 150, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 150, 150, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 150, 150, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 150, 150, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 150, 150, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 150, 150, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 151, 151, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 75, 75, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 75, 75, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 75, 75, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 75, 75, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 75, 75, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 75, 75, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 75, 75, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 75, 75, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 75, 75, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 75, 75, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 75, 75, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 75, 75, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 75, 75, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 75, 75, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 75, 75, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 75, 75, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 75, 75, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 75, 75, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 75, 75, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 75, 75, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 75, 75, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 75, 75, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 79, 79, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 38, 38, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 38, 38, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 38, 38, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 38, 38, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 38, 38, 48)   9216        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 38, 38, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 38, 38, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 38, 38, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 38, 38, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 38, 38, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 38, 38, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#  block3b_activation (Activation  (None, 38, 38, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 38, 38, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 38, 38, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 38, 38, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 38, 38, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 38, 38, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 38, 38, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 38, 38, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 38, 38, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 38, 38, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 38, 38, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 38, 38, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 38, 38, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 38, 38, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 38, 38, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 38, 38, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 38, 38, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 38, 38, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 38, 38, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 38, 38, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 39, 39, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 19, 19, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 19, 19, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 19, 19, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 19, 19, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 19, 19, 96)   27648       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 19, 19, 576)  55296       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 19, 19, 576)  2304       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 19, 19, 576)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 19, 19, 576)  5184       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 19, 19, 576)  2304       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 19, 19, 576)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 19, 19, 576)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 19, 19, 96)   55296       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 19, 19, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 19, 19, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 19, 19, 576)  55296       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 19, 19, 576)  2304       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 19, 19, 576)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 19, 19, 576)  5184       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 19, 19, 576)  2304       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 19, 19, 576)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#  block4c_se_excite (Multiply)   (None, 19, 19, 576)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 19, 19, 96)   55296       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 19, 19, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 19, 19, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 19, 19, 576)  55296       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 19, 19, 576)  2304       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 19, 19, 576)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 19, 19, 576)  5184       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 19, 19, 576)  2304       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 19, 19, 576)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 19, 19, 576)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 19, 19, 96)   55296       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 19, 19, 96)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 19, 19, 96)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 19, 19, 576)  55296       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 19, 19, 576)  2304       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 19, 19, 576)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv (DepthwiseConv2  (None, 19, 19, 576)  5184       ['block4e_expand_activation[0][0]
#  D)                                                              ']
#
#  block4e_bn (BatchNormalization  (None, 19, 19, 576)  2304       ['block4e_dwconv[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 19, 19, 576)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 576)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4e_se_squeeze[0][0]']
#
# ...
#  block6e_bn (BatchNormalization  (None, 10, 10, 1392  5568       ['block6e_dwconv[0][0]']
#  )                              )
#
#  block6e_activation (Activation  (None, 10, 10, 1392  0          ['block6e_bn[0][0]']
#  )                              )
#
#  block6e_se_squeeze (GlobalAver  (None, 1392)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 10, 10, 1392  0           ['block6e_activation[0][0]',
#                                 )                                 'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 10, 10, 232)  322944      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 10, 10, 232)  928        ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 10, 10, 232)  0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 10, 10, 232)  0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 10, 10, 1392  322944      ['block6e_add[0][0]']
#                                 )
#
#  block6f_expand_bn (BatchNormal  (None, 10, 10, 1392  5568       ['block6f_expand_conv[0][0]']
#  ization)                       )
#
#  block6f_expand_activation (Act  (None, 10, 10, 1392  0          ['block6f_expand_bn[0][0]']
#  ivation)                       )
#
#  block6f_dwconv (DepthwiseConv2  (None, 10, 10, 1392  34800      ['block6f_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6f_bn (BatchNormalization  (None, 10, 10, 1392  5568       ['block6f_dwconv[0][0]']
#  )                              )
#
#  block6f_activation (Activation  (None, 10, 10, 1392  0          ['block6f_bn[0][0]']
#  )                              )
#
#  block6f_se_squeeze (GlobalAver  (None, 1392)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 10, 10, 1392  0           ['block6f_activation[0][0]',
#                                 )                                 'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 10, 10, 232)  322944      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 10, 10, 232)  928        ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 10, 10, 232)  0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 10, 10, 232)  0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 10, 10, 1392  322944      ['block6f_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 10, 10, 1392  5568       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 10, 10, 1392  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 10, 10, 1392  12528      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 10, 10, 1392  5568       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 10, 10, 1392  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1392)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 10, 10, 1392  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 10, 10, 384)  534528      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 10, 10, 384)  1536       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 10, 10, 2304  884736      ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 10, 10, 2304  9216       ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 10, 10, 2304  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 10, 10, 2304  20736      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 10, 10, 2304  9216       ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 10, 10, 2304  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 2304)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 10, 10, 2304  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 10, 10, 384)  884736      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 10, 10, 384)  1536       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 10, 10, 384)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 10, 10, 384)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 10, 10, 1536  589824      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 10, 10, 1536  6144        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 10, 10, 1536  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1536)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         1537000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 12,320,535
# Trainable params: 12,233,232
# Non-trainable params: 87,303
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB4

# %%
EfficientNetB4 = tf.keras.applications.EfficientNetB4(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4.h5
# 78872576/78864416 [==============================] - 11s 0us/step
# 78880768/78864416 [==============================] - 11s 0us/step

# %%
model_analyze(EfficientNetB4)
# Out:
# Layers 0(-477): input_23
# Layers 1(-476): rescaling_4
# Layers 2(-475): normalization_4
# Layers 3(-474): stem_conv_pad
# Layers 4(-473): stem_conv
# Layers 5(-472): stem_bn
# Layers 6(-471): stem_activation
# Layers 7(-470): block1a_dwconv
# Layers 8(-469): block1a_bn
# Layers 9(-468): block1a_activation
# Layers 10(-467): block1a_se_squeeze
# Layers 11(-466): block1a_se_reshape
# Layers 12(-465): block1a_se_reduce
# Layers 13(-464): block1a_se_expand
# Layers 14(-463): block1a_se_excite
# Layers 15(-462): block1a_project_conv
# Layers 16(-461): block1a_project_bn
# Layers 17(-460): block1b_dwconv
# Layers 18(-459): block1b_bn
# Layers 19(-458): block1b_activation
# Layers 20(-457): block1b_se_squeeze
# Layers 21(-456): block1b_se_reshape
# Layers 22(-455): block1b_se_reduce
# Layers 23(-454): block1b_se_expand
# Layers 24(-453): block1b_se_excite
# Layers 25(-452): block1b_project_conv
# Layers 26(-451): block1b_project_bn
# Layers 27(-450): block1b_drop
# Layers 28(-449): block1b_add
# Layers 29(-448): block2a_expand_conv
# Layers 30(-447): block2a_expand_bn
# Layers 31(-446): block2a_expand_activation
# Layers 32(-445): block2a_dwconv_pad
# Layers 33(-444): block2a_dwconv
# Layers 34(-443): block2a_bn
# Layers 35(-442): block2a_activation
# Layers 36(-441): block2a_se_squeeze
# Layers 37(-440): block2a_se_reshape
# Layers 38(-439): block2a_se_reduce
# Layers 39(-438): block2a_se_expand
# Layers 40(-437): block2a_se_excite
# Layers 41(-436): block2a_project_conv
# Layers 42(-435): block2a_project_bn
# Layers 43(-434): block2b_expand_conv
# Layers 44(-433): block2b_expand_bn
# Layers 45(-432): block2b_expand_activation
# Layers 46(-431): block2b_dwconv
# Layers 47(-430): block2b_bn
# Layers 48(-429): block2b_activation
# Layers 49(-428): block2b_se_squeeze
# Layers 50(-427): block2b_se_reshape
# Layers 51(-426): block2b_se_reduce
# Layers 52(-425): block2b_se_expand
# Layers 53(-424): block2b_se_excite
# Layers 54(-423): block2b_project_conv
# Layers 55(-422): block2b_project_bn
# Layers 56(-421): block2b_drop
# Layers 57(-420): block2b_add
# Layers 58(-419): block2c_expand_conv
# Layers 59(-418): block2c_expand_bn
# Layers 60(-417): block2c_expand_activation
# Layers 61(-416): block2c_dwconv
# Layers 62(-415): block2c_bn
# Layers 63(-414): block2c_activation
# Layers 64(-413): block2c_se_squeeze
# Layers 65(-412): block2c_se_reshape
# Layers 66(-411): block2c_se_reduce
# Layers 67(-410): block2c_se_expand
# Layers 68(-409): block2c_se_excite
# Layers 69(-408): block2c_project_conv
# Layers 70(-407): block2c_project_bn
# Layers 71(-406): block2c_drop
# Layers 72(-405): block2c_add
# Layers 73(-404): block2d_expand_conv
# Layers 74(-403): block2d_expand_bn
# Layers 75(-402): block2d_expand_activation
# Layers 76(-401): block2d_dwconv
# Layers 77(-400): block2d_bn
# Layers 78(-399): block2d_activation
# Layers 79(-398): block2d_se_squeeze
# Layers 80(-397): block2d_se_reshape
# Layers 81(-396): block2d_se_reduce
# Layers 82(-395): block2d_se_expand
# Layers 83(-394): block2d_se_excite
# Layers 84(-393): block2d_project_conv
# Layers 85(-392): block2d_project_bn
# Layers 86(-391): block2d_drop
# Layers 87(-390): block2d_add
# Layers 88(-389): block3a_expand_conv
# Layers 89(-388): block3a_expand_bn
# Layers 90(-387): block3a_expand_activation
# Layers 91(-386): block3a_dwconv_pad
# Layers 92(-385): block3a_dwconv
# Layers 93(-384): block3a_bn
# Layers 94(-383): block3a_activation
# Layers 95(-382): block3a_se_squeeze
# Layers 96(-381): block3a_se_reshape
# Layers 97(-380): block3a_se_reduce
# Layers 98(-379): block3a_se_expand
# Layers 99(-378): block3a_se_excite
# Layers 100(-377): block3a_project_conv
# Layers 101(-376): block3a_project_bn
# Layers 102(-375): block3b_expand_conv
# Layers 103(-374): block3b_expand_bn
# Layers 104(-373): block3b_expand_activation
# Layers 105(-372): block3b_dwconv
# Layers 106(-371): block3b_bn
# Layers 107(-370): block3b_activation
# Layers 108(-369): block3b_se_squeeze
# Layers 109(-368): block3b_se_reshape
# Layers 110(-367): block3b_se_reduce
# Layers 111(-366): block3b_se_expand
# Layers 112(-365): block3b_se_excite
# Layers 113(-364): block3b_project_conv
# Layers 114(-363): block3b_project_bn
# Layers 115(-362): block3b_drop
# Layers 116(-361): block3b_add
# Layers 117(-360): block3c_expand_conv
# Layers 118(-359): block3c_expand_bn
# Layers 119(-358): block3c_expand_activation
# Layers 120(-357): block3c_dwconv
# Layers 121(-356): block3c_bn
# Layers 122(-355): block3c_activation
# Layers 123(-354): block3c_se_squeeze
# Layers 124(-353): block3c_se_reshape
# Layers 125(-352): block3c_se_reduce
# Layers 126(-351): block3c_se_expand
# Layers 127(-350): block3c_se_excite
# Layers 128(-349): block3c_project_conv
# Layers 129(-348): block3c_project_bn
# Layers 130(-347): block3c_drop
# Layers 131(-346): block3c_add
# Layers 132(-345): block3d_expand_conv
# Layers 133(-344): block3d_expand_bn
# Layers 134(-343): block3d_expand_activation
# Layers 135(-342): block3d_dwconv
# Layers 136(-341): block3d_bn
# Layers 137(-340): block3d_activation
# Layers 138(-339): block3d_se_squeeze
# Layers 139(-338): block3d_se_reshape
# Layers 140(-337): block3d_se_reduce
# Layers 141(-336): block3d_se_expand
# Layers 142(-335): block3d_se_excite
# Layers 143(-334): block3d_project_conv
# Layers 144(-333): block3d_project_bn
# Layers 145(-332): block3d_drop
# Layers 146(-331): block3d_add
# Layers 147(-330): block4a_expand_conv
# Layers 148(-329): block4a_expand_bn
# Layers 149(-328): block4a_expand_activation
# Layers 150(-327): block4a_dwconv_pad
# Layers 151(-326): block4a_dwconv
# Layers 152(-325): block4a_bn
# Layers 153(-324): block4a_activation
# Layers 154(-323): block4a_se_squeeze
# Layers 155(-322): block4a_se_reshape
# Layers 156(-321): block4a_se_reduce
# Layers 157(-320): block4a_se_expand
# Layers 158(-319): block4a_se_excite
# Layers 159(-318): block4a_project_conv
# Layers 160(-317): block4a_project_bn
# Layers 161(-316): block4b_expand_conv
# Layers 162(-315): block4b_expand_bn
# Layers 163(-314): block4b_expand_activation
# Layers 164(-313): block4b_dwconv
# Layers 165(-312): block4b_bn
# Layers 166(-311): block4b_activation
# Layers 167(-310): block4b_se_squeeze
# Layers 168(-309): block4b_se_reshape
# Layers 169(-308): block4b_se_reduce
# Layers 170(-307): block4b_se_expand
# Layers 171(-306): block4b_se_excite
# Layers 172(-305): block4b_project_conv
# Layers 173(-304): block4b_project_bn
# Layers 174(-303): block4b_drop
# Layers 175(-302): block4b_add
# Layers 176(-301): block4c_expand_conv
# Layers 177(-300): block4c_expand_bn
# Layers 178(-299): block4c_expand_activation
# Layers 179(-298): block4c_dwconv
# Layers 180(-297): block4c_bn
# Layers 181(-296): block4c_activation
# Layers 182(-295): block4c_se_squeeze
# Layers 183(-294): block4c_se_reshape
# Layers 184(-293): block4c_se_reduce
# Layers 185(-292): block4c_se_expand
# Layers 186(-291): block4c_se_excite
# Layers 187(-290): block4c_project_conv
# Layers 188(-289): block4c_project_bn
# Layers 189(-288): block4c_drop
# Layers 190(-287): block4c_add
# Layers 191(-286): block4d_expand_conv
# Layers 192(-285): block4d_expand_bn
# Layers 193(-284): block4d_expand_activation
# Layers 194(-283): block4d_dwconv
# Layers 195(-282): block4d_bn
# Layers 196(-281): block4d_activation
# Layers 197(-280): block4d_se_squeeze
# Layers 198(-279): block4d_se_reshape
# Layers 199(-278): block4d_se_reduce
# Layers 200(-277): block4d_se_expand
# Layers 201(-276): block4d_se_excite
# Layers 202(-275): block4d_project_conv
# Layers 203(-274): block4d_project_bn
# Layers 204(-273): block4d_drop
# Layers 205(-272): block4d_add
# Layers 206(-271): block4e_expand_conv
# Layers 207(-270): block4e_expand_bn
# Layers 208(-269): block4e_expand_activation
# Layers 209(-268): block4e_dwconv
# Layers 210(-267): block4e_bn
# Layers 211(-266): block4e_activation
# Layers 212(-265): block4e_se_squeeze
# Layers 213(-264): block4e_se_reshape
# Layers 214(-263): block4e_se_reduce
# Layers 215(-262): block4e_se_expand
# Layers 216(-261): block4e_se_excite
# Layers 217(-260): block4e_project_conv
# Layers 218(-259): block4e_project_bn
# Layers 219(-258): block4e_drop
# Layers 220(-257): block4e_add
# Layers 221(-256): block4f_expand_conv
# Layers 222(-255): block4f_expand_bn
# Layers 223(-254): block4f_expand_activation
# Layers 224(-253): block4f_dwconv
# Layers 225(-252): block4f_bn
# Layers 226(-251): block4f_activation
# Layers 227(-250): block4f_se_squeeze
# Layers 228(-249): block4f_se_reshape
# Layers 229(-248): block4f_se_reduce
# Layers 230(-247): block4f_se_expand
# Layers 231(-246): block4f_se_excite
# Layers 232(-245): block4f_project_conv
# Layers 233(-244): block4f_project_bn
# Layers 234(-243): block4f_drop
# Layers 235(-242): block4f_add
# Layers 236(-241): block5a_expand_conv
# Layers 237(-240): block5a_expand_bn
# Layers 238(-239): block5a_expand_activation
# Layers 239(-238): block5a_dwconv
# Layers 240(-237): block5a_bn
# Layers 241(-236): block5a_activation
# Layers 242(-235): block5a_se_squeeze
# Layers 243(-234): block5a_se_reshape
# Layers 244(-233): block5a_se_reduce
# Layers 245(-232): block5a_se_expand
# Layers 246(-231): block5a_se_excite
# Layers 247(-230): block5a_project_conv
# Layers 248(-229): block5a_project_bn
# Layers 249(-228): block5b_expand_conv
# Layers 250(-227): block5b_expand_bn
# Layers 251(-226): block5b_expand_activation
# Layers 252(-225): block5b_dwconv
# Layers 253(-224): block5b_bn
# Layers 254(-223): block5b_activation
# Layers 255(-222): block5b_se_squeeze
# Layers 256(-221): block5b_se_reshape
# Layers 257(-220): block5b_se_reduce
# Layers 258(-219): block5b_se_expand
# Layers 259(-218): block5b_se_excite
# Layers 260(-217): block5b_project_conv
# Layers 261(-216): block5b_project_bn
# Layers 262(-215): block5b_drop
# Layers 263(-214): block5b_add
# Layers 264(-213): block5c_expand_conv
# Layers 265(-212): block5c_expand_bn
# Layers 266(-211): block5c_expand_activation
# Layers 267(-210): block5c_dwconv
# Layers 268(-209): block5c_bn
# Layers 269(-208): block5c_activation
# Layers 270(-207): block5c_se_squeeze
# Layers 271(-206): block5c_se_reshape
# Layers 272(-205): block5c_se_reduce
# Layers 273(-204): block5c_se_expand
# Layers 274(-203): block5c_se_excite
# Layers 275(-202): block5c_project_conv
# Layers 276(-201): block5c_project_bn
# Layers 277(-200): block5c_drop
# Layers 278(-199): block5c_add
# Layers 279(-198): block5d_expand_conv
# Layers 280(-197): block5d_expand_bn
# Layers 281(-196): block5d_expand_activation
# Layers 282(-195): block5d_dwconv
# Layers 283(-194): block5d_bn
# Layers 284(-193): block5d_activation
# Layers 285(-192): block5d_se_squeeze
# Layers 286(-191): block5d_se_reshape
# Layers 287(-190): block5d_se_reduce
# Layers 288(-189): block5d_se_expand
# Layers 289(-188): block5d_se_excite
# Layers 290(-187): block5d_project_conv
# Layers 291(-186): block5d_project_bn
# Layers 292(-185): block5d_drop
# Layers 293(-184): block5d_add
# Layers 294(-183): block5e_expand_conv
# Layers 295(-182): block5e_expand_bn
# Layers 296(-181): block5e_expand_activation
# Layers 297(-180): block5e_dwconv
# Layers 298(-179): block5e_bn
# Layers 299(-178): block5e_activation
# Layers 300(-177): block5e_se_squeeze
# Layers 301(-176): block5e_se_reshape
# Layers 302(-175): block5e_se_reduce
# Layers 303(-174): block5e_se_expand
# Layers 304(-173): block5e_se_excite
# Layers 305(-172): block5e_project_conv
# Layers 306(-171): block5e_project_bn
# Layers 307(-170): block5e_drop
# Layers 308(-169): block5e_add
# Layers 309(-168): block5f_expand_conv
# Layers 310(-167): block5f_expand_bn
# Layers 311(-166): block5f_expand_activation
# Layers 312(-165): block5f_dwconv
# Layers 313(-164): block5f_bn
# Layers 314(-163): block5f_activation
# Layers 315(-162): block5f_se_squeeze
# Layers 316(-161): block5f_se_reshape
# Layers 317(-160): block5f_se_reduce
# Layers 318(-159): block5f_se_expand
# Layers 319(-158): block5f_se_excite
# Layers 320(-157): block5f_project_conv
# Layers 321(-156): block5f_project_bn
# Layers 322(-155): block5f_drop
# Layers 323(-154): block5f_add
# Layers 324(-153): block6a_expand_conv
# Layers 325(-152): block6a_expand_bn
# Layers 326(-151): block6a_expand_activation
# Layers 327(-150): block6a_dwconv_pad
# Layers 328(-149): block6a_dwconv
# Layers 329(-148): block6a_bn
# Layers 330(-147): block6a_activation
# Layers 331(-146): block6a_se_squeeze
# Layers 332(-145): block6a_se_reshape
# Layers 333(-144): block6a_se_reduce
# Layers 334(-143): block6a_se_expand
# Layers 335(-142): block6a_se_excite
# Layers 336(-141): block6a_project_conv
# Layers 337(-140): block6a_project_bn
# Layers 338(-139): block6b_expand_conv
# Layers 339(-138): block6b_expand_bn
# Layers 340(-137): block6b_expand_activation
# Layers 341(-136): block6b_dwconv
# Layers 342(-135): block6b_bn
# Layers 343(-134): block6b_activation
# Layers 344(-133): block6b_se_squeeze
# Layers 345(-132): block6b_se_reshape
# Layers 346(-131): block6b_se_reduce
# Layers 347(-130): block6b_se_expand
# Layers 348(-129): block6b_se_excite
# Layers 349(-128): block6b_project_conv
# Layers 350(-127): block6b_project_bn
# Layers 351(-126): block6b_drop
# Layers 352(-125): block6b_add
# Layers 353(-124): block6c_expand_conv
# Layers 354(-123): block6c_expand_bn
# Layers 355(-122): block6c_expand_activation
# Layers 356(-121): block6c_dwconv
# Layers 357(-120): block6c_bn
# Layers 358(-119): block6c_activation
# Layers 359(-118): block6c_se_squeeze
# Layers 360(-117): block6c_se_reshape
# Layers 361(-116): block6c_se_reduce
# Layers 362(-115): block6c_se_expand
# Layers 363(-114): block6c_se_excite
# Layers 364(-113): block6c_project_conv
# Layers 365(-112): block6c_project_bn
# Layers 366(-111): block6c_drop
# Layers 367(-110): block6c_add
# Layers 368(-109): block6d_expand_conv
# Layers 369(-108): block6d_expand_bn
# Layers 370(-107): block6d_expand_activation
# Layers 371(-106): block6d_dwconv
# Layers 372(-105): block6d_bn
# Layers 373(-104): block6d_activation
# Layers 374(-103): block6d_se_squeeze
# Layers 375(-102): block6d_se_reshape
# Layers 376(-101): block6d_se_reduce
# Layers 377(-100): block6d_se_expand
# Layers 378(-99): block6d_se_excite
# Layers 379(-98): block6d_project_conv
# Layers 380(-97): block6d_project_bn
# Layers 381(-96): block6d_drop
# Layers 382(-95): block6d_add
# Layers 383(-94): block6e_expand_conv
# Layers 384(-93): block6e_expand_bn
# Layers 385(-92): block6e_expand_activation
# Layers 386(-91): block6e_dwconv
# Layers 387(-90): block6e_bn
# Layers 388(-89): block6e_activation
# Layers 389(-88): block6e_se_squeeze
# Layers 390(-87): block6e_se_reshape
# Layers 391(-86): block6e_se_reduce
# Layers 392(-85): block6e_se_expand
# Layers 393(-84): block6e_se_excite
# Layers 394(-83): block6e_project_conv
# Layers 395(-82): block6e_project_bn
# Layers 396(-81): block6e_drop
# Layers 397(-80): block6e_add
# Layers 398(-79): block6f_expand_conv
# Layers 399(-78): block6f_expand_bn
# Layers 400(-77): block6f_expand_activation
# Layers 401(-76): block6f_dwconv
# Layers 402(-75): block6f_bn
# Layers 403(-74): block6f_activation
# Layers 404(-73): block6f_se_squeeze
# Layers 405(-72): block6f_se_reshape
# Layers 406(-71): block6f_se_reduce
# Layers 407(-70): block6f_se_expand
# Layers 408(-69): block6f_se_excite
# Layers 409(-68): block6f_project_conv
# Layers 410(-67): block6f_project_bn
# Layers 411(-66): block6f_drop
# Layers 412(-65): block6f_add
# Layers 413(-64): block6g_expand_conv
# Layers 414(-63): block6g_expand_bn
# Layers 415(-62): block6g_expand_activation
# Layers 416(-61): block6g_dwconv
# Layers 417(-60): block6g_bn
# Layers 418(-59): block6g_activation
# Layers 419(-58): block6g_se_squeeze
# Layers 420(-57): block6g_se_reshape
# Layers 421(-56): block6g_se_reduce
# Layers 422(-55): block6g_se_expand
# Layers 423(-54): block6g_se_excite
# Layers 424(-53): block6g_project_conv
# Layers 425(-52): block6g_project_bn
# Layers 426(-51): block6g_drop
# Layers 427(-50): block6g_add
# Layers 428(-49): block6h_expand_conv
# Layers 429(-48): block6h_expand_bn
# Layers 430(-47): block6h_expand_activation
# Layers 431(-46): block6h_dwconv
# Layers 432(-45): block6h_bn
# Layers 433(-44): block6h_activation
# Layers 434(-43): block6h_se_squeeze
# Layers 435(-42): block6h_se_reshape
# Layers 436(-41): block6h_se_reduce
# Layers 437(-40): block6h_se_expand
# Layers 438(-39): block6h_se_excite
# Layers 439(-38): block6h_project_conv
# Layers 440(-37): block6h_project_bn
# Layers 441(-36): block6h_drop
# Layers 442(-35): block6h_add
# Layers 443(-34): block7a_expand_conv
# Layers 444(-33): block7a_expand_bn
# Layers 445(-32): block7a_expand_activation
# Layers 446(-31): block7a_dwconv
# Layers 447(-30): block7a_bn
# Layers 448(-29): block7a_activation
# Layers 449(-28): block7a_se_squeeze
# Layers 450(-27): block7a_se_reshape
# Layers 451(-26): block7a_se_reduce
# Layers 452(-25): block7a_se_expand
# Layers 453(-24): block7a_se_excite
# Layers 454(-23): block7a_project_conv
# Layers 455(-22): block7a_project_bn
# Layers 456(-21): block7b_expand_conv
# Layers 457(-20): block7b_expand_bn
# Layers 458(-19): block7b_expand_activation
# Layers 459(-18): block7b_dwconv
# Layers 460(-17): block7b_bn
# Layers 461(-16): block7b_activation
# Layers 462(-15): block7b_se_squeeze
# Layers 463(-14): block7b_se_reshape
# Layers 464(-13): block7b_se_reduce
# Layers 465(-12): block7b_se_expand
# Layers 466(-11): block7b_se_excite
# Layers 467(-10): block7b_project_conv
# Layers 468(-9): block7b_project_bn
# Layers 469(-8): block7b_drop
# Layers 470(-7): block7b_add
# Layers 471(-6): top_conv
# Layers 472(-5): top_bn
# Layers 473(-4): top_activation
# Layers 474(-3): avg_pool
# Layers 475(-2): top_dropout
# Layers 476(-1): predictions

# %%
EfficientNetB4.summary()
# Out:
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 380, 380, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 380, 380, 3)  0           ['input_23[0][0]']
#
#  normalization_4 (Normalization  (None, 380, 380, 3)  7          ['rescaling_4[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 381, 381, 3)  0           ['normalization_4[0][0]']
#
#  stem_conv (Conv2D)             (None, 190, 190, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 190, 190, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 190, 190, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 190, 190, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 190, 190, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 190, 190, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 190, 190, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 190, 190, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 190, 190, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 190, 190, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 190, 190, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 190, 190, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 190, 190, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 190, 190, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 190, 190, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 190, 190, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 190, 190, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 190, 190, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 190, 190, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 190, 190, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 191, 191, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 95, 95, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 95, 95, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 95, 95, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 95, 95, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 95, 95, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 95, 95, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 95, 95, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 95, 95, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 95, 95, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 95, 95, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 95, 95, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 95, 95, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 95, 95, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 95, 95, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 95, 95, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 95, 95, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 95, 95, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 95, 95, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 95, 95, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 95, 95, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 95, 95, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 95, 95, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 95, 95, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 95, 95, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 95, 95, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 95, 95, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 95, 95, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 95, 95, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 95, 95, 192)  6144        ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 95, 95, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 95, 95, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 95, 95, 192)  1728       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 95, 95, 192)  768        ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 95, 95, 192)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 95, 95, 192)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 95, 95, 32)   6144        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 95, 95, 32)  128         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 95, 95, 32)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 95, 95, 32)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 95, 95, 192)  6144        ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 95, 95, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 95, 95, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 99, 99, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 48, 48, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 48, 48, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 48, 48, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 48, 48, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 48, 48, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 48, 48, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 48, 48, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 48, 48, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 48, 48, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 48, 48, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 48, 48, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 48, 48, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 48, 48, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 48, 48, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 48, 48, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 48, 48, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 48, 48, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 48, 48, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 48, 48, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 48, 48, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 48, 48, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 48, 48, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 48, 48, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 48, 48, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 48, 48, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 48, 48, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 48, 48, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 48, 48, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 48, 48, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 48, 48, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 48, 48, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 48, 48, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 48, 48, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 48, 48, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 48, 48, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 48, 48, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 48, 48, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 48, 48, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 48, 48, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 48, 48, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 48, 48, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 48, 48, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 49, 49, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 24, 24, 336)  3024       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 24, 24, 336)  1344       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 24, 24, 336)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 24, 24, 336)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 24, 24, 112)  37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 24, 24, 112)  448        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 24, 24, 672)  75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 24, 24, 672)  2688       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 24, 24, 672)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 24, 24, 672)  6048       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 24, 24, 672)  2688       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 24, 24, 672)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 24, 24, 672)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 24, 24, 112)  75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 24, 24, 112)  448        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 24, 24, 112)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 24, 24, 112)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 24, 24, 672)  75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 24, 24, 672)  2688       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 24, 24, 672)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 24, 24, 672)  6048       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 24, 24, 672)  2688       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 24, 24, 672)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 672)         0           ['block4c_activation[0][0]']
#  agePooling2D)
# ...
#  )                              )
#
#  block6g_activation (Activation  (None, 12, 12, 1632  0          ['block6g_bn[0][0]']
#  )                              )
#
#  block6g_se_squeeze (GlobalAver  (None, 1632)        0           ['block6g_activation[0][0]']
#  agePooling2D)
#
#  block6g_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6g_se_squeeze[0][0]']
#
#  block6g_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multiply)   (None, 12, 12, 1632  0           ['block6g_activation[0][0]',
#                                 )                                 'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv2D)  (None, 12, 12, 272)  443904      ['block6g_se_excite[0][0]']
#
#  block6g_project_bn (BatchNorma  (None, 12, 12, 272)  1088       ['block6g_project_conv[0][0]']
#  lization)
#
#  block6g_drop (Dropout)         (None, 12, 12, 272)  0           ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)              (None, 12, 12, 272)  0           ['block6g_drop[0][0]',
#                                                                   'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2D)   (None, 12, 12, 1632  443904      ['block6g_add[0][0]']
#                                 )
#
#  block6h_expand_bn (BatchNormal  (None, 12, 12, 1632  6528       ['block6h_expand_conv[0][0]']
#  ization)                       )
#
#  block6h_expand_activation (Act  (None, 12, 12, 1632  0          ['block6h_expand_bn[0][0]']
#  ivation)                       )
#
#  block6h_dwconv (DepthwiseConv2  (None, 12, 12, 1632  40800      ['block6h_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6h_bn (BatchNormalization  (None, 12, 12, 1632  6528       ['block6h_dwconv[0][0]']
#  )                              )
#
#  block6h_activation (Activation  (None, 12, 12, 1632  0          ['block6h_bn[0][0]']
#  )                              )
#
#  block6h_se_squeeze (GlobalAver  (None, 1632)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 12, 12, 1632  0           ['block6h_activation[0][0]',
#                                 )                                 'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 12, 12, 272)  443904      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 12, 12, 272)  1088       ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 12, 12, 272)  0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 12, 12, 272)  0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 12, 12, 1632  443904      ['block6h_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 12, 12, 1632  6528       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 12, 12, 1632  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 12, 12, 1632  14688      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 12, 12, 1632  6528       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 12, 12, 1632  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1632)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 12, 12, 1632  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 12, 12, 448)  731136      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 12, 12, 448)  1792       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 12, 12, 2688  1204224     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 12, 12, 2688  10752      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 12, 12, 2688  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 12, 12, 2688  24192      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 12, 12, 2688  10752      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 12, 12, 2688  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 2688)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2688)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 112)    301168      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2688)   303744      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 12, 12, 2688  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 12, 12, 448)  1204224     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 12, 12, 448)  1792       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 12, 12, 448)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 12, 12, 448)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 12, 12, 1792  802816      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 12, 12, 1792  7168        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 12, 12, 1792  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1792)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1792)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         1793000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 19,466,823
# Trainable params: 19,341,616
# Non-trainable params: 125,207
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB5

# %%
EfficientNetB5 = tf.keras.applications.EfficientNetB5(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5.h5
# 123469824/123465288 [==============================] - 28s 0us/step
# 123478016/123465288 [==============================] - 28s 0us/step

# %%
model_analyze(EfficientNetB5)
# Out:
# Layers 0(-579): input_24
# Layers 1(-578): rescaling_5
# Layers 2(-577): normalization_5
# Layers 3(-576): stem_conv_pad
# Layers 4(-575): stem_conv
# Layers 5(-574): stem_bn
# Layers 6(-573): stem_activation
# Layers 7(-572): block1a_dwconv
# Layers 8(-571): block1a_bn
# Layers 9(-570): block1a_activation
# Layers 10(-569): block1a_se_squeeze
# Layers 11(-568): block1a_se_reshape
# Layers 12(-567): block1a_se_reduce
# Layers 13(-566): block1a_se_expand
# Layers 14(-565): block1a_se_excite
# Layers 15(-564): block1a_project_conv
# Layers 16(-563): block1a_project_bn
# Layers 17(-562): block1b_dwconv
# Layers 18(-561): block1b_bn
# Layers 19(-560): block1b_activation
# Layers 20(-559): block1b_se_squeeze
# Layers 21(-558): block1b_se_reshape
# Layers 22(-557): block1b_se_reduce
# Layers 23(-556): block1b_se_expand
# Layers 24(-555): block1b_se_excite
# Layers 25(-554): block1b_project_conv
# Layers 26(-553): block1b_project_bn
# Layers 27(-552): block1b_drop
# Layers 28(-551): block1b_add
# Layers 29(-550): block1c_dwconv
# Layers 30(-549): block1c_bn
# Layers 31(-548): block1c_activation
# Layers 32(-547): block1c_se_squeeze
# Layers 33(-546): block1c_se_reshape
# Layers 34(-545): block1c_se_reduce
# Layers 35(-544): block1c_se_expand
# Layers 36(-543): block1c_se_excite
# Layers 37(-542): block1c_project_conv
# Layers 38(-541): block1c_project_bn
# Layers 39(-540): block1c_drop
# Layers 40(-539): block1c_add
# Layers 41(-538): block2a_expand_conv
# Layers 42(-537): block2a_expand_bn
# Layers 43(-536): block2a_expand_activation
# Layers 44(-535): block2a_dwconv_pad
# Layers 45(-534): block2a_dwconv
# Layers 46(-533): block2a_bn
# Layers 47(-532): block2a_activation
# Layers 48(-531): block2a_se_squeeze
# Layers 49(-530): block2a_se_reshape
# Layers 50(-529): block2a_se_reduce
# Layers 51(-528): block2a_se_expand
# Layers 52(-527): block2a_se_excite
# Layers 53(-526): block2a_project_conv
# Layers 54(-525): block2a_project_bn
# Layers 55(-524): block2b_expand_conv
# Layers 56(-523): block2b_expand_bn
# Layers 57(-522): block2b_expand_activation
# Layers 58(-521): block2b_dwconv
# Layers 59(-520): block2b_bn
# Layers 60(-519): block2b_activation
# Layers 61(-518): block2b_se_squeeze
# Layers 62(-517): block2b_se_reshape
# Layers 63(-516): block2b_se_reduce
# Layers 64(-515): block2b_se_expand
# Layers 65(-514): block2b_se_excite
# Layers 66(-513): block2b_project_conv
# Layers 67(-512): block2b_project_bn
# Layers 68(-511): block2b_drop
# Layers 69(-510): block2b_add
# Layers 70(-509): block2c_expand_conv
# Layers 71(-508): block2c_expand_bn
# Layers 72(-507): block2c_expand_activation
# Layers 73(-506): block2c_dwconv
# Layers 74(-505): block2c_bn
# Layers 75(-504): block2c_activation
# Layers 76(-503): block2c_se_squeeze
# Layers 77(-502): block2c_se_reshape
# Layers 78(-501): block2c_se_reduce
# Layers 79(-500): block2c_se_expand
# Layers 80(-499): block2c_se_excite
# Layers 81(-498): block2c_project_conv
# Layers 82(-497): block2c_project_bn
# Layers 83(-496): block2c_drop
# Layers 84(-495): block2c_add
# Layers 85(-494): block2d_expand_conv
# Layers 86(-493): block2d_expand_bn
# Layers 87(-492): block2d_expand_activation
# Layers 88(-491): block2d_dwconv
# Layers 89(-490): block2d_bn
# Layers 90(-489): block2d_activation
# Layers 91(-488): block2d_se_squeeze
# Layers 92(-487): block2d_se_reshape
# Layers 93(-486): block2d_se_reduce
# Layers 94(-485): block2d_se_expand
# Layers 95(-484): block2d_se_excite
# Layers 96(-483): block2d_project_conv
# Layers 97(-482): block2d_project_bn
# Layers 98(-481): block2d_drop
# Layers 99(-480): block2d_add
# Layers 100(-479): block2e_expand_conv
# Layers 101(-478): block2e_expand_bn
# Layers 102(-477): block2e_expand_activation
# Layers 103(-476): block2e_dwconv
# Layers 104(-475): block2e_bn
# Layers 105(-474): block2e_activation
# Layers 106(-473): block2e_se_squeeze
# Layers 107(-472): block2e_se_reshape
# Layers 108(-471): block2e_se_reduce
# Layers 109(-470): block2e_se_expand
# Layers 110(-469): block2e_se_excite
# Layers 111(-468): block2e_project_conv
# Layers 112(-467): block2e_project_bn
# Layers 113(-466): block2e_drop
# Layers 114(-465): block2e_add
# Layers 115(-464): block3a_expand_conv
# Layers 116(-463): block3a_expand_bn
# Layers 117(-462): block3a_expand_activation
# Layers 118(-461): block3a_dwconv_pad
# Layers 119(-460): block3a_dwconv
# Layers 120(-459): block3a_bn
# Layers 121(-458): block3a_activation
# Layers 122(-457): block3a_se_squeeze
# Layers 123(-456): block3a_se_reshape
# Layers 124(-455): block3a_se_reduce
# Layers 125(-454): block3a_se_expand
# Layers 126(-453): block3a_se_excite
# Layers 127(-452): block3a_project_conv
# Layers 128(-451): block3a_project_bn
# Layers 129(-450): block3b_expand_conv
# Layers 130(-449): block3b_expand_bn
# Layers 131(-448): block3b_expand_activation
# Layers 132(-447): block3b_dwconv
# Layers 133(-446): block3b_bn
# Layers 134(-445): block3b_activation
# Layers 135(-444): block3b_se_squeeze
# Layers 136(-443): block3b_se_reshape
# Layers 137(-442): block3b_se_reduce
# Layers 138(-441): block3b_se_expand
# Layers 139(-440): block3b_se_excite
# Layers 140(-439): block3b_project_conv
# Layers 141(-438): block3b_project_bn
# Layers 142(-437): block3b_drop
# Layers 143(-436): block3b_add
# Layers 144(-435): block3c_expand_conv
# Layers 145(-434): block3c_expand_bn
# Layers 146(-433): block3c_expand_activation
# Layers 147(-432): block3c_dwconv
# Layers 148(-431): block3c_bn
# Layers 149(-430): block3c_activation
# Layers 150(-429): block3c_se_squeeze
# Layers 151(-428): block3c_se_reshape
# Layers 152(-427): block3c_se_reduce
# Layers 153(-426): block3c_se_expand
# Layers 154(-425): block3c_se_excite
# Layers 155(-424): block3c_project_conv
# Layers 156(-423): block3c_project_bn
# Layers 157(-422): block3c_drop
# Layers 158(-421): block3c_add
# Layers 159(-420): block3d_expand_conv
# Layers 160(-419): block3d_expand_bn
# Layers 161(-418): block3d_expand_activation
# Layers 162(-417): block3d_dwconv
# Layers 163(-416): block3d_bn
# Layers 164(-415): block3d_activation
# Layers 165(-414): block3d_se_squeeze
# Layers 166(-413): block3d_se_reshape
# Layers 167(-412): block3d_se_reduce
# Layers 168(-411): block3d_se_expand
# Layers 169(-410): block3d_se_excite
# Layers 170(-409): block3d_project_conv
# Layers 171(-408): block3d_project_bn
# Layers 172(-407): block3d_drop
# Layers 173(-406): block3d_add
# Layers 174(-405): block3e_expand_conv
# Layers 175(-404): block3e_expand_bn
# Layers 176(-403): block3e_expand_activation
# Layers 177(-402): block3e_dwconv
# Layers 178(-401): block3e_bn
# Layers 179(-400): block3e_activation
# Layers 180(-399): block3e_se_squeeze
# Layers 181(-398): block3e_se_reshape
# Layers 182(-397): block3e_se_reduce
# Layers 183(-396): block3e_se_expand
# Layers 184(-395): block3e_se_excite
# Layers 185(-394): block3e_project_conv
# Layers 186(-393): block3e_project_bn
# Layers 187(-392): block3e_drop
# Layers 188(-391): block3e_add
# Layers 189(-390): block4a_expand_conv
# Layers 190(-389): block4a_expand_bn
# Layers 191(-388): block4a_expand_activation
# Layers 192(-387): block4a_dwconv_pad
# Layers 193(-386): block4a_dwconv
# Layers 194(-385): block4a_bn
# Layers 195(-384): block4a_activation
# Layers 196(-383): block4a_se_squeeze
# Layers 197(-382): block4a_se_reshape
# Layers 198(-381): block4a_se_reduce
# Layers 199(-380): block4a_se_expand
# Layers 200(-379): block4a_se_excite
# Layers 201(-378): block4a_project_conv
# Layers 202(-377): block4a_project_bn
# Layers 203(-376): block4b_expand_conv
# Layers 204(-375): block4b_expand_bn
# Layers 205(-374): block4b_expand_activation
# Layers 206(-373): block4b_dwconv
# Layers 207(-372): block4b_bn
# Layers 208(-371): block4b_activation
# Layers 209(-370): block4b_se_squeeze
# Layers 210(-369): block4b_se_reshape
# Layers 211(-368): block4b_se_reduce
# Layers 212(-367): block4b_se_expand
# Layers 213(-366): block4b_se_excite
# Layers 214(-365): block4b_project_conv
# Layers 215(-364): block4b_project_bn
# Layers 216(-363): block4b_drop
# Layers 217(-362): block4b_add
# Layers 218(-361): block4c_expand_conv
# Layers 219(-360): block4c_expand_bn
# Layers 220(-359): block4c_expand_activation
# Layers 221(-358): block4c_dwconv
# Layers 222(-357): block4c_bn
# Layers 223(-356): block4c_activation
# Layers 224(-355): block4c_se_squeeze
# Layers 225(-354): block4c_se_reshape
# Layers 226(-353): block4c_se_reduce
# Layers 227(-352): block4c_se_expand
# Layers 228(-351): block4c_se_excite
# Layers 229(-350): block4c_project_conv
# Layers 230(-349): block4c_project_bn
# Layers 231(-348): block4c_drop
# Layers 232(-347): block4c_add
# Layers 233(-346): block4d_expand_conv
# Layers 234(-345): block4d_expand_bn
# Layers 235(-344): block4d_expand_activation
# Layers 236(-343): block4d_dwconv
# Layers 237(-342): block4d_bn
# Layers 238(-341): block4d_activation
# Layers 239(-340): block4d_se_squeeze
# Layers 240(-339): block4d_se_reshape
# Layers 241(-338): block4d_se_reduce
# Layers 242(-337): block4d_se_expand
# Layers 243(-336): block4d_se_excite
# Layers 244(-335): block4d_project_conv
# Layers 245(-334): block4d_project_bn
# Layers 246(-333): block4d_drop
# Layers 247(-332): block4d_add
# Layers 248(-331): block4e_expand_conv
# Layers 249(-330): block4e_expand_bn
# Layers 250(-329): block4e_expand_activation
# Layers 251(-328): block4e_dwconv
# Layers 252(-327): block4e_bn
# Layers 253(-326): block4e_activation
# Layers 254(-325): block4e_se_squeeze
# Layers 255(-324): block4e_se_reshape
# Layers 256(-323): block4e_se_reduce
# Layers 257(-322): block4e_se_expand
# Layers 258(-321): block4e_se_excite
# Layers 259(-320): block4e_project_conv
# Layers 260(-319): block4e_project_bn
# Layers 261(-318): block4e_drop
# Layers 262(-317): block4e_add
# Layers 263(-316): block4f_expand_conv
# Layers 264(-315): block4f_expand_bn
# Layers 265(-314): block4f_expand_activation
# Layers 266(-313): block4f_dwconv
# Layers 267(-312): block4f_bn
# Layers 268(-311): block4f_activation
# Layers 269(-310): block4f_se_squeeze
# Layers 270(-309): block4f_se_reshape
# Layers 271(-308): block4f_se_reduce
# Layers 272(-307): block4f_se_expand
# Layers 273(-306): block4f_se_excite
# Layers 274(-305): block4f_project_conv
# Layers 275(-304): block4f_project_bn
# Layers 276(-303): block4f_drop
# Layers 277(-302): block4f_add
# Layers 278(-301): block4g_expand_conv
# Layers 279(-300): block4g_expand_bn
# Layers 280(-299): block4g_expand_activation
# Layers 281(-298): block4g_dwconv
# Layers 282(-297): block4g_bn
# Layers 283(-296): block4g_activation
# Layers 284(-295): block4g_se_squeeze
# Layers 285(-294): block4g_se_reshape
# Layers 286(-293): block4g_se_reduce
# Layers 287(-292): block4g_se_expand
# Layers 288(-291): block4g_se_excite
# Layers 289(-290): block4g_project_conv
# Layers 290(-289): block4g_project_bn
# Layers 291(-288): block4g_drop
# Layers 292(-287): block4g_add
# Layers 293(-286): block5a_expand_conv
# Layers 294(-285): block5a_expand_bn
# Layers 295(-284): block5a_expand_activation
# Layers 296(-283): block5a_dwconv
# Layers 297(-282): block5a_bn
# Layers 298(-281): block5a_activation
# Layers 299(-280): block5a_se_squeeze
# Layers 300(-279): block5a_se_reshape
# Layers 301(-278): block5a_se_reduce
# Layers 302(-277): block5a_se_expand
# Layers 303(-276): block5a_se_excite
# Layers 304(-275): block5a_project_conv
# Layers 305(-274): block5a_project_bn
# Layers 306(-273): block5b_expand_conv
# Layers 307(-272): block5b_expand_bn
# Layers 308(-271): block5b_expand_activation
# Layers 309(-270): block5b_dwconv
# Layers 310(-269): block5b_bn
# Layers 311(-268): block5b_activation
# Layers 312(-267): block5b_se_squeeze
# Layers 313(-266): block5b_se_reshape
# Layers 314(-265): block5b_se_reduce
# Layers 315(-264): block5b_se_expand
# Layers 316(-263): block5b_se_excite
# Layers 317(-262): block5b_project_conv
# Layers 318(-261): block5b_project_bn
# Layers 319(-260): block5b_drop
# Layers 320(-259): block5b_add
# Layers 321(-258): block5c_expand_conv
# Layers 322(-257): block5c_expand_bn
# Layers 323(-256): block5c_expand_activation
# Layers 324(-255): block5c_dwconv
# Layers 325(-254): block5c_bn
# Layers 326(-253): block5c_activation
# Layers 327(-252): block5c_se_squeeze
# Layers 328(-251): block5c_se_reshape
# Layers 329(-250): block5c_se_reduce
# Layers 330(-249): block5c_se_expand
# Layers 331(-248): block5c_se_excite
# Layers 332(-247): block5c_project_conv
# Layers 333(-246): block5c_project_bn
# Layers 334(-245): block5c_drop
# Layers 335(-244): block5c_add
# Layers 336(-243): block5d_expand_conv
# Layers 337(-242): block5d_expand_bn
# Layers 338(-241): block5d_expand_activation
# Layers 339(-240): block5d_dwconv
# Layers 340(-239): block5d_bn
# Layers 341(-238): block5d_activation
# Layers 342(-237): block5d_se_squeeze
# Layers 343(-236): block5d_se_reshape
# Layers 344(-235): block5d_se_reduce
# Layers 345(-234): block5d_se_expand
# Layers 346(-233): block5d_se_excite
# Layers 347(-232): block5d_project_conv
# Layers 348(-231): block5d_project_bn
# Layers 349(-230): block5d_drop
# Layers 350(-229): block5d_add
# Layers 351(-228): block5e_expand_conv
# Layers 352(-227): block5e_expand_bn
# Layers 353(-226): block5e_expand_activation
# Layers 354(-225): block5e_dwconv
# Layers 355(-224): block5e_bn
# Layers 356(-223): block5e_activation
# Layers 357(-222): block5e_se_squeeze
# Layers 358(-221): block5e_se_reshape
# Layers 359(-220): block5e_se_reduce
# Layers 360(-219): block5e_se_expand
# Layers 361(-218): block5e_se_excite
# Layers 362(-217): block5e_project_conv
# Layers 363(-216): block5e_project_bn
# Layers 364(-215): block5e_drop
# Layers 365(-214): block5e_add
# Layers 366(-213): block5f_expand_conv
# Layers 367(-212): block5f_expand_bn
# Layers 368(-211): block5f_expand_activation
# Layers 369(-210): block5f_dwconv
# Layers 370(-209): block5f_bn
# Layers 371(-208): block5f_activation
# Layers 372(-207): block5f_se_squeeze
# Layers 373(-206): block5f_se_reshape
# Layers 374(-205): block5f_se_reduce
# Layers 375(-204): block5f_se_expand
# Layers 376(-203): block5f_se_excite
# Layers 377(-202): block5f_project_conv
# Layers 378(-201): block5f_project_bn
# Layers 379(-200): block5f_drop
# Layers 380(-199): block5f_add
# Layers 381(-198): block5g_expand_conv
# Layers 382(-197): block5g_expand_bn
# Layers 383(-196): block5g_expand_activation
# Layers 384(-195): block5g_dwconv
# Layers 385(-194): block5g_bn
# Layers 386(-193): block5g_activation
# Layers 387(-192): block5g_se_squeeze
# Layers 388(-191): block5g_se_reshape
# Layers 389(-190): block5g_se_reduce
# Layers 390(-189): block5g_se_expand
# Layers 391(-188): block5g_se_excite
# Layers 392(-187): block5g_project_conv
# Layers 393(-186): block5g_project_bn
# Layers 394(-185): block5g_drop
# Layers 395(-184): block5g_add
# Layers 396(-183): block6a_expand_conv
# Layers 397(-182): block6a_expand_bn
# Layers 398(-181): block6a_expand_activation
# Layers 399(-180): block6a_dwconv_pad
# Layers 400(-179): block6a_dwconv
# Layers 401(-178): block6a_bn
# Layers 402(-177): block6a_activation
# Layers 403(-176): block6a_se_squeeze
# Layers 404(-175): block6a_se_reshape
# Layers 405(-174): block6a_se_reduce
# Layers 406(-173): block6a_se_expand
# Layers 407(-172): block6a_se_excite
# Layers 408(-171): block6a_project_conv
# Layers 409(-170): block6a_project_bn
# Layers 410(-169): block6b_expand_conv
# Layers 411(-168): block6b_expand_bn
# Layers 412(-167): block6b_expand_activation
# Layers 413(-166): block6b_dwconv
# Layers 414(-165): block6b_bn
# Layers 415(-164): block6b_activation
# Layers 416(-163): block6b_se_squeeze
# Layers 417(-162): block6b_se_reshape
# Layers 418(-161): block6b_se_reduce
# Layers 419(-160): block6b_se_expand
# Layers 420(-159): block6b_se_excite
# Layers 421(-158): block6b_project_conv
# Layers 422(-157): block6b_project_bn
# Layers 423(-156): block6b_drop
# Layers 424(-155): block6b_add
# Layers 425(-154): block6c_expand_conv
# Layers 426(-153): block6c_expand_bn
# Layers 427(-152): block6c_expand_activation
# Layers 428(-151): block6c_dwconv
# Layers 429(-150): block6c_bn
# Layers 430(-149): block6c_activation
# Layers 431(-148): block6c_se_squeeze
# Layers 432(-147): block6c_se_reshape
# Layers 433(-146): block6c_se_reduce
# Layers 434(-145): block6c_se_expand
# Layers 435(-144): block6c_se_excite
# Layers 436(-143): block6c_project_conv
# Layers 437(-142): block6c_project_bn
# Layers 438(-141): block6c_drop
# Layers 439(-140): block6c_add
# Layers 440(-139): block6d_expand_conv
# Layers 441(-138): block6d_expand_bn
# Layers 442(-137): block6d_expand_activation
# Layers 443(-136): block6d_dwconv
# Layers 444(-135): block6d_bn
# Layers 445(-134): block6d_activation
# Layers 446(-133): block6d_se_squeeze
# Layers 447(-132): block6d_se_reshape
# Layers 448(-131): block6d_se_reduce
# Layers 449(-130): block6d_se_expand
# Layers 450(-129): block6d_se_excite
# Layers 451(-128): block6d_project_conv
# Layers 452(-127): block6d_project_bn
# Layers 453(-126): block6d_drop
# Layers 454(-125): block6d_add
# Layers 455(-124): block6e_expand_conv
# Layers 456(-123): block6e_expand_bn
# Layers 457(-122): block6e_expand_activation
# Layers 458(-121): block6e_dwconv
# Layers 459(-120): block6e_bn
# Layers 460(-119): block6e_activation
# Layers 461(-118): block6e_se_squeeze
# Layers 462(-117): block6e_se_reshape
# Layers 463(-116): block6e_se_reduce
# Layers 464(-115): block6e_se_expand
# Layers 465(-114): block6e_se_excite
# Layers 466(-113): block6e_project_conv
# Layers 467(-112): block6e_project_bn
# Layers 468(-111): block6e_drop
# Layers 469(-110): block6e_add
# Layers 470(-109): block6f_expand_conv
# Layers 471(-108): block6f_expand_bn
# Layers 472(-107): block6f_expand_activation
# Layers 473(-106): block6f_dwconv
# Layers 474(-105): block6f_bn
# Layers 475(-104): block6f_activation
# Layers 476(-103): block6f_se_squeeze
# Layers 477(-102): block6f_se_reshape
# Layers 478(-101): block6f_se_reduce
# Layers 479(-100): block6f_se_expand
# Layers 480(-99): block6f_se_excite
# Layers 481(-98): block6f_project_conv
# Layers 482(-97): block6f_project_bn
# Layers 483(-96): block6f_drop
# Layers 484(-95): block6f_add
# Layers 485(-94): block6g_expand_conv
# Layers 486(-93): block6g_expand_bn
# Layers 487(-92): block6g_expand_activation
# Layers 488(-91): block6g_dwconv
# Layers 489(-90): block6g_bn
# Layers 490(-89): block6g_activation
# Layers 491(-88): block6g_se_squeeze
# Layers 492(-87): block6g_se_reshape
# Layers 493(-86): block6g_se_reduce
# Layers 494(-85): block6g_se_expand
# Layers 495(-84): block6g_se_excite
# Layers 496(-83): block6g_project_conv
# Layers 497(-82): block6g_project_bn
# Layers 498(-81): block6g_drop
# Layers 499(-80): block6g_add
# Layers 500(-79): block6h_expand_conv
# Layers 501(-78): block6h_expand_bn
# Layers 502(-77): block6h_expand_activation
# Layers 503(-76): block6h_dwconv
# Layers 504(-75): block6h_bn
# Layers 505(-74): block6h_activation
# Layers 506(-73): block6h_se_squeeze
# Layers 507(-72): block6h_se_reshape
# Layers 508(-71): block6h_se_reduce
# Layers 509(-70): block6h_se_expand
# Layers 510(-69): block6h_se_excite
# Layers 511(-68): block6h_project_conv
# Layers 512(-67): block6h_project_bn
# Layers 513(-66): block6h_drop
# Layers 514(-65): block6h_add
# Layers 515(-64): block6i_expand_conv
# Layers 516(-63): block6i_expand_bn
# Layers 517(-62): block6i_expand_activation
# Layers 518(-61): block6i_dwconv
# Layers 519(-60): block6i_bn
# Layers 520(-59): block6i_activation
# Layers 521(-58): block6i_se_squeeze
# Layers 522(-57): block6i_se_reshape
# Layers 523(-56): block6i_se_reduce
# Layers 524(-55): block6i_se_expand
# Layers 525(-54): block6i_se_excite
# Layers 526(-53): block6i_project_conv
# Layers 527(-52): block6i_project_bn
# Layers 528(-51): block6i_drop
# Layers 529(-50): block6i_add
# Layers 530(-49): block7a_expand_conv
# Layers 531(-48): block7a_expand_bn
# Layers 532(-47): block7a_expand_activation
# Layers 533(-46): block7a_dwconv
# Layers 534(-45): block7a_bn
# Layers 535(-44): block7a_activation
# Layers 536(-43): block7a_se_squeeze
# Layers 537(-42): block7a_se_reshape
# Layers 538(-41): block7a_se_reduce
# Layers 539(-40): block7a_se_expand
# Layers 540(-39): block7a_se_excite
# Layers 541(-38): block7a_project_conv
# Layers 542(-37): block7a_project_bn
# Layers 543(-36): block7b_expand_conv
# Layers 544(-35): block7b_expand_bn
# Layers 545(-34): block7b_expand_activation
# Layers 546(-33): block7b_dwconv
# Layers 547(-32): block7b_bn
# Layers 548(-31): block7b_activation
# Layers 549(-30): block7b_se_squeeze
# Layers 550(-29): block7b_se_reshape
# Layers 551(-28): block7b_se_reduce
# Layers 552(-27): block7b_se_expand
# Layers 553(-26): block7b_se_excite
# Layers 554(-25): block7b_project_conv
# Layers 555(-24): block7b_project_bn
# Layers 556(-23): block7b_drop
# Layers 557(-22): block7b_add
# Layers 558(-21): block7c_expand_conv
# Layers 559(-20): block7c_expand_bn
# Layers 560(-19): block7c_expand_activation
# Layers 561(-18): block7c_dwconv
# Layers 562(-17): block7c_bn
# Layers 563(-16): block7c_activation
# Layers 564(-15): block7c_se_squeeze
# Layers 565(-14): block7c_se_reshape
# Layers 566(-13): block7c_se_reduce
# Layers 567(-12): block7c_se_expand
# Layers 568(-11): block7c_se_excite
# Layers 569(-10): block7c_project_conv
# Layers 570(-9): block7c_project_bn
# Layers 571(-8): block7c_drop
# Layers 572(-7): block7c_add
# Layers 573(-6): top_conv
# Layers 574(-5): top_bn
# Layers 575(-4): top_activation
# Layers 576(-3): avg_pool
# Layers 577(-2): top_dropout
# Layers 578(-1): predictions

# %%
EfficientNetB5.summary()
# Out:
# Model: "efficientnetb5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_24 (InputLayer)          [(None, 456, 456, 3  0           []
#                                 )]
#
#  rescaling_5 (Rescaling)        (None, 456, 456, 3)  0           ['input_24[0][0]']
#
#  normalization_5 (Normalization  (None, 456, 456, 3)  7          ['rescaling_5[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 457, 457, 3)  0           ['normalization_5[0][0]']
#
#  stem_conv (Conv2D)             (None, 228, 228, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 228, 228, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 228, 228, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 228, 228, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 228, 228, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 228, 228, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 228, 228, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 228, 228, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 228, 228, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 228, 228, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 228, 228, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 228, 228, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 228, 228, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 228, 228, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 228, 228, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 228, 228, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 228, 228, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 228, 228, 24  216        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 228, 228, 24  96         ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 228, 228, 24  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 24)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 228, 228, 24  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 228, 228, 24  576         ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 228, 228, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 228, 228, 24  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 228, 228, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 228, 228, 14  3456        ['block1c_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 228, 228, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 228, 228, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 229, 229, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 114, 114, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 114, 114, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 114, 114, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 114, 114, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 114, 114, 40  5760        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 114, 114, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 114, 114, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 114, 114, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 114, 114, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 114, 114, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#  block2b_bn (BatchNormalization  (None, 114, 114, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 114, 114, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 114, 114, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 114, 114, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 114, 114, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 114, 114, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 114, 114, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 114, 114, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 114, 114, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 114, 114, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 114, 114, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 114, 114, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 114, 114, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 114, 114, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 114, 114, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 114, 114, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 114, 114, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 114, 114, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 114, 114, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 114, 114, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 114, 114, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 114, 114, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 114, 114, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 114, 114, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 114, 114, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 114, 114, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 114, 114, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 114, 114, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 114, 114, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 114, 114, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 114, 114, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 114, 114, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 114, 114, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 114, 114, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 114, 114, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 114, 114, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 114, 114, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 114, 114, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 114, 114, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 114, 114, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 114, 114, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 114, 114, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 114, 114, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 117, 117, 24  0          ['block3a_expand_activation[0][0]
#  g2D)                           0)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 57, 57, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 57, 57, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 57, 57, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 57, 57, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 57, 57, 64)   15360       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 57, 57, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 57, 57, 384)  24576       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 57, 57, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 57, 57, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 57, 57, 384)  9600       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 57, 57, 384)  1536       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 57, 57, 384)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 384)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 57, 57, 384)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 57, 57, 64)   24576       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 57, 57, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 57, 57, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 57, 57, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 57, 57, 384)  24576       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 57, 57, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 57, 57, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 57, 57, 384)  9600       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 57, 57, 384)  1536       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 57, 57, 384)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 384)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 57, 57, 384)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 57, 57, 64)   24576       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 57, 57, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 57, 57, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 57, 57, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 57, 57, 384)  24576       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 57, 57, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 57, 57, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 57, 57, 384)  9600       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 57, 57, 384)  1536       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 57, 57, 384)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 384)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 57, 57, 384)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 57, 57, 64)   24576       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 57, 57, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 57, 57, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 57, 57, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 57, 57, 384)  24576       ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 57, 57, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 57, 57, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_dwconv (DepthwiseConv2  (None, 57, 57, 384)  9600       ['block3e_expand_activation[0][0]
#  D)                                                              ']
# ...
#
#  block6i_bn (BatchNormalization  (None, 15, 15, 1824  7296       ['block6i_dwconv[0][0]']
#  )                              )
#
#  block6i_activation (Activation  (None, 15, 15, 1824  0          ['block6i_bn[0][0]']
#  )                              )
#
#  block6i_se_squeeze (GlobalAver  (None, 1824)        0           ['block6i_activation[0][0]']
#  agePooling2D)
#
#  block6i_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block6i_se_squeeze[0][0]']
#
#  block6i_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multiply)   (None, 15, 15, 1824  0           ['block6i_activation[0][0]',
#                                 )                                 'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv2D)  (None, 15, 15, 304)  554496      ['block6i_se_excite[0][0]']
#  block6i_project_bn (BatchNorma  (None, 15, 15, 304)  1216       ['block6i_project_conv[0][0]']
#  lization)
#
#  block6i_drop (Dropout)         (None, 15, 15, 304)  0           ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)              (None, 15, 15, 304)  0           ['block6i_drop[0][0]',
#                                                                   'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 15, 15, 1824  554496      ['block6i_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 15, 15, 1824  7296       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 15, 15, 1824  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 15, 15, 1824  16416      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 15, 15, 1824  7296       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 15, 15, 1824  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1824)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 15, 15, 1824  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 15, 15, 512)  933888      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 15, 15, 3072  1572864     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 15, 15, 3072  12288      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 15, 15, 3072  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 15, 15, 3072  27648      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 15, 15, 3072  12288      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 15, 15, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 15, 15, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 15, 15, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 15, 15, 512)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 15, 15, 512)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#  block7c_expand_conv (Conv2D)   (None, 15, 15, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 15, 15, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 15, 15, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 15, 15, 3072  27648      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 15, 15, 3072  12288      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 15, 15, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 15, 15, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 15, 15, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 15, 15, 512)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 15, 15, 512)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 15, 15, 2048  1048576     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 15, 15, 2048  8192        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 15, 15, 2048  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 2048)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         2049000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 30,562,527
# Trainable params: 30,389,784
# Non-trainable params: 172,743
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB6

# %%
EfficientNetB6 = tf.keras.applications.EfficientNetB6(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6.h5
# 174465024/174460376 [==============================] - 34s 0us/step
# 174473216/174460376 [==============================] - 34s 0us/step

# %%
model_analyze(EfficientNetB6)
# Out:
# Layers 0(-669): input_25
# Layers 1(-668): rescaling_6
# Layers 2(-667): normalization_6
# Layers 3(-666): stem_conv_pad
# Layers 4(-665): stem_conv
# Layers 5(-664): stem_bn
# Layers 6(-663): stem_activation
# Layers 7(-662): block1a_dwconv
# Layers 8(-661): block1a_bn
# Layers 9(-660): block1a_activation
# Layers 10(-659): block1a_se_squeeze
# Layers 11(-658): block1a_se_reshape
# Layers 12(-657): block1a_se_reduce
# Layers 13(-656): block1a_se_expand
# Layers 14(-655): block1a_se_excite
# Layers 15(-654): block1a_project_conv
# Layers 16(-653): block1a_project_bn
# Layers 17(-652): block1b_dwconv
# Layers 18(-651): block1b_bn
# Layers 19(-650): block1b_activation
# Layers 20(-649): block1b_se_squeeze
# Layers 21(-648): block1b_se_reshape
# Layers 22(-647): block1b_se_reduce
# Layers 23(-646): block1b_se_expand
# Layers 24(-645): block1b_se_excite
# Layers 25(-644): block1b_project_conv
# Layers 26(-643): block1b_project_bn
# Layers 27(-642): block1b_drop
# Layers 28(-641): block1b_add
# Layers 29(-640): block1c_dwconv
# Layers 30(-639): block1c_bn
# Layers 31(-638): block1c_activation
# Layers 32(-637): block1c_se_squeeze
# Layers 33(-636): block1c_se_reshape
# Layers 34(-635): block1c_se_reduce
# Layers 35(-634): block1c_se_expand
# Layers 36(-633): block1c_se_excite
# Layers 37(-632): block1c_project_conv
# Layers 38(-631): block1c_project_bn
# Layers 39(-630): block1c_drop
# Layers 40(-629): block1c_add
# Layers 41(-628): block2a_expand_conv
# Layers 42(-627): block2a_expand_bn
# Layers 43(-626): block2a_expand_activation
# Layers 44(-625): block2a_dwconv_pad
# Layers 45(-624): block2a_dwconv
# Layers 46(-623): block2a_bn
# Layers 47(-622): block2a_activation
# Layers 48(-621): block2a_se_squeeze
# Layers 49(-620): block2a_se_reshape
# Layers 50(-619): block2a_se_reduce
# Layers 51(-618): block2a_se_expand
# Layers 52(-617): block2a_se_excite
# Layers 53(-616): block2a_project_conv
# Layers 54(-615): block2a_project_bn
# Layers 55(-614): block2b_expand_conv
# Layers 56(-613): block2b_expand_bn
# Layers 57(-612): block2b_expand_activation
# Layers 58(-611): block2b_dwconv
# Layers 59(-610): block2b_bn
# Layers 60(-609): block2b_activation
# Layers 61(-608): block2b_se_squeeze
# Layers 62(-607): block2b_se_reshape
# Layers 63(-606): block2b_se_reduce
# Layers 64(-605): block2b_se_expand
# Layers 65(-604): block2b_se_excite
# Layers 66(-603): block2b_project_conv
# Layers 67(-602): block2b_project_bn
# Layers 68(-601): block2b_drop
# Layers 69(-600): block2b_add
# Layers 70(-599): block2c_expand_conv
# Layers 71(-598): block2c_expand_bn
# Layers 72(-597): block2c_expand_activation
# Layers 73(-596): block2c_dwconv
# Layers 74(-595): block2c_bn
# Layers 75(-594): block2c_activation
# Layers 76(-593): block2c_se_squeeze
# Layers 77(-592): block2c_se_reshape
# Layers 78(-591): block2c_se_reduce
# Layers 79(-590): block2c_se_expand
# Layers 80(-589): block2c_se_excite
# Layers 81(-588): block2c_project_conv
# Layers 82(-587): block2c_project_bn
# Layers 83(-586): block2c_drop
# Layers 84(-585): block2c_add
# Layers 85(-584): block2d_expand_conv
# Layers 86(-583): block2d_expand_bn
# Layers 87(-582): block2d_expand_activation
# Layers 88(-581): block2d_dwconv
# Layers 89(-580): block2d_bn
# Layers 90(-579): block2d_activation
# Layers 91(-578): block2d_se_squeeze
# Layers 92(-577): block2d_se_reshape
# Layers 93(-576): block2d_se_reduce
# Layers 94(-575): block2d_se_expand
# Layers 95(-574): block2d_se_excite
# Layers 96(-573): block2d_project_conv
# Layers 97(-572): block2d_project_bn
# Layers 98(-571): block2d_drop
# Layers 99(-570): block2d_add
# Layers 100(-569): block2e_expand_conv
# Layers 101(-568): block2e_expand_bn
# Layers 102(-567): block2e_expand_activation
# Layers 103(-566): block2e_dwconv
# Layers 104(-565): block2e_bn
# Layers 105(-564): block2e_activation
# Layers 106(-563): block2e_se_squeeze
# Layers 107(-562): block2e_se_reshape
# Layers 108(-561): block2e_se_reduce
# Layers 109(-560): block2e_se_expand
# Layers 110(-559): block2e_se_excite
# Layers 111(-558): block2e_project_conv
# Layers 112(-557): block2e_project_bn
# Layers 113(-556): block2e_drop
# Layers 114(-555): block2e_add
# Layers 115(-554): block2f_expand_conv
# Layers 116(-553): block2f_expand_bn
# Layers 117(-552): block2f_expand_activation
# Layers 118(-551): block2f_dwconv
# Layers 119(-550): block2f_bn
# Layers 120(-549): block2f_activation
# Layers 121(-548): block2f_se_squeeze
# Layers 122(-547): block2f_se_reshape
# Layers 123(-546): block2f_se_reduce
# Layers 124(-545): block2f_se_expand
# Layers 125(-544): block2f_se_excite
# Layers 126(-543): block2f_project_conv
# Layers 127(-542): block2f_project_bn
# Layers 128(-541): block2f_drop
# Layers 129(-540): block2f_add
# Layers 130(-539): block3a_expand_conv
# Layers 131(-538): block3a_expand_bn
# Layers 132(-537): block3a_expand_activation
# Layers 133(-536): block3a_dwconv_pad
# Layers 134(-535): block3a_dwconv
# Layers 135(-534): block3a_bn
# Layers 136(-533): block3a_activation
# Layers 137(-532): block3a_se_squeeze
# Layers 138(-531): block3a_se_reshape
# Layers 139(-530): block3a_se_reduce
# Layers 140(-529): block3a_se_expand
# Layers 141(-528): block3a_se_excite
# Layers 142(-527): block3a_project_conv
# Layers 143(-526): block3a_project_bn
# Layers 144(-525): block3b_expand_conv
# Layers 145(-524): block3b_expand_bn
# Layers 146(-523): block3b_expand_activation
# Layers 147(-522): block3b_dwconv
# Layers 148(-521): block3b_bn
# Layers 149(-520): block3b_activation
# Layers 150(-519): block3b_se_squeeze
# Layers 151(-518): block3b_se_reshape
# Layers 152(-517): block3b_se_reduce
# Layers 153(-516): block3b_se_expand
# Layers 154(-515): block3b_se_excite
# Layers 155(-514): block3b_project_conv
# Layers 156(-513): block3b_project_bn
# Layers 157(-512): block3b_drop
# Layers 158(-511): block3b_add
# Layers 159(-510): block3c_expand_conv
# Layers 160(-509): block3c_expand_bn
# Layers 161(-508): block3c_expand_activation
# Layers 162(-507): block3c_dwconv
# Layers 163(-506): block3c_bn
# Layers 164(-505): block3c_activation
# Layers 165(-504): block3c_se_squeeze
# Layers 166(-503): block3c_se_reshape
# Layers 167(-502): block3c_se_reduce
# Layers 168(-501): block3c_se_expand
# Layers 169(-500): block3c_se_excite
# Layers 170(-499): block3c_project_conv
# Layers 171(-498): block3c_project_bn
# Layers 172(-497): block3c_drop
# Layers 173(-496): block3c_add
# Layers 174(-495): block3d_expand_conv
# Layers 175(-494): block3d_expand_bn
# Layers 176(-493): block3d_expand_activation
# Layers 177(-492): block3d_dwconv
# Layers 178(-491): block3d_bn
# Layers 179(-490): block3d_activation
# Layers 180(-489): block3d_se_squeeze
# Layers 181(-488): block3d_se_reshape
# Layers 182(-487): block3d_se_reduce
# Layers 183(-486): block3d_se_expand
# Layers 184(-485): block3d_se_excite
# Layers 185(-484): block3d_project_conv
# Layers 186(-483): block3d_project_bn
# Layers 187(-482): block3d_drop
# Layers 188(-481): block3d_add
# Layers 189(-480): block3e_expand_conv
# Layers 190(-479): block3e_expand_bn
# Layers 191(-478): block3e_expand_activation
# Layers 192(-477): block3e_dwconv
# Layers 193(-476): block3e_bn
# Layers 194(-475): block3e_activation
# Layers 195(-474): block3e_se_squeeze
# Layers 196(-473): block3e_se_reshape
# Layers 197(-472): block3e_se_reduce
# Layers 198(-471): block3e_se_expand
# Layers 199(-470): block3e_se_excite
# Layers 200(-469): block3e_project_conv
# Layers 201(-468): block3e_project_bn
# Layers 202(-467): block3e_drop
# Layers 203(-466): block3e_add
# Layers 204(-465): block3f_expand_conv
# Layers 205(-464): block3f_expand_bn
# Layers 206(-463): block3f_expand_activation
# Layers 207(-462): block3f_dwconv
# Layers 208(-461): block3f_bn
# Layers 209(-460): block3f_activation
# Layers 210(-459): block3f_se_squeeze
# Layers 211(-458): block3f_se_reshape
# Layers 212(-457): block3f_se_reduce
# Layers 213(-456): block3f_se_expand
# Layers 214(-455): block3f_se_excite
# Layers 215(-454): block3f_project_conv
# Layers 216(-453): block3f_project_bn
# Layers 217(-452): block3f_drop
# Layers 218(-451): block3f_add
# Layers 219(-450): block4a_expand_conv
# Layers 220(-449): block4a_expand_bn
# Layers 221(-448): block4a_expand_activation
# Layers 222(-447): block4a_dwconv_pad
# Layers 223(-446): block4a_dwconv
# Layers 224(-445): block4a_bn
# Layers 225(-444): block4a_activation
# Layers 226(-443): block4a_se_squeeze
# Layers 227(-442): block4a_se_reshape
# Layers 228(-441): block4a_se_reduce
# Layers 229(-440): block4a_se_expand
# Layers 230(-439): block4a_se_excite
# Layers 231(-438): block4a_project_conv
# Layers 232(-437): block4a_project_bn
# Layers 233(-436): block4b_expand_conv
# Layers 234(-435): block4b_expand_bn
# Layers 235(-434): block4b_expand_activation
# Layers 236(-433): block4b_dwconv
# Layers 237(-432): block4b_bn
# Layers 238(-431): block4b_activation
# Layers 239(-430): block4b_se_squeeze
# Layers 240(-429): block4b_se_reshape
# Layers 241(-428): block4b_se_reduce
# Layers 242(-427): block4b_se_expand
# Layers 243(-426): block4b_se_excite
# Layers 244(-425): block4b_project_conv
# Layers 245(-424): block4b_project_bn
# Layers 246(-423): block4b_drop
# Layers 247(-422): block4b_add
# Layers 248(-421): block4c_expand_conv
# Layers 249(-420): block4c_expand_bn
# Layers 250(-419): block4c_expand_activation
# Layers 251(-418): block4c_dwconv
# Layers 252(-417): block4c_bn
# Layers 253(-416): block4c_activation
# Layers 254(-415): block4c_se_squeeze
# Layers 255(-414): block4c_se_reshape
# Layers 256(-413): block4c_se_reduce
# Layers 257(-412): block4c_se_expand
# Layers 258(-411): block4c_se_excite
# Layers 259(-410): block4c_project_conv
# Layers 260(-409): block4c_project_bn
# Layers 261(-408): block4c_drop
# Layers 262(-407): block4c_add
# Layers 263(-406): block4d_expand_conv
# Layers 264(-405): block4d_expand_bn
# Layers 265(-404): block4d_expand_activation
# Layers 266(-403): block4d_dwconv
# Layers 267(-402): block4d_bn
# Layers 268(-401): block4d_activation
# Layers 269(-400): block4d_se_squeeze
# Layers 270(-399): block4d_se_reshape
# Layers 271(-398): block4d_se_reduce
# Layers 272(-397): block4d_se_expand
# Layers 273(-396): block4d_se_excite
# Layers 274(-395): block4d_project_conv
# Layers 275(-394): block4d_project_bn
# Layers 276(-393): block4d_drop
# Layers 277(-392): block4d_add
# Layers 278(-391): block4e_expand_conv
# Layers 279(-390): block4e_expand_bn
# Layers 280(-389): block4e_expand_activation
# Layers 281(-388): block4e_dwconv
# Layers 282(-387): block4e_bn
# Layers 283(-386): block4e_activation
# Layers 284(-385): block4e_se_squeeze
# Layers 285(-384): block4e_se_reshape
# Layers 286(-383): block4e_se_reduce
# Layers 287(-382): block4e_se_expand
# Layers 288(-381): block4e_se_excite
# Layers 289(-380): block4e_project_conv
# Layers 290(-379): block4e_project_bn
# Layers 291(-378): block4e_drop
# Layers 292(-377): block4e_add
# Layers 293(-376): block4f_expand_conv
# Layers 294(-375): block4f_expand_bn
# Layers 295(-374): block4f_expand_activation
# Layers 296(-373): block4f_dwconv
# Layers 297(-372): block4f_bn
# Layers 298(-371): block4f_activation
# Layers 299(-370): block4f_se_squeeze
# Layers 300(-369): block4f_se_reshape
# Layers 301(-368): block4f_se_reduce
# Layers 302(-367): block4f_se_expand
# Layers 303(-366): block4f_se_excite
# Layers 304(-365): block4f_project_conv
# Layers 305(-364): block4f_project_bn
# Layers 306(-363): block4f_drop
# Layers 307(-362): block4f_add
# Layers 308(-361): block4g_expand_conv
# Layers 309(-360): block4g_expand_bn
# Layers 310(-359): block4g_expand_activation
# Layers 311(-358): block4g_dwconv
# Layers 312(-357): block4g_bn
# Layers 313(-356): block4g_activation
# Layers 314(-355): block4g_se_squeeze
# Layers 315(-354): block4g_se_reshape
# Layers 316(-353): block4g_se_reduce
# Layers 317(-352): block4g_se_expand
# Layers 318(-351): block4g_se_excite
# Layers 319(-350): block4g_project_conv
# Layers 320(-349): block4g_project_bn
# Layers 321(-348): block4g_drop
# Layers 322(-347): block4g_add
# Layers 323(-346): block4h_expand_conv
# Layers 324(-345): block4h_expand_bn
# Layers 325(-344): block4h_expand_activation
# Layers 326(-343): block4h_dwconv
# Layers 327(-342): block4h_bn
# Layers 328(-341): block4h_activation
# Layers 329(-340): block4h_se_squeeze
# Layers 330(-339): block4h_se_reshape
# Layers 331(-338): block4h_se_reduce
# Layers 332(-337): block4h_se_expand
# Layers 333(-336): block4h_se_excite
# Layers 334(-335): block4h_project_conv
# Layers 335(-334): block4h_project_bn
# Layers 336(-333): block4h_drop
# Layers 337(-332): block4h_add
# Layers 338(-331): block5a_expand_conv
# Layers 339(-330): block5a_expand_bn
# Layers 340(-329): block5a_expand_activation
# Layers 341(-328): block5a_dwconv
# Layers 342(-327): block5a_bn
# Layers 343(-326): block5a_activation
# Layers 344(-325): block5a_se_squeeze
# Layers 345(-324): block5a_se_reshape
# Layers 346(-323): block5a_se_reduce
# Layers 347(-322): block5a_se_expand
# Layers 348(-321): block5a_se_excite
# Layers 349(-320): block5a_project_conv
# Layers 350(-319): block5a_project_bn
# Layers 351(-318): block5b_expand_conv
# Layers 352(-317): block5b_expand_bn
# Layers 353(-316): block5b_expand_activation
# Layers 354(-315): block5b_dwconv
# Layers 355(-314): block5b_bn
# Layers 356(-313): block5b_activation
# Layers 357(-312): block5b_se_squeeze
# Layers 358(-311): block5b_se_reshape
# Layers 359(-310): block5b_se_reduce
# Layers 360(-309): block5b_se_expand
# Layers 361(-308): block5b_se_excite
# Layers 362(-307): block5b_project_conv
# Layers 363(-306): block5b_project_bn
# Layers 364(-305): block5b_drop
# Layers 365(-304): block5b_add
# Layers 366(-303): block5c_expand_conv
# Layers 367(-302): block5c_expand_bn
# Layers 368(-301): block5c_expand_activation
# Layers 369(-300): block5c_dwconv
# Layers 370(-299): block5c_bn
# Layers 371(-298): block5c_activation
# Layers 372(-297): block5c_se_squeeze
# Layers 373(-296): block5c_se_reshape
# Layers 374(-295): block5c_se_reduce
# Layers 375(-294): block5c_se_expand
# Layers 376(-293): block5c_se_excite
# Layers 377(-292): block5c_project_conv
# Layers 378(-291): block5c_project_bn
# Layers 379(-290): block5c_drop
# Layers 380(-289): block5c_add
# Layers 381(-288): block5d_expand_conv
# Layers 382(-287): block5d_expand_bn
# Layers 383(-286): block5d_expand_activation
# Layers 384(-285): block5d_dwconv
# Layers 385(-284): block5d_bn
# Layers 386(-283): block5d_activation
# Layers 387(-282): block5d_se_squeeze
# Layers 388(-281): block5d_se_reshape
# Layers 389(-280): block5d_se_reduce
# Layers 390(-279): block5d_se_expand
# Layers 391(-278): block5d_se_excite
# Layers 392(-277): block5d_project_conv
# Layers 393(-276): block5d_project_bn
# Layers 394(-275): block5d_drop
# Layers 395(-274): block5d_add
# Layers 396(-273): block5e_expand_conv
# Layers 397(-272): block5e_expand_bn
# Layers 398(-271): block5e_expand_activation
# Layers 399(-270): block5e_dwconv
# Layers 400(-269): block5e_bn
# Layers 401(-268): block5e_activation
# Layers 402(-267): block5e_se_squeeze
# Layers 403(-266): block5e_se_reshape
# Layers 404(-265): block5e_se_reduce
# Layers 405(-264): block5e_se_expand
# Layers 406(-263): block5e_se_excite
# Layers 407(-262): block5e_project_conv
# Layers 408(-261): block5e_project_bn
# Layers 409(-260): block5e_drop
# Layers 410(-259): block5e_add
# Layers 411(-258): block5f_expand_conv
# Layers 412(-257): block5f_expand_bn
# Layers 413(-256): block5f_expand_activation
# Layers 414(-255): block5f_dwconv
# Layers 415(-254): block5f_bn
# Layers 416(-253): block5f_activation
# Layers 417(-252): block5f_se_squeeze
# Layers 418(-251): block5f_se_reshape
# Layers 419(-250): block5f_se_reduce
# Layers 420(-249): block5f_se_expand
# Layers 421(-248): block5f_se_excite
# Layers 422(-247): block5f_project_conv
# Layers 423(-246): block5f_project_bn
# Layers 424(-245): block5f_drop
# Layers 425(-244): block5f_add
# Layers 426(-243): block5g_expand_conv
# Layers 427(-242): block5g_expand_bn
# Layers 428(-241): block5g_expand_activation
# Layers 429(-240): block5g_dwconv
# Layers 430(-239): block5g_bn
# Layers 431(-238): block5g_activation
# Layers 432(-237): block5g_se_squeeze
# Layers 433(-236): block5g_se_reshape
# Layers 434(-235): block5g_se_reduce
# Layers 435(-234): block5g_se_expand
# Layers 436(-233): block5g_se_excite
# Layers 437(-232): block5g_project_conv
# Layers 438(-231): block5g_project_bn
# Layers 439(-230): block5g_drop
# Layers 440(-229): block5g_add
# Layers 441(-228): block5h_expand_conv
# Layers 442(-227): block5h_expand_bn
# Layers 443(-226): block5h_expand_activation
# Layers 444(-225): block5h_dwconv
# Layers 445(-224): block5h_bn
# Layers 446(-223): block5h_activation
# Layers 447(-222): block5h_se_squeeze
# Layers 448(-221): block5h_se_reshape
# Layers 449(-220): block5h_se_reduce
# Layers 450(-219): block5h_se_expand
# Layers 451(-218): block5h_se_excite
# Layers 452(-217): block5h_project_conv
# Layers 453(-216): block5h_project_bn
# Layers 454(-215): block5h_drop
# Layers 455(-214): block5h_add
# Layers 456(-213): block6a_expand_conv
# Layers 457(-212): block6a_expand_bn
# Layers 458(-211): block6a_expand_activation
# Layers 459(-210): block6a_dwconv_pad
# Layers 460(-209): block6a_dwconv
# Layers 461(-208): block6a_bn
# Layers 462(-207): block6a_activation
# Layers 463(-206): block6a_se_squeeze
# Layers 464(-205): block6a_se_reshape
# Layers 465(-204): block6a_se_reduce
# Layers 466(-203): block6a_se_expand
# Layers 467(-202): block6a_se_excite
# Layers 468(-201): block6a_project_conv
# Layers 469(-200): block6a_project_bn
# Layers 470(-199): block6b_expand_conv
# Layers 471(-198): block6b_expand_bn
# Layers 472(-197): block6b_expand_activation
# Layers 473(-196): block6b_dwconv
# Layers 474(-195): block6b_bn
# Layers 475(-194): block6b_activation
# Layers 476(-193): block6b_se_squeeze
# Layers 477(-192): block6b_se_reshape
# Layers 478(-191): block6b_se_reduce
# Layers 479(-190): block6b_se_expand
# Layers 480(-189): block6b_se_excite
# Layers 481(-188): block6b_project_conv
# Layers 482(-187): block6b_project_bn
# Layers 483(-186): block6b_drop
# Layers 484(-185): block6b_add
# Layers 485(-184): block6c_expand_conv
# Layers 486(-183): block6c_expand_bn
# Layers 487(-182): block6c_expand_activation
# Layers 488(-181): block6c_dwconv
# Layers 489(-180): block6c_bn
# Layers 490(-179): block6c_activation
# Layers 491(-178): block6c_se_squeeze
# Layers 492(-177): block6c_se_reshape
# Layers 493(-176): block6c_se_reduce
# Layers 494(-175): block6c_se_expand
# Layers 495(-174): block6c_se_excite
# Layers 496(-173): block6c_project_conv
# Layers 497(-172): block6c_project_bn
# Layers 498(-171): block6c_drop
# Layers 499(-170): block6c_add
# Layers 500(-169): block6d_expand_conv
# Layers 501(-168): block6d_expand_bn
# Layers 502(-167): block6d_expand_activation
# Layers 503(-166): block6d_dwconv
# Layers 504(-165): block6d_bn
# Layers 505(-164): block6d_activation
# Layers 506(-163): block6d_se_squeeze
# Layers 507(-162): block6d_se_reshape
# Layers 508(-161): block6d_se_reduce
# Layers 509(-160): block6d_se_expand
# Layers 510(-159): block6d_se_excite
# Layers 511(-158): block6d_project_conv
# Layers 512(-157): block6d_project_bn
# Layers 513(-156): block6d_drop
# Layers 514(-155): block6d_add
# Layers 515(-154): block6e_expand_conv
# Layers 516(-153): block6e_expand_bn
# Layers 517(-152): block6e_expand_activation
# Layers 518(-151): block6e_dwconv
# Layers 519(-150): block6e_bn
# Layers 520(-149): block6e_activation
# Layers 521(-148): block6e_se_squeeze
# Layers 522(-147): block6e_se_reshape
# Layers 523(-146): block6e_se_reduce
# Layers 524(-145): block6e_se_expand
# Layers 525(-144): block6e_se_excite
# Layers 526(-143): block6e_project_conv
# Layers 527(-142): block6e_project_bn
# Layers 528(-141): block6e_drop
# Layers 529(-140): block6e_add
# Layers 530(-139): block6f_expand_conv
# Layers 531(-138): block6f_expand_bn
# Layers 532(-137): block6f_expand_activation
# Layers 533(-136): block6f_dwconv
# Layers 534(-135): block6f_bn
# Layers 535(-134): block6f_activation
# Layers 536(-133): block6f_se_squeeze
# Layers 537(-132): block6f_se_reshape
# Layers 538(-131): block6f_se_reduce
# Layers 539(-130): block6f_se_expand
# Layers 540(-129): block6f_se_excite
# Layers 541(-128): block6f_project_conv
# Layers 542(-127): block6f_project_bn
# Layers 543(-126): block6f_drop
# Layers 544(-125): block6f_add
# Layers 545(-124): block6g_expand_conv
# Layers 546(-123): block6g_expand_bn
# Layers 547(-122): block6g_expand_activation
# Layers 548(-121): block6g_dwconv
# Layers 549(-120): block6g_bn
# Layers 550(-119): block6g_activation
# Layers 551(-118): block6g_se_squeeze
# Layers 552(-117): block6g_se_reshape
# Layers 553(-116): block6g_se_reduce
# Layers 554(-115): block6g_se_expand
# Layers 555(-114): block6g_se_excite
# Layers 556(-113): block6g_project_conv
# Layers 557(-112): block6g_project_bn
# Layers 558(-111): block6g_drop
# Layers 559(-110): block6g_add
# Layers 560(-109): block6h_expand_conv
# Layers 561(-108): block6h_expand_bn
# Layers 562(-107): block6h_expand_activation
# Layers 563(-106): block6h_dwconv
# Layers 564(-105): block6h_bn
# Layers 565(-104): block6h_activation
# Layers 566(-103): block6h_se_squeeze
# Layers 567(-102): block6h_se_reshape
# Layers 568(-101): block6h_se_reduce
# Layers 569(-100): block6h_se_expand
# Layers 570(-99): block6h_se_excite
# Layers 571(-98): block6h_project_conv
# Layers 572(-97): block6h_project_bn
# Layers 573(-96): block6h_drop
# Layers 574(-95): block6h_add
# Layers 575(-94): block6i_expand_conv
# Layers 576(-93): block6i_expand_bn
# Layers 577(-92): block6i_expand_activation
# Layers 578(-91): block6i_dwconv
# Layers 579(-90): block6i_bn
# Layers 580(-89): block6i_activation
# Layers 581(-88): block6i_se_squeeze
# Layers 582(-87): block6i_se_reshape
# Layers 583(-86): block6i_se_reduce
# Layers 584(-85): block6i_se_expand
# Layers 585(-84): block6i_se_excite
# Layers 586(-83): block6i_project_conv
# Layers 587(-82): block6i_project_bn
# Layers 588(-81): block6i_drop
# Layers 589(-80): block6i_add
# Layers 590(-79): block6j_expand_conv
# Layers 591(-78): block6j_expand_bn
# Layers 592(-77): block6j_expand_activation
# Layers 593(-76): block6j_dwconv
# Layers 594(-75): block6j_bn
# Layers 595(-74): block6j_activation
# Layers 596(-73): block6j_se_squeeze
# Layers 597(-72): block6j_se_reshape
# Layers 598(-71): block6j_se_reduce
# Layers 599(-70): block6j_se_expand
# Layers 600(-69): block6j_se_excite
# Layers 601(-68): block6j_project_conv
# Layers 602(-67): block6j_project_bn
# Layers 603(-66): block6j_drop
# Layers 604(-65): block6j_add
# Layers 605(-64): block6k_expand_conv
# Layers 606(-63): block6k_expand_bn
# Layers 607(-62): block6k_expand_activation
# Layers 608(-61): block6k_dwconv
# Layers 609(-60): block6k_bn
# Layers 610(-59): block6k_activation
# Layers 611(-58): block6k_se_squeeze
# Layers 612(-57): block6k_se_reshape
# Layers 613(-56): block6k_se_reduce
# Layers 614(-55): block6k_se_expand
# Layers 615(-54): block6k_se_excite
# Layers 616(-53): block6k_project_conv
# Layers 617(-52): block6k_project_bn
# Layers 618(-51): block6k_drop
# Layers 619(-50): block6k_add
# Layers 620(-49): block7a_expand_conv
# Layers 621(-48): block7a_expand_bn
# Layers 622(-47): block7a_expand_activation
# Layers 623(-46): block7a_dwconv
# Layers 624(-45): block7a_bn
# Layers 625(-44): block7a_activation
# Layers 626(-43): block7a_se_squeeze
# Layers 627(-42): block7a_se_reshape
# Layers 628(-41): block7a_se_reduce
# Layers 629(-40): block7a_se_expand
# Layers 630(-39): block7a_se_excite
# Layers 631(-38): block7a_project_conv
# Layers 632(-37): block7a_project_bn
# Layers 633(-36): block7b_expand_conv
# Layers 634(-35): block7b_expand_bn
# Layers 635(-34): block7b_expand_activation
# Layers 636(-33): block7b_dwconv
# Layers 637(-32): block7b_bn
# Layers 638(-31): block7b_activation
# Layers 639(-30): block7b_se_squeeze
# Layers 640(-29): block7b_se_reshape
# Layers 641(-28): block7b_se_reduce
# Layers 642(-27): block7b_se_expand
# Layers 643(-26): block7b_se_excite
# Layers 644(-25): block7b_project_conv
# Layers 645(-24): block7b_project_bn
# Layers 646(-23): block7b_drop
# Layers 647(-22): block7b_add
# Layers 648(-21): block7c_expand_conv
# Layers 649(-20): block7c_expand_bn
# Layers 650(-19): block7c_expand_activation
# Layers 651(-18): block7c_dwconv
# Layers 652(-17): block7c_bn
# Layers 653(-16): block7c_activation
# Layers 654(-15): block7c_se_squeeze
# Layers 655(-14): block7c_se_reshape
# Layers 656(-13): block7c_se_reduce
# Layers 657(-12): block7c_se_expand
# Layers 658(-11): block7c_se_excite
# Layers 659(-10): block7c_project_conv
# Layers 660(-9): block7c_project_bn
# Layers 661(-8): block7c_drop
# Layers 662(-7): block7c_add
# Layers 663(-6): top_conv
# Layers 664(-5): top_bn
# Layers 665(-4): top_activation
# Layers 666(-3): avg_pool
# Layers 667(-2): top_dropout
# Layers 668(-1): predictions

# %%
EfficientNetB6.summary()
# Out:
# Model: "efficientnetb6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_25 (InputLayer)          [(None, 528, 528, 3  0           []
#                                 )]
#
#  rescaling_6 (Rescaling)        (None, 528, 528, 3)  0           ['input_25[0][0]']
#
#  normalization_6 (Normalization  (None, 528, 528, 3)  7          ['rescaling_6[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 529, 529, 3)  0           ['normalization_6[0][0]']
#
#  stem_conv (Conv2D)             (None, 264, 264, 56  1512        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 264, 264, 56  224         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 264, 264, 56  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 264, 264, 56  504        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 264, 264, 56  224        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 264, 264, 56  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 56)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 56)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 14)     798         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 56)     840         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 264, 264, 56  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 264, 264, 32  1792        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 264, 264, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 264, 264, 32  288        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 264, 264, 32  128        ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 264, 264, 32  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 264, 264, 32  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 264, 264, 32  1024        ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 264, 264, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 264, 264, 32  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 264, 264, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 264, 264, 32  288        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 264, 264, 32  128        ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 264, 264, 32  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 264, 264, 32  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 264, 264, 32  1024        ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 264, 264, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 264, 264, 32  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 264, 264, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 264, 264, 19  6144        ['block1c_add[0][0]']
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 264, 264, 19  768        ['block2a_expand_conv[0][0]']
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 264, 264, 19  0          ['block2a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 265, 265, 19  0          ['block2a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 132, 132, 19  1728       ['block2a_dwconv_pad[0][0]']
#  D)                             2)
#
#  block2a_bn (BatchNormalization  (None, 132, 132, 19  768        ['block2a_dwconv[0][0]']
#  )                              2)
#
#  block2a_activation (Activation  (None, 132, 132, 19  0          ['block2a_bn[0][0]']
#  )                              2)
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 132, 132, 19  0           ['block2a_activation[0][0]',
#                                 2)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 132, 132, 40  7680        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 132, 132, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 132, 132, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 132, 132, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 132, 132, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 132, 132, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#  block2b_bn (BatchNormalization  (None, 132, 132, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 132, 132, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 132, 132, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 132, 132, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 132, 132, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 132, 132, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 132, 132, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 132, 132, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 132, 132, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 132, 132, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 132, 132, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 132, 132, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 132, 132, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 132, 132, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 132, 132, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 132, 132, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 132, 132, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 132, 132, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 132, 132, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 132, 132, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 132, 132, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 132, 132, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 132, 132, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 132, 132, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 132, 132, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 132, 132, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 132, 132, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 132, 132, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 132, 132, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 132, 132, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 132, 132, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 132, 132, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 132, 132, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 132, 132, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 132, 132, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 132, 132, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 132, 132, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 132, 132, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 132, 132, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 132, 132, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 132, 132, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block2f_expand_bn (BatchNormal  (None, 132, 132, 24  960        ['block2f_expand_conv[0][0]']
#  ization)                       0)
#
#  block2f_expand_activation (Act  (None, 132, 132, 24  0          ['block2f_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2f_dwconv (DepthwiseConv2  (None, 132, 132, 24  2160       ['block2f_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2f_bn (BatchNormalization  (None, 132, 132, 24  960        ['block2f_dwconv[0][0]']
#  )                              0)
#
#  block2f_activation (Activation  (None, 132, 132, 24  0          ['block2f_bn[0][0]']
#  )                              0)
#
#  block2f_se_squeeze (GlobalAver  (None, 240)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 132, 132, 24  0           ['block2f_activation[0][0]',
#                                 0)                                'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 132, 132, 40  9600        ['block2f_se_excite[0][0]']
#                                 )
#
#  block2f_project_bn (BatchNorma  (None, 132, 132, 40  160        ['block2f_project_conv[0][0]']
#  lization)                      )
#
#  block2f_drop (Dropout)         (None, 132, 132, 40  0           ['block2f_project_bn[0][0]']
#                                 )
#
#  block2f_add (Add)              (None, 132, 132, 40  0           ['block2f_drop[0][0]',
#                                 )                                 'block2e_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 132, 132, 24  9600        ['block2f_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 132, 132, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 132, 132, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 135, 135, 24  0          ['block3a_expand_activation[0][0]
#  g2D)                           0)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 66, 66, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 66, 66, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 66, 66, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 66, 66, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 66, 66, 72)   17280       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 66, 66, 72)  288         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 66, 66, 432)  31104       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 66, 66, 432)  1728       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 66, 66, 432)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 66, 66, 432)  10800      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 66, 66, 432)  1728       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 66, 66, 432)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 432)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 432)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 18)     7794        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 432)    8208        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 66, 66, 432)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 66, 66, 72)   31104       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 66, 66, 72)  288         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 66, 66, 72)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 66, 66, 72)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 66, 66, 432)  31104       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 66, 66, 432)  1728       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 66, 66, 432)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 66, 66, 432)  10800      ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 66, 66, 432)  1728       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 66, 66, 432)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 432)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 432)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 18)     7794        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 432)    8208        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 66, 66, 432)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 66, 66, 72)   31104       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 66, 66, 72)  288         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 66, 66, 72)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 66, 66, 72)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 66, 66, 432)  31104       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 66, 66, 432)  1728       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 66, 66, 432)  0          ['block3d_expand_bn[0][0]']
#  ivation)
# ...
#
#  block6k_bn (BatchNormalization  (None, 17, 17, 2064  8256       ['block6k_dwconv[0][0]']
#  )                              )
#
#  block6k_activation (Activation  (None, 17, 17, 2064  0          ['block6k_bn[0][0]']
#  )                              )
#
#  block6k_se_squeeze (GlobalAver  (None, 2064)        0           ['block6k_activation[0][0]']
#  agePooling2D)
#
#  block6k_se_reshape (Reshape)   (None, 1, 1, 2064)   0           ['block6k_se_squeeze[0][0]']
#
#  block6k_se_reduce (Conv2D)     (None, 1, 1, 86)     177590      ['block6k_se_reshape[0][0]']
#
#  block6k_se_expand (Conv2D)     (None, 1, 1, 2064)   179568      ['block6k_se_reduce[0][0]']
#
#  block6k_se_excite (Multiply)   (None, 17, 17, 2064  0           ['block6k_activation[0][0]',
#                                 )                                 'block6k_se_expand[0][0]']
#
#  block6k_project_conv (Conv2D)  (None, 17, 17, 344)  710016      ['block6k_se_excite[0][0]']
#
#  block6k_project_bn (BatchNorma  (None, 17, 17, 344)  1376       ['block6k_project_conv[0][0]']
#  lization)
#
#  block6k_drop (Dropout)         (None, 17, 17, 344)  0           ['block6k_project_bn[0][0]']
#
#  block6k_add (Add)              (None, 17, 17, 344)  0           ['block6k_drop[0][0]',
#                                                                   'block6j_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 17, 17, 2064  710016      ['block6k_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 17, 17, 2064  8256       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 17, 17, 2064  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 17, 17, 2064  18576      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 17, 17, 2064  8256       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 17, 17, 2064  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 2064)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2064)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 86)     177590      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2064)   179568      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 17, 17, 2064  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 17, 17, 576)  1188864     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 17, 17, 576)  2304       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 17, 17, 3456  1990656     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 17, 17, 3456  13824      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 17, 17, 3456  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 17, 17, 3456  31104      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 17, 17, 3456  13824      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 17, 17, 3456  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3456)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3456)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 144)    497808      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3456)   501120      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 17, 17, 3456  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 17, 17, 576)  1990656     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 17, 17, 576)  2304       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 17, 17, 576)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 17, 17, 576)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 17, 17, 3456  1990656     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 17, 17, 3456  13824      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 17, 17, 3456  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#  block7c_dwconv (DepthwiseConv2  (None, 17, 17, 3456  31104      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 17, 17, 3456  13824      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 17, 17, 3456  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3456)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3456)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 144)    497808      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3456)   501120      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 17, 17, 3456  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 17, 17, 576)  1990656     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 17, 17, 576)  2304       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 17, 17, 576)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 17, 17, 576)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 17, 17, 2304  1327104     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 17, 17, 2304  9216        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 17, 17, 2304  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 2304)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 2304)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         2305000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 43,265,143
# Trainable params: 43,040,704
# Non-trainable params: 224,439
# __________________________________________________________________________________________________

# %% [markdown]
# # EfficientNetB7

# %%
EfficientNetB7 = tf.keras.applications.EfficientNetB7(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax"
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7.h5
# 268328960/268326632 [==============================] - 43s 0us/step
# 268337152/268326632 [==============================] - 43s 0us/step

# %%
model_analyze(EfficientNetB7)
# Out:
# Layers 0(-816): input_26
# Layers 1(-815): rescaling_7
# Layers 2(-814): normalization_7
# Layers 3(-813): stem_conv_pad
# Layers 4(-812): stem_conv
# Layers 5(-811): stem_bn
# Layers 6(-810): stem_activation
# Layers 7(-809): block1a_dwconv
# Layers 8(-808): block1a_bn
# Layers 9(-807): block1a_activation
# Layers 10(-806): block1a_se_squeeze
# Layers 11(-805): block1a_se_reshape
# Layers 12(-804): block1a_se_reduce
# Layers 13(-803): block1a_se_expand
# Layers 14(-802): block1a_se_excite
# Layers 15(-801): block1a_project_conv
# Layers 16(-800): block1a_project_bn
# Layers 17(-799): block1b_dwconv
# Layers 18(-798): block1b_bn
# Layers 19(-797): block1b_activation
# Layers 20(-796): block1b_se_squeeze
# Layers 21(-795): block1b_se_reshape
# Layers 22(-794): block1b_se_reduce
# Layers 23(-793): block1b_se_expand
# Layers 24(-792): block1b_se_excite
# Layers 25(-791): block1b_project_conv
# Layers 26(-790): block1b_project_bn
# Layers 27(-789): block1b_drop
# Layers 28(-788): block1b_add
# Layers 29(-787): block1c_dwconv
# Layers 30(-786): block1c_bn
# Layers 31(-785): block1c_activation
# Layers 32(-784): block1c_se_squeeze
# Layers 33(-783): block1c_se_reshape
# Layers 34(-782): block1c_se_reduce
# Layers 35(-781): block1c_se_expand
# Layers 36(-780): block1c_se_excite
# Layers 37(-779): block1c_project_conv
# Layers 38(-778): block1c_project_bn
# Layers 39(-777): block1c_drop
# Layers 40(-776): block1c_add
# Layers 41(-775): block1d_dwconv
# Layers 42(-774): block1d_bn
# Layers 43(-773): block1d_activation
# Layers 44(-772): block1d_se_squeeze
# Layers 45(-771): block1d_se_reshape
# Layers 46(-770): block1d_se_reduce
# Layers 47(-769): block1d_se_expand
# Layers 48(-768): block1d_se_excite
# Layers 49(-767): block1d_project_conv
# Layers 50(-766): block1d_project_bn
# Layers 51(-765): block1d_drop
# Layers 52(-764): block1d_add
# Layers 53(-763): block2a_expand_conv
# Layers 54(-762): block2a_expand_bn
# Layers 55(-761): block2a_expand_activation
# Layers 56(-760): block2a_dwconv_pad
# Layers 57(-759): block2a_dwconv
# Layers 58(-758): block2a_bn
# Layers 59(-757): block2a_activation
# Layers 60(-756): block2a_se_squeeze
# Layers 61(-755): block2a_se_reshape
# Layers 62(-754): block2a_se_reduce
# Layers 63(-753): block2a_se_expand
# Layers 64(-752): block2a_se_excite
# Layers 65(-751): block2a_project_conv
# Layers 66(-750): block2a_project_bn
# Layers 67(-749): block2b_expand_conv
# Layers 68(-748): block2b_expand_bn
# Layers 69(-747): block2b_expand_activation
# Layers 70(-746): block2b_dwconv
# Layers 71(-745): block2b_bn
# Layers 72(-744): block2b_activation
# Layers 73(-743): block2b_se_squeeze
# Layers 74(-742): block2b_se_reshape
# Layers 75(-741): block2b_se_reduce
# Layers 76(-740): block2b_se_expand
# Layers 77(-739): block2b_se_excite
# Layers 78(-738): block2b_project_conv
# Layers 79(-737): block2b_project_bn
# Layers 80(-736): block2b_drop
# Layers 81(-735): block2b_add
# Layers 82(-734): block2c_expand_conv
# Layers 83(-733): block2c_expand_bn
# Layers 84(-732): block2c_expand_activation
# Layers 85(-731): block2c_dwconv
# Layers 86(-730): block2c_bn
# Layers 87(-729): block2c_activation
# Layers 88(-728): block2c_se_squeeze
# Layers 89(-727): block2c_se_reshape
# Layers 90(-726): block2c_se_reduce
# Layers 91(-725): block2c_se_expand
# Layers 92(-724): block2c_se_excite
# Layers 93(-723): block2c_project_conv
# Layers 94(-722): block2c_project_bn
# Layers 95(-721): block2c_drop
# Layers 96(-720): block2c_add
# Layers 97(-719): block2d_expand_conv
# Layers 98(-718): block2d_expand_bn
# Layers 99(-717): block2d_expand_activation
# Layers 100(-716): block2d_dwconv
# Layers 101(-715): block2d_bn
# Layers 102(-714): block2d_activation
# Layers 103(-713): block2d_se_squeeze
# Layers 104(-712): block2d_se_reshape
# Layers 105(-711): block2d_se_reduce
# Layers 106(-710): block2d_se_expand
# Layers 107(-709): block2d_se_excite
# Layers 108(-708): block2d_project_conv
# Layers 109(-707): block2d_project_bn
# Layers 110(-706): block2d_drop
# Layers 111(-705): block2d_add
# Layers 112(-704): block2e_expand_conv
# Layers 113(-703): block2e_expand_bn
# Layers 114(-702): block2e_expand_activation
# Layers 115(-701): block2e_dwconv
# Layers 116(-700): block2e_bn
# Layers 117(-699): block2e_activation
# Layers 118(-698): block2e_se_squeeze
# Layers 119(-697): block2e_se_reshape
# Layers 120(-696): block2e_se_reduce
# Layers 121(-695): block2e_se_expand
# Layers 122(-694): block2e_se_excite
# Layers 123(-693): block2e_project_conv
# Layers 124(-692): block2e_project_bn
# Layers 125(-691): block2e_drop
# Layers 126(-690): block2e_add
# Layers 127(-689): block2f_expand_conv
# Layers 128(-688): block2f_expand_bn
# Layers 129(-687): block2f_expand_activation
# Layers 130(-686): block2f_dwconv
# Layers 131(-685): block2f_bn
# Layers 132(-684): block2f_activation
# Layers 133(-683): block2f_se_squeeze
# Layers 134(-682): block2f_se_reshape
# Layers 135(-681): block2f_se_reduce
# Layers 136(-680): block2f_se_expand
# Layers 137(-679): block2f_se_excite
# Layers 138(-678): block2f_project_conv
# Layers 139(-677): block2f_project_bn
# Layers 140(-676): block2f_drop
# Layers 141(-675): block2f_add
# Layers 142(-674): block2g_expand_conv
# Layers 143(-673): block2g_expand_bn
# Layers 144(-672): block2g_expand_activation
# Layers 145(-671): block2g_dwconv
# Layers 146(-670): block2g_bn
# Layers 147(-669): block2g_activation
# Layers 148(-668): block2g_se_squeeze
# Layers 149(-667): block2g_se_reshape
# Layers 150(-666): block2g_se_reduce
# Layers 151(-665): block2g_se_expand
# Layers 152(-664): block2g_se_excite
# Layers 153(-663): block2g_project_conv
# Layers 154(-662): block2g_project_bn
# Layers 155(-661): block2g_drop
# Layers 156(-660): block2g_add
# Layers 157(-659): block3a_expand_conv
# Layers 158(-658): block3a_expand_bn
# Layers 159(-657): block3a_expand_activation
# Layers 160(-656): block3a_dwconv_pad
# Layers 161(-655): block3a_dwconv
# Layers 162(-654): block3a_bn
# Layers 163(-653): block3a_activation
# Layers 164(-652): block3a_se_squeeze
# Layers 165(-651): block3a_se_reshape
# Layers 166(-650): block3a_se_reduce
# Layers 167(-649): block3a_se_expand
# Layers 168(-648): block3a_se_excite
# Layers 169(-647): block3a_project_conv
# Layers 170(-646): block3a_project_bn
# Layers 171(-645): block3b_expand_conv
# Layers 172(-644): block3b_expand_bn
# Layers 173(-643): block3b_expand_activation
# Layers 174(-642): block3b_dwconv
# Layers 175(-641): block3b_bn
# Layers 176(-640): block3b_activation
# Layers 177(-639): block3b_se_squeeze
# Layers 178(-638): block3b_se_reshape
# Layers 179(-637): block3b_se_reduce
# Layers 180(-636): block3b_se_expand
# Layers 181(-635): block3b_se_excite
# Layers 182(-634): block3b_project_conv
# Layers 183(-633): block3b_project_bn
# Layers 184(-632): block3b_drop
# Layers 185(-631): block3b_add
# Layers 186(-630): block3c_expand_conv
# Layers 187(-629): block3c_expand_bn
# Layers 188(-628): block3c_expand_activation
# Layers 189(-627): block3c_dwconv
# Layers 190(-626): block3c_bn
# Layers 191(-625): block3c_activation
# Layers 192(-624): block3c_se_squeeze
# Layers 193(-623): block3c_se_reshape
# Layers 194(-622): block3c_se_reduce
# Layers 195(-621): block3c_se_expand
# Layers 196(-620): block3c_se_excite
# Layers 197(-619): block3c_project_conv
# Layers 198(-618): block3c_project_bn
# Layers 199(-617): block3c_drop
# Layers 200(-616): block3c_add
# Layers 201(-615): block3d_expand_conv
# Layers 202(-614): block3d_expand_bn
# Layers 203(-613): block3d_expand_activation
# Layers 204(-612): block3d_dwconv
# Layers 205(-611): block3d_bn
# Layers 206(-610): block3d_activation
# Layers 207(-609): block3d_se_squeeze
# Layers 208(-608): block3d_se_reshape
# Layers 209(-607): block3d_se_reduce
# Layers 210(-606): block3d_se_expand
# Layers 211(-605): block3d_se_excite
# Layers 212(-604): block3d_project_conv
# Layers 213(-603): block3d_project_bn
# Layers 214(-602): block3d_drop
# Layers 215(-601): block3d_add
# Layers 216(-600): block3e_expand_conv
# Layers 217(-599): block3e_expand_bn
# Layers 218(-598): block3e_expand_activation
# Layers 219(-597): block3e_dwconv
# Layers 220(-596): block3e_bn
# Layers 221(-595): block3e_activation
# Layers 222(-594): block3e_se_squeeze
# Layers 223(-593): block3e_se_reshape
# Layers 224(-592): block3e_se_reduce
# Layers 225(-591): block3e_se_expand
# Layers 226(-590): block3e_se_excite
# Layers 227(-589): block3e_project_conv
# Layers 228(-588): block3e_project_bn
# Layers 229(-587): block3e_drop
# Layers 230(-586): block3e_add
# Layers 231(-585): block3f_expand_conv
# Layers 232(-584): block3f_expand_bn
# Layers 233(-583): block3f_expand_activation
# Layers 234(-582): block3f_dwconv
# Layers 235(-581): block3f_bn
# Layers 236(-580): block3f_activation
# Layers 237(-579): block3f_se_squeeze
# Layers 238(-578): block3f_se_reshape
# Layers 239(-577): block3f_se_reduce
# Layers 240(-576): block3f_se_expand
# Layers 241(-575): block3f_se_excite
# Layers 242(-574): block3f_project_conv
# Layers 243(-573): block3f_project_bn
# Layers 244(-572): block3f_drop
# Layers 245(-571): block3f_add
# Layers 246(-570): block3g_expand_conv
# Layers 247(-569): block3g_expand_bn
# Layers 248(-568): block3g_expand_activation
# Layers 249(-567): block3g_dwconv
# Layers 250(-566): block3g_bn
# Layers 251(-565): block3g_activation
# Layers 252(-564): block3g_se_squeeze
# Layers 253(-563): block3g_se_reshape
# Layers 254(-562): block3g_se_reduce
# Layers 255(-561): block3g_se_expand
# Layers 256(-560): block3g_se_excite
# Layers 257(-559): block3g_project_conv
# Layers 258(-558): block3g_project_bn
# Layers 259(-557): block3g_drop
# Layers 260(-556): block3g_add
# Layers 261(-555): block4a_expand_conv
# Layers 262(-554): block4a_expand_bn
# Layers 263(-553): block4a_expand_activation
# Layers 264(-552): block4a_dwconv_pad
# Layers 265(-551): block4a_dwconv
# Layers 266(-550): block4a_bn
# Layers 267(-549): block4a_activation
# Layers 268(-548): block4a_se_squeeze
# Layers 269(-547): block4a_se_reshape
# Layers 270(-546): block4a_se_reduce
# Layers 271(-545): block4a_se_expand
# Layers 272(-544): block4a_se_excite
# Layers 273(-543): block4a_project_conv
# Layers 274(-542): block4a_project_bn
# Layers 275(-541): block4b_expand_conv
# Layers 276(-540): block4b_expand_bn
# Layers 277(-539): block4b_expand_activation
# Layers 278(-538): block4b_dwconv
# Layers 279(-537): block4b_bn
# Layers 280(-536): block4b_activation
# Layers 281(-535): block4b_se_squeeze
# Layers 282(-534): block4b_se_reshape
# Layers 283(-533): block4b_se_reduce
# Layers 284(-532): block4b_se_expand
# Layers 285(-531): block4b_se_excite
# Layers 286(-530): block4b_project_conv
# Layers 287(-529): block4b_project_bn
# Layers 288(-528): block4b_drop
# Layers 289(-527): block4b_add
# Layers 290(-526): block4c_expand_conv
# Layers 291(-525): block4c_expand_bn
# Layers 292(-524): block4c_expand_activation
# Layers 293(-523): block4c_dwconv
# Layers 294(-522): block4c_bn
# Layers 295(-521): block4c_activation
# Layers 296(-520): block4c_se_squeeze
# Layers 297(-519): block4c_se_reshape
# Layers 298(-518): block4c_se_reduce
# Layers 299(-517): block4c_se_expand
# Layers 300(-516): block4c_se_excite
# Layers 301(-515): block4c_project_conv
# Layers 302(-514): block4c_project_bn
# Layers 303(-513): block4c_drop
# Layers 304(-512): block4c_add
# Layers 305(-511): block4d_expand_conv
# Layers 306(-510): block4d_expand_bn
# Layers 307(-509): block4d_expand_activation
# Layers 308(-508): block4d_dwconv
# Layers 309(-507): block4d_bn
# Layers 310(-506): block4d_activation
# Layers 311(-505): block4d_se_squeeze
# Layers 312(-504): block4d_se_reshape
# Layers 313(-503): block4d_se_reduce
# Layers 314(-502): block4d_se_expand
# Layers 315(-501): block4d_se_excite
# Layers 316(-500): block4d_project_conv
# Layers 317(-499): block4d_project_bn
# Layers 318(-498): block4d_drop
# Layers 319(-497): block4d_add
# Layers 320(-496): block4e_expand_conv
# Layers 321(-495): block4e_expand_bn
# Layers 322(-494): block4e_expand_activation
# Layers 323(-493): block4e_dwconv
# Layers 324(-492): block4e_bn
# Layers 325(-491): block4e_activation
# Layers 326(-490): block4e_se_squeeze
# Layers 327(-489): block4e_se_reshape
# Layers 328(-488): block4e_se_reduce
# Layers 329(-487): block4e_se_expand
# Layers 330(-486): block4e_se_excite
# Layers 331(-485): block4e_project_conv
# Layers 332(-484): block4e_project_bn
# Layers 333(-483): block4e_drop
# Layers 334(-482): block4e_add
# Layers 335(-481): block4f_expand_conv
# Layers 336(-480): block4f_expand_bn
# Layers 337(-479): block4f_expand_activation
# Layers 338(-478): block4f_dwconv
# Layers 339(-477): block4f_bn
# Layers 340(-476): block4f_activation
# Layers 341(-475): block4f_se_squeeze
# Layers 342(-474): block4f_se_reshape
# Layers 343(-473): block4f_se_reduce
# Layers 344(-472): block4f_se_expand
# Layers 345(-471): block4f_se_excite
# Layers 346(-470): block4f_project_conv
# Layers 347(-469): block4f_project_bn
# Layers 348(-468): block4f_drop
# Layers 349(-467): block4f_add
# Layers 350(-466): block4g_expand_conv
# Layers 351(-465): block4g_expand_bn
# Layers 352(-464): block4g_expand_activation
# Layers 353(-463): block4g_dwconv
# Layers 354(-462): block4g_bn
# Layers 355(-461): block4g_activation
# Layers 356(-460): block4g_se_squeeze
# Layers 357(-459): block4g_se_reshape
# Layers 358(-458): block4g_se_reduce
# Layers 359(-457): block4g_se_expand
# Layers 360(-456): block4g_se_excite
# Layers 361(-455): block4g_project_conv
# Layers 362(-454): block4g_project_bn
# Layers 363(-453): block4g_drop
# Layers 364(-452): block4g_add
# Layers 365(-451): block4h_expand_conv
# Layers 366(-450): block4h_expand_bn
# Layers 367(-449): block4h_expand_activation
# Layers 368(-448): block4h_dwconv
# Layers 369(-447): block4h_bn
# Layers 370(-446): block4h_activation
# Layers 371(-445): block4h_se_squeeze
# Layers 372(-444): block4h_se_reshape
# Layers 373(-443): block4h_se_reduce
# Layers 374(-442): block4h_se_expand
# Layers 375(-441): block4h_se_excite
# Layers 376(-440): block4h_project_conv
# Layers 377(-439): block4h_project_bn
# Layers 378(-438): block4h_drop
# Layers 379(-437): block4h_add
# Layers 380(-436): block4i_expand_conv
# Layers 381(-435): block4i_expand_bn
# Layers 382(-434): block4i_expand_activation
# Layers 383(-433): block4i_dwconv
# Layers 384(-432): block4i_bn
# Layers 385(-431): block4i_activation
# Layers 386(-430): block4i_se_squeeze
# Layers 387(-429): block4i_se_reshape
# Layers 388(-428): block4i_se_reduce
# Layers 389(-427): block4i_se_expand
# Layers 390(-426): block4i_se_excite
# Layers 391(-425): block4i_project_conv
# Layers 392(-424): block4i_project_bn
# Layers 393(-423): block4i_drop
# Layers 394(-422): block4i_add
# Layers 395(-421): block4j_expand_conv
# Layers 396(-420): block4j_expand_bn
# Layers 397(-419): block4j_expand_activation
# Layers 398(-418): block4j_dwconv
# Layers 399(-417): block4j_bn
# Layers 400(-416): block4j_activation
# Layers 401(-415): block4j_se_squeeze
# Layers 402(-414): block4j_se_reshape
# Layers 403(-413): block4j_se_reduce
# Layers 404(-412): block4j_se_expand
# Layers 405(-411): block4j_se_excite
# Layers 406(-410): block4j_project_conv
# Layers 407(-409): block4j_project_bn
# Layers 408(-408): block4j_drop
# Layers 409(-407): block4j_add
# Layers 410(-406): block5a_expand_conv
# Layers 411(-405): block5a_expand_bn
# Layers 412(-404): block5a_expand_activation
# Layers 413(-403): block5a_dwconv
# Layers 414(-402): block5a_bn
# Layers 415(-401): block5a_activation
# Layers 416(-400): block5a_se_squeeze
# Layers 417(-399): block5a_se_reshape
# Layers 418(-398): block5a_se_reduce
# Layers 419(-397): block5a_se_expand
# Layers 420(-396): block5a_se_excite
# Layers 421(-395): block5a_project_conv
# Layers 422(-394): block5a_project_bn
# Layers 423(-393): block5b_expand_conv
# Layers 424(-392): block5b_expand_bn
# Layers 425(-391): block5b_expand_activation
# Layers 426(-390): block5b_dwconv
# Layers 427(-389): block5b_bn
# Layers 428(-388): block5b_activation
# Layers 429(-387): block5b_se_squeeze
# Layers 430(-386): block5b_se_reshape
# Layers 431(-385): block5b_se_reduce
# Layers 432(-384): block5b_se_expand
# Layers 433(-383): block5b_se_excite
# Layers 434(-382): block5b_project_conv
# Layers 435(-381): block5b_project_bn
# Layers 436(-380): block5b_drop
# Layers 437(-379): block5b_add
# Layers 438(-378): block5c_expand_conv
# Layers 439(-377): block5c_expand_bn
# Layers 440(-376): block5c_expand_activation
# Layers 441(-375): block5c_dwconv
# Layers 442(-374): block5c_bn
# Layers 443(-373): block5c_activation
# Layers 444(-372): block5c_se_squeeze
# Layers 445(-371): block5c_se_reshape
# Layers 446(-370): block5c_se_reduce
# Layers 447(-369): block5c_se_expand
# Layers 448(-368): block5c_se_excite
# Layers 449(-367): block5c_project_conv
# Layers 450(-366): block5c_project_bn
# Layers 451(-365): block5c_drop
# Layers 452(-364): block5c_add
# Layers 453(-363): block5d_expand_conv
# Layers 454(-362): block5d_expand_bn
# Layers 455(-361): block5d_expand_activation
# Layers 456(-360): block5d_dwconv
# Layers 457(-359): block5d_bn
# Layers 458(-358): block5d_activation
# Layers 459(-357): block5d_se_squeeze
# Layers 460(-356): block5d_se_reshape
# Layers 461(-355): block5d_se_reduce
# Layers 462(-354): block5d_se_expand
# Layers 463(-353): block5d_se_excite
# Layers 464(-352): block5d_project_conv
# Layers 465(-351): block5d_project_bn
# Layers 466(-350): block5d_drop
# Layers 467(-349): block5d_add
# Layers 468(-348): block5e_expand_conv
# Layers 469(-347): block5e_expand_bn
# Layers 470(-346): block5e_expand_activation
# Layers 471(-345): block5e_dwconv
# Layers 472(-344): block5e_bn
# Layers 473(-343): block5e_activation
# Layers 474(-342): block5e_se_squeeze
# Layers 475(-341): block5e_se_reshape
# Layers 476(-340): block5e_se_reduce
# Layers 477(-339): block5e_se_expand
# Layers 478(-338): block5e_se_excite
# Layers 479(-337): block5e_project_conv
# Layers 480(-336): block5e_project_bn
# Layers 481(-335): block5e_drop
# Layers 482(-334): block5e_add
# Layers 483(-333): block5f_expand_conv
# Layers 484(-332): block5f_expand_bn
# Layers 485(-331): block5f_expand_activation
# Layers 486(-330): block5f_dwconv
# Layers 487(-329): block5f_bn
# Layers 488(-328): block5f_activation
# Layers 489(-327): block5f_se_squeeze
# Layers 490(-326): block5f_se_reshape
# Layers 491(-325): block5f_se_reduce
# Layers 492(-324): block5f_se_expand
# Layers 493(-323): block5f_se_excite
# Layers 494(-322): block5f_project_conv
# Layers 495(-321): block5f_project_bn
# Layers 496(-320): block5f_drop
# Layers 497(-319): block5f_add
# Layers 498(-318): block5g_expand_conv
# Layers 499(-317): block5g_expand_bn
# Layers 500(-316): block5g_expand_activation
# Layers 501(-315): block5g_dwconv
# Layers 502(-314): block5g_bn
# Layers 503(-313): block5g_activation
# Layers 504(-312): block5g_se_squeeze
# Layers 505(-311): block5g_se_reshape
# Layers 506(-310): block5g_se_reduce
# Layers 507(-309): block5g_se_expand
# Layers 508(-308): block5g_se_excite
# Layers 509(-307): block5g_project_conv
# Layers 510(-306): block5g_project_bn
# Layers 511(-305): block5g_drop
# Layers 512(-304): block5g_add
# Layers 513(-303): block5h_expand_conv
# Layers 514(-302): block5h_expand_bn
# Layers 515(-301): block5h_expand_activation
# Layers 516(-300): block5h_dwconv
# Layers 517(-299): block5h_bn
# Layers 518(-298): block5h_activation
# Layers 519(-297): block5h_se_squeeze
# Layers 520(-296): block5h_se_reshape
# Layers 521(-295): block5h_se_reduce
# Layers 522(-294): block5h_se_expand
# Layers 523(-293): block5h_se_excite
# Layers 524(-292): block5h_project_conv
# Layers 525(-291): block5h_project_bn
# Layers 526(-290): block5h_drop
# Layers 527(-289): block5h_add
# Layers 528(-288): block5i_expand_conv
# Layers 529(-287): block5i_expand_bn
# Layers 530(-286): block5i_expand_activation
# Layers 531(-285): block5i_dwconv
# Layers 532(-284): block5i_bn
# Layers 533(-283): block5i_activation
# Layers 534(-282): block5i_se_squeeze
# Layers 535(-281): block5i_se_reshape
# Layers 536(-280): block5i_se_reduce
# Layers 537(-279): block5i_se_expand
# Layers 538(-278): block5i_se_excite
# Layers 539(-277): block5i_project_conv
# Layers 540(-276): block5i_project_bn
# Layers 541(-275): block5i_drop
# Layers 542(-274): block5i_add
# Layers 543(-273): block5j_expand_conv
# Layers 544(-272): block5j_expand_bn
# Layers 545(-271): block5j_expand_activation
# Layers 546(-270): block5j_dwconv
# Layers 547(-269): block5j_bn
# Layers 548(-268): block5j_activation
# Layers 549(-267): block5j_se_squeeze
# Layers 550(-266): block5j_se_reshape
# Layers 551(-265): block5j_se_reduce
# Layers 552(-264): block5j_se_expand
# Layers 553(-263): block5j_se_excite
# Layers 554(-262): block5j_project_conv
# Layers 555(-261): block5j_project_bn
# Layers 556(-260): block5j_drop
# Layers 557(-259): block5j_add
# Layers 558(-258): block6a_expand_conv
# Layers 559(-257): block6a_expand_bn
# Layers 560(-256): block6a_expand_activation
# Layers 561(-255): block6a_dwconv_pad
# Layers 562(-254): block6a_dwconv
# Layers 563(-253): block6a_bn
# Layers 564(-252): block6a_activation
# Layers 565(-251): block6a_se_squeeze
# Layers 566(-250): block6a_se_reshape
# Layers 567(-249): block6a_se_reduce
# Layers 568(-248): block6a_se_expand
# Layers 569(-247): block6a_se_excite
# Layers 570(-246): block6a_project_conv
# Layers 571(-245): block6a_project_bn
# Layers 572(-244): block6b_expand_conv
# Layers 573(-243): block6b_expand_bn
# Layers 574(-242): block6b_expand_activation
# Layers 575(-241): block6b_dwconv
# Layers 576(-240): block6b_bn
# Layers 577(-239): block6b_activation
# Layers 578(-238): block6b_se_squeeze
# Layers 579(-237): block6b_se_reshape
# Layers 580(-236): block6b_se_reduce
# Layers 581(-235): block6b_se_expand
# Layers 582(-234): block6b_se_excite
# Layers 583(-233): block6b_project_conv
# Layers 584(-232): block6b_project_bn
# Layers 585(-231): block6b_drop
# Layers 586(-230): block6b_add
# Layers 587(-229): block6c_expand_conv
# Layers 588(-228): block6c_expand_bn
# Layers 589(-227): block6c_expand_activation
# Layers 590(-226): block6c_dwconv
# Layers 591(-225): block6c_bn
# Layers 592(-224): block6c_activation
# Layers 593(-223): block6c_se_squeeze
# Layers 594(-222): block6c_se_reshape
# Layers 595(-221): block6c_se_reduce
# Layers 596(-220): block6c_se_expand
# Layers 597(-219): block6c_se_excite
# Layers 598(-218): block6c_project_conv
# Layers 599(-217): block6c_project_bn
# Layers 600(-216): block6c_drop
# Layers 601(-215): block6c_add
# Layers 602(-214): block6d_expand_conv
# Layers 603(-213): block6d_expand_bn
# Layers 604(-212): block6d_expand_activation
# Layers 605(-211): block6d_dwconv
# Layers 606(-210): block6d_bn
# Layers 607(-209): block6d_activation
# Layers 608(-208): block6d_se_squeeze
# Layers 609(-207): block6d_se_reshape
# Layers 610(-206): block6d_se_reduce
# Layers 611(-205): block6d_se_expand
# Layers 612(-204): block6d_se_excite
# Layers 613(-203): block6d_project_conv
# Layers 614(-202): block6d_project_bn
# Layers 615(-201): block6d_drop
# Layers 616(-200): block6d_add
# Layers 617(-199): block6e_expand_conv
# Layers 618(-198): block6e_expand_bn
# Layers 619(-197): block6e_expand_activation
# Layers 620(-196): block6e_dwconv
# Layers 621(-195): block6e_bn
# Layers 622(-194): block6e_activation
# Layers 623(-193): block6e_se_squeeze
# Layers 624(-192): block6e_se_reshape
# Layers 625(-191): block6e_se_reduce
# Layers 626(-190): block6e_se_expand
# Layers 627(-189): block6e_se_excite
# Layers 628(-188): block6e_project_conv
# Layers 629(-187): block6e_project_bn
# Layers 630(-186): block6e_drop
# Layers 631(-185): block6e_add
# Layers 632(-184): block6f_expand_conv
# Layers 633(-183): block6f_expand_bn
# Layers 634(-182): block6f_expand_activation
# Layers 635(-181): block6f_dwconv
# Layers 636(-180): block6f_bn
# Layers 637(-179): block6f_activation
# Layers 638(-178): block6f_se_squeeze
# Layers 639(-177): block6f_se_reshape
# Layers 640(-176): block6f_se_reduce
# Layers 641(-175): block6f_se_expand
# Layers 642(-174): block6f_se_excite
# Layers 643(-173): block6f_project_conv
# Layers 644(-172): block6f_project_bn
# Layers 645(-171): block6f_drop
# Layers 646(-170): block6f_add
# Layers 647(-169): block6g_expand_conv
# Layers 648(-168): block6g_expand_bn
# Layers 649(-167): block6g_expand_activation
# Layers 650(-166): block6g_dwconv
# Layers 651(-165): block6g_bn
# Layers 652(-164): block6g_activation
# Layers 653(-163): block6g_se_squeeze
# Layers 654(-162): block6g_se_reshape
# Layers 655(-161): block6g_se_reduce
# Layers 656(-160): block6g_se_expand
# Layers 657(-159): block6g_se_excite
# Layers 658(-158): block6g_project_conv
# Layers 659(-157): block6g_project_bn
# Layers 660(-156): block6g_drop
# Layers 661(-155): block6g_add
# Layers 662(-154): block6h_expand_conv
# Layers 663(-153): block6h_expand_bn
# Layers 664(-152): block6h_expand_activation
# Layers 665(-151): block6h_dwconv
# Layers 666(-150): block6h_bn
# Layers 667(-149): block6h_activation
# Layers 668(-148): block6h_se_squeeze
# Layers 669(-147): block6h_se_reshape
# Layers 670(-146): block6h_se_reduce
# Layers 671(-145): block6h_se_expand
# Layers 672(-144): block6h_se_excite
# Layers 673(-143): block6h_project_conv
# Layers 674(-142): block6h_project_bn
# Layers 675(-141): block6h_drop
# Layers 676(-140): block6h_add
# Layers 677(-139): block6i_expand_conv
# Layers 678(-138): block6i_expand_bn
# Layers 679(-137): block6i_expand_activation
# Layers 680(-136): block6i_dwconv
# Layers 681(-135): block6i_bn
# Layers 682(-134): block6i_activation
# Layers 683(-133): block6i_se_squeeze
# Layers 684(-132): block6i_se_reshape
# Layers 685(-131): block6i_se_reduce
# Layers 686(-130): block6i_se_expand
# Layers 687(-129): block6i_se_excite
# Layers 688(-128): block6i_project_conv
# Layers 689(-127): block6i_project_bn
# Layers 690(-126): block6i_drop
# Layers 691(-125): block6i_add
# Layers 692(-124): block6j_expand_conv
# Layers 693(-123): block6j_expand_bn
# Layers 694(-122): block6j_expand_activation
# Layers 695(-121): block6j_dwconv
# Layers 696(-120): block6j_bn
# Layers 697(-119): block6j_activation
# Layers 698(-118): block6j_se_squeeze
# Layers 699(-117): block6j_se_reshape
# Layers 700(-116): block6j_se_reduce
# Layers 701(-115): block6j_se_expand
# Layers 702(-114): block6j_se_excite
# Layers 703(-113): block6j_project_conv
# Layers 704(-112): block6j_project_bn
# Layers 705(-111): block6j_drop
# Layers 706(-110): block6j_add
# Layers 707(-109): block6k_expand_conv
# Layers 708(-108): block6k_expand_bn
# Layers 709(-107): block6k_expand_activation
# Layers 710(-106): block6k_dwconv
# Layers 711(-105): block6k_bn
# Layers 712(-104): block6k_activation
# Layers 713(-103): block6k_se_squeeze
# Layers 714(-102): block6k_se_reshape
# Layers 715(-101): block6k_se_reduce
# Layers 716(-100): block6k_se_expand
# Layers 717(-99): block6k_se_excite
# Layers 718(-98): block6k_project_conv
# Layers 719(-97): block6k_project_bn
# Layers 720(-96): block6k_drop
# Layers 721(-95): block6k_add
# Layers 722(-94): block6l_expand_conv
# Layers 723(-93): block6l_expand_bn
# Layers 724(-92): block6l_expand_activation
# Layers 725(-91): block6l_dwconv
# Layers 726(-90): block6l_bn
# Layers 727(-89): block6l_activation
# Layers 728(-88): block6l_se_squeeze
# Layers 729(-87): block6l_se_reshape
# Layers 730(-86): block6l_se_reduce
# Layers 731(-85): block6l_se_expand
# Layers 732(-84): block6l_se_excite
# Layers 733(-83): block6l_project_conv
# Layers 734(-82): block6l_project_bn
# Layers 735(-81): block6l_drop
# Layers 736(-80): block6l_add
# Layers 737(-79): block6m_expand_conv
# Layers 738(-78): block6m_expand_bn
# Layers 739(-77): block6m_expand_activation
# Layers 740(-76): block6m_dwconv
# Layers 741(-75): block6m_bn
# Layers 742(-74): block6m_activation
# Layers 743(-73): block6m_se_squeeze
# Layers 744(-72): block6m_se_reshape
# Layers 745(-71): block6m_se_reduce
# Layers 746(-70): block6m_se_expand
# Layers 747(-69): block6m_se_excite
# Layers 748(-68): block6m_project_conv
# Layers 749(-67): block6m_project_bn
# Layers 750(-66): block6m_drop
# Layers 751(-65): block6m_add
# Layers 752(-64): block7a_expand_conv
# Layers 753(-63): block7a_expand_bn
# Layers 754(-62): block7a_expand_activation
# Layers 755(-61): block7a_dwconv
# Layers 756(-60): block7a_bn
# Layers 757(-59): block7a_activation
# Layers 758(-58): block7a_se_squeeze
# Layers 759(-57): block7a_se_reshape
# Layers 760(-56): block7a_se_reduce
# Layers 761(-55): block7a_se_expand
# Layers 762(-54): block7a_se_excite
# Layers 763(-53): block7a_project_conv
# Layers 764(-52): block7a_project_bn
# Layers 765(-51): block7b_expand_conv
# Layers 766(-50): block7b_expand_bn
# Layers 767(-49): block7b_expand_activation
# Layers 768(-48): block7b_dwconv
# Layers 769(-47): block7b_bn
# Layers 770(-46): block7b_activation
# Layers 771(-45): block7b_se_squeeze
# Layers 772(-44): block7b_se_reshape
# Layers 773(-43): block7b_se_reduce
# Layers 774(-42): block7b_se_expand
# Layers 775(-41): block7b_se_excite
# Layers 776(-40): block7b_project_conv
# Layers 777(-39): block7b_project_bn
# Layers 778(-38): block7b_drop
# Layers 779(-37): block7b_add
# Layers 780(-36): block7c_expand_conv
# Layers 781(-35): block7c_expand_bn
# Layers 782(-34): block7c_expand_activation
# Layers 783(-33): block7c_dwconv
# Layers 784(-32): block7c_bn
# Layers 785(-31): block7c_activation
# Layers 786(-30): block7c_se_squeeze
# Layers 787(-29): block7c_se_reshape
# Layers 788(-28): block7c_se_reduce
# Layers 789(-27): block7c_se_expand
# Layers 790(-26): block7c_se_excite
# Layers 791(-25): block7c_project_conv
# Layers 792(-24): block7c_project_bn
# Layers 793(-23): block7c_drop
# Layers 794(-22): block7c_add
# Layers 795(-21): block7d_expand_conv
# Layers 796(-20): block7d_expand_bn
# Layers 797(-19): block7d_expand_activation
# Layers 798(-18): block7d_dwconv
# Layers 799(-17): block7d_bn
# Layers 800(-16): block7d_activation
# Layers 801(-15): block7d_se_squeeze
# Layers 802(-14): block7d_se_reshape
# Layers 803(-13): block7d_se_reduce
# Layers 804(-12): block7d_se_expand
# Layers 805(-11): block7d_se_excite
# Layers 806(-10): block7d_project_conv
# Layers 807(-9): block7d_project_bn
# Layers 808(-8): block7d_drop
# Layers 809(-7): block7d_add
# Layers 810(-6): top_conv
# Layers 811(-5): top_bn
# Layers 812(-4): top_activation
# Layers 813(-3): avg_pool
# Layers 814(-2): top_dropout
# Layers 815(-1): predictions

# %%
EfficientNetB7.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_26 (InputLayer)          [(None, 600, 600, 3  0           []
#                                 )]
#
#  rescaling_7 (Rescaling)        (None, 600, 600, 3)  0           ['input_26[0][0]']
#
#  normalization_7 (Normalization  (None, 600, 600, 3)  7          ['rescaling_7[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 601, 601, 3)  0           ['normalization_7[0][0]']
#
#  stem_conv (Conv2D)             (None, 300, 300, 64  1728        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 300, 300, 64  256         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 300, 300, 64  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 300, 300, 64  576        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 300, 300, 64  256        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 300, 300, 64  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 300, 300, 64  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 300, 300, 32  2048        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 300, 300, 32  288        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 300, 300, 32  128        ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 300, 300, 32  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 300, 300, 32  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 300, 300, 32  1024        ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 300, 300, 32  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 300, 300, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 300, 300, 32  288        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 300, 300, 32  128        ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 300, 300, 32  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 300, 300, 32  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 300, 300, 32  1024        ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 300, 300, 32  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 300, 300, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 300, 300, 32  288        ['block1c_add[0][0]']
#  D)                             )
#
#  block1d_bn (BatchNormalization  (None, 300, 300, 32  128        ['block1d_dwconv[0][0]']
#  )                              )
#
#  block1d_activation (Activation  (None, 300, 300, 32  0          ['block1d_bn[0][0]']
#  )                              )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 300, 300, 32  0           ['block1d_activation[0][0]',
#                                 )                                 'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 300, 300, 32  1024        ['block1d_se_excite[0][0]']
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1d_project_conv[0][0]']
#  lization)                      )
#
#  block1d_drop (Dropout)         (None, 300, 300, 32  0           ['block1d_project_bn[0][0]']
#                                 )
#
#  block1d_add (Add)              (None, 300, 300, 32  0           ['block1d_drop[0][0]',
#                                 )                                 'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 300, 300, 19  6144        ['block1d_add[0][0]']
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 300, 300, 19  768        ['block2a_expand_conv[0][0]']
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 300, 300, 19  0          ['block2a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 301, 301, 19  0          ['block2a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 150, 150, 19  1728       ['block2a_dwconv_pad[0][0]']
#  D)                             2)
#
#  block2a_bn (BatchNormalization  (None, 150, 150, 19  768        ['block2a_dwconv[0][0]']
#  )                              2)
#  block2a_activation (Activation  (None, 150, 150, 19  0          ['block2a_bn[0][0]']
#  )                              2)
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 150, 150, 19  0           ['block2a_activation[0][0]',
#                                 2)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 150, 150, 48  9216        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2a_project_bn[0][0]']
#                                 8)
#
#  block2b_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2b_expand_conv[0][0]']
#  ization)                       8)
#
#  block2b_expand_activation (Act  (None, 150, 150, 28  0          ['block2b_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2b_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2b_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2b_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2b_dwconv[0][0]']
#  )                              8)
#
#  block2b_activation (Activation  (None, 150, 150, 28  0          ['block2b_bn[0][0]']
#  )                              8)
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2b_activation[0][0]',
#                                 8)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 150, 150, 48  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 150, 150, 48  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2b_add[0][0]']
#                                 8)
#
#  block2c_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2c_expand_conv[0][0]']
#  ization)                       8)
#
#  block2c_expand_activation (Act  (None, 150, 150, 28  0          ['block2c_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2c_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2c_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2c_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2c_dwconv[0][0]']
#  )                              8)
#
#  block2c_activation (Activation  (None, 150, 150, 28  0          ['block2c_bn[0][0]']
#  )                              8)
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2c_activation[0][0]',
#                                 8)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 150, 150, 48  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 150, 150, 48  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2c_add[0][0]']
#                                 8)
#
#  block2d_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2d_expand_conv[0][0]']
#  ization)                       8)
#
#  block2d_expand_activation (Act  (None, 150, 150, 28  0          ['block2d_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2d_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2d_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2d_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2d_dwconv[0][0]']
#  )                              8)
#
#  block2d_activation (Activation  (None, 150, 150, 28  0          ['block2d_bn[0][0]']
#  )                              8)
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2d_activation[0][0]',
#                                 8)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 150, 150, 48  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 150, 150, 48  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2d_add[0][0]']
#                                 8)
#
#  block2e_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2e_expand_conv[0][0]']
#  ization)                       8)
#
#  block2e_expand_activation (Act  (None, 150, 150, 28  0          ['block2e_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2e_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2e_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2e_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2e_dwconv[0][0]']
#  )                              8)
#
#  block2e_activation (Activation  (None, 150, 150, 28  0          ['block2e_bn[0][0]']
#  )                              8)
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2e_activation[0][0]',
#                                 8)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 150, 150, 48  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 150, 150, 48  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2e_add[0][0]']
#                                 8)
#
#  block2f_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2f_expand_conv[0][0]']
#  ization)                       8)
#
#  block2f_expand_activation (Act  (None, 150, 150, 28  0          ['block2f_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2f_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2f_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2f_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2f_dwconv[0][0]']
#  )                              8)
#
#  block2f_activation (Activation  (None, 150, 150, 28  0          ['block2f_bn[0][0]']
#  )                              8)
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2f_activation[0][0]',
#                                 8)                                'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2f_se_excite[0][0]']
#                                 )
#
#  block2f_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2f_project_conv[0][0]']
#  lization)                      )
#
#  block2f_drop (Dropout)         (None, 150, 150, 48  0           ['block2f_project_bn[0][0]']
#                                 )
#
#  block2f_add (Add)              (None, 150, 150, 48  0           ['block2f_drop[0][0]',
#                                 )                                 'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2f_add[0][0]']
#                                 8)
#
#  block2g_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2g_expand_conv[0][0]']
#  ization)                       8)
#
#  block2g_expand_activation (Act  (None, 150, 150, 28  0          ['block2g_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2g_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2g_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2g_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2g_dwconv[0][0]']
#  )                              8)
#
#  block2g_activation (Activation  (None, 150, 150, 28  0          ['block2g_bn[0][0]']
#  )                              8)
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2g_activation[0][0]',
#                                 8)                                'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2g_se_excite[0][0]']
#                                 )
#
#  block2g_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2g_project_conv[0][0]']
#  lization)                      )
#
#  block2g_drop (Dropout)         (None, 150, 150, 48  0           ['block2g_project_bn[0][0]']
#                                 )
#
#  block2g_add (Add)              (None, 150, 150, 48  0           ['block2g_drop[0][0]',
#                                 )                                 'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2g_add[0][0]']
#                                 8)
#
#  block3a_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block3a_expand_conv[0][0]']
#  ization)                       8)
#
#  block3a_expand_activation (Act  (None, 150, 150, 28  0          ['block3a_expand_bn[0][0]']
#  ivation)                       8)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 153, 153, 28  0          ['block3a_expand_activation[0][0]
#  g2D)                           8)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 75, 75, 288)  7200       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 75, 75, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 75, 75, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 75, 75, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 75, 75, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 75, 75, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 75, 75, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 75, 75, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 75, 75, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 75, 75, 480)  12000      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
# ...
#  block7a_bn (BatchNormalization  (None, 19, 19, 2304  9216       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 19, 19, 2304  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 2304)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 19, 19, 2304  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 19, 19, 640)  1474560     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 19, 19, 3840  2457600     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 19, 19, 3840  15360      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 19, 19, 3840  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 19, 19, 3840  34560      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 19, 19, 3840  15360      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 19, 19, 3840  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3840)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 19, 19, 3840  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 19, 19, 640)  2457600     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 19, 19, 640)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 19, 19, 640)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 19, 19, 3840  2457600     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 19, 19, 3840  15360      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 19, 19, 3840  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 19, 19, 3840  34560      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 19, 19, 3840  15360      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 19, 19, 3840  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3840)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 19, 19, 3840  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 19, 19, 640)  2457600     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 19, 19, 640)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 19, 19, 640)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 19, 19, 3840  2457600     ['block7c_add[0][0]']
#                                 )
#
#  block7d_expand_bn (BatchNormal  (None, 19, 19, 3840  15360      ['block7d_expand_conv[0][0]']
#  ization)                       )
#
#  block7d_expand_activation (Act  (None, 19, 19, 3840  0          ['block7d_expand_bn[0][0]']
#  ivation)                       )
#
#  block7d_dwconv (DepthwiseConv2  (None, 19, 19, 3840  34560      ['block7d_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7d_bn (BatchNormalization  (None, 19, 19, 3840  15360      ['block7d_dwconv[0][0]']
#  )                              )
#
#  block7d_activation (Activation  (None, 19, 19, 3840  0          ['block7d_bn[0][0]']
#  )                              )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 19, 19, 3840  0           ['block7d_activation[0][0]',
#                                 )                                 'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 19, 19, 640)  2457600     ['block7d_se_excite[0][0]']
#  block7d_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 19, 19, 640)  0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 19, 19, 640)  0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 19, 19, 2560  1638400     ['block7d_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 19, 19, 2560  10240       ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 19, 19, 2560  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 2560)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 2560)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         2561000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 66,658,687
# Trainable params: 66,347,960
# Non-trainable params: 310,727
# __________________________________________________________________________________________________
